# %%
# Import required libraries
import chess
import chess.engine
import chess.pgn
import chess.svg
import subprocess
import os
from PIL import Image
import io

# Paths to your engines and Maia models
stockfish_path = "/opt/homebrew/bin/stockfish"
maia_model_paths = {
    1100: "maia_weights/maia-1100.pb.gz",
    1200: "maia_weights/maia-1200.pb.gz",
    1300: "maia_weights/maia-1300.pb.gz",
    1400: "maia_weights/maia-1400.pb.gz",
    1500: "maia_weights/maia-1500.pb.gz",
    1600: "maia_weights/maia-1600.pb.gz",
    1700: "maia_weights/maia-1700.pb.gz",
    1800: "maia_weights/maia-1800.pb.gz",
    1900: "maia_weights/maia-1900.pb.gz",
}

# Initialize Stockfish engine
print("Initializing Stockfish engine...")
stockfish_engine = chess.engine.SimpleEngine.popen_uci(stockfish_path, stderr=subprocess.DEVNULL)
print("Stockfish engine initialized.")

# Initialize Maia engines
print("Initializing Maia engines...")
maia_engines = {}
for elo, path in maia_model_paths.items():
    print(f"Initializing Maia {elo} engine...")
    maia_engines[elo] = chess.engine.SimpleEngine.popen_uci(["lc0", f"--weights={path}"], stderr=subprocess.DEVNULL)
print("Maia engines initialized.")
# Out:
# Initializing Stockfish engine...
# Stockfish engine initialized.
# Initializing Maia engines...
# Initializing Maia 1100 engine...
# Initializing Maia 1200 engine...
# Initializing Maia 1300 engine...
# Initializing Maia 1400 engine...
# Initializing Maia 1500 engine...
# Initializing Maia 1600 engine...
# Initializing Maia 1700 engine...
# Initializing Maia 1800 engine...
# Initializing Maia 1900 engine...
# Maia engines initialized.

# %%
def load_games_from_pgn(file_path):
    games = []
    with open(file_path, 'r') as pgn_file:
        while True:
            game = chess.pgn.read_game(pgn_file)
            if game is None:
                break
            games.append(game)
    print(f"Loaded {len(games)} games from PGN file.")
    return games

# %%
def analyze_with_engines(game, stockfish_engine, maia_engines):
    board = game.board()
    blunders = []

    for move in game.mainline_moves():
        # Analyze the position before the move
        stockfish_info = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1))
        stockfish_eval = stockfish_info["score"].relative.score(mate_score=10000) / 100.0
        stockfish_best_move = stockfish_info["pv"][0] if "pv" in stockfish_info else None

        board.push(move)

        # Define blunder threshold
        if abs(stockfish_eval) > 1.5:
            maia_suggestions = {}
            for elo, maia_engine in maia_engines.items():
                maia_info = maia_engine.analyse(board, chess.engine.Limit(nodes=1))
                maia_eval = maia_info["score"].relative.score(mate_score=10000) / 100.0
                maia_best_move = maia_info["pv"][0] if "pv" in maia_info else None
                maia_suggestions[elo] = (maia_best_move, maia_eval)

            blunders.append((board.fen(), move, stockfish_eval, stockfish_best_move, maia_suggestions))

    print(f"Analyzed game with {len(blunders)} blunders found.")
    return blunders

def filter_best_blunders(blunders):
    filtered_blunders = []

    # Threshold for considering a majority agreement
    majority_threshold = 0  # 60% of the engines should agree

    for fen, move, stockfish_eval, stockfish_best_move, maia_suggestions in blunders:
        # Count how many Maia engines agree with Stockfish's best move
        agreeing_engines = sum(
            1 for elo in maia_suggestions if elo > 1300 and maia_suggestions[elo][0] == stockfish_best_move
        )

        total_considered = sum(1 for elo in maia_suggestions if elo > 1300)
        agreement_ratio = agreeing_engines / total_considered if total_considered > 0 else 0

        if agreement_ratio >= majority_threshold:
            filtered_blunders.append((fen, move, stockfish_eval, stockfish_best_move, maia_suggestions))

    print(f"Filtered blunders down to {len(filtered_blunders)} consistent ones.")
    return filtered_blunders

def output_blunder_analysis(blunders):
    for fen, move, stockfish_eval, stockfish_best_move, maia_suggestions in blunders:
        print(f"Position: {fen}")
        print(f"Blunder: {move}")
        print(f"Stockfish Evaluation: {stockfish_eval}")
        print(f"Stockfish Suggested Move: {stockfish_best_move}")
        for elo, (best_move, maia_eval) in maia_suggestions.items():
            print(f"Maia {elo} Evaluation: {maia_eval}, Suggested Move: {best_move}")
        print()

# Load games from PGN file
pgn_file_path = "analysis_pgns/0KNdpNQd---1910 Lasker vs. Schlechter.pgn"
all_games = load_games_from_pgn(pgn_file_path)

# Analyze games
all_blunders = []
for game in all_games:
    blunders = analyze_with_engines(game, stockfish_engine, maia_engines)
    filtered_blunders = filter_best_blunders(blunders)
    #filtered_blunders = blunders
    if filtered_blunders:
        all_blunders.append((game.headers["Event"], filtered_blunders))

# Output analysis
for event, blunder_list in all_blunders:
    print(f"Event: {event}")
    output_blunder_analysis(blunder_list)
# Out:
# Loaded 10 games from PGN file.
# Analyzed game with 1 blunders found.
# Filtered blunders down to 1 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 3 blunders found.
# Filtered blunders down to 3 consistent ones.
# Analyzed game with 11 blunders found.
# Filtered blunders down to 11 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 4 blunders found.
# Filtered blunders down to 4 consistent ones.
# Analyzed game with 40 blunders found.
# Filtered blunders down to 40 consistent ones.
# Event: World Championship Match 1910
# Position: 7r/2R1N3/3p3k/p3np2/r6P/6P1/2P3K1/4R3 b - - 2 46
# Blunder: d5e7
# Stockfish Evaluation: 1.6
# Stockfish Suggested Move: d5e3
# Maia 1100 Evaluation: -1.36, Suggested Move: a4a2
# Maia 1200 Evaluation: -2.04, Suggested Move: a4a2
# Maia 1300 Evaluation: -0.51, Suggested Move: a4a2
# Maia 1400 Evaluation: -1.29, Suggested Move: a4a2
# Maia 1500 Evaluation: -0.95, Suggested Move: f5f4
# Maia 1600 Evaluation: -3.61, Suggested Move: a4a2
# Maia 1700 Evaluation: -3.73, Suggested Move: a4g4
# Maia 1800 Evaluation: -1.55, Suggested Move: h8f8
# Maia 1900 Evaluation: -0.78, Suggested Move: h8f8
#
# Event: World Championship Match 1910
# Position: 2r3k1/3qbbpp/7r/1p1pBP2/3p2Q1/3B4/1P4PP/R4RK1 b - - 8 23
# Blunder: d1g4
# Stockfish Evaluation: 1.55
# Stockfish Suggested Move: d1g4
# Maia 1100 Evaluation: -13.15, Suggested Move: e7f6
# Maia 1200 Evaluation: -6.43, Suggested Move: e7f6
# Maia 1300 Evaluation: -9.77, Suggested Move: e7f6
# Maia 1400 Evaluation: -6.09, Suggested Move: e7f6
# Maia 1500 Evaluation: -10.73, Suggested Move: e7f6
# Maia 1600 Evaluation: -6.6, Suggested Move: e7f6
# Maia 1700 Evaluation: -10.57, Suggested Move: e7f6
# Maia 1800 Evaluation: -7.56, Suggested Move: e7f6
# Maia 1900 Evaluation: -5.07, Suggested Move: e7f6
#
# Position: 2r3k1/3q1bpp/5b1r/1p1pBP2/3p2Q1/3B4/1P4PP/R4RK1 w - - 9 24
# Blunder: e7f6
# Stockfish Evaluation: -1.52
# Stockfish Suggested Move: e7f6
# Maia 1100 Evaluation: 3.73, Suggested Move: e5f6
# Maia 1200 Evaluation: 1.98, Suggested Move: e5f6
# Maia 1300 Evaluation: 2.76, Suggested Move: e5f6
# Maia 1400 Evaluation: 1.7, Suggested Move: e5f6
# Maia 1500 Evaluation: 4.19, Suggested Move: e5f6
# Maia 1600 Evaluation: 1.81, Suggested Move: e5f6
# Maia 1700 Evaluation: 2.18, Suggested Move: e5f6
# Maia 1800 Evaluation: 0.95, Suggested Move: e5f6
# Maia 1900 Evaluation: 4.55, Suggested Move: e5f6
#
# Position: 2r3k1/3q1bpp/5B1r/1p1p1P2/3p2Q1/3B4/1P4PP/R4RK1 b - - 0 24
# Blunder: e5f6
# Stockfish Evaluation: 1.52
# Stockfish Suggested Move: e5f4
# Maia 1100 Evaluation: -4.2, Suggested Move: h6f6
# Maia 1200 Evaluation: -4.59, Suggested Move: h6f6
# Maia 1300 Evaluation: -1.19, Suggested Move: h6f6
# Maia 1400 Evaluation: -5.88, Suggested Move: h6f6
# Maia 1500 Evaluation: -9.35, Suggested Move: h6f6
# Maia 1600 Evaluation: -5.09, Suggested Move: h6f6
# Maia 1700 Evaluation: -7.46, Suggested Move: h6f6
# Maia 1800 Evaluation: -2.95, Suggested Move: h6f6
# Maia 1900 Evaluation: -5.16, Suggested Move: h6f6
#
# Event: World Championship Match 1910
# Position: 8/2k3p1/2pp1p2/1q2r1p1/1Q2P1P1/7P/5PK1/1R6 w - - 8 45
# Blunder: a6b5
# Stockfish Evaluation: 2.25
# Stockfish Suggested Move: a6b5
# Maia 1100 Evaluation: -0.45, Suggested Move: b4e1
# Maia 1200 Evaluation: -1.76, Suggested Move: b4b5
# Maia 1300 Evaluation: -1.55, Suggested Move: b4b5
# Maia 1400 Evaluation: -1.92, Suggested Move: b4b5
# Maia 1500 Evaluation: -0.73, Suggested Move: b4e1
# Maia 1600 Evaluation: -2.54, Suggested Move: b4b5
# Maia 1700 Evaluation: -2.32, Suggested Move: b4b5
# Maia 1800 Evaluation: -2.38, Suggested Move: b4b5
# Maia 1900 Evaluation: -1.79, Suggested Move: b4b5
#
# Position: 8/2k3p1/2pp1p2/1q2r1p1/4P1P1/7P/5PK1/1R2Q3 b - - 9 45
# Blunder: b4e1
# Stockfish Evaluation: -2.35
# Stockfish Suggested Move: b4e1
# Maia 1100 Evaluation: 0.61, Suggested Move: b5d3
# Maia 1200 Evaluation: 1.56, Suggested Move: b5d3
# Maia 1300 Evaluation: 1.27, Suggested Move: b5d3
# Maia 1400 Evaluation: 1.51, Suggested Move: b5d3
# Maia 1500 Evaluation: 1.22, Suggested Move: b5d3
# Maia 1600 Evaluation: 0.99, Suggested Move: b5c4
# Maia 1700 Evaluation: 2.58, Suggested Move: b5d3
# Maia 1800 Evaluation: 2.19, Suggested Move: b5d3
# Maia 1900 Evaluation: 1.47, Suggested Move: b5d3
#
# Position: 8/2k3p1/2pp1p2/4r1p1/4P1P1/3q3P/5PK1/1R2Q3 w - - 10 46
# Blunder: b5d3
# Stockfish Evaluation: 2.45
# Stockfish Suggested Move: b5a4
# Maia 1100 Evaluation: -0.48, Suggested Move: f2f3
# Maia 1200 Evaluation: -0.9, Suggested Move: f2f3
# Maia 1300 Evaluation: -1.22, Suggested Move: f2f3
# Maia 1400 Evaluation: -1.21, Suggested Move: f2f3
# Maia 1500 Evaluation: -1.18, Suggested Move: f2f3
# Maia 1600 Evaluation: -1.64, Suggested Move: f2f3
# Maia 1700 Evaluation: -1.71, Suggested Move: f2f3
# Maia 1800 Evaluation: -1.64, Suggested Move: b1a1
# Maia 1900 Evaluation: -1.5, Suggested Move: f2f3
#
# Position: 8/2k3p1/2pp1p2/4r1p1/1R2P1P1/3q3P/5PK1/4Q3 b - - 11 46
# Blunder: b1b4
# Stockfish Evaluation: -2.2
# Stockfish Suggested Move: b1b4
# Maia 1100 Evaluation: 1.63, Suggested Move: c6c5
# Maia 1200 Evaluation: 3.65, Suggested Move: d6d5
# Maia 1300 Evaluation: 1.66, Suggested Move: c6c5
# Maia 1400 Evaluation: 1.04, Suggested Move: c6c5
# Maia 1500 Evaluation: 2.25, Suggested Move: d6d5
# Maia 1600 Evaluation: 4.7, Suggested Move: d6d5
# Maia 1700 Evaluation: 1.67, Suggested Move: c6c5
# Maia 1800 Evaluation: 3.61, Suggested Move: c6c5
# Maia 1900 Evaluation: 2.69, Suggested Move: d6d5
#
# Position: 8/2k3p1/3p1p2/2p1r1p1/1R2P1P1/3q3P/5PK1/4Q3 w - - 0 47
# Blunder: c6c5
# Stockfish Evaluation: 2.12
# Stockfish Suggested Move: e5b5
# Maia 1100 Evaluation: -1.67, Suggested Move: b4a4
# Maia 1200 Evaluation: -0.27, Suggested Move: b4a4
# Maia 1300 Evaluation: -1.12, Suggested Move: b4a4
# Maia 1400 Evaluation: -0.34, Suggested Move: b4a4
# Maia 1500 Evaluation: 0.03, Suggested Move: b4a4
# Maia 1600 Evaluation: -2.28, Suggested Move: b4a4
# Maia 1700 Evaluation: -1.57, Suggested Move: b4a4
# Maia 1800 Evaluation: -3.61, Suggested Move: b4a4
# Maia 1900 Evaluation: -0.6, Suggested Move: b4a4
#
# Position: 1r6/R1k3p1/Q4p2/2qp2p1/2p3P1/7P/5PK1/8 b - - 7 56
# Blunder: a8a7
# Stockfish Evaluation: 3.89
# Stockfish Suggested Move: a8a7
# Maia 1100 Evaluation: -2.57, Suggested Move: c7d8
# Maia 1200 Evaluation: -1.64, Suggested Move: c7d8
# Maia 1300 Evaluation: -2.01, Suggested Move: c7d8
# Maia 1400 Evaluation: 0.21, Suggested Move: c7d8
# Maia 1500 Evaluation: -1.53, Suggested Move: c5a7
# Maia 1600 Evaluation: -0.55, Suggested Move: c7d8
# Maia 1700 Evaluation: -1.0, Suggested Move: c7d8
# Maia 1800 Evaluation: -0.05, Suggested Move: c7d8
# Maia 1900 Evaluation: -1.64, Suggested Move: c7d8
#
# Position: 1r1k4/R5p1/Q4p2/2qp2p1/2p3P1/7P/5PK1/8 w - - 8 57
# Blunder: c7d8
# Stockfish Evaluation: -3.61
# Stockfish Suggested Move: c5a7
# Maia 1100 Evaluation: 3.71, Suggested Move: a7g7
# Maia 1200 Evaluation: 2.1, Suggested Move: a7g7
# Maia 1300 Evaluation: 2.89, Suggested Move: a7g7
# Maia 1400 Evaluation: -1.4, Suggested Move: a6a5
# Maia 1500 Evaluation: 3.16, Suggested Move: a7g7
# Maia 1600 Evaluation: 1.44, Suggested Move: a7g7
# Maia 1700 Evaluation: 2.51, Suggested Move: a7g7
# Maia 1800 Evaluation: -0.1, Suggested Move: a7g7
# Maia 1900 Evaluation: 1.37, Suggested Move: a7g7
#
# Position: 1r1k4/6R1/Q4p2/2qp2p1/2p3P1/7P/5PK1/8 b - - 0 57
# Blunder: a7g7
# Stockfish Evaluation: 5.84
# Stockfish Suggested Move: a7g7
# Maia 1100 Evaluation: -5.43, Suggested Move: c4c3
# Maia 1200 Evaluation: -2.5, Suggested Move: b8b6
# Maia 1300 Evaluation: -2.9, Suggested Move: c4c3
# Maia 1400 Evaluation: -0.2, Suggested Move: c5b6
# Maia 1500 Evaluation: -1.47, Suggested Move: c5b6
# Maia 1600 Evaluation: -0.27, Suggested Move: c5b6
# Maia 1700 Evaluation: -2.31, Suggested Move: c5e7
# Maia 1800 Evaluation: 0.1, Suggested Move: c4c3
# Maia 1900 Evaluation: -2.63, Suggested Move: c4c3
#
# Position: 1r1k4/6R1/Qq3p2/3p2p1/2p3P1/7P/5PK1/8 w - - 1 58
# Blunder: c5b6
# Stockfish Evaluation: -6.15
# Stockfish Suggested Move: c5c7
# Maia 1100 Evaluation: -0.26, Suggested Move: g7g8
# Maia 1200 Evaluation: 1.03, Suggested Move: g7g8
# Maia 1300 Evaluation: 0.03, Suggested Move: g7g8
# Maia 1400 Evaluation: -0.12, Suggested Move: g7g8
# Maia 1500 Evaluation: 1.31, Suggested Move: g7g8
# Maia 1600 Evaluation: 0.21, Suggested Move: g7g8
# Maia 1700 Evaluation: 1.03, Suggested Move: a6a7
# Maia 1800 Evaluation: 0.66, Suggested Move: g7g8
# Maia 1900 Evaluation: 1.32, Suggested Move: g7g8
#
# Position: 1r1k4/6R1/1q3p2/3p2p1/2p3P1/Q6P/5PK1/8 b - - 2 58
# Blunder: a6a3
# Stockfish Evaluation: 7.28
# Stockfish Suggested Move: a6a3
# Maia 1100 Evaluation: -7.84, Suggested Move: b6b3
# Maia 1200 Evaluation: -3.28, Suggested Move: b6c6
# Maia 1300 Evaluation: -4.09, Suggested Move: b6e6
# Maia 1400 Evaluation: -2.79, Suggested Move: b6e6
# Maia 1500 Evaluation: -2.02, Suggested Move: b6b4
# Maia 1600 Evaluation: -4.97, Suggested Move: b6e6
# Maia 1700 Evaluation: -2.43, Suggested Move: b6b4
# Maia 1800 Evaluation: -1.4, Suggested Move: b6b4
# Maia 1900 Evaluation: -2.43, Suggested Move: b6b4
#
# Position: 1rk5/6R1/1q3p2/3p2p1/2p3P1/Q6P/5PK1/8 w - - 3 59
# Blunder: d8c8
# Stockfish Evaluation: -7.47
# Stockfish Suggested Move: b6b4
# Maia 1100 Evaluation: 2.39, Suggested Move: a3f8
# Maia 1200 Evaluation: 2.44, Suggested Move: g7g8
# Maia 1300 Evaluation: 2.62, Suggested Move: a3f8
# Maia 1400 Evaluation: 2.06, Suggested Move: a3f8
# Maia 1500 Evaluation: 1.52, Suggested Move: a3f8
# Maia 1600 Evaluation: 3.78, Suggested Move: a3f8
# Maia 1700 Evaluation: 2.16, Suggested Move: a3f8
# Maia 1800 Evaluation: 2.76, Suggested Move: a3f8
# Maia 1900 Evaluation: 3.41, Suggested Move: a3f8
#
# Event: World Championship Match 1910
# Position: 5r1r/ppqk1pp1/2nbb2p/5BBQ/5p2/1NP5/P1P3PP/4RRK1 w - - 4 17
# Blunder: a8f8
# Stockfish Evaluation: 1.55
# Stockfish Suggested Move: c7b6
# Maia 1100 Evaluation: 1.78, Suggested Move: f5e6
# Maia 1200 Evaluation: -0.6, Suggested Move: f5e6
# Maia 1300 Evaluation: 1.26, Suggested Move: f5e6
# Maia 1400 Evaluation: 0.79, Suggested Move: f5e6
# Maia 1500 Evaluation: 5.43, Suggested Move: f5e6
# Maia 1600 Evaluation: 11.37, Suggested Move: f5e6
# Maia 1700 Evaluation: 5.4, Suggested Move: f5e6
# Maia 1800 Evaluation: 8.73, Suggested Move: f5e6
# Maia 1900 Evaluation: 4.75, Suggested Move: f5e6
#
# Position: 8/1p4p1/p1kn3p/8/2P3r1/1N1R2P1/P1PK4/8 w - - 3 56
# Blunder: b5d6
# Stockfish Evaluation: 1.84
# Stockfish Suggested Move: b5d6
# Maia 1100 Evaluation: -0.34, Suggested Move: b3a5
# Maia 1200 Evaluation: -1.03, Suggested Move: c4c5
# Maia 1300 Evaluation: -1.16, Suggested Move: b3d4
# Maia 1400 Evaluation: -0.5, Suggested Move: b3d4
# Maia 1500 Evaluation: -0.57, Suggested Move: b3a5
# Maia 1600 Evaluation: -1.5, Suggested Move: c4c5
# Maia 1700 Evaluation: -1.21, Suggested Move: b3a5
# Maia 1800 Evaluation: -0.49, Suggested Move: b3d4
# Maia 1900 Evaluation: -1.02, Suggested Move: c4c5
#
# Position: 8/1p4p1/p1kn3p/8/2PN2r1/3R2P1/P1PK4/8 b - - 4 56
# Blunder: b3d4
# Stockfish Evaluation: -1.72
# Stockfish Suggested Move: d3d4
# Maia 1100 Evaluation: 0.27, Suggested Move: c6c5
# Maia 1200 Evaluation: 1.68, Suggested Move: c6c5
# Maia 1300 Evaluation: 0.73, Suggested Move: c6c5
# Maia 1400 Evaluation: 0.16, Suggested Move: c6c5
# Maia 1500 Evaluation: 0.14, Suggested Move: c6c5
# Maia 1600 Evaluation: 0.4, Suggested Move: c6c5
# Maia 1700 Evaluation: 2.77, Suggested Move: c6c5
# Maia 1800 Evaluation: 0.04, Suggested Move: c6c5
# Maia 1900 Evaluation: 1.1, Suggested Move: c6c5
#
# Position: 8/1pk3p1/p2n3p/8/2PN2r1/3R2P1/P1PK4/8 w - - 5 57
# Blunder: c6c7
# Stockfish Evaluation: 2.03
# Stockfish Suggested Move: c6b6
# Maia 1100 Evaluation: -0.21, Suggested Move: d4e6
# Maia 1200 Evaluation: -0.56, Suggested Move: d4e6
# Maia 1300 Evaluation: -0.21, Suggested Move: d4e6
# Maia 1400 Evaluation: -0.22, Suggested Move: d4e6
# Maia 1500 Evaluation: 0.58, Suggested Move: d4e6
# Maia 1600 Evaluation: 0.49, Suggested Move: d4e6
# Maia 1700 Evaluation: -0.2, Suggested Move: d4e6
# Maia 1800 Evaluation: -0.12, Suggested Move: d4e6
# Maia 1900 Evaluation: -0.39, Suggested Move: d4e6
#
# Event: World Championship Match 1910
# Position: r4rk1/pbq1ppbp/n1p3p1/4N2n/N2P2P1/P2BP3/2Q2P1P/1RB1K2R b K - 0 15
# Blunder: g2g4
# Stockfish Evaluation: 1.53
# Stockfish Suggested Move: e1g1
# Maia 1100 Evaluation: -0.03, Suggested Move: h5f6
# Maia 1200 Evaluation: 3.23, Suggested Move: h5f6
# Maia 1300 Evaluation: -0.8, Suggested Move: h5f6
# Maia 1400 Evaluation: -1.74, Suggested Move: h5f6
# Maia 1500 Evaluation: 0.5, Suggested Move: h5f6
# Maia 1600 Evaluation: 1.88, Suggested Move: h5f6
# Maia 1700 Evaluation: -0.04, Suggested Move: h5f6
# Maia 1800 Evaluation: -1.98, Suggested Move: h5f6
# Maia 1900 Evaluation: -0.95, Suggested Move: h5f6
#
# Position: r4rk1/pb2ppb1/n1p3p1/3q4/N1QP4/P2BP3/3B1P1P/2R1K1R1 w - - 8 22
# Blunder: c8b7
# Stockfish Evaluation: -1.56
# Stockfish Suggested Move: a8b8
# Maia 1100 Evaluation: 1.79, Suggested Move: c4d5
# Maia 1200 Evaluation: 0.8, Suggested Move: c4d5
# Maia 1300 Evaluation: -0.02, Suggested Move: c4d5
# Maia 1400 Evaluation: -0.06, Suggested Move: c4d5
# Maia 1500 Evaluation: 0.47, Suggested Move: c4d5
# Maia 1600 Evaluation: 0.52, Suggested Move: c4d5
# Maia 1700 Evaluation: 3.65, Suggested Move: c4d5
# Maia 1800 Evaluation: 3.45, Suggested Move: c4d5
# Maia 1900 Evaluation: 4.43, Suggested Move: c4d5
#
# Position: r4rk1/pb2ppb1/n1p3p1/3q4/N2P4/P2BP3/2QB1P1P/2R1K1R1 b - - 9 22
# Blunder: c4c2
# Stockfish Evaluation: 1.78
# Stockfish Suggested Move: h2h4
# Maia 1100 Evaluation: 0.43, Suggested Move: a8c8
# Maia 1200 Evaluation: -0.18, Suggested Move: a8c8
# Maia 1300 Evaluation: -1.55, Suggested Move: a8c8
# Maia 1400 Evaluation: -1.62, Suggested Move: a8c8
# Maia 1500 Evaluation: -5.42, Suggested Move: a8c8
# Maia 1600 Evaluation: -2.2, Suggested Move: a8c8
# Maia 1700 Evaluation: 0.74, Suggested Move: e7e5
# Maia 1800 Evaluation: -2.86, Suggested Move: a8c8
# Maia 1900 Evaluation: -3.52, Suggested Move: a6c7
#
# Position: 6k1/p3p1b1/3nN3/3R4/8/PK1Q4/5q2/8 b - - 15 50
# Blunder: c5e6
# Stockfish Evaluation: 1.71
# Stockfish Suggested Move: d5g5
# Maia 1100 Evaluation: -1.0, Suggested Move: f2b2
# Maia 1200 Evaluation: 0.47, Suggested Move: f2b6
# Maia 1300 Evaluation: -0.05, Suggested Move: f2b2
# Maia 1400 Evaluation: 1.82, Suggested Move: f2b6
# Maia 1500 Evaluation: -0.26, Suggested Move: f2b2
# Maia 1600 Evaluation: -0.13, Suggested Move: f2b2
# Maia 1700 Evaluation: -0.47, Suggested Move: f2b2
# Maia 1800 Evaluation: -0.27, Suggested Move: f2b2
# Maia 1900 Evaluation: -1.33, Suggested Move: f2b2
#
# Position: 8/p3pkq1/3n4/3R4/K7/P2Q4/8/8 w - - 0 53
# Blunder: b2g7
# Stockfish Evaluation: -1.63
# Stockfish Suggested Move: b2g7
# Maia 1100 Evaluation: 1.65, Suggested Move: d3f3
# Maia 1200 Evaluation: 1.28, Suggested Move: d3f3
# Maia 1300 Evaluation: 1.49, Suggested Move: d3f3
# Maia 1400 Evaluation: 1.48, Suggested Move: d3f3
# Maia 1500 Evaluation: 3.02, Suggested Move: d3f3
# Maia 1600 Evaluation: 3.87, Suggested Move: d3f3
# Maia 1700 Evaluation: 2.02, Suggested Move: d3f3
# Maia 1800 Evaluation: 1.06, Suggested Move: d5d6
# Maia 1900 Evaluation: 2.35, Suggested Move: d5d6
#
# Position: 1Q2k3/p3p1q1/3n4/3R4/K7/P7/8/8 b - - 3 54
# Blunder: b3b8
# Stockfish Evaluation: 1.71
# Stockfish Suggested Move: b3b8
# Maia 1100 Evaluation: -0.59, Suggested Move: e8f7
# Maia 1200 Evaluation: -0.63, Suggested Move: e8f7
# Maia 1300 Evaluation: -0.85, Suggested Move: e8f7
# Maia 1400 Evaluation: -1.18, Suggested Move: e8f7
# Maia 1500 Evaluation: -1.31, Suggested Move: e8f7
# Maia 1600 Evaluation: -1.39, Suggested Move: e8f7
# Maia 1700 Evaluation: -1.02, Suggested Move: e8f7
# Maia 1800 Evaluation: -0.91, Suggested Move: e8f7
# Maia 1900 Evaluation: -1.38, Suggested Move: e8f7
#
# Position: 1Q6/p3pkq1/3n4/3R4/K7/P7/8/8 w - - 4 55
# Blunder: e8f7
# Stockfish Evaluation: -1.55
# Stockfish Suggested Move: e8f7
# Maia 1100 Evaluation: 0.5, Suggested Move: b8a7
# Maia 1200 Evaluation: 0.91, Suggested Move: b8a7
# Maia 1300 Evaluation: 0.86, Suggested Move: b8a7
# Maia 1400 Evaluation: 1.2, Suggested Move: b8a7
# Maia 1500 Evaluation: 0.93, Suggested Move: b8a7
# Maia 1600 Evaluation: 1.55, Suggested Move: b8a7
# Maia 1700 Evaluation: 0.97, Suggested Move: b8b3
# Maia 1800 Evaluation: 0.86, Suggested Move: b8a7
# Maia 1900 Evaluation: 1.03, Suggested Move: b8a7
#
# Position: 8/Q3pkq1/3n4/3R4/K7/P7/8/8 b - - 0 55
# Blunder: b8a7
# Stockfish Evaluation: 1.67
# Stockfish Suggested Move: b8a7
# Maia 1100 Evaluation: -0.32, Suggested Move: g7g4
# Maia 1200 Evaluation: -1.09, Suggested Move: g7g4
# Maia 1300 Evaluation: -0.77, Suggested Move: g7b2
# Maia 1400 Evaluation: -1.28, Suggested Move: g7g4
# Maia 1500 Evaluation: -0.1, Suggested Move: g7g4
# Maia 1600 Evaluation: -1.24, Suggested Move: g7g4
# Maia 1700 Evaluation: -0.95, Suggested Move: g7f6
# Maia 1800 Evaluation: -0.71, Suggested Move: g7g4
# Maia 1900 Evaluation: -0.8, Suggested Move: g7g4
#
# Position: 8/Q3pk2/3n4/3R4/K5q1/P7/8/8 w - - 1 56
# Blunder: g7g4
# Stockfish Evaluation: -1.75
# Stockfish Suggested Move: g7g2
# Maia 1100 Evaluation: 0.12, Suggested Move: a4b3
# Maia 1200 Evaluation: 2.04, Suggested Move: d5d4
# Maia 1300 Evaluation: 1.34, Suggested Move: d5d4
# Maia 1400 Evaluation: 1.27, Suggested Move: d5d4
# Maia 1500 Evaluation: -0.46, Suggested Move: a4b3
# Maia 1600 Evaluation: 1.3, Suggested Move: d5d4
# Maia 1700 Evaluation: 2.68, Suggested Move: d5d4
# Maia 1800 Evaluation: 0.77, Suggested Move: a4a5
# Maia 1900 Evaluation: 0.62, Suggested Move: a4a5
#
# Position: 8/4pk2/3n4/3R4/K2Q2q1/P7/8/8 b - - 2 56
# Blunder: a7d4
# Stockfish Evaluation: 2.12
# Stockfish Suggested Move: a7d4
# Maia 1100 Evaluation: -0.82, Suggested Move: g4d7
# Maia 1200 Evaluation: -1.12, Suggested Move: g4d7
# Maia 1300 Evaluation: -1.25, Suggested Move: g4d7
# Maia 1400 Evaluation: -1.27, Suggested Move: g4d4
# Maia 1500 Evaluation: -1.36, Suggested Move: g4d7
# Maia 1600 Evaluation: -0.99, Suggested Move: g4d7
# Maia 1700 Evaluation: -1.42, Suggested Move: g4d7
# Maia 1800 Evaluation: -1.54, Suggested Move: g4d7
# Maia 1900 Evaluation: -1.35, Suggested Move: g4d7
#
# Position: 8/3qpk2/3n4/3R4/K2Q4/P7/8/8 w - - 3 57
# Blunder: g4d7
# Stockfish Evaluation: -2.23
# Stockfish Suggested Move: g4f3
# Maia 1100 Evaluation: 0.86, Suggested Move: a4b3
# Maia 1200 Evaluation: 1.12, Suggested Move: a4b3
# Maia 1300 Evaluation: 1.24, Suggested Move: a4b3
# Maia 1400 Evaluation: 1.07, Suggested Move: a4b3
# Maia 1500 Evaluation: 1.3, Suggested Move: a4b3
# Maia 1600 Evaluation: 1.45, Suggested Move: a4b3
# Maia 1700 Evaluation: 1.43, Suggested Move: a4b3
# Maia 1800 Evaluation: 1.74, Suggested Move: a4b3
# Maia 1900 Evaluation: 1.42, Suggested Move: a4b3
#
# Position: 8/3qpk2/3n4/3R4/3Q4/PK6/8/8 b - - 4 57
# Blunder: a4b3
# Stockfish Evaluation: 2.26
# Stockfish Suggested Move: a4b3
# Maia 1100 Evaluation: -0.79, Suggested Move: d7b7
# Maia 1200 Evaluation: -1.16, Suggested Move: d7b7
# Maia 1300 Evaluation: -1.16, Suggested Move: d7b7
# Maia 1400 Evaluation: -1.07, Suggested Move: d7b7
# Maia 1500 Evaluation: -0.9, Suggested Move: d7e6
# Maia 1600 Evaluation: -1.42, Suggested Move: d7e6
# Maia 1700 Evaluation: -1.37, Suggested Move: d7b7
# Maia 1800 Evaluation: -1.74, Suggested Move: d7e6
# Maia 1900 Evaluation: -1.36, Suggested Move: d7b7
#
# Position: 8/1q2pk2/3n4/3R4/3Q4/PK6/8/8 w - - 5 58
# Blunder: d7b7
# Stockfish Evaluation: -2.19
# Stockfish Suggested Move: d7e6
# Maia 1100 Evaluation: 0.76, Suggested Move: b3a2
# Maia 1200 Evaluation: 1.27, Suggested Move: b3a2
# Maia 1300 Evaluation: 0.96, Suggested Move: b3a2
# Maia 1400 Evaluation: 1.18, Suggested Move: b3a2
# Maia 1500 Evaluation: 2.15, Suggested Move: b3a2
# Maia 1600 Evaluation: 1.92, Suggested Move: b3a2
# Maia 1700 Evaluation: 1.27, Suggested Move: b3a2
# Maia 1800 Evaluation: 1.67, Suggested Move: b3a2
# Maia 1900 Evaluation: 1.52, Suggested Move: b3a2
#
# Position: 8/1q2pk2/3n4/3R4/3Q4/P7/K7/8 b - - 6 58
# Blunder: b3a2
# Stockfish Evaluation: 2.59
# Stockfish Suggested Move: b3a2
# Maia 1100 Evaluation: -1.03, Suggested Move: d6b5
# Maia 1200 Evaluation: -1.85, Suggested Move: d6b5
# Maia 1300 Evaluation: -0.96, Suggested Move: d6b5
# Maia 1400 Evaluation: -1.21, Suggested Move: d6b5
# Maia 1500 Evaluation: -3.55, Suggested Move: d6b5
# Maia 1600 Evaluation: -1.37, Suggested Move: d6b5
# Maia 1700 Evaluation: -1.23, Suggested Move: b7c6
# Maia 1800 Evaluation: -1.61, Suggested Move: b7c6
# Maia 1900 Evaluation: -1.52, Suggested Move: f7e6
#
# Position: 8/4pk2/2qn4/3R4/3Q4/P7/K7/8 w - - 7 59
# Blunder: b7c6
# Stockfish Evaluation: -2.55
# Stockfish Suggested Move: f7e8
# Maia 1100 Evaluation: 0.35, Suggested Move: d4f4
# Maia 1200 Evaluation: 0.89, Suggested Move: d5c5
# Maia 1300 Evaluation: 1.18, Suggested Move: d5c5
# Maia 1400 Evaluation: 0.91, Suggested Move: d5c5
# Maia 1500 Evaluation: 1.24, Suggested Move: d5c5
# Maia 1600 Evaluation: 1.57, Suggested Move: d5c5
# Maia 1700 Evaluation: 1.38, Suggested Move: d5c5
# Maia 1800 Evaluation: 1.64, Suggested Move: d5c5
# Maia 1900 Evaluation: 1.29, Suggested Move: d5c5
#
# Position: 8/4pk2/2qn4/3R4/8/P2Q4/K7/8 b - - 8 59
# Blunder: d4d3
# Stockfish Evaluation: 2.57
# Stockfish Suggested Move: d5c5
# Maia 1100 Evaluation: -0.38, Suggested Move: c6c4
# Maia 1200 Evaluation: -0.95, Suggested Move: c6c4
# Maia 1300 Evaluation: -1.08, Suggested Move: f7e6
# Maia 1400 Evaluation: -0.32, Suggested Move: c6c4
# Maia 1500 Evaluation: -0.14, Suggested Move: c6c4
# Maia 1600 Evaluation: -0.53, Suggested Move: c6c4
# Maia 1700 Evaluation: -0.76, Suggested Move: c6c4
# Maia 1800 Evaluation: -0.94, Suggested Move: c6c4
# Maia 1900 Evaluation: -1.96, Suggested Move: f7e6
#
# Position: 8/4p3/2qnk3/3R4/8/P2Q4/K7/8 w - - 9 60
# Blunder: f7e6
# Stockfish Evaluation: -2.5
# Stockfish Suggested Move: f7e6
# Maia 1100 Evaluation: 1.28, Suggested Move: d5h5
# Maia 1200 Evaluation: 0.85, Suggested Move: d5h5
# Maia 1300 Evaluation: 0.71, Suggested Move: d5h5
# Maia 1400 Evaluation: 0.5, Suggested Move: d5d6
# Maia 1500 Evaluation: 0.98, Suggested Move: d5h5
# Maia 1600 Evaluation: 0.99, Suggested Move: d5d4
# Maia 1700 Evaluation: 1.44, Suggested Move: d5d4
# Maia 1800 Evaluation: 1.11, Suggested Move: d5d6
# Maia 1900 Evaluation: 1.69, Suggested Move: d5d4
#
# Position: 8/4p3/2qnk3/6R1/8/P2Q4/K7/8 b - - 10 60
# Blunder: d5g5
# Stockfish Evaluation: 2.49
# Stockfish Suggested Move: d5g5
# Maia 1100 Evaluation: -0.56, Suggested Move: c6c4
# Maia 1200 Evaluation: -0.88, Suggested Move: c6c4
# Maia 1300 Evaluation: -0.58, Suggested Move: e6d7
# Maia 1400 Evaluation: -0.9, Suggested Move: e6d7
# Maia 1500 Evaluation: -0.93, Suggested Move: e6d7
# Maia 1600 Evaluation: -1.29, Suggested Move: e6d7
# Maia 1700 Evaluation: -0.01, Suggested Move: c6c4
# Maia 1800 Evaluation: -0.66, Suggested Move: c6c4
# Maia 1900 Evaluation: -0.2, Suggested Move: c6c4
#
# Position: 8/3kp3/2qn4/6R1/8/P2Q4/K7/8 w - - 11 61
# Blunder: e6d7
# Stockfish Evaluation: -2.53
# Stockfish Suggested Move: e6d7
# Maia 1100 Evaluation: 1.45, Suggested Move: d3h3
# Maia 1200 Evaluation: 0.6, Suggested Move: g5d5
# Maia 1300 Evaluation: 1.1, Suggested Move: g5g4
# Maia 1400 Evaluation: 1.32, Suggested Move: g5d5
# Maia 1500 Evaluation: 0.9, Suggested Move: g5d5
# Maia 1600 Evaluation: 1.26, Suggested Move: g5a5
# Maia 1700 Evaluation: 1.26, Suggested Move: g5d5
# Maia 1800 Evaluation: 1.14, Suggested Move: g5d5
# Maia 1900 Evaluation: 1.0, Suggested Move: g5d5
#
# Position: 8/3kp3/2qn4/4R3/8/P2Q4/K7/8 b - - 12 61
# Blunder: g5e5
# Stockfish Evaluation: 2.52
# Stockfish Suggested Move: g5e5
# Maia 1100 Evaluation: -0.22, Suggested Move: c6c4
# Maia 1200 Evaluation: -0.71, Suggested Move: c6g2
# Maia 1300 Evaluation: -0.7, Suggested Move: d7e8
# Maia 1400 Evaluation: -1.18, Suggested Move: c6g2
# Maia 1500 Evaluation: -0.11, Suggested Move: c6c4
# Maia 1600 Evaluation: -0.99, Suggested Move: d7e8
# Maia 1700 Evaluation: 0.03, Suggested Move: c6c4
# Maia 1800 Evaluation: -0.71, Suggested Move: c6c4
# Maia 1900 Evaluation: -0.61, Suggested Move: c6c4
#
# Position: 8/3kp3/3n4/4R3/8/P2Q4/K5q1/8 w - - 13 62
# Blunder: c6g2
# Stockfish Evaluation: -2.57
# Stockfish Suggested Move: c6g2
# Maia 1100 Evaluation: 0.82, Suggested Move: a2b3
# Maia 1200 Evaluation: 0.87, Suggested Move: a2b3
# Maia 1300 Evaluation: 1.34, Suggested Move: e5e2
# Maia 1400 Evaluation: 1.02, Suggested Move: a2b3
# Maia 1500 Evaluation: 1.03, Suggested Move: a2b3
# Maia 1600 Evaluation: 1.31, Suggested Move: a2b3
# Maia 1700 Evaluation: 0.38, Suggested Move: e5e2
# Maia 1800 Evaluation: 1.93, Suggested Move: a2b3
# Maia 1900 Evaluation: 1.47, Suggested Move: a2b3
#
# Position: 8/3kp3/3n4/8/8/P2Q4/K3R1q1/8 b - - 14 62
# Blunder: e5e2
# Stockfish Evaluation: 2.56
# Stockfish Suggested Move: e5e2
# Maia 1100 Evaluation: -0.75, Suggested Move: g2g4
# Maia 1200 Evaluation: -0.2, Suggested Move: g2g4
# Maia 1300 Evaluation: -1.36, Suggested Move: g2g5
# Maia 1400 Evaluation: -2.69, Suggested Move: g2g4
# Maia 1500 Evaluation: -1.21, Suggested Move: g2g4
# Maia 1600 Evaluation: -1.33, Suggested Move: g2g4
# Maia 1700 Evaluation: 0.48, Suggested Move: g2f1
# Maia 1800 Evaluation: -1.28, Suggested Move: g2g4
# Maia 1900 Evaluation: -1.03, Suggested Move: g2f1
#
# Position: 8/3kp3/3n4/8/6q1/P2Q4/K3R3/8 w - - 15 63
# Blunder: g2g4
# Stockfish Evaluation: -2.56
# Stockfish Suggested Move: g2g8
# Maia 1100 Evaluation: 0.79, Suggested Move: e2b2
# Maia 1200 Evaluation: 0.27, Suggested Move: a3a4
# Maia 1300 Evaluation: 1.5, Suggested Move: e2b2
# Maia 1400 Evaluation: 1.02, Suggested Move: e2b2
# Maia 1500 Evaluation: 1.19, Suggested Move: d3e3
# Maia 1600 Evaluation: 1.43, Suggested Move: e2b2
# Maia 1700 Evaluation: 1.39, Suggested Move: e2c2
# Maia 1800 Evaluation: 1.51, Suggested Move: e2c2
# Maia 1900 Evaluation: 2.32, Suggested Move: e2d2
#
# Position: 8/3kp3/3n4/8/6q1/P2Q4/K2R4/8 b - - 16 63
# Blunder: e2d2
# Stockfish Evaluation: 2.57
# Stockfish Suggested Move: e2d2
# Maia 1100 Evaluation: -0.77, Suggested Move: g4e6
# Maia 1200 Evaluation: -0.42, Suggested Move: g4e6
# Maia 1300 Evaluation: -0.98, Suggested Move: g4e6
# Maia 1400 Evaluation: -0.87, Suggested Move: g4e6
# Maia 1500 Evaluation: -0.87, Suggested Move: g4e6
# Maia 1600 Evaluation: -1.24, Suggested Move: g4e6
# Maia 1700 Evaluation: -1.08, Suggested Move: g4e6
# Maia 1800 Evaluation: -1.13, Suggested Move: g4e6
# Maia 1900 Evaluation: -2.32, Suggested Move: g4e6
#
# Position: 8/3kp3/3n4/8/q7/P2Q4/K2R4/8 w - - 17 64
# Blunder: g4a4
# Stockfish Evaluation: -2.57
# Stockfish Suggested Move: g4e6
# Maia 1100 Evaluation: 1.22, Suggested Move: d3b3
# Maia 1200 Evaluation: 1.32, Suggested Move: d3b3
# Maia 1300 Evaluation: 1.9, Suggested Move: d3b3
# Maia 1400 Evaluation: 1.7, Suggested Move: d3b3
# Maia 1500 Evaluation: 1.54, Suggested Move: d3b3
# Maia 1600 Evaluation: 1.34, Suggested Move: d3b3
# Maia 1700 Evaluation: 1.45, Suggested Move: d3b3
# Maia 1800 Evaluation: 1.25, Suggested Move: d3b3
# Maia 1900 Evaluation: 1.24, Suggested Move: d3b3
#
# Position: 8/3kp3/3n4/5Q2/q7/P7/K2R4/8 b - - 18 64
# Blunder: d3f5
# Stockfish Evaluation: 2.56
# Stockfish Suggested Move: d3h3
# Maia 1100 Evaluation: -1.27, Suggested Move: e7e6
# Maia 1200 Evaluation: -0.91, Suggested Move: e7e6
# Maia 1300 Evaluation: -0.71, Suggested Move: d7e8
# Maia 1400 Evaluation: -0.91, Suggested Move: d7e8
# Maia 1500 Evaluation: -0.85, Suggested Move: d7e8
# Maia 1600 Evaluation: -0.82, Suggested Move: d7e8
# Maia 1700 Evaluation: -0.88, Suggested Move: d7c7
# Maia 1800 Evaluation: -0.92, Suggested Move: d7e8
# Maia 1900 Evaluation: -0.5, Suggested Move: d7e8
#
# Position: 8/2k1p3/3n4/5Q2/q7/P7/K2R4/8 w - - 19 65
# Blunder: d7c7
# Stockfish Evaluation: -2.56
# Stockfish Suggested Move: d7d8
# Maia 1100 Evaluation: 0.86, Suggested Move: f5c2
# Maia 1200 Evaluation: 1.01, Suggested Move: f5c5
# Maia 1300 Evaluation: 1.27, Suggested Move: f5c5
# Maia 1400 Evaluation: 0.89, Suggested Move: f5c5
# Maia 1500 Evaluation: 0.92, Suggested Move: f5c5
# Maia 1600 Evaluation: 0.9, Suggested Move: f5c5
# Maia 1700 Evaluation: 0.84, Suggested Move: f5c5
# Maia 1800 Evaluation: 1.68, Suggested Move: f5c5
# Maia 1900 Evaluation: 1.12, Suggested Move: f5c5
#
# Position: 8/2k1p3/3n4/8/q7/P7/K1QR4/8 b - - 20 65
# Blunder: f5c2
# Stockfish Evaluation: 3.22
# Stockfish Suggested Move: f5c2
# Maia 1100 Evaluation: -0.76, Suggested Move: a4c2
# Maia 1200 Evaluation: -0.47, Suggested Move: a4c4
# Maia 1300 Evaluation: -1.27, Suggested Move: a4c2
# Maia 1400 Evaluation: -1.14, Suggested Move: a4c4
# Maia 1500 Evaluation: -1.74, Suggested Move: a4c2
# Maia 1600 Evaluation: -0.94, Suggested Move: a4c6
# Maia 1700 Evaluation: -1.45, Suggested Move: a4c2
# Maia 1800 Evaluation: -1.39, Suggested Move: a4c2
# Maia 1900 Evaluation: -0.67, Suggested Move: a4c4
#
# Position: 8/2k1p3/3n4/8/8/P7/K1qR4/8 w - - 0 66
# Blunder: a4c2
# Stockfish Evaluation: -3.27
# Stockfish Suggested Move: a4c2
# Maia 1100 Evaluation: 0.85, Suggested Move: d2c2
# Maia 1200 Evaluation: 1.69, Suggested Move: d2c2
# Maia 1300 Evaluation: 1.2, Suggested Move: d2c2
# Maia 1400 Evaluation: 1.07, Suggested Move: d2c2
# Maia 1500 Evaluation: 1.62, Suggested Move: d2c2
# Maia 1600 Evaluation: 1.79, Suggested Move: d2c2
# Maia 1700 Evaluation: 1.45, Suggested Move: d2c2
# Maia 1800 Evaluation: 1.38, Suggested Move: d2c2
# Maia 1900 Evaluation: 1.57, Suggested Move: d2c2
#
# Position: 8/2k1p3/3n4/8/8/P7/K1R5/8 b - - 0 66
# Blunder: d2c2
# Stockfish Evaluation: 3.31
# Stockfish Suggested Move: d2c2
# Maia 1100 Evaluation: -0.95, Suggested Move: c7d7
# Maia 1200 Evaluation: -1.27, Suggested Move: c7d7
# Maia 1300 Evaluation: -1.31, Suggested Move: c7d7
# Maia 1400 Evaluation: -1.19, Suggested Move: c7d7
# Maia 1500 Evaluation: -1.75, Suggested Move: c7d7
# Maia 1600 Evaluation: -1.4, Suggested Move: c7d7
# Maia 1700 Evaluation: -1.54, Suggested Move: c7d7
# Maia 1800 Evaluation: -1.21, Suggested Move: c7b6
# Maia 1900 Evaluation: -1.57, Suggested Move: c7b6
#
# Position: 8/1k2p3/3n4/8/8/P7/K1R5/8 w - - 1 67
# Blunder: c7b7
# Stockfish Evaluation: -3.42
# Stockfish Suggested Move: c7b6
# Maia 1100 Evaluation: 1.0, Suggested Move: c2e2
# Maia 1200 Evaluation: 0.9, Suggested Move: a3a4
# Maia 1300 Evaluation: 0.9, Suggested Move: a3a4
# Maia 1400 Evaluation: 0.96, Suggested Move: a3a4
# Maia 1500 Evaluation: 1.24, Suggested Move: c2e2
# Maia 1600 Evaluation: 1.4, Suggested Move: a2b3
# Maia 1700 Evaluation: 1.58, Suggested Move: c2e2
# Maia 1800 Evaluation: 1.45, Suggested Move: a2b3
# Maia 1900 Evaluation: 1.76, Suggested Move: a2b3
#
# Position: 8/1k2p3/3n4/8/8/P7/K3R3/8 b - - 2 67
# Blunder: c2e2
# Stockfish Evaluation: 3.46
# Stockfish Suggested Move: c2e2
# Maia 1100 Evaluation: -0.95, Suggested Move: d6f5
# Maia 1200 Evaluation: -1.03, Suggested Move: d6f5
# Maia 1300 Evaluation: -0.96, Suggested Move: d6f5
# Maia 1400 Evaluation: -1.05, Suggested Move: d6f5
# Maia 1500 Evaluation: -1.33, Suggested Move: d6f5
# Maia 1600 Evaluation: -1.39, Suggested Move: d6f5
# Maia 1700 Evaluation: -1.04, Suggested Move: d6f5
# Maia 1800 Evaluation: -1.5, Suggested Move: d6f5
# Maia 1900 Evaluation: -1.53, Suggested Move: d6c8
#
# Position: 2n5/1k2p3/8/8/8/P7/K3R3/8 w - - 3 68
# Blunder: d6c8
# Stockfish Evaluation: -3.57
# Stockfish Suggested Move: d6c8
# Maia 1100 Evaluation: 1.01, Suggested Move: a3a4
# Maia 1200 Evaluation: 1.07, Suggested Move: a2b3
# Maia 1300 Evaluation: 0.84, Suggested Move: a3a4
# Maia 1400 Evaluation: 1.09, Suggested Move: a2b3
# Maia 1500 Evaluation: 1.38, Suggested Move: a2b3
# Maia 1600 Evaluation: 1.84, Suggested Move: a2b3
# Maia 1700 Evaluation: 1.64, Suggested Move: a2b3
# Maia 1800 Evaluation: 1.67, Suggested Move: a2b3
# Maia 1900 Evaluation: 1.53, Suggested Move: a2b3
#
# Position: 2n5/1k2p3/8/8/8/PK6/4R3/8 b - - 4 68
# Blunder: a2b3
# Stockfish Evaluation: 3.59
# Stockfish Suggested Move: a2b3
# Maia 1100 Evaluation: -1.01, Suggested Move: b7c7
# Maia 1200 Evaluation: -1.04, Suggested Move: c8d6
# Maia 1300 Evaluation: -1.16, Suggested Move: b7b6
# Maia 1400 Evaluation: -1.26, Suggested Move: b7b6
# Maia 1500 Evaluation: -1.42, Suggested Move: b7a6
# Maia 1600 Evaluation: -1.59, Suggested Move: b7c6
# Maia 1700 Evaluation: -1.7, Suggested Move: b7b6
# Maia 1800 Evaluation: -1.7, Suggested Move: b7c6
# Maia 1900 Evaluation: -1.42, Suggested Move: b7c6
#
# Position: 2n5/4p3/2k5/8/8/PK6/4R3/8 w - - 5 69
# Blunder: b7c6
# Stockfish Evaluation: -3.71
# Stockfish Suggested Move: b7c7
# Maia 1100 Evaluation: 1.05, Suggested Move: a3a4
# Maia 1200 Evaluation: 0.85, Suggested Move: a3a4
# Maia 1300 Evaluation: 1.15, Suggested Move: b3b4
# Maia 1400 Evaluation: 1.1, Suggested Move: b3b4
# Maia 1500 Evaluation: 1.58, Suggested Move: b3b4
# Maia 1600 Evaluation: 1.6, Suggested Move: b3b4
# Maia 1700 Evaluation: 1.72, Suggested Move: b3b4
# Maia 1800 Evaluation: 2.03, Suggested Move: b3b4
# Maia 1900 Evaluation: 1.88, Suggested Move: a3a4
#
# Position: 2n5/4p3/2k5/8/8/PK6/2R5/8 b - - 6 69
# Blunder: e2c2
# Stockfish Evaluation: 3.9
# Stockfish Suggested Move: b3b4
# Maia 1100 Evaluation: -1.06, Suggested Move: c6d7
# Maia 1200 Evaluation: -1.25, Suggested Move: c6d7
# Maia 1300 Evaluation: -1.35, Suggested Move: c6d7
# Maia 1400 Evaluation: -1.21, Suggested Move: c6d7
# Maia 1500 Evaluation: -1.46, Suggested Move: c6b7
# Maia 1600 Evaluation: -1.6, Suggested Move: c6b7
# Maia 1700 Evaluation: -1.52, Suggested Move: c6b7
# Maia 1800 Evaluation: -2.25, Suggested Move: c6d7
# Maia 1900 Evaluation: -1.58, Suggested Move: c6b7
#
# Position: 2n5/1k2p3/8/8/8/PK6/2R5/8 w - - 7 70
# Blunder: c6b7
# Stockfish Evaluation: -3.91
# Stockfish Suggested Move: c6b7
# Maia 1100 Evaluation: 1.04, Suggested Move: b3b4
# Maia 1200 Evaluation: 1.27, Suggested Move: b3b4
# Maia 1300 Evaluation: 0.99, Suggested Move: a3a4
# Maia 1400 Evaluation: 1.09, Suggested Move: b3b4
# Maia 1500 Evaluation: 1.51, Suggested Move: b3b4
# Maia 1600 Evaluation: 1.59, Suggested Move: b3b4
# Maia 1700 Evaluation: 1.61, Suggested Move: b3b4
# Maia 1800 Evaluation: 1.64, Suggested Move: b3b4
# Maia 1900 Evaluation: 1.54, Suggested Move: a3a4
#
# Position: 2n5/1k2p3/8/8/1K6/P7/2R5/8 b - - 8 70
# Blunder: b3b4
# Stockfish Evaluation: 3.99
# Stockfish Suggested Move: c2e2
# Maia 1100 Evaluation: -0.93, Suggested Move: c8b6
# Maia 1200 Evaluation: -1.16, Suggested Move: c8d6
# Maia 1300 Evaluation: -1.15, Suggested Move: e7e5
# Maia 1400 Evaluation: -1.02, Suggested Move: c8d6
# Maia 1500 Evaluation: -1.51, Suggested Move: e7e5
# Maia 1600 Evaluation: -1.72, Suggested Move: c8d6
# Maia 1700 Evaluation: -1.59, Suggested Move: c8b6
# Maia 1800 Evaluation: -1.5, Suggested Move: c8d6
# Maia 1900 Evaluation: -1.44, Suggested Move: c8d6
#
# Position: 8/nk2p3/8/8/1K6/P7/2R5/8 w - - 9 71
# Blunder: c8a7
# Stockfish Evaluation: -4.07
# Stockfish Suggested Move: e7e5
# Maia 1100 Evaluation: 1.06, Suggested Move: a3a4
# Maia 1200 Evaluation: 1.06, Suggested Move: a3a4
# Maia 1300 Evaluation: 1.05, Suggested Move: a3a4
# Maia 1400 Evaluation: 0.99, Suggested Move: a3a4
# Maia 1500 Evaluation: 1.31, Suggested Move: c2e2
# Maia 1600 Evaluation: 1.13, Suggested Move: a3a4
# Maia 1700 Evaluation: 1.51, Suggested Move: a3a4
# Maia 1800 Evaluation: 1.54, Suggested Move: c2e2
# Maia 1900 Evaluation: 1.68, Suggested Move: b4c5
#
# Position: 8/nk2p3/8/2K5/8/P7/2R5/8 b - - 10 71
# Blunder: b4c5
# Stockfish Evaluation: 4.14
# Stockfish Suggested Move: c2e2
# Maia 1100 Evaluation: -0.93, Suggested Move: a7c6
# Maia 1200 Evaluation: -1.09, Suggested Move: a7c6
# Maia 1300 Evaluation: -1.19, Suggested Move: a7c6
# Maia 1400 Evaluation: -1.18, Suggested Move: a7c6
# Maia 1500 Evaluation: -1.67, Suggested Move: a7c6
# Maia 1600 Evaluation: -1.55, Suggested Move: a7c6
# Maia 1700 Evaluation: -1.47, Suggested Move: a7c8
# Maia 1800 Evaluation: -1.46, Suggested Move: a7c6
# Maia 1900 Evaluation: -1.55, Suggested Move: a7c6

# %%
# Function to save board image with annotations using svgwrite
def save_board_image_with_svgwrite(board, move=None, output_file="board.png"):
    svg_data = chess.svg.board(board, lastmove=move)
    svg_path = output_file.replace(".png", ".svg")

    # Save the SVG file
    with open(svg_path, "w") as svg_file:
        svg_file.write(svg_data)

    # Convert SVG to PNG using rsvg-convert
    subprocess.run(["rsvg-convert", "-o", output_file, svg_path])

# Function to highlight a move on the board
def highlight_move_with_svgwrite(board, move, output_file="highlighted_board.png"):
    if move in board.legal_moves:
        board.push(move)
        save_board_image_with_svgwrite(board, move, output_file)
        board.pop()  # Revert the move
    else:
        print(f"Illegal move {move} in position {board.fen()}")

# Directory to save images
image_dir = "chess_images"
os.makedirs(image_dir, exist_ok=True)

# Generate images for each critical position
for event, blunder_list in all_blunders:
    print(f"Event: {event}")
    for i, (fen, move, stockfish_eval, stockfish_best_move, maia_suggestions) in enumerate(blunder_list):
        board = chess.Board(fen)

        # Save initial board state
        initial_image_path = os.path.join(image_dir, f"{event.replace(' ', '_')}_pos_{i}_initial.png")
        save_board_image_with_svgwrite(board, output_file=initial_image_path)

        # Highlight the blunder move
        blunder_image_path = os.path.join(image_dir, f"{event.replace(' ', '_')}_pos_{i}_blunder.png")
        highlight_move_with_svgwrite(board, move, output_file=blunder_image_path)

        # Highlight the correct move
        correct_image_path = os.path.join(image_dir, f"{event.replace(' ', '_')}_pos_{i}_correct.png")
        highlight_move_with_svgwrite(board, stockfish_best_move, output_file=correct_image_path)

        print(f"Position: {fen}")
        print(f"Blunder: {move}")
        print(f"Stockfish Evaluation: {stockfish_eval}")
        print(f"Stockfish Suggested Move: {stockfish_best_move}")
        for elo, (best_move, maia_eval) in maia_suggestions.items():
            print(f"Maia {elo} Evaluation: {maia_eval}, Suggested Move: {best_move}")
        print(f"Initial Image: {initial_image_path}")
        print(f"Blunder Image: {blunder_image_path}")
        print(f"Correct Move Image: {correct_image_path}")
        print()

# Cleanup Engines
print("Cleaning up engines...")
stockfish_engine.quit()
for maia_engine in maia_engines.values():
    maia_engine.quit()
print("Engines cleaned up.")
# Out:
# Initializing Stockfish engine...
# Stockfish engine initialized.
# Initializing Maia engines...
# Initializing Maia 1100 engine...
# Initializing Maia 1200 engine...
# Initializing Maia 1300 engine...
# Initializing Maia 1400 engine...
# Initializing Maia 1500 engine...
# Initializing Maia 1600 engine...
# Initializing Maia 1700 engine...
# Initializing Maia 1800 engine...
# Initializing Maia 1900 engine...
# Maia engines initialized.
# Loaded 10 games from PGN file.
# Analyzed game with 1 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 1 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 12 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 4 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 40 blunders found.
# Filtered blunders down to 0 consistent ones.
# Cleaning up engines...
# Engines cleaned up.
