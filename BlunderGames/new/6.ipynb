# %%
import chess
import chess.engine
import chess.pgn
import subprocess
import os
import json
import csv
from statistics import mean

# Paths to your engines and Maia models
stockfish_path = "/opt/homebrew/bin/stockfish"
maia_model_paths = {
    1100: "maia_weights/maia-1100.pb.gz",
    1200: "maia_weights/maia-1200.pb.gz",
    1300: "maia_weights/maia-1300.pb.gz",
    1400: "maia_weights/maia-1400.pb.gz",
    1500: "maia_weights/maia-1500.pb.gz",
    1600: "maia_weights/maia-1600.pb.gz",
    1700: "maia_weights/maia-1700.pb.gz",
    1800: "maia_weights/maia-1800.pb.gz",
    1900: "maia_weights/maia-1900.pb.gz",
}

# Initialize Stockfish engine
print("Initializing Stockfish engine...")
stockfish_engine = chess.engine.SimpleEngine.popen_uci(stockfish_path)
print("Stockfish engine initialized.")

# Initialize Maia engines
print("Initializing Maia engines...")
maia_engines = {}
for elo, path in maia_model_paths.items():
    print(f"Initializing Maia {elo} engine...")
    maia_engines[elo] = chess.engine.SimpleEngine.popen_uci(["lc0", f"--weights={path}"])
print("Maia engines initialized.")

# Function to load games from a PGN file
def load_games_from_pgn(file_path):
    games = []
    with open(file_path, 'r') as pgn_file:
        while True:
            game = chess.pgn.read_game(pgn_file)
            if game is None:
                break
            games.append(game)
    print(f"Loaded {len(games)} games from PGN file {file_path}.")
    return games

# Function to find classic puzzles in a game
def find_classic_puzzles(game, stockfish_engine, threshold=200):
    board = game.board()
    puzzles = []

    for move in game.mainline_moves():
        fen_before = board.fen()

        # Analyze the position before the move
        info = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1), multipv=2)
        if len(info) < 2:
            continue

        best_move = info[0]["pv"][0]
        best_eval = info[0]["score"].relative.score(mate_score=10000)
        second_best_eval = info[1]["score"].relative.score(mate_score=10000)

        # Check if the difference is large enough and the move is not a simple recapture
        if abs(best_eval - second_best_eval) >= threshold and not board.is_capture(best_move):
            puzzles.append((fen_before, best_move, best_eval, second_best_eval))
            print(f"Puzzle found: {fen_before}, Best move: {best_move}, Eval difference: {abs(best_eval - second_best_eval)}")

        board.push(move)

    return puzzles

# Function to evaluate Maia easiness
def evaluate_maia_easiness(fen, best_move, maia_engines):
    board = chess.Board(fen)
    easiness_scores = {}
    print(f"Evaluating Maia easiness for FEN: {fen}, Best Move: {best_move}")

    for elo, engine in maia_engines.items():
        result = engine.analyse(board, chess.engine.Limit(nodes=1))
        if "pv" in result and best_move in result["pv"]:
            easiness_scores[elo] = result["pv"].index(best_move) / len(result["pv"])
        else:
            easiness_scores[elo] = 0.0  # Assign 0 if the best move is not in pv

    return easiness_scores

# Function to save results incrementally to CSV
def save_results_to_csv(csv_file_path, data):
    with open(csv_file_path, "a", newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        for fen, best_move, best_eval, second_best_eval, maia_easiness in data:
            csvwriter.writerow([
                fen,
                best_move.uci(),  # Convert Move object to UCI notation
                best_eval,
                second_best_eval,
                maia_easiness
            ])

# Function to save results incrementally to JSON
def save_results_to_json(json_file_path, data):
    if os.path.exists(json_file_path):
        with open(json_file_path, "r") as jsonfile:
            json_data = json.load(jsonfile)
    else:
        json_data = []

    json_data.extend(data)

    with open(json_file_path, "w") as jsonfile:
        json.dump(json_data, jsonfile, indent=4)

# Function to sort and save results
def sort_and_save_results(puzzles, output_dir="results/classic_puzzles"):
    os.makedirs(output_dir, exist_ok=True)

    # Calculate average easiness and handle missing values
    for puzzle in puzzles:
        maia_scores = [score for score in puzzle["maia_easiness"].values()]
        puzzle["average_easiness"] = mean(maia_scores) if maia_scores else 0.0

    # Sort puzzles by average easiness
    puzzles.sort(key=lambda x: x["average_easiness"], reverse=True)

    csv_file_path = os.path.join(output_dir, "classic_puzzles.csv")
    json_file_path = os.path.join(output_dir, "classic_puzzles.json")

    with open(csv_file_path, "w", newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(["FEN", "Best Move", "Best Eval", "Second Best Eval", "Average Easiness"])
        for puzzle in puzzles:
            csvwriter.writerow([
                puzzle["fen"],
                puzzle["best_move"].uci(),  # Convert Move object to UCI notation
                puzzle["best_eval"],
                puzzle["second_best_eval"],
                puzzle["average_easiness"]
            ])

    with open(json_file_path, "w") as jsonfile:
        json.dump(puzzles, jsonfile, indent=4)

# Load PGN files and find classic puzzles
pgn_directory = "analysis_pgns_test"
all_puzzles = []

print("Starting to find classic puzzles in PGN files...")

for pgn_file in os.listdir(pgn_directory):
    if pgn_file.endswith(".pgn"):
        pgn_file_path = os.path.join(pgn_directory, pgn_file)
        print(f"Analyzing {pgn_file_path}...")
        all_games = load_games_from_pgn(pgn_file_path)

        for game in all_games:
            print(f"Analyzing game {game.headers.get('Event', 'Unknown Event')}")
            puzzles = find_classic_puzzles(game, stockfish_engine)
            for fen, best_move, best_eval, second_best_eval in puzzles:
                maia_easiness = evaluate_maia_easiness(fen, best_move, maia_engines)
                all_puzzles.append({
                    "fen": fen,
                    "best_move": best_move,
                    "best_eval": best_eval,
                    "second_best_eval": second_best_eval,
                    "maia_easiness": maia_easiness
                })

# Sort and save results
sort_and_save_results(all_puzzles)
print("Classic puzzles analysis complete. Results saved.")
# Out:
# Initializing Stockfish engine...
# <UciProtocol (pid=18989)>: stderr >>        _
# <UciProtocol (pid=18989)>: stderr >> |   _ | |
# <UciProtocol (pid=18989)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18990)>: stderr >>        _
# <UciProtocol (pid=18990)>: stderr >> |   _ | |
# <UciProtocol (pid=18990)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18991)>: stderr >>        _
# <UciProtocol (pid=18991)>: stderr >> |   _ | |
# <UciProtocol (pid=18991)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18992)>: stderr >>        _
# <UciProtocol (pid=18992)>: stderr >> |   _ | |
# <UciProtocol (pid=18992)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18994)>: stderr >>        _
# <UciProtocol (pid=18994)>: stderr >> |   _ | |
# <UciProtocol (pid=18994)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18995)>: stderr >>        _
# <UciProtocol (pid=18995)>: stderr >> |   _ | |
# <UciProtocol (pid=18995)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18997)>: stderr >>        _
# <UciProtocol (pid=18997)>: stderr >> |   _ | |
# <UciProtocol (pid=18997)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18998)>: stderr >>        _
# <UciProtocol (pid=18998)>: stderr >> |   _ | |
# <UciProtocol (pid=18998)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18999)>: stderr >>        _
# <UciProtocol (pid=18999)>: stderr >> |   _ | |
# <UciProtocol (pid=18999)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# Stockfish engine initialized.
# Initializing Maia engines...
# Initializing Maia 1100 engine...
# Initializing Maia 1200 engine...
# Initializing Maia 1300 engine...
# Initializing Maia 1400 engine...
# Initializing Maia 1500 engine...
# Initializing Maia 1600 engine...
# Initializing Maia 1700 engine...
# Initializing Maia 1800 engine...
# Initializing Maia 1900 engine...
# Maia engines initialized.
# Starting to find classic puzzles in PGN files...
# Analyzing analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn...
# Loaded 4 games from PGN file analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn.
# Analyzing game FIDE World Championship Match 1969
# Puzzle found: 8/6kp/2Pn2p1/3B4/1p1R2P1/7P/2rp4/6K1 w - - 0 40, Best move: d5b3, Eval difference: 249
# Puzzle found: 8/5B1R/5kp1/2n4P/8/5K2/1pr5/8 w - - 0 50, Best move: f7a2, Eval difference: 281
# <UciProtocol (pid=18989)>: stderr >> Loading weights file from: maia_weights/maia-1100.pb.gz
# <UciProtocol (pid=18989)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=18989)>: stderr >> Initialized metal backend on device Apple M1 Pro
# <UciProtocol (pid=18990)>: stderr >> Loading weights file from: maia_weights/maia-1200.pb.gz
# <UciProtocol (pid=18990)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=18990)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Evaluating Maia easiness for FEN: 8/6kp/2Pn2p1/3B4/1p1R2P1/7P/2rp4/6K1 w - - 0 40, Best Move: d5b3
# <UciProtocol (pid=18991)>: stderr >> Loading weights file from: maia_weights/maia-1300.pb.gz
# <UciProtocol (pid=18991)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=18991)>: stderr >> Initialized metal backend on device Apple M1 Pro
# <UciProtocol (pid=18992)>: stderr >> Loading weights file from: maia_weights/maia-1400.pb.gz
# <UciProtocol (pid=18992)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=18992)>: stderr >> Initialized metal backend on device Apple M1 Pro
# <UciProtocol (pid=18994)>: stderr >> Loading weights file from: maia_weights/maia-1500.pb.gz
# <UciProtocol (pid=18994)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=18994)>: stderr >> Initialized metal backend on device Apple M1 Pro
# <UciProtocol (pid=18995)>: stderr >> Loading weights file from: maia_weights/maia-1600.pb.gz
# <UciProtocol (pid=18995)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=18995)>: stderr >> Initialized metal backend on device Apple M1 Pro
# <UciProtocol (pid=18997)>: stderr >> Loading weights file from: maia_weights/maia-1700.pb.gz
# <UciProtocol (pid=18997)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=18997)>: stderr >> Initialized metal backend on device Apple M1 Pro
# <UciProtocol (pid=18998)>: stderr >> Loading weights file from: maia_weights/maia-1800.pb.gz
# <UciProtocol (pid=18998)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=18998)>: stderr >> Initialized metal backend on device Apple M1 Pro
# <UciProtocol (pid=18999)>: stderr >> Loading weights file from: maia_weights/maia-1900.pb.gz
# <UciProtocol (pid=18999)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=18999)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Evaluating Maia easiness for FEN: 8/5B1R/5kp1/2n4P/8/5K2/1pr5/8 w - - 0 50, Best Move: f7a2
# Analyzing game FIDE World Championship Match 1969
# Analyzing game FIDE World Championship Match 1969
# Analyzing game FIDE World Championship Match 1969
# Puzzle found: 4r1k1/pp3pp1/7p/P1Rp2q1/3P1nP1/1P1bNP2/3Q1K1P/5B2 b - - 4 40, Best move: g5h4, Eval difference: 251
# Evaluating Maia easiness for FEN: 4r1k1/pp3pp1/7p/P1Rp2q1/3P1nP1/1P1bNP2/3Q1K1P/5B2 b - - 4 40, Best Move: g5h4
# Analyzing analysis_pgns_test/4S5UuAGn---1986 Karpov vs. Kasparov III.pgn...
# Loaded 5 games from PGN file analysis_pgns_test/4S5UuAGn---1986 Karpov vs. Kasparov III.pgn.
# Analyzing game FIDE World Championship Match 1986
# Analyzing game FIDE World Championship Match 1986
# Analyzing game FIDE World Championship Match 1986
# Analyzing game FIDE World Championship Match 1986
# Analyzing game FIDE World Championship Match 1986
# Analyzing analysis_pgns_test/vNaOB23W---1935 Alekhine vs. Euwe.pgn...
# Loaded 30 games from PGN file analysis_pgns_test/vNaOB23W---1935 Alekhine vs. Euwe.pgn.
# Analyzing game World Championship Match 1935
# Analyzing game World Championship Match 1935
# Puzzle found: 1r2kb1r/pppq1p1p/3n1np1/3Pp3/4PP2/2NQ4/PP4PP/R1B1KB1R b KQk - 0 14, Best move: d7e7, Eval difference: 211
# Evaluating Maia easiness for FEN: 1r2kb1r/pppq1p1p/3n1np1/3Pp3/4PP2/2NQ4/PP4PP/R1B1KB1R b KQk - 0 14, Best Move: d7e7
# Analyzing game World Championship Match 1935
# Puzzle found: rnbqk1r1/ppp2pQp/4pn2/8/3Pp3/P1P5/2P2PPP/R1B1KBNR w KQq - 1 8, Best move: g7h6, Eval difference: 387
# Puzzle found: r1b1k3/pp4rp/1n2p1q1/3n1p2/3PB3/P2Q2N1/5PPP/R1B1K2R w KQq - 0 20, Best move: e4f3, Eval difference: 240
# Evaluating Maia easiness for FEN: rnbqk1r1/ppp2pQp/4pn2/8/3Pp3/P1P5/2P2PPP/R1B1KBNR w KQq - 1 8, Best Move: g7h6
# Evaluating Maia easiness for FEN: r1b1k3/pp4rp/1n2p1q1/3n1p2/3PB3/P2Q2N1/5PPP/R1B1K2R w KQq - 0 20, Best Move: e4f3
# Analyzing game World Championship Match 1935
# Puzzle found: 1B4k1/p4p1p/6p1/2q5/1p4n1/1Pb5/P1QR2PP/4K2R b K - 0 26, Best move: c5e7, Eval difference: 273
# Puzzle found: 1B4k1/p3qp1p/6p1/8/1p4n1/1Pb5/P1QR2PP/4K2R w K - 1 27, Best move: e1d1, Eval difference: 276
# Puzzle found: 1B4k1/p3qp1p/6p1/8/1p4n1/1Pb5/P1QR2PP/3K3R b - - 2 27, Best move: g4e3, Eval difference: 401
# Puzzle found: 1B4k1/p3qp1p/6p1/8/1p6/1Pb1n3/P1QR2PP/3K3R w - - 3 28, Best move: d1c1, Eval difference: 335
# Puzzle found: 6k1/2B2pb1/6p1/7p/P7/1q5P/2R3P1/1K1R4 w - - 0 37, Best move: b1c1, Eval difference: 9525
# Evaluating Maia easiness for FEN: 1B4k1/p4p1p/6p1/2q5/1p4n1/1Pb5/P1QR2PP/4K2R b K - 0 26, Best Move: c5e7
# Evaluating Maia easiness for FEN: 1B4k1/p3qp1p/6p1/8/1p4n1/1Pb5/P1QR2PP/4K2R w K - 1 27, Best Move: e1d1
# Evaluating Maia easiness for FEN: 1B4k1/p3qp1p/6p1/8/1p4n1/1Pb5/P1QR2PP/3K3R b - - 2 27, Best Move: g4e3
# Evaluating Maia easiness for FEN: 1B4k1/p3qp1p/6p1/8/1p6/1Pb1n3/P1QR2PP/3K3R w - - 3 28, Best Move: d1c1
# Evaluating Maia easiness for FEN: 6k1/2B2pb1/6p1/7p/P7/1q5P/2R3P1/1K1R4 w - - 0 37, Best Move: b1c1
# Analyzing game World Championship Match 1935
# Puzzle found: r4rk1/1q2bppp/1p6/2p5/6B1/P1P3N1/2P2PPP/R3Q1K1 w - - 0 23, Best move: g4f3, Eval difference: 234
# Evaluating Maia easiness for FEN: r4rk1/1q2bppp/1p6/2p5/6B1/P1P3N1/2P2PPP/R3Q1K1 w - - 0 23, Best Move: g4f3
# Analyzing game World Championship Match 1935
# Puzzle found: r1n2rk1/pq2bppp/4p3/2pP3b/4P1P1/5Q1P/BP3P2/RNB2RK1 b - - 0 19, Best move: h5g6, Eval difference: 330
# Puzzle found: 2Q3k1/5pp1/1r6/3Pp1qb/4P1p1/4R3/2B2PK1/8 b - - 2 46, Best move: g8h7, Eval difference: 740
# Puzzle found: 8/5bP1/3r4/3Pp1k1/4p1p1/6K1/5P2/7R w - - 0 56, Best move: h1h8, Eval difference: 281
# Puzzle found: 7R/5bP1/6r1/3Pp1k1/4p1p1/6K1/5P2/8 w - - 2 57, Best move: d5d6, Eval difference: 366
# Puzzle found: 4R3/8/5k2/4p3/6K1/3r1p2/8/8 w - - 0 64, Best move: e8f8, Eval difference: 385
# Evaluating Maia easiness for FEN: r1n2rk1/pq2bppp/4p3/2pP3b/4P1P1/5Q1P/BP3P2/RNB2RK1 b - - 0 19, Best Move: h5g6
# Evaluating Maia easiness for FEN: 2Q3k1/5pp1/1r6/3Pp1qb/4P1p1/4R3/2B2PK1/8 b - - 2 46, Best Move: g8h7
# Evaluating Maia easiness for FEN: 8/5bP1/3r4/3Pp1k1/4p1p1/6K1/5P2/7R w - - 0 56, Best Move: h1h8
# Evaluating Maia easiness for FEN: 7R/5bP1/6r1/3Pp1k1/4p1p1/6K1/5P2/8 w - - 2 57, Best Move: d5d6
# Evaluating Maia easiness for FEN: 4R3/8/5k2/4p3/6K1/3r1p2/8/8 w - - 0 64, Best Move: e8f8
# Analyzing game World Championship Match 1935
# Puzzle found: r3qr1k/pbp2p1p/1pn1pp2/8/3P3Q/P1P5/1P3PBP/R1B1K2R b KQ - 1 16, Best move: e8d8, Eval difference: 345
# Puzzle found: 4r1rk/pbp2p2/1pn2B1p/4P3/4p3/P1P5/1P2BP1P/2KR3R b - - 3 25, Best move: h8h7, Eval difference: 309
# Puzzle found: 4r1r1/p1p2R1k/1p3B1p/2n1P3/8/P1P5/1P5P/2K4R b - - 0 30, Best move: h7g6, Eval difference: 9754
# Evaluating Maia easiness for FEN: r3qr1k/pbp2p1p/1pn1pp2/8/3P3Q/P1P5/1P3PBP/R1B1K2R b KQ - 1 16, Best Move: e8d8
# Evaluating Maia easiness for FEN: 4r1rk/pbp2p2/1pn2B1p/4P3/4p3/P1P5/1P2BP1P/2KR3R b - - 3 25, Best Move: h8h7
# Evaluating Maia easiness for FEN: 4r1r1/p1p2R1k/1p3B1p/2n1P3/8/P1P5/1P5P/2K4R b - - 0 30, Best Move: h7g6
# Analyzing game World Championship Match 1935
# Puzzle found: 4kb1r/3n1ppp/prp1p3/3p4/Q2P4/3BP3/Pq1BKPPP/1R5R b k - 5 16, Best move: b2a3, Eval difference: 313
# Puzzle found: 2B2k2/P2R4/8/5K2/r7/8/5bP1/8 w - - 1 69, Best move: c8a6, Eval difference: 348
# Evaluating Maia easiness for FEN: 4kb1r/3n1ppp/prp1p3/3p4/Q2P4/3BP3/Pq1BKPPP/1R5R b k - 5 16, Best Move: b2a3
# Evaluating Maia easiness for FEN: 2B2k2/P2R4/8/5K2/r7/8/5bP1/8 w - - 1 69, Best Move: c8a6
# Analyzing game World Championship Match 1935
# Puzzle found: rnbqk1r1/ppp2pQp/4pn2/3p4/1b1PP3/2N5/PPP2PPP/R1B1KBNR w KQq - 1 6, Best move: g7h6, Eval difference: 202
# Puzzle found: 8/pp4RP/4kB2/4P3/3pb3/1P6/P7/2r3K1 w - - 1 36, Best move: g1f2, Eval difference: 338
# Puzzle found: 8/p6R/4kB2/1p2P3/3pK3/1P6/r7/8 b - - 1 40, Best move: a2e2, Eval difference: 9635
# Evaluating Maia easiness for FEN: rnbqk1r1/ppp2pQp/4pn2/3p4/1b1PP3/2N5/PPP2PPP/R1B1KBNR w KQq - 1 6, Best Move: g7h6
# Evaluating Maia easiness for FEN: 8/pp4RP/4kB2/4P3/3pb3/1P6/P7/2r3K1 w - - 1 36, Best Move: g1f2
# Evaluating Maia easiness for FEN: 8/p6R/4kB2/1p2P3/3pK3/1P6/r7/8 b - - 1 40, Best Move: a2e2
# Analyzing game World Championship Match 1935
# Analyzing game World Championship Match 1935
# Puzzle found: 1Q6/1p3ppk/p1q1p2p/3pP3/bP1P4/3B3P/P4PP1/6K1 b - - 7 28, Best move: g7g6, Eval difference: 680
# Evaluating Maia easiness for FEN: 1Q6/1p3ppk/p1q1p2p/3pP3/bP1P4/3B3P/P4PP1/6K1 b - - 7 28, Best Move: g7g6
# Analyzing game World Championship Match 1935
# Puzzle found: r1b1qrk1/2Q1ppbp/p5p1/1p1n4/4NB2/5N2/PP2BPPP/R4RK1 w - - 0 14, Best move: c7c1, Eval difference: 487
# Puzzle found: 2r1qrk1/4ppbp/p5p1/1p1n1b2/5B2/5NN1/PP2BPPP/R1Q2RK1 w - - 4 16, Best move: c1d2, Eval difference: 424
# Evaluating Maia easiness for FEN: r1b1qrk1/2Q1ppbp/p5p1/1p1n4/4NB2/5N2/PP2BPPP/R4RK1 w - - 0 14, Best Move: c7c1
# Evaluating Maia easiness for FEN: 2r1qrk1/4ppbp/p5p1/1p1n1b2/5B2/5NN1/PP2BPPP/R1Q2RK1 w - - 4 16, Best Move: c1d2
# Analyzing game World Championship Match 1935
# Puzzle found: 6k1/1b3ppp/8/p7/PPR5/2N4P/6r1/6K1 w - - 0 39, Best move: g1f1, Eval difference: 381
# Puzzle found: 8/P1R5/5pk1/8/r4Kp1/8/8/8 w - - 2 57, Best move: f4g3, Eval difference: 323
# Puzzle found: 8/P1R5/6k1/5p2/r5p1/6K1/8/8 w - - 0 58, Best move: g3h4, Eval difference: 340
# Evaluating Maia easiness for FEN: 6k1/1b3ppp/8/p7/PPR5/2N4P/6r1/6K1 w - - 0 39, Best Move: g1f1
# Evaluating Maia easiness for FEN: 8/P1R5/5pk1/8/r4Kp1/8/8/8 w - - 2 57, Best Move: f4g3
# Evaluating Maia easiness for FEN: 8/P1R5/6k1/5p2/r5p1/6K1/8/8 w - - 0 58, Best Move: g3h4
# Analyzing game World Championship Match 1935
# Puzzle found: r1b2r2/pp4k1/5np1/3p1pN1/B6R/2q1P1P1/P4PP1/3Q1K1R w - - 12 24, Best move: h4h7, Eval difference: 211
# Puzzle found: 7r/pR6/5kb1/3p1p2/6P1/1B2PQ2/P4PK1/q7 w - - 3 37, Best move: g4g5, Eval difference: 502
# Puzzle found: 7r/pR6/5kb1/3p1p2/5Q2/1B2P3/P4PK1/q7 w - - 2 39, Best move: f4d6, Eval difference: 9900
# Evaluating Maia easiness for FEN: r1b2r2/pp4k1/5np1/3p1pN1/B6R/2q1P1P1/P4PP1/3Q1K1R w - - 12 24, Best Move: h4h7
# Evaluating Maia easiness for FEN: 7r/pR6/5kb1/3p1p2/6P1/1B2PQ2/P4PK1/q7 w - - 3 37, Best Move: g4g5
# Evaluating Maia easiness for FEN: 7r/pR6/5kb1/3p1p2/5Q2/1B2P3/P4PK1/q7 w - - 2 39, Best Move: f4d6
# Analyzing game World Championship Match 1935
# Puzzle found: 2k5/pp3ppp/2b5/P1p1P3/2p1rPP1/2RnK3/4B2P/5R2 w - - 3 28, Best move: e3d2, Eval difference: 559
# Puzzle found: 8/p4B1p/2k5/Pp2P1p1/1Kp1b1P1/3n4/7P/5R2 w - - 2 39, Best move: b4c3, Eval difference: 270
# Puzzle found: 8/p4B1p/2k5/Pp2n1p1/2p1b1P1/2K5/7P/5R2 w - - 0 40, Best move: f7e8, Eval difference: 278
# Puzzle found: 8/p6p/8/PBk1n1p1/2p3P1/2Kb4/7P/5R2 w - - 1 42, Best move: f1e1, Eval difference: 415
# Puzzle found: 8/pB5p/8/P1k3p1/2p3P1/2Kb4/4n2P/4R3 w - - 7 45, Best move: c3d2, Eval difference: 358
# Puzzle found: 8/7p/8/6R1/1k4P1/8/p1K4n/8 w - - 0 58, Best move: c2b2, Eval difference: 449
# Evaluating Maia easiness for FEN: 2k5/pp3ppp/2b5/P1p1P3/2p1rPP1/2RnK3/4B2P/5R2 w - - 3 28, Best Move: e3d2
# Evaluating Maia easiness for FEN: 8/p4B1p/2k5/Pp2P1p1/1Kp1b1P1/3n4/7P/5R2 w - - 2 39, Best Move: b4c3
# Evaluating Maia easiness for FEN: 8/p4B1p/2k5/Pp2n1p1/2p1b1P1/2K5/7P/5R2 w - - 0 40, Best Move: f7e8
# Evaluating Maia easiness for FEN: 8/p6p/8/PBk1n1p1/2p3P1/2Kb4/7P/5R2 w - - 1 42, Best Move: f1e1
# Evaluating Maia easiness for FEN: 8/pB5p/8/P1k3p1/2p3P1/2Kb4/4n2P/4R3 w - - 7 45, Best Move: c3d2
# Evaluating Maia easiness for FEN: 8/7p/8/6R1/1k4P1/8/p1K4n/8 w - - 0 58, Best Move: c2b2
# Analyzing game World Championship Match 1935
# Puzzle found: r1r3k1/p4ppp/2B1p3/3p1b2/4n3/4PN2/PP3PPP/2R2RK1 b - - 0 19, Best move: a8b8, Eval difference: 418
# Puzzle found: 1R6/8/8/8/p7/2k1K3/7r/8 w - - 2 58, Best move: b8a8, Eval difference: 354
# Puzzle found: 2R5/8/8/8/p7/2k1K3/7r/8 b - - 3 58, Best move: c3b2, Eval difference: 346
# Evaluating Maia easiness for FEN: r1r3k1/p4ppp/2B1p3/3p1b2/4n3/4PN2/PP3PPP/2R2RK1 b - - 0 19, Best Move: a8b8
# Evaluating Maia easiness for FEN: 1R6/8/8/8/p7/2k1K3/7r/8 w - - 2 58, Best Move: b8a8
# Evaluating Maia easiness for FEN: 2R5/8/8/8/p7/2k1K3/7r/8 b - - 3 58, Best Move: c3b2
# Analyzing game World Championship Match 1935
# Analyzing game World Championship Match 1935
# Analyzing game World Championship Match 1935
# Puzzle found: 2RR4/p4pkp/4p1p1/Pb2P3/8/7P/5PP1/1r4K1 w - - 5 31, Best move: g1h2, Eval difference: 864
# Evaluating Maia easiness for FEN: 2RR4/p4pkp/4p1p1/Pb2P3/8/7P/5PP1/1r4K1 w - - 5 31, Best Move: g1h2
# Analyzing game World Championship Match 1935
# Puzzle found: 3r2k1/pp3rpp/2pBb3/6p1/P7/2P3P1/4PPBP/3R1RK1 b - - 0 22, Best move: f7d7, Eval difference: 289
# Evaluating Maia easiness for FEN: 3r2k1/pp3rpp/2pBb3/6p1/P7/2P3P1/4PPBP/3R1RK1 b - - 0 22, Best Move: f7d7
# Analyzing game World Championship Match 1935
# Analyzing game World Championship Match 1935
# Puzzle found: r4rk1/ppp1qp1p/3p2p1/3Ppb2/2P1Q3/P1B1P3/1P3PPP/R4RK1 w - - 1 17, Best move: e4f3, Eval difference: 474
# Evaluating Maia easiness for FEN: r4rk1/ppp1qp1p/3p2p1/3Ppb2/2P1Q3/P1B1P3/1P3PPP/R4RK1 w - - 1 17, Best Move: e4f3
# Analyzing game World Championship Match 1935
# Puzzle found: 5k2/p5pp/b3pp2/8/Ppr1PP2/5N2/1R4PP/6K1 w - - 4 31, Best move: f3d2, Eval difference: 214
# Puzzle found: 5k2/p5pp/b3pp2/8/Pp2rP2/1N6/1R4PP/6K1 w - - 0 33, Best move: b3c5, Eval difference: 270
# Puzzle found: 5k2/p5pp/b3pp2/2N5/Pp2rP2/8/1R4PP/6K1 b - - 1 33, Best move: e4e1, Eval difference: 313
# Evaluating Maia easiness for FEN: 5k2/p5pp/b3pp2/8/Ppr1PP2/5N2/1R4PP/6K1 w - - 4 31, Best Move: f3d2
# Evaluating Maia easiness for FEN: 5k2/p5pp/b3pp2/8/Pp2rP2/1N6/1R4PP/6K1 w - - 0 33, Best Move: b3c5
# Evaluating Maia easiness for FEN: 5k2/p5pp/b3pp2/2N5/Pp2rP2/8/1R4PP/6K1 b - - 1 33, Best Move: e4e1
# Analyzing game World Championship Match 1935
# Analyzing game World Championship Match 1935
# Puzzle found: r1b1k2r/pp3ppp/2p1p3/6B1/1b1P4/q1nBPN2/3Q1PPP/R4RK1 b kq - 1 14, Best move: a3b3, Eval difference: 333
# Puzzle found: r1b1k2r/1p4p1/2p1ppN1/p2q2n1/3P4/Q7/5PPP/R4RK1 b kq - 0 21, Best move: g5f3, Eval difference: 340
# Puzzle found: 2k5/8/1pp2r2/p3NPp1/2b3K1/8/8/3R4 b - - 0 42, Best move: c4e2, Eval difference: 239
# Evaluating Maia easiness for FEN: r1b1k2r/pp3ppp/2p1p3/6B1/1b1P4/q1nBPN2/3Q1PPP/R4RK1 b kq - 1 14, Best Move: a3b3
# Evaluating Maia easiness for FEN: r1b1k2r/1p4p1/2p1ppN1/p2q2n1/3P4/Q7/5PPP/R4RK1 b kq - 0 21, Best Move: g5f3
# Evaluating Maia easiness for FEN: 2k5/8/1pp2r2/p3NPp1/2b3K1/8/8/3R4 b - - 0 42, Best Move: c4e2
# Analyzing game World Championship Match 1935
# Puzzle found: r1q2r1k/p2n2pp/1p1N4/2pP4/2P1pP2/1Qb3P1/PP2P2P/R4R1K b - - 0 22, Best move: c8b8, Eval difference: 303
# Puzzle found: 4r3/pN2P3/5k1p/1ppP4/2P5/8/PP1r3P/4R2K w - - 4 45, Best move: e1e6, Eval difference: 231
# Evaluating Maia easiness for FEN: r1q2r1k/p2n2pp/1p1N4/2pP4/2P1pP2/1Qb3P1/PP2P2P/R4R1K b - - 0 22, Best Move: c8b8
# Evaluating Maia easiness for FEN: 4r3/pN2P3/5k1p/1ppP4/2P5/8/PP1r3P/4R2K w - - 4 45, Best Move: e1e6
# Analyzing game World Championship Match 1935
# Puzzle found: R5k1/5pp1/1p2p1p1/8/1P6/2r2P2/P4KPP/8 b - - 1 31, Best move: g8h7, Eval difference: 542
# Evaluating Maia easiness for FEN: R5k1/5pp1/1p2p1p1/8/1P6/2r2P2/P4KPP/8 b - - 1 31, Best Move: g8h7
# Analyzing game World Championship Match 1935
# Puzzle found: 5rk1/1b3pp1/p3p2p/2R5/p1NP2q1/4Q3/1P3PPP/6K1 w - - 4 27, Best move: f2f3, Eval difference: 522
# Puzzle found: 8/8/p6p/4k3/p4p2/2K2P2/1P4NP/5b2 w - - 2 45, Best move: g2e1, Eval difference: 308
# Evaluating Maia easiness for FEN: 5rk1/1b3pp1/p3p2p/2R5/p1NP2q1/4Q3/1P3PPP/6K1 w - - 4 27, Best Move: f2f3
# Evaluating Maia easiness for FEN: 8/8/p6p/4k3/p4p2/2K2P2/1P4NP/5b2 w - - 2 45, Best Move: g2e1
# Analyzing game World Championship Match 1935
# Analyzing game World Championship Match 1935
# Puzzle found: r5r1/pp6/2p1kb1p/7q/PP1PP2n/4BPP1/4NR2/5RK1 w - - 0 28, Best move: e2f4, Eval difference: 813
# Evaluating Maia easiness for FEN: r5r1/pp6/2p1kb1p/7q/PP1PP2n/4BPP1/4NR2/5RK1 w - - 0 28, Best Move: e2f4
# Analyzing analysis_pgns_test/TFFyOff1---1908 Lasker vs. Tarrasch.pgn...
# Loaded 16 games from PGN file analysis_pgns_test/TFFyOff1---1908 Lasker vs. Tarrasch.pgn.
# Analyzing game World Championship Match 1908
# Analyzing game World Championship Match 1908
# Puzzle found: 3rr2k/p1pqbp1p/2pp4/5N2/3QP3/1P6/P1P2KPP/R3R3 b - - 3 18, Best move: f7f6, Eval difference: 9843
# Puzzle found: 3Q4/4r1kp/4r3/8/P2p1p2/1P2b3/2P1R1P1/R2KN1q1 b - - 0 40, Best move: f4f3, Eval difference: 241
# Puzzle found: 3Q4/4r1kp/4r3/8/P2p4/1P2bP2/2P1R3/R2KN1q1 b - - 0 41, Best move: e3g5, Eval difference: 553
# Evaluating Maia easiness for FEN: 3rr2k/p1pqbp1p/2pp4/5N2/3QP3/1P6/P1P2KPP/R3R3 b - - 3 18, Best Move: f7f6
# Evaluating Maia easiness for FEN: 3Q4/4r1kp/4r3/8/P2p1p2/1P2b3/2P1R1P1/R2KN1q1 b - - 0 40, Best Move: f4f3
# Evaluating Maia easiness for FEN: 3Q4/4r1kp/4r3/8/P2p4/1P2bP2/2P1R3/R2KN1q1 b - - 0 41, Best Move: e3g5
# Analyzing game World Championship Match 1908
# Puzzle found: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQR1K1 w kq - 0 7, Best move: a4b3, Eval difference: 324
# Puzzle found: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4R2P/PP3KN1/3q4 b - - 0 36, Best move: d1f3, Eval difference: 313
# Puzzle found: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4Rq1P/PP3KN1/8 w - - 1 37, Best move: f2g1, Eval difference: 9315
# Puzzle found: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4Rq1P/PP4N1/4K3 b - - 2 37, Best move: e5d3, Eval difference: 9138
# Puzzle found: 2b4k/4Q2p/p2p2p1/qp1Bn3/4P3/4Rq1P/PP4N1/4K3 w - - 3 38, Best move: e3c3, Eval difference: 9485
# Evaluating Maia easiness for FEN: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQR1K1 w kq - 0 7, Best Move: a4b3
# Evaluating Maia easiness for FEN: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4R2P/PP3KN1/3q4 b - - 0 36, Best Move: d1f3
# Evaluating Maia easiness for FEN: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4Rq1P/PP3KN1/8 w - - 1 37, Best Move: f2g1
# Evaluating Maia easiness for FEN: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4Rq1P/PP4N1/4K3 b - - 2 37, Best Move: e5d3
# Evaluating Maia easiness for FEN: 2b4k/4Q2p/p2p2p1/qp1Bn3/4P3/4Rq1P/PP4N1/4K3 w - - 3 38, Best Move: e3c3
# Analyzing game World Championship Match 1908
# Puzzle found: 4r1k1/1pp2pp1/1n1p1q1p/2r5/pP1NPP2/2P2Q2/P5PP/3RR1K1 b - - 0 22, Best move: c5c4, Eval difference: 260
# Puzzle found: 6k1/1p3pp1/1n1r1q1p/1N2P3/pp3P2/2P1RQ2/P6P/6K1 b - - 0 28, Best move: f6g6, Eval difference: 519
# Puzzle found: 6k1/1p3pp1/1n1r3p/1N2P3/pp3P2/2P1RQ2/P6P/1q5K w - - 3 30, Best move: h1g2, Eval difference: 207
# Evaluating Maia easiness for FEN: 4r1k1/1pp2pp1/1n1p1q1p/2r5/pP1NPP2/2P2Q2/P5PP/3RR1K1 b - - 0 22, Best Move: c5c4
# Evaluating Maia easiness for FEN: 6k1/1p3pp1/1n1r1q1p/1N2P3/pp3P2/2P1RQ2/P6P/6K1 b - - 0 28, Best Move: f6g6
# Evaluating Maia easiness for FEN: 6k1/1p3pp1/1n1r3p/1N2P3/pp3P2/2P1RQ2/P6P/1q5K w - - 3 30, Best Move: h1g2
# Analyzing game World Championship Match 1908
# Puzzle found: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQR1K1 w kq - 0 7, Best move: a4b3, Eval difference: 321
# Puzzle found: r1r3k1/3nbp2/pq1pb2p/1p2P1p1/3p4/3Q2BP/PP3PP1/1B1RRNK1 b - - 0 22, Best move: d7f8, Eval difference: 219
# Puzzle found: 5k1r/2r2b2/p1q5/1p1pRN2/8/4Q2P/PP4P1/4R2K w - - 4 38, Best move: e3g5, Eval difference: 263
# Evaluating Maia easiness for FEN: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQR1K1 w kq - 0 7, Best Move: a4b3
# Evaluating Maia easiness for FEN: r1r3k1/3nbp2/pq1pb2p/1p2P1p1/3p4/3Q2BP/PP3PP1/1B1RRNK1 b - - 0 22, Best Move: d7f8
# Evaluating Maia easiness for FEN: 5k1r/2r2b2/p1q5/1p1pRN2/8/4Q2P/PP4P1/4R2K w - - 4 38, Best Move: e3g5
# Analyzing game World Championship Match 1908
# Analyzing game World Championship Match 1908
# Puzzle found: 3r4/p3kp1p/5p2/1Rn1p3/8/2P1P1N1/P1P2RPP/3r2K1 w - - 5 24, Best move: f2f1, Eval difference: 256
# Evaluating Maia easiness for FEN: 3r4/p3kp1p/5p2/1Rn1p3/8/2P1P1N1/P1P2RPP/3r2K1 w - - 5 24, Best Move: f2f1
# Analyzing game World Championship Match 1908
# Puzzle found: r1bq1rk1/p1ppbppp/8/2p1P3/3B4/2N5/PPP1QPPP/R3R1K1 w - - 0 14, Best move: d4e3, Eval difference: 301
# Evaluating Maia easiness for FEN: r1bq1rk1/p1ppbppp/8/2p1P3/3B4/2N5/PPP1QPPP/R3R1K1 w - - 0 14, Best Move: d4e3
# Analyzing game World Championship Match 1908
# Analyzing game World Championship Match 1908
# Puzzle found: r1bq1rk1/p1ppbppp/8/2p1P3/3B4/2N5/PPP1QPPP/R3R1K1 w - - 0 14, Best move: d4e3, Eval difference: 318
# Evaluating Maia easiness for FEN: r1bq1rk1/p1ppbppp/8/2p1P3/3B4/2N5/PPP1QPPP/R3R1K1 w - - 0 14, Best Move: d4e3
# Analyzing game World Championship Match 1908
# Puzzle found: 2r1k1r1/7p/p2Qpp2/2n2p2/1pP5/5BP1/Pq3P1P/3RR1K1 w - - 0 26, Best move: f3h5, Eval difference: 9339
# Evaluating Maia easiness for FEN: 2r1k1r1/7p/p2Qpp2/2n2p2/1pP5/5BP1/Pq3P1P/3RR1K1 w - - 0 26, Best Move: f3h5
# Analyzing game World Championship Match 1908
# Puzzle found: 2r3n1/2p2p2/pp3k1p/4R3/8/2B5/PPP3PP/6K1 b - - 3 31, Best move: f6g6, Eval difference: 421
# Puzzle found: 3r2n1/2p2p2/pp4kp/8/8/2B3R1/PPP3PP/6K1 b - - 7 33, Best move: g6f5, Eval difference: 246
# Evaluating Maia easiness for FEN: 2r3n1/2p2p2/pp3k1p/4R3/8/2B5/PPP3PP/6K1 b - - 3 31, Best Move: f6g6
# Evaluating Maia easiness for FEN: 3r2n1/2p2p2/pp4kp/8/8/2B3R1/PPP3PP/6K1 b - - 7 33, Best Move: g6f5
# Analyzing game World Championship Match 1908
# Analyzing game World Championship Match 1908
# Puzzle found: r1bq1rk1/p1ppbppp/8/2p1P3/3B4/2N5/PPP1QPPP/R3R1K1 w - - 0 14, Best move: d4e3, Eval difference: 327
# Puzzle found: 3r4/4kppp/8/1P1b2B1/8/7P/5PP1/1R4K1 b - - 6 35, Best move: f7f6, Eval difference: 439
# Puzzle found: 8/1kR5/1P3rp1/5P2/4b3/4B1K1/8/8 b - - 1 61, Best move: b7a6, Eval difference: 309
# Evaluating Maia easiness for FEN: r1bq1rk1/p1ppbppp/8/2p1P3/3B4/2N5/PPP1QPPP/R3R1K1 w - - 0 14, Best Move: d4e3
# Evaluating Maia easiness for FEN: 3r4/4kppp/8/1P1b2B1/8/7P/5PP1/1R4K1 b - - 6 35, Best Move: f7f6
# Evaluating Maia easiness for FEN: 8/1kR5/1P3rp1/5P2/4b3/4B1K1/8/8 b - - 1 61, Best Move: b7a6
# Analyzing game World Championship Match 1908
# Analyzing game World Championship Match 1908
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 172
#     163                 all_puzzles.append({
#     164                     "fen": fen,
#     165                     "best_move": best_move,
#    (...)
#     168                     "maia_easiness": maia_easiness
#     169                 })
#     171 # Sort and save results
# --> 172 sort_and_save_results(all_puzzles)
#     173 print("Classic puzzles analysis complete. Results saved.")
#
# Cell In[2], line 144, in sort_and_save_results(puzzles, output_dir)
#     135         csvwriter.writerow([
#     136             puzzle["fen"],
#     137             puzzle["best_move"].uci(),  # Convert Move object to UCI notation
#    (...)
#     140             puzzle["average_easiness"]
#     141         ])
#     143 with open(json_file_path, "w") as jsonfile:
# --> 144     json.dump(puzzles, jsonfile, indent=4)
#
# File ~/miniconda3/envs/CSSLAB/lib/python3.8/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~/miniconda3/envs/CSSLAB/lib/python3.8/json/encoder.py:429, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     427     yield _floatstr(o)
#     428 elif isinstance(o, (list, tuple)):
# --> 429     yield from _iterencode_list(o, _current_indent_level)
#     430 elif isinstance(o, dict):
#     431     yield from _iterencode_dict(o, _current_indent_level)
#
# File ~/miniconda3/envs/CSSLAB/lib/python3.8/json/encoder.py:325, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     323         else:
#     324             chunks = _iterencode(value, _current_indent_level)
# --> 325         yield from chunks
#     326 if newline_indent is not None:
#     327     _current_indent_level -= 1
#
# File ~/miniconda3/envs/CSSLAB/lib/python3.8/json/encoder.py:405, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     403         else:
#     404             chunks = _iterencode(value, _current_indent_level)
# --> 405         yield from chunks
#     406 if newline_indent is not None:
#     407     _current_indent_level -= 1
#
# File ~/miniconda3/envs/CSSLAB/lib/python3.8/json/encoder.py:438, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     436         raise ValueError("Circular reference detected")
#     437     markers[markerid] = o
# --> 438 o = _default(o)
#     439 yield from _iterencode(o, _current_indent_level)
#     440 if markers is not None:
#
# File ~/miniconda3/envs/CSSLAB/lib/python3.8/json/encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type Move is not JSON serializable

# %%
best_move
# Out:
# Move.from_uci('b7a6')
