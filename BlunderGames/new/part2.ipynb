# %%
# Part 1: Initialization and Loading PGN Files

# Import required libraries
import chess
import chess.engine
import chess.pgn
import subprocess
import os
import json
import csv
from IPython.display import display

# Paths to your engines and Maia models
stockfish_path = "/opt/homebrew/bin/stockfish"
maia_model_paths = {
    1100: "maia_weights/maia-1100.pb.gz",
    1200: "maia_weights/maia-1200.pb.gz",
    1300: "maia_weights/maia-1300.pb.gz",
    1400: "maia_weights/maia-1400.pb.gz",
    1500: "maia_weights/maia-1500.pb.gz",
    1600: "maia_weights/maia-1600.pb.gz",
    1700: "maia_weights/maia-1700.pb.gz",
    1800: "maia_weights/maia-1800.pb.gz",
    1900: "maia_weights/maia-1900.pb.gz",
}

# Initialize Stockfish engine
print("Initializing Stockfish engine...")
stockfish_engine = chess.engine.SimpleEngine.popen_uci(stockfish_path)
print("Stockfish engine initialized.")

# Initialize Maia engines
print("Initializing Maia engines...")
maia_engines = {}
for elo, path in maia_model_paths.items():
    maia_engines[elo] = chess.engine.SimpleEngine.popen_uci(["lc0", f"--weights={path}"])
    print(f"Maia {elo} engine initialized.")
print("Maia engines initialized.")
# Function to load games from a PGN file
def load_games_from_pgn(file_path):
    games = []
    with open(file_path, 'r') as pgn_file:
        while True:
            game = chess.pgn.read_game(pgn_file)
            if game is None:
                break
            games.append(game)
    print(f"Loaded {len(games)} games from PGN file {file_path}.")
    return games
# Out:
# Initializing Stockfish engine...
# <UciProtocol (pid=18149)>: stderr >>        _
# <UciProtocol (pid=18149)>: stderr >> |   _ | |
# <UciProtocol (pid=18149)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18151)>: stderr >>        _
# <UciProtocol (pid=18151)>: stderr >> |   _ | |
# <UciProtocol (pid=18151)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18152)>: stderr >>        _
# <UciProtocol (pid=18152)>: stderr >> |   _ | |
# <UciProtocol (pid=18152)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18153)>: stderr >>        _
# <UciProtocol (pid=18153)>: stderr >> |   _ | |
# <UciProtocol (pid=18153)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18154)>: stderr >>        _
# <UciProtocol (pid=18154)>: stderr >> |   _ | |
# <UciProtocol (pid=18154)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18155)>: stderr >>        _
# <UciProtocol (pid=18155)>: stderr >> |   _ | |
# <UciProtocol (pid=18155)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18157)>: stderr >>        _
# <UciProtocol (pid=18157)>: stderr >> |   _ | |
# <UciProtocol (pid=18157)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18158)>: stderr >>        _
# <UciProtocol (pid=18158)>: stderr >> |   _ | |
# <UciProtocol (pid=18158)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18159)>: stderr >>        _
# <UciProtocol (pid=18159)>: stderr >> |   _ | |
# <UciProtocol (pid=18159)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# Stockfish engine initialized.
# Initializing Maia engines...
# Maia 1100 engine initialized.
# Maia 1200 engine initialized.
# Maia 1300 engine initialized.
# Maia 1400 engine initialized.
# Maia 1500 engine initialized.
# Maia 1600 engine initialized.
# Maia 1700 engine initialized.
# Maia 1800 engine initialized.
# Maia 1900 engine initialized.
# Maia engines initialized.

# %%
# Function to find classic puzzles in a game with enhanced debugging
def find_classic_puzzles_with_debug(game, stockfish_engine, threshold=200):
    board = game.board()
    puzzles = []

    for move in game.mainline_moves():
        fen_before = board.fen()
        player = board.turn  # True for White, False for Black

        print(f"Analyzing position: {fen_before}")

        # Analyze the position before the move
        info = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1), multipv=2)
        if len(info) < 2:
            print(f"Insufficient moves found in analysis.")
            continue

        best_move = info[0]["pv"][0]
        best_eval = info[0]["score"].relative.score(mate_score=10000)
        second_best_eval = info[1]["score"].relative.score(mate_score=10000)

        print(f"Best move: {best_move}, Eval: {best_eval}, Second best move eval: {second_best_eval}")

        # Check if the difference is large enough
        if abs(best_eval - second_best_eval) >= threshold:
            print(f"Eval difference is large enough: {abs(best_eval - second_best_eval)}")

            board.push(best_move)
            is_capture = board.is_capture(best_move)
            board.pop()

            print(f"Move {best_move} is a capture: {is_capture}")

            if not is_capture:
                puzzles.append((fen_before, best_move, best_eval, second_best_eval))
                print(f"Puzzle found: {fen_before}, Best move: {best_move}, Eval difference: {abs(best_eval - second_best_eval)}")
            else:
                print(f"Best move is a simple capture, skipping: {best_move}")
        else:
            print(f"Eval difference is too small: {abs(best_eval - second_best_eval)}")

        board.push(move)

    print(f"Total puzzles found in game: {len(puzzles)}")
    return puzzles

# Function to load games from a PGN file
def load_games_from_pgn(file_path):
    games = []
    with open(file_path, 'r') as pgn_file:
        while True:
            game = chess.pgn.read_game(pgn_file)
            if game is None:
                break
            games.append(game)
    print(f"Loaded {len(games)} games from PGN file {file_path}.")
    return games

# Function to evaluate Maia easiness
def evaluate_maia_easiness(fen, best_move, maia_engines):
    board = chess.Board(fen)
    easiness_scores = {}

    for elo, engine in maia_engines.items():
        result = engine.analyse(board, chess.engine.Limit(nodes=1))
        if "pv" in result and best_move in result["pv"]:
            easiness_scores[elo] = result["pv"].index(best_move) / len(result["pv"])

    return easiness_scores

# Function to sort and save results
def sort_and_save_results(puzzles, output_dir="results/classic_puzzles"):
    os.makedirs(output_dir, exist_ok=True)
    puzzles.sort(key=lambda x: max(x["maia_easiness"].values(), default=1), reverse=True)

    csv_file_path = os.path.join(output_dir, "classic_puzzles.csv")
    json_file_path = os.path.join(output_dir, "classic_puzzles.json")

    with open(csv_file_path, "w", newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(["FEN", "Best Move", "Best Eval", "Second Best Eval", "Maia Easiness"])
        for puzzle in puzzles:
            maia_easiness = max(puzzle["maia_easiness"].values(), default=1)
            csvwriter.writerow([puzzle["fen"], puzzle["best_move"], puzzle["best_eval"], puzzle["second_best_eval"], maia_easiness])

    with open(json_file_path, "w") as jsonfile:
        json.dump(puzzles, jsonfile, indent=4)

# Load PGN files and find classic puzzles
pgn_directory = "analysis_pgns_test"
all_puzzles = []

print("Starting to find classic puzzles in PGN files...")

for pgn_file in os.listdir(pgn_directory):
    if pgn_file.endswith(".pgn"):
        pgn_file_path = os.path.join(pgn_directory, pgn_file)
        print(f"Analyzing {pgn_file_path}...")
        all_games = load_games_from_pgn(pgn_file_path)

        for game in all_games:
            print(f"Analyzing game {game.headers.get('Event', 'Unknown Event')}")
            puzzles = find_classic_puzzles_with_debug(game, stockfish_engine)
            for fen, best_move, best_eval, second_best_eval in puzzles:
                maia_easiness = evaluate_maia_easiness(fen, best_move, maia_engines)
                all_puzzles.append({
                    "fen": fen,
                    "best_move": best_move,
                    "best_eval": best_eval,
                    "second_best_eval": second_best_eval,
                    "maia_easiness": maia_easiness
                })

            print(f"Total puzzles after game: {len(all_puzzles)}")

# Sort and save results
sort_and_save_results(all_puzzles)
print("Classic puzzles analysis complete. Results saved.")
# Out:
# Starting to find classic puzzles in PGN files...
# Analyzing analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn...
# Loaded 4 games from PGN file analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn.
# Analyzing game FIDE World Championship Match 1969
# Analyzing position: rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1
# Best move: e2e4, Eval: 33, Second best move eval: 23
# Eval difference is too small: 10
# Analyzing position: rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1
# Best move: c7c5, Eval: -32, Second best move eval: -37
# Eval difference is too small: 5
# Analyzing position: rnbqkbnr/pp1ppppp/8/2p5/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Best move: g1f3, Eval: 26, Second best move eval: 24
# Eval difference is too small: 2
# Analyzing position: rnbqkbnr/pp1ppppp/8/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 2
# Best move: d7d6, Eval: -32, Second best move eval: -40
# Eval difference is too small: 8
# Analyzing position: rnbqkbnr/pp1p1ppp/4p3/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R w KQkq - 0 3
# Best move: b1c3, Eval: 44, Second best move eval: 42
# Eval difference is too small: 2
# Analyzing position: rnbqkbnr/pp1p1ppp/4p3/2p5/3PP3/5N2/PPP2PPP/RNBQKB1R b KQkq - 0 3
# Best move: c5d4, Eval: -46, Second best move eval: -61
# Eval difference is too small: 15
# Analyzing position: rnbqkbnr/pp1p1ppp/4p3/8/3pP3/5N2/PPP2PPP/RNBQKB1R w KQkq - 0 4
# Best move: f3d4, Eval: 47, Second best move eval: 24
# Eval difference is too small: 23
# Analyzing position: rnbqkbnr/pp1p1ppp/4p3/8/3NP3/8/PPP2PPP/RNBQKB1R b KQkq - 0 4
# Best move: b8c6, Eval: -41, Second best move eval: -43
# Eval difference is too small: 2
# Analyzing position: rnbqkbnr/1p1p1ppp/p3p3/8/3NP3/8/PPP2PPP/RNBQKB1R w KQkq - 0 5
# Best move: d1f3, Eval: 49, Second best move eval: 47
# Eval difference is too small: 2
# Analyzing position: rnbqkbnr/1p1p1ppp/p3p3/8/3NP3/3B4/PPP2PPP/RNBQK2R b KQkq - 1 5
# Best move: d7d5, Eval: -45, Second best move eval: -46
# Eval difference is too small: 1
# Analyzing position: r1bqkbnr/1p1p1ppp/p1n1p3/8/3NP3/3B4/PPP2PPP/RNBQK2R w KQkq - 2 6
# Best move: d4c6, Eval: 61, Second best move eval: 53
# Eval difference is too small: 8
# Analyzing position: r1bqkbnr/1p1p1ppp/p1N1p3/8/4P3/3B4/PPP2PPP/RNBQK2R b KQkq - 0 6
# Best move: d7c6, Eval: -54, Second best move eval: -59
# Eval difference is too small: 5
# Analyzing position: r1bqkbnr/3p1ppp/p1p1p3/8/4P3/3B4/PPP2PPP/RNBQK2R w KQkq - 0 7
# Best move: b1d2, Eval: 69, Second best move eval: 63
# Eval difference is too small: 6
# Analyzing position: r1bqkbnr/3p1ppp/p1p1p3/8/4P3/3B4/PPP2PPP/RNBQ1RK1 b kq - 1 7
# Best move: d8c7, Eval: -67, Second best move eval: -74
# Eval difference is too small: 7
# Analyzing position: r1bqkbnr/5ppp/p1p1p3/3p4/4P3/3B4/PPP2PPP/RNBQ1RK1 w kq - 0 8
# Best move: f1e1, Eval: 65, Second best move eval: 62
# Eval difference is too small: 3
# Analyzing position: r1bqkbnr/5ppp/p1p1p3/3p4/4P3/3B4/PPPN1PPP/R1BQ1RK1 b kq - 1 8
# Best move: f8d6, Eval: -57, Second best move eval: -55
# Eval difference is too small: 2
# Analyzing position: r1bqkb1r/5ppp/p1p1pn2/3p4/4P3/3B4/PPPN1PPP/R1BQ1RK1 w kq - 2 9
# Best move: f1e1, Eval: 54, Second best move eval: 47
# Eval difference is too small: 7
# Analyzing position: r1bqkb1r/5ppp/p1p1pn2/3p4/4P3/3B4/PPPNQPPP/R1B2RK1 b kq - 3 9
# Best move: a6a5, Eval: -42, Second best move eval: -44
# Eval difference is too small: 2
# Analyzing position: r1bqk2r/4bppp/p1p1pn2/3p4/4P3/3B4/PPPNQPPP/R1B2RK1 w kq - 4 10
# Best move: e4e5, Eval: 41, Second best move eval: 41
# Eval difference is too small: 0
# Analyzing position: r1bqk2r/4bppp/p1p1pn2/3p4/4P3/1P1B4/P1PNQPPP/R1B2RK1 b kq - 0 10
# Best move: e8g8, Eval: -32, Second best move eval: -32
# Eval difference is too small: 0
# Analyzing position: r1bq1rk1/4bppp/p1p1pn2/3p4/4P3/1P1B4/P1PNQPPP/R1B2RK1 w - - 1 11
# Best move: c1b2, Eval: 34, Second best move eval: 26
# Eval difference is too small: 8
# Analyzing position: r1bq1rk1/4bppp/p1p1pn2/3p4/4P3/1P1B4/PBPNQPPP/R4RK1 b - - 2 11
# Best move: a6a5, Eval: -32, Second best move eval: -37
# Eval difference is too small: 5
# Analyzing position: r1bq1rk1/4bppp/2p1pn2/p2p4/4P3/1P1B4/PBPNQPPP/R4RK1 w - - 0 12
# Best move: c2c4, Eval: 33, Second best move eval: 34
# Eval difference is too small: 1
# Analyzing position: r1bq1rk1/4bppp/2p1pn2/p2p4/4PP2/1P1B4/PBPNQ1PP/R4RK1 b - - 0 12
# Best move: a5a4, Eval: 10, Second best move eval: 0
# Eval difference is too small: 10
# Analyzing position: r1bq1rk1/4bp1p/2p1pnp1/p2p4/4PP2/1P1B4/PBPNQ1PP/R4RK1 w - - 0 13
# Best move: g1h1, Eval: 48, Second best move eval: 54
# Eval difference is too small: 6
# Analyzing position: r1bq1rk1/4bp1p/2p1pnp1/p2p4/4PP2/1P1B4/PBPNQ1PP/3R1RK1 b - - 1 13
# Best move: a5a4, Eval: -21, Second best move eval: -60
# Eval difference is too small: 39
# Analyzing position: r1bq1rk1/3nbp1p/2p1p1p1/p2p4/4PP2/1P1B4/PBPNQ1PP/3R1RK1 w - - 2 14
# Best move: f4f5, Eval: 55, Second best move eval: 48
# Eval difference is too small: 7
# Analyzing position: r1bq1rk1/3nbp1p/2p1p1p1/p2p4/2P1PP2/1P1B4/PB1NQ1PP/3R1RK1 b - - 0 14
# Best move: a5a4, Eval: -44, Second best move eval: -54
# Eval difference is too small: 10
# Analyzing position: r1bq1rk1/3nbp1p/2p1p1p1/3p4/p1P1PP2/1P1B4/PB1NQ1PP/3R1RK1 w - - 0 15
# Best move: g1h1, Eval: 46, Second best move eval: 31
# Eval difference is too small: 15
# Analyzing position: r1bq1rk1/3nbp1p/2p1p1p1/3p1P2/p1P1P3/1P1B4/PB1NQ1PP/3R1RK1 b - - 0 15
# Best move: a4b3, Eval: 0, Second best move eval: -9
# Eval difference is too small: 9
# Analyzing position: r1bq1rk1/3nbp1p/2p3p1/3p1p2/p1P1P3/1P1B4/PB1NQ1PP/3R1RK1 w - - 0 16
# Best move: e4f5, Eval: 17, Second best move eval: -5
# Eval difference is too small: 22
# Analyzing position: r1bq1rk1/3nbp1p/2p3p1/3p1P2/p1P5/1P1B4/PB1NQ1PP/3R1RK1 b - - 0 16
# Best move: e7f6, Eval: -13, Second best move eval: -18
# Eval difference is too small: 5
# Analyzing position: r1bq1rk1/3n1p1p/2p2bp1/3p1P2/p1P5/1P1B4/PB1NQ1PP/3R1RK1 w - - 1 17
# Best move: b2f6, Eval: 4, Second best move eval: -3
# Eval difference is too small: 7
# Analyzing position: r1bq1rk1/3n1p1p/2p2Bp1/3p1P2/p1P5/1P1B4/P2NQ1PP/3R1RK1 b - - 0 17
# Best move: d7f6, Eval: -5, Second best move eval: -25
# Eval difference is too small: 20
# Analyzing position: r1bq1rk1/5p1p/2p2np1/3p1P2/p1P5/1P1B4/P2NQ1PP/3R1RK1 w - - 0 18
# Best move: b3b4, Eval: 0, Second best move eval: -2
# Eval difference is too small: 2
# Analyzing position: r1bq1rk1/5p1p/2p2np1/3p1P2/p1P5/1P1B4/P2N1QPP/3R1RK1 b - - 1 18
# Best move: f6g4, Eval: 6, Second best move eval: 3
# Eval difference is too small: 3
# Analyzing position: r1bq1rk1/5p1p/2p2np1/3p1P2/2P5/1p1B4/P2N1QPP/3R1RK1 w - - 0 19
# Best move: a2b3, Eval: 0, Second best move eval: -7
# Eval difference is too small: 7
# Analyzing position: r1bq1rk1/5p1p/2p2np1/3p1P2/2P5/1P1B4/3N1QPP/3R1RK1 b - - 0 19
# Best move: f6g4, Eval: 5, Second best move eval: -32
# Eval difference is too small: 37
# Analyzing position: 2bq1rk1/5p1p/2p2np1/3p1P2/2P5/1P1B4/r2N1QPP/3R1RK1 w - - 1 20
# Best move: f5g6, Eval: 43, Second best move eval: 42
# Eval difference is too small: 1
# Analyzing position: 2bq1rk1/5p1p/2p2nP1/3p4/2P5/1P1B4/r2N1QPP/3R1RK1 b - - 0 20
# Best move: f7g6, Eval: -41, Second best move eval: -206
# Eval difference is too small: 165
# Analyzing position: 2bq1rk1/7p/2p2np1/3p4/2P5/1P1B4/r2N1QPP/3R1RK1 w - - 0 21
# Best move: f2d4, Eval: 39, Second best move eval: 34
# Eval difference is too small: 5
# Analyzing position: 2bq1rk1/7p/2p2np1/3p4/2P5/1P1B3P/r2N1QP1/3R1RK1 b - - 0 21
# Best move: f6h5, Eval: -20, Second best move eval: -30
# Eval difference is too small: 10
# Analyzing position: 2b2rk1/4q2p/2p2np1/3p4/2P5/1P1B3P/r2N1QP1/3R1RK1 w - - 1 22
# Best move: d3b1, Eval: 26, Second best move eval: 19
# Eval difference is too small: 7
# Analyzing position: 2b2rk1/4q2p/2p2np1/3p4/2PQ4/1P1B3P/r2N2P1/3R1RK1 b - - 2 22
# Best move: c6c5, Eval: 6, Second best move eval: -55
# Eval difference is too small: 61
# Analyzing position: 2b2rk1/4q2p/5np1/2pp4/2PQ4/1P1B3P/r2N2P1/3R1RK1 w - - 0 23
# Best move: d4f4, Eval: -18, Second best move eval: -19
# Eval difference is too small: 1
# Analyzing position: 2b2rk1/4q2p/5np1/2pp4/2P2Q2/1P1B3P/r2N2P1/3R1RK1 b - - 1 23
# Best move: d5d4, Eval: 14, Second best move eval: -45
# Eval difference is too small: 59
# Analyzing position: 5rk1/1b2q2p/5np1/2pp4/2P2Q2/1P1B3P/r2N2P1/3R1RK1 w - - 2 24
# Best move: f4g5, Eval: 74, Second best move eval: 46
# Eval difference is too small: 28
# Analyzing position: 5rk1/1b2q2p/5np1/2pp4/2P2Q2/1P1B3P/r2N2P1/4RRK1 b - - 3 24
# Best move: f6h5, Eval: 83, Second best move eval: -28
# Eval difference is too small: 111
# Analyzing position: 5rk1/1b4qp/5np1/2pp4/2P2Q2/1P1B3P/r2N2P1/4RRK1 w - - 4 25
# Best move: f4g5, Eval: 63, Second best move eval: 45
# Eval difference is too small: 18
# Analyzing position: 5rk1/1b4qp/5np1/2pp4/2P5/1P1BQ2P/r2N2P1/4RRK1 b - - 5 25
# Best move: d5d4, Eval: 12, Second best move eval: -37
# Eval difference is too small: 49
# Analyzing position: 5rk1/1b4qp/5np1/2p5/2Pp4/1P1BQ2P/r2N2P1/4RRK1 w - - 0 26
# Best move: e3f4, Eval: -5, Second best move eval: -31
# Eval difference is too small: 26
# Analyzing position: 5rk1/1b4qp/4Qnp1/2p5/2Pp4/1P1B3P/r2N2P1/4RRK1 b - - 1 26
# Best move: g7f7, Eval: 45, Second best move eval: -129
# Eval difference is too small: 174
# Analyzing position: 5rk1/1b3q1p/4Qnp1/2p5/2Pp4/1P1B3P/r2N2P1/4RRK1 w - - 2 27
# Best move: e6e2, Eval: -26, Second best move eval: -28
# Eval difference is too small: 2
# Analyzing position: 5rk1/1b3q1p/5np1/2p5/2Pp4/1P1B3P/r2NQ1P1/4RRK1 b - - 3 27
# Best move: f8e8, Eval: 69, Second best move eval: 62
# Eval difference is too small: 7
# Analyzing position: 4r1k1/1b3q1p/5np1/2p5/2Pp4/1P1B3P/r2NQ1P1/4RRK1 w - - 4 28
# Best move: e2f2, Eval: -59, Second best move eval: -61
# Eval difference is too small: 2
# Analyzing position: 4r1k1/1b3q1p/5np1/2p5/2Pp4/1P1B3P/r2N1QP1/4RRK1 b - - 5 28
# Best move: e8e1, Eval: 62, Second best move eval: 38
# Eval difference is too small: 24
# Analyzing position: 6k1/1b3q1p/5np1/2p5/2Pp4/1P1B3P/r2N1QP1/4rRK1 w - - 0 29
# Best move: f2e1, Eval: -41, Second best move eval: -106
# Eval difference is too small: 65
# Analyzing position: 6k1/1b3q1p/5np1/2p5/2Pp4/1P1B3P/r2N2P1/4QRK1 b - - 0 29
# Best move: f7e8, Eval: 32, Second best move eval: 32
# Eval difference is too small: 0
# Analyzing position: 4q1k1/1b5p/5np1/2p5/2Pp4/1P1B3P/r2N2P1/4QRK1 w - - 1 30
# Best move: e1e8, Eval: -42, Second best move eval: -117
# Eval difference is too small: 75
# Analyzing position: 4Q1k1/1b5p/5np1/2p5/2Pp4/1P1B3P/r2N2P1/5RK1 b - - 0 30
# Best move: f6e8, Eval: 29, Second best move eval: -798
# Eval difference is large enough: 827
# Move f6e8 is a capture: True
# Best move is a simple capture, skipping: f6e8
# Analyzing position: 4n1k1/1b5p/6p1/2p5/2Pp4/1P1B3P/r2N2P1/5RK1 w - - 0 31
# Best move: f1f2, Eval: -27, Second best move eval: -54
# Eval difference is too small: 27
# Analyzing position: 4n1k1/1b5p/6p1/2p5/2PpB3/1P5P/r2N2P1/5RK1 b - - 1 31
# Best move: a2d2, Eval: 68, Second best move eval: 51
# Eval difference is too small: 17
# Analyzing position: 4n1k1/1b5p/6p1/2p5/2PpB3/1P5P/3r2P1/5RK1 w - - 0 32
# Best move: e4b7, Eval: -70, Second best move eval: -420
# Eval difference is large enough: 350
# Move e4b7 is a capture: True
# Best move is a simple capture, skipping: e4b7
# Analyzing position: 4n1k1/1B5p/6p1/2p5/2Pp4/1P5P/3r2P1/5RK1 b - - 0 32
# Best move: d2b2, Eval: 67, Second best move eval: 51
# Eval difference is too small: 16
# Analyzing position: 6k1/1B5p/3n2p1/2p5/2Pp4/1P5P/3r2P1/5RK1 w - - 1 33
# Best move: b7d5, Eval: -35, Second best move eval: -67
# Eval difference is too small: 32
# Analyzing position: 6k1/7p/3n2p1/2pB4/2Pp4/1P5P/3r2P1/5RK1 b - - 2 33
# Best move: g8g7, Eval: 42, Second best move eval: 6
# Eval difference is too small: 36
# Analyzing position: 8/6kp/3n2p1/2pB4/2Pp4/1P5P/3r2P1/5RK1 w - - 3 34
# Best move: g2g4, Eval: -34, Second best move eval: -49
# Eval difference is too small: 15
# Analyzing position: 8/6kp/3n2p1/2pB4/1PPp4/7P/3r2P1/5RK1 b - - 0 34
# Best move: c5b4, Eval: 80, Second best move eval: 3
# Eval difference is too small: 77
# Analyzing position: 8/6kp/3n2p1/3B4/1pPp4/7P/3r2P1/5RK1 w - - 0 35
# Best move: c4c5, Eval: -66, Second best move eval: -153
# Eval difference is too small: 87
# Analyzing position: 8/6kp/3n2p1/2PB4/1p1p4/7P/3r2P1/5RK1 b - - 0 35
# Best move: d6f5, Eval: 70, Second best move eval: 11
# Eval difference is too small: 59
# Analyzing position: 8/6kp/6p1/2PB1n2/1p1p4/7P/3r2P1/5RK1 w - - 1 36
# Best move: c5c6, Eval: -39, Second best move eval: -78
# Eval difference is too small: 39
# Analyzing position: 8/6kp/2P3p1/3B1n2/1p1p4/7P/3r2P1/5RK1 b - - 0 36
# Best move: d2b2, Eval: 43, Second best move eval: 40
# Eval difference is too small: 3
# Analyzing position: 8/6kp/2P3p1/3B1n2/1p1p4/7P/2r3P1/5RK1 w - - 1 37
# Best move: d5e4, Eval: -41, Second best move eval: -58
# Eval difference is too small: 17
# Analyzing position: 8/6kp/2P3p1/3B1n2/1p1p2P1/7P/2r5/5RK1 b - - 0 37
# Best move: f5d6, Eval: 79, Second best move eval: 76
# Eval difference is too small: 3
# Analyzing position: 8/6kp/2Pn2p1/3B4/1p1p2P1/7P/2r5/5RK1 w - - 1 38
# Best move: f1f4, Eval: -92, Second best move eval: -109
# Eval difference is too small: 17
# Analyzing position: 8/6kp/2Pn2p1/3B4/1p1p1RP1/7P/2r5/6K1 b - - 2 38
# Best move: d4d3, Eval: 99, Second best move eval: 33
# Eval difference is too small: 66
# Analyzing position: 8/6kp/2Pn2p1/3B4/1p3RP1/3p3P/2r5/6K1 w - - 0 39
# Best move: f4d4, Eval: -118, Second best move eval: -125
# Eval difference is too small: 7
# Analyzing position: 8/6kp/2Pn2p1/3B4/1p1R2P1/3p3P/2r5/6K1 b - - 1 39
# Best move: c2c3, Eval: 133, Second best move eval: 79
# Eval difference is too small: 54
# Analyzing position: 8/6kp/2Pn2p1/3B4/1p1R2P1/7P/2rp4/6K1 w - - 0 40
# Best move: d5b3, Eval: -87, Second best move eval: -292
# Eval difference is large enough: 205
# Move d5b3 is a capture: True
# Best move is a simple capture, skipping: d5b3
# Analyzing position: 8/6kp/2Pn2p1/8/1p1R2P1/1B5P/2rp4/6K1 b - - 1 40
# Best move: c2c6, Eval: 96, Second best move eval: 24
# Eval difference is too small: 72
# Analyzing position: 8/6kp/2rn2p1/8/1p1R2P1/1B5P/3p4/6K1 w - - 0 41
# Best move: d4d2, Eval: -102, Second best move eval: -133
# Eval difference is too small: 31
# Analyzing position: 8/6kp/2rn2p1/8/1p4P1/1B5P/3R4/6K1 b - - 0 41
# Best move: d6e4, Eval: 95, Second best move eval: 95
# Eval difference is too small: 0
# Analyzing position: 8/6kp/2r3p1/8/1p2n1P1/1B5P/3R4/6K1 w - - 1 42
# Best move: d2d7, Eval: -86, Second best move eval: -130
# Eval difference is too small: 44
# Analyzing position: 8/3R2kp/2r3p1/8/1p2n1P1/1B5P/8/6K1 b - - 2 42
# Best move: g7h6, Eval: 52, Second best move eval: 32
# Eval difference is too small: 20
# Analyzing position: 8/3R3p/2r2kp1/8/1p2n1P1/1B5P/8/6K1 w - - 3 43
# Best move: d7d4, Eval: -25, Second best move eval: -26
# Eval difference is too small: 1
# Analyzing position: 8/7R/2r2kp1/8/1p2n1P1/1B5P/8/6K1 b - - 0 43
# Best move: c6c3, Eval: 117, Second best move eval: 106
# Eval difference is too small: 11
# Analyzing position: 8/7R/5kp1/8/1p2n1P1/1B5P/8/2r3K1 w - - 1 44
# Best move: g1g2, Eval: -73, Second best move eval: -116
# Eval difference is too small: 43
# Analyzing position: 8/7R/5kp1/8/1p2n1P1/1B5P/6K1/2r5 b - - 2 44
# Best move: c1c3, Eval: 67, Second best move eval: 51
# Eval difference is too small: 16
# Analyzing position: 8/7R/5kp1/2n5/1p4P1/1B5P/6K1/2r5 w - - 3 45
# Best move: h7f7, Eval: -48, Second best move eval: -144
# Eval difference is too small: 96
# Analyzing position: 8/5B1R/5kp1/2n5/1p4P1/7P/6K1/2r5 b - - 4 45
# Best move: c1c2, Eval: 142, Second best move eval: 108
# Eval difference is too small: 34
# Analyzing position: 8/5B1R/5kp1/2n5/6P1/1p5P/6K1/2r5 w - - 0 46
# Best move: f7b3, Eval: -117, Second best move eval: -108
# Eval difference is too small: 9
# Analyzing position: 8/5B1R/5kp1/2n3P1/8/1p5P/6K1/2r5 b - - 0 46
# Best move: f6g5, Eval: 116, Second best move eval: 30
# Eval difference is too small: 86
# Analyzing position: 8/5B1R/6p1/2n3k1/8/1p5P/6K1/2r5 w - - 0 47
# Best move: h3h4, Eval: -129, Second best move eval: -317
# Eval difference is too small: 188
# Analyzing position: 8/5B1R/6p1/2n3k1/7P/1p6/6K1/2r5 b - - 0 47
# Best move: g5f6, Eval: 136, Second best move eval: 82
# Eval difference is too small: 54
# Analyzing position: 8/5B1R/5kp1/2n5/7P/1p6/6K1/2r5 w - - 1 48
# Best move: h4h5, Eval: -142, Second best move eval: -279
# Eval difference is too small: 137
# Analyzing position: 8/5B1R/5kp1/2n4P/8/1p6/6K1/2r5 b - - 0 48
# Best move: c1c2, Eval: 139, Second best move eval: 124
# Eval difference is too small: 15
# Analyzing position: 8/5B1R/5kp1/2n4P/8/1p6/2r3K1/8 w - - 1 49
# Best move: g2f3, Eval: -158, Second best move eval: -229
# Eval difference is too small: 71
# Analyzing position: 8/5B1R/5kp1/2n4P/8/1p3K2/2r5/8 b - - 2 49
# Best move: b3b2, Eval: 128, Second best move eval: 128
# Eval difference is too small: 0
# Analyzing position: 8/5B1R/5kp1/2n4P/8/5K2/1pr5/8 w - - 0 50
# Best move: f7a2, Eval: -182, Second best move eval: -424
# Eval difference is large enough: 242
# Move f7a2 is a capture: True
# Best move is a simple capture, skipping: f7a2
# Analyzing position: 8/7R/5kp1/2n4P/8/5K2/Bpr5/8 b - - 1 50
# Best move: c2c3, Eval: 173, Second best move eval: 75
# Eval difference is too small: 98
# Analyzing position: 8/7R/5k2/2n4p/8/5K2/Bpr5/8 w - - 0 51
# Best move: h7h5, Eval: -41, Second best move eval: -255
# Eval difference is large enough: 214
# Move h7h5 is a capture: True
# Best move is a simple capture, skipping: h7h5
# Analyzing position: 8/8/5k2/2n4R/8/5K2/Bpr5/8 b - - 0 51
# Best move: c2c3, Eval: 31, Second best move eval: 31
# Eval difference is too small: 0
# Analyzing position: 8/8/5k2/2n4R/8/5K2/Bp6/2r5 w - - 1 52
# Best move: f3e3, Eval: -42, Second best move eval: -105
# Eval difference is too small: 63
# Analyzing position: 8/8/5k1R/2n5/8/5K2/Bp6/2r5 b - - 2 52
# Best move: f6e7, Eval: 237, Second best move eval: 222
# Eval difference is too small: 15
# Analyzing position: 8/8/7R/2n1k3/8/5K2/Bp6/2r5 w - - 3 53
# Best move: h6b6, Eval: -220, Second best move eval: -225
# Eval difference is too small: 5
# Analyzing position: 8/8/1R6/2n1k3/8/5K2/Bp6/2r5 b - - 4 53
# Best move: c5a4, Eval: 221, Second best move eval: 34
# Eval difference is too small: 187
# Analyzing position: 8/8/1R6/4k3/n7/5K2/Bp6/2r5 w - - 5 54
# Best move: b6e6, Eval: -206, Second best move eval: -230
# Eval difference is too small: 24
# Analyzing position: 8/8/4R3/4k3/n7/5K2/Bp6/2r5 b - - 6 54
# Best move: e5d4, Eval: 205, Second best move eval: 170
# Eval difference is too small: 35
# Analyzing position: 8/8/4R3/8/n2k4/5K2/Bp6/2r5 w - - 7 55
# Best move: e6e4, Eval: -217, Second best move eval: -266
# Eval difference is too small: 49
# Analyzing position: 8/8/8/8/n2kR3/5K2/Bp6/2r5 b - - 8 55
# Best move: d4c5, Eval: 224, Second best move eval: 81
# Eval difference is too small: 143
# Analyzing position: 8/8/8/2k5/n3R3/5K2/Bp6/2r5 w - - 9 56
# Best move: e4a4, Eval: -216, Second best move eval: -245
# Eval difference is too small: 29
# Analyzing position: 8/8/8/2k5/R7/5K2/Bp6/2r5 b - - 0 56
# Best move: c1a1, Eval: 217, Second best move eval: 49
# Eval difference is too small: 168
# Total puzzles found in game: 0
# Total puzzles after game: 0
# Analyzing game FIDE World Championship Match 1969
# Analyzing position: rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1
# Best move: e2e4, Eval: 27, Second best move eval: 26
# Eval difference is too small: 1
# Analyzing position: rnbqkbnr/pppppppp/8/8/2P5/8/PP1PPPPP/RNBQKBNR b KQkq - 0 1
# Best move: e7e5, Eval: -17, Second best move eval: -21
# Eval difference is too small: 4
# Analyzing position: rnbqkbnr/pppp1ppp/4p3/8/2P5/8/PP1PPPPP/RNBQKBNR w KQkq - 0 2
# Best move: b1c3, Eval: 28, Second best move eval: 26
# Eval difference is too small: 2
# Analyzing position: rnbqkbnr/pppp1ppp/4p3/8/2PP4/8/PP2PPPP/RNBQKBNR b KQkq - 0 2
# Best move: g8f6, Eval: -28, Second best move eval: -29
# Eval difference is too small: 1
# Analyzing position: rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/8/PP2PPPP/RNBQKBNR w KQkq - 0 3
# Best move: b1c3, Eval: 29, Second best move eval: 29
# Eval difference is too small: 0
# Analyzing position: rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/2N5/PP2PPPP/R1BQKBNR b KQkq - 1 3
# Best move: g8f6, Eval: -28, Second best move eval: -32
# Eval difference is too small: 4
# Analyzing position: rnbqkbnr/pp3ppp/4p3/2pp4/2PP4/2N5/PP2PPPP/R1BQKBNR w KQkq - 0 4
# Best move: c4d5, Eval: 38, Second best move eval: 22
# Eval difference is too small: 16
# Analyzing position: rnbqkbnr/pp3ppp/4p3/2pP4/3P4/2N5/PP2PPPP/R1BQKBNR b KQkq - 0 4
# Best move: e6d5, Eval: -38, Second best move eval: -63
# Eval difference is too small: 25
# Analyzing position: rnbqkbnr/pp3ppp/8/2pp4/3P4/2N5/PP2PPPP/R1BQKBNR w KQkq - 0 5
# Best move: g1f3, Eval: 39, Second best move eval: 14
# Eval difference is too small: 25
# Analyzing position: rnbqkbnr/pp3ppp/8/2pp4/3P4/2N2N2/PP2PPPP/R1BQKB1R b KQkq - 1 5
# Best move: b8c6, Eval: -41, Second best move eval: -47
# Eval difference is too small: 6
# Analyzing position: r1bqkbnr/pp3ppp/2n5/2pp4/3P4/2N2N2/PP2PPPP/R1BQKB1R w KQkq - 2 6
# Best move: d4c5, Eval: 49, Second best move eval: 45
# Eval difference is too small: 4
# Analyzing position: r1bqkbnr/pp3ppp/2n5/2pp4/3P4/2N2NP1/PP2PP1P/R1BQKB1R b KQkq - 0 6
# Best move: c5d4, Eval: -37, Second best move eval: -47
# Eval difference is too small: 10
# Analyzing position: r1bqkb1r/pp3ppp/2n2n2/2pp4/3P4/2N2NP1/PP2PP1P/R1BQKB1R w KQkq - 1 7
# Best move: f1g2, Eval: 47, Second best move eval: 16
# Eval difference is too small: 31
# Analyzing position: r1bqkb1r/pp3ppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQK2R b KQkq - 2 7
# Best move: c5d4, Eval: -37, Second best move eval: -44
# Eval difference is too small: 7
# Analyzing position: r1bqk2r/pp2bppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQK2R w KQkq - 3 8
# Best move: d4c5, Eval: 53, Second best move eval: 50
# Eval difference is too small: 3
# Analyzing position: r1bqk2r/pp2bppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQ1RK1 b kq - 4 8
# Best move: c5c4, Eval: -54, Second best move eval: -48
# Eval difference is too small: 6
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQ1RK1 w - - 5 9
# Best move: c1g5, Eval: 49, Second best move eval: 41
# Eval difference is too small: 8
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/2pp2B1/3P4/2N2NP1/PP2PPBP/R2Q1RK1 b - - 6 9
# Best move: c5c4, Eval: -35, Second best move eval: -44
# Eval difference is too small: 9
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/3p2B1/3p4/2N2NP1/PP2PPBP/R2Q1RK1 w - - 0 10
# Best move: f3d4, Eval: 56, Second best move eval: 0
# Eval difference is too small: 56
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/3p2B1/3N4/2N3P1/PP2PPBP/R2Q1RK1 b - - 0 10
# Best move: h7h6, Eval: -42, Second best move eval: -49
# Eval difference is too small: 7
# Analyzing position: r1bq1rk1/pp2bpp1/2n2n1p/3p2B1/3N4/2N3P1/PP2PPBP/R2Q1RK1 w - - 0 11
# Best move: g5e3, Eval: 52, Second best move eval: 40
# Eval difference is too small: 12
# Analyzing position: r1bq1rk1/pp2bpp1/2n2n1p/3p4/3N4/2N1B1P1/PP2PPBP/R2Q1RK1 b - - 1 11
# Best move: c8g4, Eval: -53, Second best move eval: -66
# Eval difference is too small: 13
# Analyzing position: r2q1rk1/pp2bpp1/2n2n1p/3p4/3N2b1/2N1B1P1/PP2PPBP/R2Q1RK1 w - - 2 12
# Best move: h2h3, Eval: 53, Second best move eval: 22
# Eval difference is too small: 31
# Analyzing position: r2q1rk1/pp2bpp1/2n2n1p/3p4/6b1/1NN1B1P1/PP2PPBP/R2Q1RK1 b - - 3 12
# Best move: d8d7, Eval: -16, Second best move eval: -23
# Eval difference is too small: 7
# Analyzing position: r2q1rk1/pp2bpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/R2Q1RK1 w - - 4 13
# Best move: b3d4, Eval: 47, Second best move eval: 35
# Eval difference is too small: 12
# Analyzing position: r2q1rk1/pp2bpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/2RQ1RK1 b - - 5 13
# Best move: d8d7, Eval: -35, Second best move eval: -47
# Eval difference is too small: 12
# Analyzing position: r2qr1k1/pp2bpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/2RQ1RK1 w - - 6 14
# Best move: b3d4, Eval: 73, Second best move eval: 41
# Eval difference is too small: 32
# Analyzing position: r2qr1k1/pp2bpp1/2n1bn1p/1N1p4/8/1N2B1P1/PP2PPBP/2RQ1RK1 b - - 7 14
# Best move: d8d7, Eval: -19, Second best move eval: -32
# Eval difference is too small: 13
# Analyzing position: r3r1k1/pp1qbpp1/2n1bn1p/1N1p4/8/1N2B1P1/PP2PPBP/2RQ1RK1 w - - 8 15
# Best move: b3c5, Eval: 16, Second best move eval: 18
# Eval difference is too small: 2
# Analyzing position: r3r1k1/pp1qbpp1/2n1bn1p/3p4/3N4/1N2B1P1/PP2PPBP/2RQ1RK1 b - - 9 15
# Best move: e6h3, Eval: 5, Second best move eval: -4
# Eval difference is too small: 9
# Analyzing position: r3r1k1/pp1qbpp1/2n2n1p/3p4/3N4/1N2B1Pb/PP2PPBP/2RQ1RK1 w - - 10 16
# Best move: d4c6, Eval: -1, Second best move eval: -11
# Eval difference is too small: 10
# Analyzing position: r3r1k1/pp1qbpp1/2N2n1p/3p4/8/1N2B1Pb/PP2PPBP/2RQ1RK1 b - - 0 16
# Best move: b7c6, Eval: 5, Second best move eval: -312
# Eval difference is large enough: 317
# Move b7c6 is a capture: True
# Best move is a simple capture, skipping: b7c6
# Analyzing position: r3r1k1/p2qbpp1/2p2n1p/3p4/8/1N2B1Pb/PP2PPBP/2RQ1RK1 w - - 0 17
# Best move: b3a5, Eval: 1, Second best move eval: -3
# Eval difference is too small: 4
# Analyzing position: r3r1k1/p2qbpp1/2p2n1p/3p4/8/1N1QB1Pb/PP2PPBP/2R2RK1 b - - 1 17
# Best move: a7a5, Eval: 7, Second best move eval: 5
# Eval difference is too small: 2
# Analyzing position: r3r1k1/p2qbpp1/2p2n1p/3p4/8/1N1QB1P1/PP2PPbP/2R2RK1 w - - 0 18
# Best move: g1g2, Eval: -5, Second best move eval: -501
# Eval difference is large enough: 496
# Move g1g2 is a capture: True
# Best move is a simple capture, skipping: g1g2
# Analyzing position: r3r1k1/p2qbpp1/2p2n1p/3p4/8/1N1QB1P1/PP2PPKP/2R2R2 b - - 0 18
# Best move: a7a5, Eval: 10, Second best move eval: 5
# Eval difference is too small: 5
# Analyzing position: r3r1k1/3qbpp1/2p2n1p/p2p4/8/1N1QB1P1/PP2PPKP/2R2R2 w - - 0 19
# Best move: c1c2, Eval: -8, Second best move eval: -10
# Eval difference is too small: 2
# Analyzing position: r3r1k1/3qbpp1/2p2n1p/p2p4/8/1N1QB1P1/PPR1PPKP/5R2 b - - 1 19
# Best move: a5a4, Eval: 1, Second best move eval: -3
# Eval difference is too small: 4
# Analyzing position: r3r1k1/3qbpp1/2p2n1p/3p4/p7/1N1QB1P1/PPR1PPKP/5R2 w - - 0 20
# Best move: b3c5, Eval: -1, Second best move eval: -12
# Eval difference is too small: 11
# Analyzing position: r3r1k1/3qbpp1/2p2n1p/3p4/p7/3QB1P1/PPRNPPKP/5R2 b - - 1 20
# Best move: d7b7, Eval: 33, Second best move eval: 18
# Eval difference is too small: 15
# Analyzing position: r3r1k1/1q2bpp1/2p2n1p/3p4/p7/3QB1P1/PPRNPPKP/5R2 w - - 2 21
# Best move: e3d4, Eval: -40, Second best move eval: -49
# Eval difference is too small: 9
# Analyzing position: r3r1k1/1q2bpp1/2p2n1p/3p4/p7/3QB1P1/PPRNPP1P/5RK1 b - - 3 21
# Best move: f6d7, Eval: 100, Second best move eval: 82
# Eval difference is too small: 18
# Analyzing position: 2r1r1k1/1q2bpp1/2p2n1p/3p4/p7/3QB1P1/PPRNPP1P/5RK1 w - - 4 22
# Best move: f1c1, Eval: -79, Second best move eval: -92
# Eval difference is too small: 13
# Analyzing position: 2r1r1k1/1q2bpp1/2p2n1p/3p4/p7/3QB1P1/PPRNPP1P/2R3K1 b - - 5 22
# Best move: f6d7, Eval: 88, Second best move eval: 31
# Eval difference is too small: 57
# Analyzing position: 2r1r1k1/1q1nbpp1/2p4p/3p4/p7/3QB1P1/PPRNPP1P/2R3K1 w - - 6 23
# Best move: d2f3, Eval: -72, Second best move eval: -76
# Eval difference is too small: 4
# Analyzing position: 2r1r1k1/1q1nbpp1/2p4p/3p4/p7/3QBNP1/PPR1PP1P/2R3K1 b - - 7 23
# Best move: c6c5, Eval: 74, Second best move eval: 52
# Eval difference is too small: 22
# Analyzing position: 2r1r1k1/1q1nbpp1/7p/2pp4/p7/3QBNP1/PPR1PP1P/2R3K1 w - - 0 24
# Best move: b2b3, Eval: -82, Second best move eval: -89
# Eval difference is too small: 7
# Analyzing position: 2r1r1k1/1q1nbpp1/7p/2pp4/p7/1P1QBNP1/P1R1PP1P/2R3K1 b - - 0 24
# Best move: a4a3, Eval: 68, Second best move eval: 65
# Eval difference is too small: 3
# Analyzing position: 2r1r1k1/1q1nbpp1/7p/2pp4/8/1p1QBNP1/P1R1PP1P/2R3K1 w - - 0 25
# Best move: a2b3, Eval: -81, Second best move eval: -87
# Eval difference is too small: 6
# Analyzing position: 2r1r1k1/1q1nbpp1/7p/2pp4/8/1P1QBNP1/2R1PP1P/2R3K1 b - - 0 25
# Best move: e7f8, Eval: 86, Second best move eval: 58
# Eval difference is too small: 28
# Analyzing position: 2r1rbk1/1q1n1pp1/7p/2pp4/8/1P1QBNP1/2R1PP1P/2R3K1 w - - 1 26
# Best move: b3b4, Eval: -89, Second best move eval: -89
# Eval difference is too small: 0
# Analyzing position: 2r1rbk1/1q1n1pp1/7p/2pp4/8/1P1QBNP1/2R1PP1P/R5K1 b - - 2 26
# Best move: d5d4, Eval: 92, Second best move eval: 88
# Eval difference is too small: 4
# Analyzing position: 2r1rbk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/2R1PP1P/R5K1 w - - 3 27
# Best move: c2a2, Eval: -100, Second best move eval: -105
# Eval difference is too small: 5
# Analyzing position: 2r1rbk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/R3PP1P/R5K1 b - - 4 27
# Best move: d5d4, Eval: 94, Second best move eval: 76
# Eval difference is too small: 18
# Analyzing position: r3rbk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/R3PP1P/R5K1 w - - 5 28
# Best move: a2a8, Eval: -29, Second best move eval: -78
# Eval difference is too small: 49
# Analyzing position: R3rbk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/4PP1P/R5K1 b - - 0 28
# Best move: e8a8, Eval: 21, Second best move eval: -160
# Eval difference is too small: 181
# Analyzing position: r4bk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/4PP1P/R5K1 w - - 0 29
# Best move: a1a8, Eval: -23, Second best move eval: -69
# Eval difference is too small: 46
# Analyzing position: R4bk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/4PP1P/6K1 b - - 0 29
# Best move: b7a8, Eval: 18, Second best move eval: -414
# Eval difference is large enough: 432
# Move b7a8 is a capture: True
# Best move is a simple capture, skipping: b7a8
# Analyzing position: q4bk1/5pp1/5n1p/2pp4/8/1P1QBNP1/4PP1P/6K1 w - - 0 30
# Best move: h2h4, Eval: -13, Second best move eval: -14
# Eval difference is too small: 1
# Analyzing position: q4bk1/5pp1/5n1p/2pp4/8/1P2BNP1/2Q1PP1P/6K1 b - - 1 30
# Best move: f6e4, Eval: 10, Second best move eval: 10
# Eval difference is too small: 0
# Analyzing position: q4bk1/5pp1/7p/2pp4/4n3/1P2BNP1/2Q1PP1P/6K1 w - - 2 31
# Best move: f3d2, Eval: -12, Second best move eval: -19
# Eval difference is too small: 7
# Analyzing position: q4bk1/5pp1/7p/2pp4/4n3/1P2B1P1/2QNPP1P/6K1 b - - 3 31
# Best move: e4d2, Eval: 12, Second best move eval: 11
# Eval difference is too small: 1
# Analyzing position: q4bk1/5pp1/7p/2pp4/8/1P2B1P1/2QnPP1P/6K1 w - - 0 32
# Best move: e3d2, Eval: -12, Second best move eval: -14
# Eval difference is too small: 2
# Analyzing position: q4bk1/5pp1/7p/2pp4/8/1P4P1/2QBPP1P/6K1 b - - 0 32
# Best move: h6h5, Eval: 16, Second best move eval: 12
# Eval difference is too small: 4
# Analyzing position: 5bk1/5pp1/q6p/2pp4/8/1P4P1/2QBPP1P/6K1 w - - 1 33
# Best move: c2d3, Eval: -3, Second best move eval: -5
# Eval difference is too small: 2
# Analyzing position: 5bk1/5pp1/q6p/2pp4/8/1P4P1/2QBPP1P/5K2 b - - 2 33
# Best move: a6b5, Eval: 12, Second best move eval: 9
# Eval difference is too small: 3
# Analyzing position: 5bk1/5pp1/7p/1qpp4/8/1P4P1/2QBPP1P/5K2 w - - 3 34
# Best move: f2f3, Eval: -12, Second best move eval: -15
# Eval difference is too small: 3
# Analyzing position: 5bk1/5pp1/7p/1qpp4/8/1PB3P1/2Q1PP1P/5K2 b - - 4 34
# Best move: h6h5, Eval: 18, Second best move eval: 15
# Eval difference is too small: 3
# Analyzing position: 5bk1/5p2/6pp/1qpp4/8/1PB3P1/2Q1PP1P/5K2 w - - 0 35
# Best move: c3b2, Eval: -7, Second best move eval: -9
# Eval difference is too small: 2
# Analyzing position: 5bk1/5p2/6pp/1qpp4/8/1PB3P1/4PP1P/3Q1K2 b - - 1 35
# Best move: b5b7, Eval: 14, Second best move eval: 12
# Eval difference is too small: 2
# Analyzing position: 5bk1/5p2/2q3pp/2pp4/8/1PB3P1/4PP1P/3Q1K2 w - - 2 36
# Best move: c3b2, Eval: -13, Second best move eval: -14
# Eval difference is too small: 1
# Analyzing position: 5bk1/5p2/2q3pp/2pp4/8/1PB2PP1/4P2P/3Q1K2 b - - 0 36
# Best move: h6h5, Eval: 11, Second best move eval: 19
# Eval difference is too small: 8
# Analyzing position: 5bk1/5p2/4q1pp/2pp4/8/1PB2PP1/4P2P/3Q1K2 w - - 1 37
# Best move: d1d3, Eval: -14, Second best move eval: -13
# Eval difference is too small: 1
# Analyzing position: 5bk1/5p2/4q1pp/2pp4/8/1PB2PP1/4P1KP/3Q4 b - - 2 37
# Best move: f8e7, Eval: 13, Second best move eval: 12
# Eval difference is too small: 1
# Analyzing position: 5bk1/5p2/4q1p1/2pp3p/8/1PB2PP1/4P1KP/3Q4 w - - 0 38
# Best move: d1d3, Eval: -16, Second best move eval: -16
# Eval difference is too small: 0
# Analyzing position: 5bk1/5p2/4q1p1/2pp3p/8/1PB2PPP/4P1K1/3Q4 b - - 0 38
# Best move: c5c4, Eval: 25, Second best move eval: 28
# Eval difference is too small: 3
# Analyzing position: 6k1/5p2/3bq1p1/2pp3p/8/1PB2PPP/4P1K1/3Q4 w - - 1 39
# Best move: h3h4, Eval: -18, Second best move eval: -17
# Eval difference is too small: 1
# Analyzing position: 6k1/5p2/3bq1p1/2pp3p/8/1PBQ1PPP/4P1K1/8 b - - 2 39
# Best move: g8h7, Eval: 31, Second best move eval: 20
# Eval difference is too small: 11
# Analyzing position: 6k1/5p2/4q1p1/2ppb2p/8/1PBQ1PPP/4P1K1/8 w - - 3 40
# Best move: c3e5, Eval: -9, Second best move eval: -41
# Eval difference is too small: 32
# Analyzing position: 6k1/5p2/4q1p1/2ppB2p/8/1P1Q1PPP/4P1K1/8 b - - 0 40
# Best move: e6e5, Eval: 18, Second best move eval: -369
# Eval difference is large enough: 387
# Move e6e5 is a capture: True
# Best move is a simple capture, skipping: e6e5
# Analyzing position: 6k1/5p2/6p1/2ppq2p/8/1P1Q1PPP/4P1K1/8 w - - 0 41
# Best move: h3h4, Eval: -5, Second best move eval: -11
# Eval difference is too small: 6
# Analyzing position: 6k1/5p2/6p1/2ppq2p/7P/1P1Q1PP1/4P1K1/8 b - - 0 41
# Best move: e5e6, Eval: 7, Second best move eval: 3
# Eval difference is too small: 4
# Analyzing position: 5k2/5p2/6p1/2ppq2p/7P/1P1Q1PP1/4P1K1/8 w - - 1 42
# Best move: g2f1, Eval: -2, Second best move eval: -3
# Eval difference is too small: 1
# Analyzing position: 5k2/5p2/6p1/2ppq2p/7P/1P1Q1PP1/4P3/5K2 b - - 2 42
# Best move: f8g7, Eval: 2, Second best move eval: 1
# Eval difference is too small: 1
# Analyzing position: 8/4kp2/6p1/2ppq2p/7P/1P1Q1PP1/4P3/5K2 w - - 3 43
# Best move: f1g2, Eval: -2, Second best move eval: -4
# Eval difference is too small: 2
# Analyzing position: 8/4kp2/6p1/2ppq2p/7P/1P1Q1PP1/4PK2/8 b - - 4 43
# Best move: e5d6, Eval: 3, Second best move eval: 3
# Eval difference is too small: 0
# Analyzing position: 8/4kp2/4q1p1/2pp3p/7P/1P1Q1PP1/4PK2/8 w - - 5 44
# Best move: d3c3, Eval: -3, Second best move eval: -4
# Eval difference is too small: 1
# Analyzing position: 8/4kp2/4q1p1/1Qpp3p/7P/1P3PP1/4PK2/8 b - - 6 44
# Best move: e6d6, Eval: 3, Second best move eval: 0
# Eval difference is too small: 3
# Analyzing position: 8/4kp2/3q2p1/1Qpp3p/7P/1P3PP1/4PK2/8 w - - 7 45
# Best move: f3f4, Eval: -5, Second best move eval: -5
# Eval difference is too small: 0
# Analyzing position: 8/1Q2kp2/3q2p1/2pp3p/7P/1P3PP1/4PK2/8 b - - 8 45
# Best move: e7f6, Eval: 5, Second best move eval: 4
# Eval difference is too small: 1
# Analyzing position: 8/1Q3p2/3q1kp1/2pp3p/7P/1P3PP1/4PK2/8 w - - 9 46
# Best move: b7b5, Eval: -5, Second best move eval: -6
# Eval difference is too small: 1
# Analyzing position: 8/5p2/3q1kp1/1Qpp3p/7P/1P3PP1/4PK2/8 b - - 10 46
# Best move: d6c7, Eval: 4, Second best move eval: 4
# Eval difference is too small: 0
# Analyzing position: 8/2q2p2/5kp1/1Qpp3p/7P/1P3PP1/4PK2/8 w - - 11 47
# Best move: b5d3, Eval: -3, Second best move eval: -4
# Eval difference is too small: 1
# Analyzing position: 8/2q2p2/5kp1/2pp3p/7P/1P1Q1PP1/4PK2/8 b - - 12 47
# Best move: c5c4, Eval: 3, Second best move eval: 2
# Eval difference is too small: 1
# Analyzing position: 8/2q2p2/5kp1/3p3p/2p4P/1P1Q1PP1/4PK2/8 w - - 0 48
# Best move: b3c4, Eval: 0, Second best move eval: -3
# Eval difference is too small: 3
# Analyzing position: 8/2q2p2/5kp1/3p3p/2P4P/3Q1PP1/4PK2/8 b - - 0 48
# Best move: d5c4, Eval: 0, Second best move eval: -3
# Eval difference is too small: 3
# Analyzing position: 8/2q2p2/5kp1/7p/2p4P/3Q1PP1/4PK2/8 w - - 0 49
# Best move: d3d4, Eval: 0, Second best move eval: -2
# Eval difference is too small: 2
# Analyzing position: 8/2q2p2/5kp1/7p/2p4P/2Q2PP1/4PK2/8 b - - 1 49
# Best move: f6e6, Eval: 2, Second best move eval: 0
# Eval difference is too small: 2
# Analyzing position: 8/2q2p2/4k1p1/7p/2p4P/2Q2PP1/4PK2/8 w - - 2 50
# Best move: f2e3, Eval: 0, Second best move eval: -13
# Eval difference is too small: 13
# Analyzing position: 8/2q2p2/4k1p1/7p/2p4P/2Q1KPP1/4P3/8 b - - 3 50
# Best move: c7c5, Eval: 8, Second best move eval: 6
# Eval difference is too small: 2
# Analyzing position: 8/5p2/4k1p1/2q4p/2p4P/2Q1KPP1/4P3/8 w - - 4 51
# Best move: e3d2, Eval: -4, Second best move eval: -5
# Eval difference is too small: 1
# Analyzing position: 8/5p2/4k1p1/2q4p/2pQ3P/4KPP1/4P3/8 b - - 5 51
# Best move: c5e5, Eval: 1, Second best move eval: 0
# Eval difference is too small: 1
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/q3KPP1/4P3/8 w - - 6 52
# Best move: e3d2, Eval: 0, Second best move eval: -20
# Eval difference is too small: 20
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/q4PP1/3KP3/8 b - - 7 52
# Best move: a3a5, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 8/5p2/4k1p1/q6p/2pQ3P/5PP1/3KP3/8 w - - 8 53
# Best move: d2c2, Eval: 0, Second best move eval: -3
# Eval difference is too small: 3
# Analyzing position: 8/5p2/4k1p1/q6p/2pQ3P/5PP1/2K1P3/8 b - - 9 53
# Best move: a5a4, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 8/5p2/4k1p1/1q5p/2pQ3P/5PP1/2K1P3/8 w - - 10 54
# Best move: d4e3, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 8/5p2/4k1p1/1q5p/2pQ3P/2K2PP1/4P3/8 b - - 11 54
# Best move: b5b3, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Insufficient moves found in analysis.
# Total puzzles found in game: 0
# Total puzzles after game: 0
# Analyzing game FIDE World Championship Match 1969
# Analyzing position: rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1
# Best move: d2d4, Eval: 29, Second best move eval: 30
# Eval difference is too small: 1
# Analyzing position: rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1
# Best move: e7e5, Eval: -26, Second best move eval: -30
# Eval difference is too small: 4
# Analyzing position: rnbqkbnr/pp1ppppp/8/2p5/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Best move: c2c3, Eval: 32, Second best move eval: 25
# Eval difference is too small: 7
# Analyzing position: rnbqkbnr/pp1ppppp/8/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 2
# Best move: d7d6, Eval: -24, Second best move eval: -35
# Eval difference is too small: 11
# Analyzing position: r1bqkbnr/pp1ppppp/2n5/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R w KQkq - 2 3
# Best move: d2d4, Eval: 32, Second best move eval: 23
# Eval difference is too small: 9
# Analyzing position: r1bqkbnr/pp1ppppp/2n5/2p5/3PP3/5N2/PPP2PPP/RNBQKB1R b KQkq - 0 3
# Best move: c5d4, Eval: -18, Second best move eval: -103
# Eval difference is too small: 85
# Analyzing position: r1bqkbnr/pp1ppppp/2n5/8/3pP3/5N2/PPP2PPP/RNBQKB1R w KQkq - 0 4
# Best move: f3d4, Eval: 12, Second best move eval: 0
# Eval difference is too small: 12
# Analyzing position: r1bqkbnr/pp1ppppp/2n5/8/3NP3/8/PPP2PPP/RNBQKB1R b KQkq - 0 4
# Best move: e7e5, Eval: -11, Second best move eval: -14
# Eval difference is too small: 3
# Analyzing position: r1bqkbnr/pp1ppp1p/2n3p1/8/3NP3/8/PPP2PPP/RNBQKB1R w KQkq - 0 5
# Best move: b1c3, Eval: 36, Second best move eval: 36
# Eval difference is too small: 0
# Analyzing position: r1bqkbnr/pp1ppp1p/2n3p1/8/2PNP3/8/PP3PPP/RNBQKB1R b KQkq - 0 5
# Best move: g8f6, Eval: -42, Second best move eval: -55
# Eval difference is too small: 13
# Analyzing position: r1bqkb1r/pp1ppp1p/2n2np1/8/2PNP3/8/PP3PPP/RNBQKB1R w KQkq - 1 6
# Best move: b1c3, Eval: 59, Second best move eval: 37
# Eval difference is too small: 22
# Analyzing position: r1bqkb1r/pp1ppp1p/2n2np1/8/2PNP3/2N5/PP3PPP/R1BQKB1R b KQkq - 2 6
# Best move: f8g7, Eval: -56, Second best move eval: -59
# Eval difference is too small: 3
# Analyzing position: r1bqkb1r/pp1ppp1p/5np1/8/2PnP3/2N5/PP3PPP/R1BQKB1R w KQkq - 0 7
# Best move: d1d4, Eval: 61, Second best move eval: 7
# Eval difference is too small: 54
# Analyzing position: r1bqkb1r/pp1ppp1p/5np1/8/2PQP3/2N5/PP3PPP/R1B1KB1R b KQkq - 0 7
# Best move: d7d6, Eval: -66, Second best move eval: -136
# Eval difference is too small: 70
# Analyzing position: r1bqkb1r/pp2pp1p/3p1np1/8/2PQP3/2N5/PP3PPP/R1B1KB1R w KQkq - 0 8
# Best move: f2f3, Eval: 62, Second best move eval: 62
# Eval difference is too small: 0
# Analyzing position: r1bqkb1r/pp2pp1p/3p1np1/8/2PQP3/2N1B3/PP3PPP/R3KB1R b KQkq - 1 8
# Best move: c8d7, Eval: -63, Second best move eval: -64
# Eval difference is too small: 1
# Analyzing position: r1bqk2r/pp2ppbp/3p1np1/8/2PQP3/2N1B3/PP3PPP/R3KB1R w KQkq - 2 9
# Best move: d4d2, Eval: 60, Second best move eval: 58
# Eval difference is too small: 2
# Analyzing position: r1bqk2r/pp2ppbp/3p1np1/8/2PQP3/2N1BP2/PP4PP/R3KB1R b KQkq - 0 9
# Best move: c8d7, Eval: -63, Second best move eval: -71
# Eval difference is too small: 8
# Analyzing position: r1bq1rk1/pp2ppbp/3p1np1/8/2PQP3/2N1BP2/PP4PP/R3KB1R w KQ - 1 10
# Best move: d4d2, Eval: 72, Second best move eval: 49
# Eval difference is too small: 23
# Analyzing position: r1bq1rk1/pp2ppbp/3p1np1/8/2P1P3/2N1BP2/PP1Q2PP/R3KB1R b KQ - 2 10
# Best move: c8e6, Eval: -56, Second best move eval: -65
# Eval difference is too small: 9
# Analyzing position: r2q1rk1/pp2ppbp/3pbnp1/8/2P1P3/2N1BP2/PP1Q2PP/R3KB1R w KQ - 3 11
# Best move: a1c1, Eval: 60, Second best move eval: 55
# Eval difference is too small: 5
# Analyzing position: r2q1rk1/pp2ppbp/3pbnp1/8/2P1P3/2N1BP2/PP1Q2PP/2R1KB1R b K - 4 11
# Best move: a7a6, Eval: -52, Second best move eval: -55
# Eval difference is too small: 3
# Analyzing position: r4rk1/pp2ppbp/3pbnp1/q7/2P1P3/2N1BP2/PP1Q2PP/2R1KB1R w K - 5 12
# Best move: f1e2, Eval: 62, Second best move eval: 60
# Eval difference is too small: 2
# Analyzing position: r4rk1/pp2ppbp/3pbnp1/q7/2P1P3/2N1BP2/PP1QB1PP/2R1K2R b K - 6 12
# Best move: f8c8, Eval: -39, Second best move eval: -64
# Eval difference is too small: 25
# Analyzing position: r1r3k1/pp2ppbp/3pbnp1/q7/2P1P3/2N1BP2/PP1QB1PP/2R1K2R w K - 7 13
# Best move: e1g1, Eval: 53, Second best move eval: 43
# Eval difference is too small: 10
# Analyzing position: r1r3k1/pp2ppbp/3pbnp1/q7/2P1P3/1PN1BP2/P2QB1PP/2R1K2R b K - 0 13
# Best move: a7a6, Eval: -48, Second best move eval: -57
# Eval difference is too small: 9
# Analyzing position: r1r3k1/1p2ppbp/p2pbnp1/q7/2P1P3/1PN1BP2/P2QB1PP/2R1K2R w K - 0 14
# Best move: c3a4, Eval: 40, Second best move eval: 33
# Eval difference is too small: 7
# Analyzing position: r1r3k1/1p2ppbp/p2pbnp1/q2N4/2P1P3/1P2BP2/P2QB1PP/2R1K2R b K - 1 14
# Best move: a5d2, Eval: -16, Second best move eval: -142
# Eval difference is too small: 126
# Analyzing position: r1r3k1/1p2ppbp/p2pbnp1/3N4/2P1P3/1P2BP2/P2qB1PP/2R1K2R w K - 0 15
# Best move: e1d2, Eval: 19, Second best move eval: 9
# Eval difference is too small: 10
# Analyzing position: r1r3k1/1p2ppbp/p2pbnp1/3N4/2P1P3/1P2BP2/P2KB1PP/2R4R b - - 0 15
# Best move: f6d5, Eval: -25, Second best move eval: -50
# Eval difference is too small: 25
# Analyzing position: r1r3k1/1p2ppbp/p2pb1p1/3n4/2P1P3/1P2BP2/P2KB1PP/2R4R w - - 0 16
# Best move: c4d5, Eval: 15, Second best move eval: 12
# Eval difference is too small: 3
# Analyzing position: r1r3k1/1p2ppbp/p2pb1p1/3P4/4P3/1P2BP2/P2KB1PP/2R4R b - - 0 16
# Best move: e6d7, Eval: -14, Second best move eval: -142
# Eval difference is too small: 128
# Analyzing position: r1r3k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P2KB1PP/2R4R w - - 1 17
# Best move: c1c8, Eval: 16, Second best move eval: 15
# Eval difference is too small: 1
# Analyzing position: r1R3k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P2KB1PP/7R b - - 0 17
# Best move: a8c8, Eval: -15, Second best move eval: -110
# Eval difference is too small: 95
# Analyzing position: 2r3k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P2KB1PP/7R w - - 0 18
# Best move: h1c1, Eval: 12, Second best move eval: 9
# Eval difference is too small: 3
# Analyzing position: 2r3k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P2KB1PP/2R5 b - - 1 18
# Best move: c8c1, Eval: -12, Second best move eval: -19
# Eval difference is too small: 7
# Analyzing position: 6k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P2KB1PP/2r5 w - - 0 19
# Best move: d2c1, Eval: 13, Second best move eval: -418
# Eval difference is large enough: 431
# Move d2c1 is a capture: True
# Best move is a simple capture, skipping: d2c1
# Analyzing position: 6k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P3B1PP/2K5 b - - 0 19
# Best move: g7c3, Eval: -8, Second best move eval: -12
# Eval difference is too small: 4
# Analyzing position: 5k2/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P3B1PP/2K5 w - - 1 20
# Best move: c1d2, Eval: 13, Second best move eval: 9
# Eval difference is too small: 4
# Analyzing position: 5k2/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P1K1B1PP/8 b - - 2 20
# Best move: e7e6, Eval: -13, Second best move eval: -16
# Eval difference is too small: 3
# Analyzing position: 5k2/1p1b1pbp/p2pp1p1/3P4/4P3/1P2BP2/P1K1B1PP/8 w - - 0 21
# Best move: d5e6, Eval: 9, Second best move eval: 10
# Eval difference is too small: 1
# Analyzing position: 5k2/1p1b1pbp/p2pp1p1/3P4/P3P3/1P2BP2/2K1B1PP/8 b - - 0 21
# Best move: e6d5, Eval: -3, Second best move eval: -7
# Eval difference is too small: 4
# Analyzing position: 5k2/1p1b1pbp/p2p2p1/3p4/P3P3/1P2BP2/2K1B1PP/8 w - - 0 22
# Best move: e4d5, Eval: 4, Second best move eval: -85
# Eval difference is too small: 89
# Analyzing position: 5k2/1p1b1pbp/p2p2p1/3P4/P7/1P2BP2/2K1B1PP/8 b - - 0 22
# Best move: h7h5, Eval: -3, Second best move eval: -3
# Eval difference is too small: 0
# Analyzing position: 8/1p1bkpbp/p2p2p1/3P4/P7/1P2BP2/2K1B1PP/8 w - - 1 23
# Best move: f3f4, Eval: 2, Second best move eval: 3
# Eval difference is too small: 1
# Analyzing position: 8/1p1bkpbp/p2p2p1/3P4/P7/1P1BBP2/2K3PP/8 b - - 2 23
# Best move: g7e5, Eval: 0, Second best move eval: -2
# Eval difference is too small: 2
# Analyzing position: 8/1p1bkp1p/p2p2p1/3Pb3/P7/1P1BBP2/2K3PP/8 w - - 3 24
# Best move: f3f4, Eval: 0, Second best move eval: -5
# Eval difference is too small: 5
# Analyzing position: 8/1p1bkp1p/p2p2p1/3Pb3/P7/1P1BBPP1/2K4P/8 b - - 0 24
# Best move: e7f6, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 4k3/1p1b1p1p/p2p2p1/3Pb3/P7/1P1BBPP1/2K4P/8 w - - 1 25
# Best move: d3e2, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 4k3/1p1b1p1p/p2p2p1/3Pb3/P7/1P1BBPP1/3K3P/8 b - - 2 25
# Best move: h7h5, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 8/1p1bkp1p/p2p2p1/3Pb3/P7/1P1BBPP1/3K3P/8 w - - 3 26
# Best move: d3e2, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 8/1p1bkp1p/pB1p2p1/3Pb3/P7/1P1B1PP1/3K3P/8 b - - 4 26
# Best move: h7h5, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 4b3/1p2kp1p/pB1p2p1/3Pb3/P7/1P1B1PP1/3K3P/8 w - - 5 27
# Best move: d3e2, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 4b3/1p2kp1p/pB1p2p1/3Pb3/P4P2/1P1B2P1/3K3P/8 b - - 0 27
# Best move: e5f6, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 4b3/1p2kpbp/pB1p2p1/3P4/P4P2/1P1B2P1/3K3P/8 w - - 1 28
# Best move: g3g4, Eval: 0, Second best move eval: 0
# Eval difference is too small: 0
# Analyzing position: 4b3/1p2kpbp/pB1p2p1/3P4/P4PP1/1P1B4/3K3P/8 b - - 0 28
# Best move: e8d7, Eval: -1, Second best move eval: -3
# Eval difference is too small: 2
# Analyzing position: 8/1p1bkpbp/pB1p2p1/3P4/P4PP1/1P1B4/3K3P/8 w - - 1 29
# Best move: d3e2, Eval: 0, Second best move eval: -3
# Eval difference is too small: 3
# Analyzing position: 8/1p1bkpbp/pB1p2p1/3P4/P4PP1/1P1B3P/3K4/8 b - - 0 29
# Best move: h7h5, Eval: 1, Second best move eval: 0
# Eval difference is too small: 1
# Analyzing position: 8/1p1bkpb1/pB1p2p1/3P3p/P4PP1/1P1B3P/3K4/8 w - - 0 30
# ...
# Eval difference is too small: 6
# Analyzing position: 3q1rk1/p1rbnppp/B2np3/8/4Q3/1N4P1/P3PP1P/R1B2RK1 w - - 7 20
# Best move: e4b4, Eval: 86, Second best move eval: 78
# Eval difference is too small: 8
# Analyzing position: 3q1rk1/p1rbnppp/B2np3/8/8/1N1Q2P1/P3PP1P/R1B2RK1 b - - 8 20
# Best move: d7c8, Eval: -85, Second best move eval: -93
# Eval difference is too small: 8
# Analyzing position: 3q1rk1/p2bnppp/B1rnp3/8/8/1N1Q2P1/P3PP1P/R1B2RK1 w - - 9 21
# Best move: c1a3, Eval: 131, Second best move eval: 78
# Eval difference is too small: 53
# Analyzing position: 3q1rk1/p2bnppp/B1rnp3/8/8/BN1Q2P1/P3PP1P/R4RK1 b - - 10 21
# Best move: d7c8, Eval: -102, Second best move eval: -165
# Eval difference is too small: 63
# Analyzing position: 2bq1rk1/p3nppp/B1rnp3/8/8/BN1Q2P1/P3PP1P/R4RK1 w - - 11 22
# Best move: a6b5, Eval: 106, Second best move eval: 97
# Eval difference is too small: 9
# Analyzing position: 2Bq1rk1/p3nppp/2rnp3/8/8/BN1Q2P1/P3PP1P/R4RK1 b - - 0 22
# Best move: d6c8, Eval: -76, Second best move eval: -178
# Eval difference is too small: 102
# Analyzing position: 2nq1rk1/p3nppp/2r1p3/8/8/BN1Q2P1/P3PP1P/R4RK1 w - - 0 23
# Best move: b3d4, Eval: 79, Second best move eval: 78
# Eval difference is too small: 1
# Analyzing position: 2nq1rk1/p3nppp/2r1p3/8/8/BN1Q2P1/P3PP1P/R2R2K1 b - - 1 23
# Best move: d8d3, Eval: -52, Second best move eval: -108
# Eval difference is too small: 56
# Analyzing position: 2n2rk1/p3nppp/2r1p3/8/8/BN1q2P1/P3PP1P/R2R2K1 w - - 0 24
# Best move: d1d3, Eval: 68, Second best move eval: 7
# Eval difference is too small: 61
# Analyzing position: 2n2rk1/p3nppp/2r1p3/8/8/BN1R2P1/P3PP1P/R5K1 b - - 0 24
# Best move: h7h6, Eval: -73, Second best move eval: -83
# Eval difference is too small: 10
# Analyzing position: 2n1r1k1/p3nppp/2r1p3/8/8/BN1R2P1/P3PP1P/R5K1 w - - 1 25
# Best move: a1d1, Eval: 99, Second best move eval: 47
# Eval difference is too small: 52
# Analyzing position: 2n1r1k1/p3nppp/2r1p3/8/8/BN1R2P1/P3PP1P/3R2K1 b - - 2 25
# Best move: h7h6, Eval: -81, Second best move eval: -93
# Eval difference is too small: 12
# Analyzing position: 2n1r1k1/p3n1pp/2r1pp2/8/8/BN1R2P1/P3PP1P/3R2K1 w - - 0 26
# Best move: b3d4, Eval: 117, Second best move eval: 46
# Eval difference is too small: 71
# Analyzing position: 2n1r1k1/p3n1pp/2r1pp2/8/3N4/B2R2P1/P3PP1P/3R2K1 b - - 1 26
# Best move: c6b6, Eval: -117, Second best move eval: -124
# Eval difference is too small: 7
# Analyzing position: 2n1r1k1/p3n1pp/1r2pp2/8/3N4/B2R2P1/P3PP1P/3R2K1 w - - 2 27
# Best move: a3c5, Eval: 122, Second best move eval: 60
# Eval difference is too small: 62
# Analyzing position: 2n1r1k1/p3n1pp/1r2pp2/2B5/3N4/3R2P1/P3PP1P/3R2K1 b - - 3 27
# Best move: b6b2, Eval: -103, Second best move eval: -138
# Eval difference is too small: 35
# Analyzing position: 2n1r1k1/p3n1pp/r3pp2/2B5/3N4/3R2P1/P3PP1P/3R2K1 w - - 4 28
# Best move: d4b5, Eval: 138, Second best move eval: 79
# Eval difference is too small: 59
# Analyzing position: 2n1r1k1/p3n1pp/r3pp2/1NB5/8/3R2P1/P3PP1P/3R2K1 b - - 5 28
# Best move: e7d5, Eval: -138, Second best move eval: -168
# Eval difference is too small: 30
# Analyzing position: 2n1r1k1/p3n1pp/2r1pp2/1NB5/8/3R2P1/P3PP1P/3R2K1 w - - 6 29
# Best move: c5e7, Eval: 179, Second best move eval: 75
# Eval difference is too small: 104
# Analyzing position: 2n1r1k1/p3B1pp/2r1pp2/1N6/8/3R2P1/P3PP1P/3R2K1 b - - 0 29
# Best move: c8e7, Eval: -189, Second best move eval: -373
# Eval difference is too small: 184
# Analyzing position: 4r1k1/p3n1pp/2r1pp2/1N6/8/3R2P1/P3PP1P/3R2K1 w - - 0 30
# Best move: d3d7, Eval: 190, Second best move eval: 65
# Eval difference is too small: 125
# Analyzing position: 4r1k1/p2Rn1pp/2r1pp2/1N6/8/6P1/P3PP1P/3R2K1 b - - 1 30
# Best move: e7d5, Eval: -184, Second best move eval: -201
# Eval difference is too small: 17
# Analyzing position: 4r1k1/p2R2pp/2r1ppn1/1N6/8/6P1/P3PP1P/3R2K1 w - - 2 31
# Best move: d7a7, Eval: 210, Second best move eval: 145
# Eval difference is too small: 65
# Analyzing position: 4r1k1/R5pp/2r1ppn1/1N6/8/6P1/P3PP1P/3R2K1 b - - 0 31
# Best move: g6f8, Eval: -194, Second best move eval: -218
# Eval difference is too small: 24
# Analyzing position: 4rnk1/R5pp/2r1pp2/1N6/8/6P1/P3PP1P/3R2K1 w - - 1 32
# Best move: a2a4, Eval: 190, Second best move eval: 186
# Eval difference is too small: 4
# Analyzing position: 4rnk1/R5pp/2r1pp2/1N6/P7/6P1/4PP1P/3R2K1 b - - 0 32
# Best move: c6c2, Eval: -197, Second best move eval: -207
# Eval difference is too small: 10
# Analyzing position: 1r3nk1/R5pp/2r1pp2/1N6/P7/6P1/4PP1P/3R2K1 w - - 1 33
# Best move: d1a1, Eval: 203, Second best move eval: 196
# Eval difference is too small: 7
# Analyzing position: 1r3nk1/R5pp/2r1pp2/1N6/P7/4P1P1/5P1P/3R2K1 b - - 0 33
# Best move: c6c2, Eval: -158, Second best move eval: -194
# Eval difference is too small: 36
# Analyzing position: 1r3nk1/R5p1/2r1pp2/1N5p/P7/4P1P1/5P1P/3R2K1 w - - 0 34
# Best move: b5d4, Eval: 208, Second best move eval: 171
# Eval difference is too small: 37
# Analyzing position: 1r3nk1/R5p1/2r1pp2/1N5p/P7/4P1P1/5PKP/3R4 b - - 1 34
# Best move: e6e5, Eval: -155, Second best move eval: -162
# Eval difference is too small: 7
# Analyzing position: 1r3nk1/R5p1/2r2p2/1N2p2p/P7/4P1P1/5PKP/3R4 w - - 0 35
# Best move: d1d2, Eval: 177, Second best move eval: 167
# Eval difference is too small: 10
# Analyzing position: 1r3nk1/R5p1/2r2p2/1N2p2p/P7/3RP1P1/5PKP/8 b - - 1 35
# Best move: f8e6, Eval: -152, Second best move eval: -164
# Eval difference is too small: 12
# Analyzing position: 1r3n2/R5pk/2r2p2/1N2p2p/P7/3RP1P1/5PKP/8 w - - 2 36
# Best move: d3d6, Eval: 196, Second best move eval: 164
# Eval difference is too small: 32
# Analyzing position: 1r3n2/R5pk/2r2p2/1N2p2p/P7/2R1P1P1/5PKP/8 b - - 3 36
# Best move: c6b6, Eval: -124, Second best move eval: -159
# Eval difference is too small: 35
# Analyzing position: 2r2n2/R5pk/2r2p2/1N2p2p/P7/2R1P1P1/5PKP/8 w - - 4 37
# Best move: c3c6, Eval: 161, Second best move eval: 123
# Eval difference is too small: 38
# Analyzing position: 2r2n2/R5pk/2R2p2/1N2p2p/P7/4P1P1/5PKP/8 b - - 0 37
# Best move: c8c6, Eval: -163, Second best move eval: -585
# Eval difference is large enough: 422
# Move c8c6 is a capture: True
# Best move is a simple capture, skipping: c8c6
# Analyzing position: 5n2/R5pk/2r2p2/1N2p2p/P7/4P1P1/5PKP/8 w - - 0 38
# Best move: a4a5, Eval: 187, Second best move eval: 190
# Eval difference is too small: 3
# Analyzing position: 5n2/R1N3pk/2r2p2/4p2p/P7/4P1P1/5PKP/8 b - - 1 38
# Best move: f8e6, Eval: -116, Second best move eval: -190
# Eval difference is too small: 74
# Analyzing position: 8/R1N3pk/2r1np2/4p2p/P7/4P1P1/5PKP/8 w - - 2 39
# Best move: c7e6, Eval: 124, Second best move eval: 119
# Eval difference is too small: 5
# Analyzing position: 8/R5pk/2r1np2/3Np2p/P7/4P1P1/5PKP/8 b - - 3 39
# Best move: e6c5, Eval: -88, Second best move eval: -126
# Eval difference is too small: 38
# Analyzing position: 8/R5p1/2r1np1k/3Np2p/P7/4P1P1/5PKP/8 w - - 4 40
# Best move: a4a5, Eval: 188, Second best move eval: 140
# Eval difference is too small: 48
# Analyzing position: 8/R5p1/2r1np1k/P2Np2p/8/4P1P1/5PKP/8 b - - 0 40
# Best move: c6c5, Eval: -189, Second best move eval: -220
# Eval difference is too small: 31
# Analyzing position: 8/R5p1/2r1np1k/P2N3p/4p3/4P1P1/5PKP/8 w - - 0 41
# Best move: a5a6, Eval: 212, Second best move eval: 200
# Eval difference is too small: 12
# Total puzzles found in game: 0
# Total puzzles after game: 0
# Analyzing game FIDE World Championship Match 1986
# Analyzing position: rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1
# Best move: d2d4, Eval: 26, Second best move eval: 23
# Eval difference is too small: 3
# Analyzing position: rnbqkbnr/pppppppp/8/8/3P4/8/PPP1PPPP/RNBQKBNR b KQkq - 0 1
# Best move: g8f6, Eval: -22, Second best move eval: -26
# Eval difference is too small: 4
# Analyzing position: rnbqkb1r/pppppppp/5n2/8/3P4/8/PPP1PPPP/RNBQKBNR w KQkq - 1 2
# Best move: c2c4, Eval: 24, Second best move eval: 23
# Eval difference is too small: 1
# Analyzing position: rnbqkb1r/pppppppp/5n2/8/2PP4/8/PP2PPPP/RNBQKBNR b KQkq - 0 2
# Best move: e7e6, Eval: -32, Second best move eval: -35
# Eval difference is too small: 3
# Analyzing position: rnbqkb1r/pppppp1p/5np1/8/2PP4/8/PP2PPPP/RNBQKBNR w KQkq - 0 3
# Best move: g1f3, Eval: 45, Second best move eval: 38
# Eval difference is too small: 7
# Analyzing position: rnbqkb1r/pppppp1p/5np1/8/2PP4/2N5/PP2PPPP/R1BQKBNR b KQkq - 1 3
# Best move: d7d5, Eval: -33, Second best move eval: -40
# Eval difference is too small: 7
# Analyzing position: rnbqkb1r/ppp1pp1p/5np1/3p4/2PP4/2N5/PP2PPPP/R1BQKBNR w KQkq - 0 4
# Best move: c4d5, Eval: 40, Second best move eval: 35
# Eval difference is too small: 5
# Analyzing position: rnbqkb1r/ppp1pp1p/5np1/3p4/2PP1B2/2N5/PP2PPPP/R2QKBNR b KQkq - 1 4
# Best move: f8g7, Eval: -17, Second best move eval: -70
# Eval difference is too small: 53
# Analyzing position: rnbqk2r/ppp1ppbp/5np1/3p4/2PP1B2/2N5/PP2PPPP/R2QKBNR w KQkq - 2 5
# Best move: g1f3, Eval: 33, Second best move eval: 22
# Eval difference is too small: 11
# Analyzing position: rnbqk2r/ppp1ppbp/5np1/3p4/2PP1B2/2N1P3/PP3PPP/R2QKBNR b KQkq - 0 5
# Best move: e8g8, Eval: -4, Second best move eval: -21
# Eval difference is too small: 17
# Analyzing position: rnbqk2r/pp2ppbp/5np1/2pp4/2PP1B2/2N1P3/PP3PPP/R2QKBNR w KQkq - 0 6
# Best move: d4c5, Eval: 36, Second best move eval: 6
# Eval difference is too small: 30
# Analyzing position: rnbqk2r/pp2ppbp/5np1/2Pp4/2P2B2/2N1P3/PP3PPP/R2QKBNR b KQkq - 0 6
# Best move: d8a5, Eval: -17, Second best move eval: -48
# Eval difference is too small: 31
# Analyzing position: rnb1k2r/pp2ppbp/5np1/q1Pp4/2P2B2/2N1P3/PP3PPP/R2QKBNR w KQkq - 1 7
# Best move: a1c1, Eval: 17, Second best move eval: 22
# Eval difference is too small: 5
# Analyzing position: rnb1k2r/pp2ppbp/5np1/q1Pp4/2P2B2/2N1P3/PP3PPP/2RQKBNR b Kkq - 2 7
# Best move: c8e6, Eval: -17, Second best move eval: -31
# Eval difference is too small: 14
# Analyzing position: rnb1k2r/pp2ppbp/6p1/q1Pp4/2P1nB2/2N1P3/PP3PPP/2RQKBNR w Kkq - 3 8
# Best move: c4d5, Eval: 10, Second best move eval: -5
# Eval difference is too small: 15
# Analyzing position: rnb1k2r/pp2ppbp/6p1/q1PP4/4nB2/2N1P3/PP3PPP/2RQKBNR b Kkq - 0 8
# Best move: b8d7, Eval: -42, Second best move eval: -59
# Eval difference is too small: 17
# Analyzing position: rnb1k2r/pp2ppbp/6p1/q1PP4/5B2/2n1P3/PP3PPP/2RQKBNR w Kkq - 0 9
# Best move: d1d2, Eval: 42, Second best move eval: -93
# Eval difference is too small: 135
# Analyzing position: rnb1k2r/pp2ppbp/6p1/q1PP4/5B2/2n1P3/PP1Q1PPP/2R1KBNR b Kkq - 1 9
# Best move: a5a2, Eval: -42, Second best move eval: -83
# Eval difference is too small: 41
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2n1P3/qP1Q1PPP/2R1KBNR w Kkq - 0 10
# Best move: b2c3, Eval: 42, Second best move eval: 12
# Eval difference is too small: 30
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/q2Q1PPP/2R1KBNR b Kkq - 0 10
# Best move: a2d2, Eval: -44, Second best move eval: -48
# Eval difference is too small: 4
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Analyzing position: rnb1k2r/pp2ppbp/6p1/2PP4/5B2/2P1P3/3q1PPP/2R1KBNR w Kkq - 0 11
# Insufficient moves found in analysis.
# Total puzzles found in game: 0
# Total puzzles after game: 0
# Classic puzzles analysis complete. Results saved.
