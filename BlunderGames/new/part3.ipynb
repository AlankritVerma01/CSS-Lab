# %%
# Import required libraries
import chess
import chess.engine
import chess.pgn
import subprocess
import os
import json
import csv
from IPython.display import display

# Paths to your engines and Maia models
stockfish_path = "/opt/homebrew/bin/stockfish"
maia_model_paths = {
    1100: "maia_weights/maia-1100.pb.gz",
    1200: "maia_weights/maia-1200.pb.gz",
    1300: "maia_weights/maia-1300.pb.gz",
    1400: "maia_weights/maia-1400.pb.gz",
    1500: "maia_weights/maia-1500.pb.gz",
    1600: "maia_weights/maia-1600.pb.gz",
    1700: "maia_weights/maia-1700.pb.gz",
    1800: "maia_weights/maia-1800.pb.gz",
    1900: "maia_weights/maia-1900.pb.gz",
}

# Initialize Stockfish engine
print("Initializing Stockfish engine...")
stockfish_engine = chess.engine.SimpleEngine.popen_uci(stockfish_path)

# Initialize Maia engines
print("Initializing Maia engines...")
maia_engines = {}
for elo, path in maia_model_paths.items():
    maia_engines[elo] = chess.engine.SimpleEngine.popen_uci(["lc0", f"--weights={path}"])
# Out:
# Initializing Stockfish engine...
# <UciProtocol (pid=18472)>: stderr >>        _
# <UciProtocol (pid=18472)>: stderr >> |   _ | |
# <UciProtocol (pid=18472)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18473)>: stderr >>        _
# <UciProtocol (pid=18473)>: stderr >> |   _ | |
# <UciProtocol (pid=18473)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18474)>: stderr >>        _
# <UciProtocol (pid=18474)>: stderr >> |   _ | |
# <UciProtocol (pid=18474)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18475)>: stderr >>        _
# <UciProtocol (pid=18475)>: stderr >> |   _ | |
# <UciProtocol (pid=18475)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18476)>: stderr >>        _
# <UciProtocol (pid=18476)>: stderr >> |   _ | |
# <UciProtocol (pid=18476)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18477)>: stderr >>        _
# <UciProtocol (pid=18477)>: stderr >> |   _ | |
# <UciProtocol (pid=18477)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18478)>: stderr >>        _
# <UciProtocol (pid=18478)>: stderr >> |   _ | |
# <UciProtocol (pid=18478)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18479)>: stderr >>        _
# <UciProtocol (pid=18479)>: stderr >> |   _ | |
# <UciProtocol (pid=18479)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=18480)>: stderr >>        _
# <UciProtocol (pid=18480)>: stderr >> |   _ | |
# <UciProtocol (pid=18480)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# Initializing Maia engines...

# %%
# Part 2: Analysis Functions

import chess.pgn

# Function to calculate average error for a position using Stockfish
def calculate_average_error(board, stockfish_engine):
    legal_moves = list(board.legal_moves)
    total_error = 0
    num_moves = len(legal_moves)

    for move in legal_moves:
        board.push(move)
        info = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1))
        eval_score = info["score"].relative.score(mate_score=10000) / 100.0
        total_error += abs(eval_score)
        board.pop()

    average_error = total_error / num_moves if num_moves > 0 else 0
    return average_error

# Function to find classic puzzles in a game
def find_classic_puzzles(game, stockfish_engine, threshold=200):
    board = game.board()
    puzzles = []

    for move in game.mainline_moves():
        fen_before = board.fen()

        # Analyze the position before the move
        info = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1), multipv=2)
        if len(info) < 2:
            board.push(move)
            continue

        best_move = info[0]["pv"][0]
        best_eval = info[0]["score"].relative.score(mate_score=10000)
        second_best_eval = info[1]["score"].relative.score(mate_score=10000)

        # Check if the difference is large enough and the best move is not a simple recapture
        if abs(best_eval - second_best_eval) >= threshold and not board.is_capture(best_move):
            puzzles.append((fen_before, best_move, best_eval, second_best_eval))
            print(f"Puzzle found: {fen_before}, Best move: {best_move}, Eval difference: {abs(best_eval - second_best_eval)}")

        board.push(move)

    return puzzles

# Function to evaluate Maia easiness
def evaluate_maia_easiness(fen, best_move, maia_engines):
    board = chess.Board(fen)
    easiness_scores = {}

    for elo, engine in maia_engines.items():
        result = engine.analyse(board, chess.engine.Limit(nodes=1))
        if "pv" in result and best_move in result["pv"]:
            easiness_scores[elo] = result["pv"].index(best_move) / len(result["pv"])

    return easiness_scores

# %%
# Part 3: Analyzing Games and Saving Results

import csv
import json

# Function to save results incrementally to CSV
def save_results_to_csv(csv_file_path, data):
    with open(csv_file_path, "a", newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        for fen, best_move, best_eval, second_best_eval, maia_easiness in data:
            csvwriter.writerow([
                fen,
                best_move.uci(),  # Convert Move object to UCI notation
                best_eval,
                second_best_eval,
                maia_easiness
            ])

# Function to save results incrementally to JSON
def save_results_to_json(json_file_path, data):
    if os.path.exists(json_file_path):
        with open(json_file_path, "r") as jsonfile:
            json_data = json.load(jsonfile)
    else:
        json_data = []

    for fen, best_move, best_eval, second_best_eval, maia_easiness in data:
        json_data.append({
            "fen": fen,
            "best_move": best_move.uci(),  # Convert Move object to UCI notation
            "best_eval": best_eval,
            "second_best_eval": second_best_eval,
            "maia_easiness": maia_easiness
        })

    with open(json_file_path, "w") as jsonfile:
        json.dump(json_data, jsonfile, indent=4)

# Function to sort and save results
def sort_and_save_results(puzzles, output_dir="results/classic_puzzles"):
    os.makedirs(output_dir, exist_ok=True)
    puzzles.sort(key=lambda x: x["maia_easiness"], reverse=True)

    csv_file_path = os.path.join(output_dir, "classic_puzzles.csv")
    json_file_path = os.path.join(output_dir, "classic_puzzles.json")

    with open(csv_file_path, "w", newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(["FEN", "Best Move", "Best Eval", "Second Best Eval", "Maia Easiness"])
        for puzzle in puzzles:
            csvwriter.writerow([puzzle["fen"], puzzle["best_move"], puzzle["best_eval"], puzzle["second_best_eval"], puzzle["maia_easiness"]])

    with open(json_file_path, "w") as jsonfile:
        json.dump(puzzles, jsonfile, indent=4)

# Load PGN files and find classic puzzles
pgn_directory = "analysis_pgns_test"
all_puzzles = []

print("Starting to find classic puzzles in PGN files...")

for pgn_file in os.listdir(pgn_directory):
    if pgn_file.endswith(".pgn"):
        pgn_file_path = os.path.join(pgn_directory, pgn_file)
        print(f"Analyzing {pgn_file_path}...")
        all_games = load_games_from_pgn(pgn_file_path)

        for game in all_games:
            print(f"Analyzing game {game.headers.get('Event', 'Unknown Event')}")
            puzzles = find_classic_puzzles(game, stockfish_engine)
            for fen, best_move, best_eval, second_best_eval in puzzles:
                maia_easiness = evaluate_maia_easiness(fen, best_move, maia_engines)
                all_puzzles.append((fen, best_move, best_eval, second_best_eval, maia_easiness))

            # Save results incrementally
            save_results_to_csv("classic_puzzles.csv", all_puzzles)
            save_results_to_json("classic_puzzles.json", all_puzzles)

print("Classic puzzles analysis complete. Results saved.")
# Out:
# Starting to find classic puzzles in PGN files...
# Analyzing analysis_pgns_test/QFkiT2sJ---1890 Steinitz vs. Gunsburg.pgn...
# Loaded 19 games from PGN file analysis_pgns_test/QFkiT2sJ---1890 Steinitz vs. Gunsburg.pgn.
# Analyzing game World Championship Match 1890/91
# Analyzing game World Championship Match 1890/91
# Analyzing game World Championship Match 1890/91
# Analyzing game World Championship Match 1890/91
# Puzzle found: 6k1/1R6/4Np2/5rpp/3PN3/6KP/8/8 b - - 1 53, Best move: g8h8, Eval difference: 9281
# Puzzle found: 7k/6R1/4Np2/5rp1/3PN2p/7P/6K1/8 b - - 1 55, Best move: g5g4, Eval difference: 230
# Analyzing game World Championship Match 1890/91
# Puzzle found: 2kr1b1r/pp1n1ppp/2p5/5b2/4P1n1/1KN2N2/PP2BPPP/R1B2R2 b - - 0 14, Best move: d7c5, Eval difference: 223
# Puzzle found: 2kr3r/pp1nb1pp/2p2p2/5PP1/4b1BN/1K6/PP5P/R1B2R2 b - - 1 24, Best move: d7c5, Eval difference: 234
# Puzzle found: 2kr3r/pp2b1pp/2p2p2/2n2PP1/4b1BN/K7/PP5P/R1B2R2 b - - 3 25, Best move: d8d3, Eval difference: 9392
# Puzzle found: 2k4r/pp2b1pp/2p2p2/2n2PP1/4b1BN/KP1r4/P6P/R1B2R2 b - - 0 26, Best move: c5a4, Eval difference: 9146
# Analyzing game World Championship Match 1890/91
# Puzzle found: 4r1k1/2b2pp1/p6p/Pp2q2n/1Pp5/2P2P1P/2NQ1B2/1B1R1K2 b - - 0 40, Best move: e5h2, Eval difference: 532
# Puzzle found: 4r1k1/2bQ1pp1/p6p/Pp5n/1Pp5/2P2P1P/2N2B1q/1B1R1K2 b - - 2 41, Best move: h2h1, Eval difference: 9627
# Analyzing game World Championship Match 1890/91
# Puzzle found: rn1qr1k1/p5pp/1p1P4/4p3/3Pn3/BQ6/P4PPP/2RR2K1 b - - 0 18, Best move: g8h8, Eval difference: 228
# Puzzle found: q6k/p2P3p/1p3p2/4P1r1/8/B7/P5PP/2R3K1 w - - 0 26, Best move: c1c8, Eval difference: 770
# Puzzle found: r6k/p2P3p/1p3p2/4P3/8/B7/P5PP/6K1 w - - 0 28, Best move: e5e6, Eval difference: 364
# Analyzing game World Championship Match 1890/91
# Analyzing game World Championship Match 1890/91
# Puzzle found: 6k1/1p1r2pp/p3rp2/4p3/P3P3/q2NQ2P/5PPK/1R6 w - - 0 31, Best move: d3c5, Eval difference: 259
# Puzzle found: 8/6k1/6p1/R5K1/4P2P/8/p7/r7 w - - 0 68, Best move: a5a7, Eval difference: 335
# Puzzle found: 8/5K2/8/8/7P/8/5k2/r7 w - - 0 78, Best move: h4h5, Eval difference: 449
# Puzzle found: 8/5K2/8/7P/8/8/5k2/7r w - - 1 79, Best move: f7g6, Eval difference: 442
# Analyzing game World Championship Match 1890/91
# Analyzing game World Championship Match 1890/91
# Analyzing game World Championship Match 1890/91
# Puzzle found: 1rb1kq1r/Qpbp1ppp/1Np1n3/4pN2/4P1B1/2P5/P4PPP/R2R2K1 w k - 4 21, Best move: b6a8, Eval difference: 208
# Puzzle found: Q1b2q1r/1pbk1ppp/2p1n3/4pN2/4P1B1/2P5/P4PPP/R5K1 w - - 0 24, Best move: a1d1, Eval difference: 333
# Analyzing game World Championship Match 1890/91
# Analyzing game World Championship Match 1890/91
# Puzzle found: r1b2rk1/pp2n1p1/1qp3np/bB1pPp2/Q2P1P2/B7/P3N1PP/R3NRK1 w - - 0 20, Best move: b5d3, Eval difference: 414
# Analyzing game World Championship Match 1890/91
# Puzzle found: q4rk1/p3bppp/1pb1p3/n7/Q2PP3/3BB3/P1RN1PPP/6K1 w - - 3 22, Best move: d3b5, Eval difference: 255
# Analyzing game World Championship Match 1890/91
# Puzzle found: r1b1k2r/ppppnpp1/1b2n2p/4P3/Q2P3N/6P1/PB1NBq1P/R3R2K w kq - 0 21, Best move: d2e4, Eval difference: 325
# Analyzing game World Championship Match 1890/91
# Puzzle found: rnb1k2r/pp3pR1/2p3p1/8/1b2P3/2NK3N/P3B2P/R1B5 w - - 0 20, Best move: h3g5, Eval difference: 274
# Analyzing game World Championship Match 1890/91
# Puzzle found: r1b1k2r/ppppnppp/1bnq4/1N4B1/Q1BpP3/2P2N2/P4PPP/R4RK1 b kq - 1 11, Best move: d6g6, Eval difference: 225
# Puzzle found: 2rr3k/2b2pq1/pn4p1/8/1Qp4R/5NN1/P4PPP/5RK1 b - - 4 35, Best move: h8g8, Eval difference: 559
# Puzzle found: 2rr2k1/5p2/pb3qp1/3n4/Q3R3/5N1P/P1p1NPP1/2R3K1 b - - 0 43, Best move: f6b2, Eval difference: 232
# Puzzle found: 3r2k1/5p2/1b4p1/p2n4/2P5/5N1P/2p1NPP1/2R3K1 b - - 0 47, Best move: d5b4, Eval difference: 244
# Puzzle found: 3r2k1/5p2/6p1/p7/1nP5/5NPP/2p1NK2/2R5 b - - 0 49, Best move: b4d3, Eval difference: 466
# Puzzle found: 3r2k1/5p2/6p1/p7/2P5/4KNPP/2p5/2N5 b - - 0 51, Best move: d8d1, Eval difference: 434
# Analyzing game World Championship Match 1890/91
# Analyzing analysis_pgns_test/hm6ViybN---1966 Petrosian vs. Spassky.pgn...
# Loaded 24 games from PGN file analysis_pgns_test/hm6ViybN---1966 Petrosian vs. Spassky.pgn.
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Puzzle found: 3r4/3r1pk1/pp1qp1p1/6Qp/2PPn3/3RN2P/5PP1/3R2K1 w - - 2 36, Best move: g5h4, Eval difference: 242
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Puzzle found: 8/5b2/5pk1/1R6/4NK2/1P4P1/8/5r2 w - - 3 56, Best move: f4e3, Eval difference: 330
# Puzzle found: 1R6/5k2/5p2/3b4/1P1r1K1N/6P1/8/8 w - - 11 67, Best move: f4e3, Eval difference: 10017
# Puzzle found: 4k3/1R6/5p2/1b1N4/1r6/6P1/5K2/8 b - - 1 76, Best move: b4b2, Eval difference: 359
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Puzzle found: 1k5r/8/p2q4/Pp1P4/1Pp1ppP1/2P3p1/3R4/3QRK2 b - - 0 42, Best move: f4f3, Eval difference: 9374
# Puzzle found: 1k5r/8/p2q4/Pp1P4/1Pp1p1P1/2P2pp1/6R1/3QRK2 b - - 1 43, Best move: h8h1, Eval difference: 9235
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Puzzle found: r2q2k1/7p/p2p4/nppP4/2P2rB1/1P2N3/PQ1N3P/6K1 w - - 0 25, Best move: g4e6, Eval difference: 320
# Puzzle found: 6k1/5r1p/p2N4/nppP2q1/2P5/1P2N3/PQ5P/7K w - - 0 30, Best move: b2h8, Eval difference: 378
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Puzzle found: r4r1k/p1pb2q1/1p1p3p/3P3P/2P1pp2/3BB3/PPQN1P1P/4R2K w - - 0 30, Best move: e1g1, Eval difference: 381
# Puzzle found: r4r1k/p1pb4/1p1p3p/3Pq2P/2P1pp2/3BB3/PPQN1P1P/6RK w - - 2 31, Best move: d2f3, Eval difference: 255
# Puzzle found: r4r1k/p1pb4/1p5p/3PB2P/2P2p2/8/PPp2P1P/6RK b - - 0 34, Best move: h8h7, Eval difference: 400
# Puzzle found: r4r2/p1pb3k/1p5p/3PB2P/2P2p2/8/PPp2P1P/6RK w - - 1 35, Best move: g1g7, Eval difference: 510
# Puzzle found: r4rk1/p1pb1R2/1p5p/3PB2P/2P2p2/8/PPp2P1P/7K w - - 5 37, Best move: f7g7, Eval difference: 655
# Puzzle found: r4r1k/p1pb4/1p4Rp/3PB2P/2P2p2/8/PPp2P1P/7K b - - 8 38, Best move: h8h7, Eval difference: 443
# Puzzle found: r4r2/p1pb3k/1p4Rp/3PB2P/2P2p2/8/PPp2P1P/7K w - - 9 39, Best move: g6g7, Eval difference: 466
# Analyzing game FIDE World Championship Match 1966
# Puzzle found: 5R2/8/8/3Rb1kp/4n3/6P1/4KB2/8 b - - 0 75, Best move: e4c3, Eval difference: 393
# Puzzle found: 8/8/2R5/5k1p/8/5KP1/1b6/8 w - - 0 90, Best move: c6c5, Eval difference: 302
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Puzzle found: 8/p4k2/1n4R1/8/8/8/P1B4P/4r1K1 w - - 3 51, Best move: g1f2, Eval difference: 229
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Puzzle found: r3r1k1/pp1b1ppp/5n2/4q3/P1p1P3/2PB1P2/2Q3PP/R1B2RK1 w - - 0 18, Best move: d3e2, Eval difference: 434
# Puzzle found: r6k/3n2p1/1Bq1bp1p/1R6/2p1P3/2P2P1P/rQ4P1/1R3BK1 w - - 1 32, Best move: b2b4, Eval difference: 371
# Analyzing game FIDE World Championship Match 1966
# Puzzle found: r4rk1/ppp2pb1/6p1/8/3PBqbR/1Q3N2/PP3PP1/2KR4 w - - 5 19, Best move: b3e3, Eval difference: 344
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Analyzing game FIDE World Championship Match 1966
# Puzzle found: r2r4/1p1n2k1/2pP1ppb/p1P1p2p/P1Q1P1qP/BP1N1RP1/6K1/5R2 b - - 12 47, Best move: d8e8, Eval difference: 296
# Analyzing analysis_pgns_test/HpQRsYHb---1995 Kasparov vs. Anand.pgn...
# Loaded 18 games from PGN file analysis_pgns_test/HpQRsYHb---1995 Kasparov vs. Anand.pgn.
# Analyzing game PCA World Championship Match 1995
# Puzzle found: 2brr1k1/2q1bppp/ppnppn2/8/P3PP2/1NN1BB2/1PP2QPP/3R1R1K b - - 1 16, Best move: f6d7, Eval difference: 221
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Puzzle found: 2r1r1k1/1pqbbppp/pB1ppn2/P7/1n2PP2/2NB1N2/1PP3PP/R2Q1R1K b - - 4 15, Best move: c7b8, Eval difference: 294
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Puzzle found: 3rr1k1/1p2bppp/p1bppn2/q7/PP2PP2/2NQBB2/2P3PP/R2R3K b - - 0 17, Best move: a5c7, Eval difference: 234
# Puzzle found: r4bk1/1p1Q1ppp/1B4q1/P1PP2r1/4p3/7P/4B1P1/1R5K w - - 4 32, Best move: b1g1, Eval difference: 222
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Puzzle found: 2r5/4ppk1/3pb1p1/1prN3p/1P2P2P/5P2/1KPR2P1/4R3 b - - 0 29, Best move: c5c4, Eval difference: 283
# Analyzing game PCA World Championship Match 1995
# Puzzle found: r1bqkb1r/2pp1ppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQ1RK1 w kq - 0 6, Best move: a4b3, Eval difference: 301
# Puzzle found: 5rk1/1Rp3r1/p1Pp3p/8/P3K3/2P1PP1P/8/1R6 b - - 0 33, Best move: g7e7, Eval difference: 215
# Puzzle found: 6k1/2r5/p1Pp3p/8/P2KP3/2P4r/8/1R6 w - - 0 37, Best move: b1b8, Eval difference: 290
# Puzzle found: 1R4k1/2r5/p1Pp3p/8/P2KP3/2P4r/8/8 b - - 1 37, Best move: g8f7, Eval difference: 260
# Puzzle found: 1R6/2r2k2/p1Pp3p/8/P2KP3/2P4r/8/8 w - - 2 38, Best move: b8b7, Eval difference: 308
# Puzzle found: 8/1Rr2k2/p1Pp3p/8/P2KP3/2P4r/8/8 b - - 3 38, Best move: c7e7, Eval difference: 367
# Puzzle found: 8/1R2rk2/p1Pp3p/8/P2KP3/2P4r/8/8 w - - 4 39, Best move: c6c7, Eval difference: 297
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Puzzle found: 2r1r1k1/1pqbbppp/pB1ppn2/P7/1n2PP2/2NB1N2/1PP3PP/R2Q1R1K b - - 4 15, Best move: c7b8, Eval difference: 276
# Analyzing game PCA World Championship Match 1995
# Analyzing game PCA World Championship Match 1995
# Analyzing analysis_pgns_test/edeMUtJW---2016 Carlsen vs. Karjakin.pgn...
# Loaded 12 games from PGN file analysis_pgns_test/edeMUtJW---2016 Carlsen vs. Karjakin.pgn.
# Analyzing game FIDE World Championship Match 2016
# Analyzing game FIDE World Championship Match 2016
# Puzzle found: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/3P1N2/PPP2PPP/RNBQ1RK1 w kq - 0 7, Best move: a4b3, Eval difference: 331
# Puzzle found: 6k1/3n2p1/3Npn1p/4p3/1R2P3/5N1P/5PP1/2r3K1 w - - 2 32, Best move: g1h2, Eval difference: 435
# Analyzing game FIDE World Championship Match 2016
# Puzzle found: 3N4/5kbp/8/2r5/1p3PK1/1P6/4R2P/8 b - - 12 50, Best move: f7g6, Eval difference: 488
# Puzzle found: 8/6b1/4N1k1/2r4p/1p3P2/1P3K2/4R2P/8 b - - 1 52, Best move: c5c3, Eval difference: 326
# Puzzle found: 8/4bk2/4R3/4NP1K/1p5p/1P5r/8/8 b - - 1 68, Best move: f7g7, Eval difference: 274
# Puzzle found: 8/4R1k1/8/4NP1K/1p5p/1P5r/8/8 b - - 0 69, Best move: g7f6, Eval difference: 9858
# Puzzle found: 8/8/8/NR3k1K/1p5p/1P6/8/r7 b - - 5 73, Best move: f5f4, Eval difference: 257
# Puzzle found: 8/8/8/7K/2N3Rp/1P6/5k2/r7 b - - 4 76, Best move: h4h3, Eval difference: 242
# Analyzing game FIDE World Championship Match 2016
# Puzzle found: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQR1K1 w kq - 0 7, Best move: a4b3, Eval difference: 322
# Puzzle found: 8/5kp1/p1bp4/4rp2/2pR4/P1P3bP/1P3NP1/2B3K1 w - - 4 34, Best move: g1f1, Eval difference: 255
# Puzzle found: 3b4/8/6b1/p5p1/2pB1pP1/PkP5/1P1K1N2/8 w - - 30 61, Best move: d2c1, Eval difference: 289
# Puzzle found: 3b4/8/8/p1B3p1/2p2pP1/P1P4N/kP2b3/2K5 w - - 36 64, Best move: h3f2, Eval difference: 309
# Puzzle found: 8/2bb4/8/p5p1/2p3P1/P1P1Bp2/kPK2N2/8 w - - 6 73, Best move: c2c1, Eval difference: 200
# Analyzing game FIDE World Championship Match 2016
# Analyzing game FIDE World Championship Match 2016
# Puzzle found: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQR1K1 w kq - 0 7, Best move: a4b3, Eval difference: 331
# Puzzle found: r2q1rk1/1b2b1pp/p4p2/1pp1N3/1n2NB2/1P1P3P/1PP2PP1/R2QR1K1 w - - 0 16, Best move: e5f3, Eval difference: 286
# Puzzle found: r2q1rk1/1b4p1/p3N2p/1pp2p2/1n3B2/1P1P3P/1PP2PP1/R2QR1K1 b - - 1 19, Best move: d8d5, Eval difference: 305
# Analyzing game FIDE World Championship Match 2016
# Analyzing game FIDE World Championship Match 2016
# Puzzle found: 8/6k1/1p1Qpnpp/p1n5/5P2/3qP1PP/6BK/8 w - - 0 39, Best move: d6e7, Eval difference: 375
# Puzzle found: 8/6k1/4Q3/2q1n2p/4P2P/p5P1/6BK/8 b - - 0 52, Best move: a3a2, Eval difference: 265
# Analyzing game FIDE World Championship Match 2016
# Puzzle found: r1bqkb1r/2pp1ppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQ1RK1 w kq - 0 6, Best move: a4b3, Eval difference: 303
# Puzzle found: 6k1/2bq1p1p/6p1/3n4/2BP3R/3Q1P2/3B1P1P/r6K w - - 0 38, Best move: h1g2, Eval difference: 533
# Puzzle found: 8/2bqnk1p/6p1/8/2QP3R/5P2/3B1PKP/r7 b - - 1 40, Best move: f7g7, Eval difference: 354
# Puzzle found: 8/2bq2kp/6p1/3P1n2/2Q4R/2B2P2/5PKP/r7 b - - 2 42, Best move: g7f8, Eval difference: 285
# Puzzle found: 5k2/2b4p/5Qp1/3q4/8/5P2/5PKP/B7 b - - 1 45, Best move: d5f7, Eval difference: 239
# Puzzle found: 8/3kb3/4q1p1/7p/Q7/5P2/3B1PKP/8 b - - 13 61, Best move: e6c6, Eval difference: 210
# Analyzing game FIDE World Championship Match 2016
# Puzzle found: 2k5/1p6/3R4/P3P2p/3p3P/4r1P1/6K1/8 w - - 1 69, Best move: e5e6, Eval difference: 202
# Analyzing game FIDE World Championship Match 2016
# Puzzle found: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/3P1N2/PPP2PPP/RNBQ1RK1 w kq - 0 7, Best move: a4b3, Eval difference: 308
# Puzzle found: 8/6pk/4Q2p/pp6/2PP4/P2P3P/4pqPK/8 w - - 2 34, Best move: e6e4, Eval difference: 573
# Analyzing game FIDE World Championship Match 2016
# Analyzing analysis_pgns_test/Niha8CRu---1951 Botvinnik vs. Bronstein.pgn...
# Loaded 24 games from PGN file analysis_pgns_test/Niha8CRu---1951 Botvinnik vs. Bronstein.pgn.
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: r4rk1/pp1n2pp/3p1nq1/b2Ppb2/6P1/2N1BP2/PP1QN1BP/2R2RK1 b - - 0 17, Best move: f5d3, Eval difference: 237
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 8/2P3bk/3Rb2p/8/2r1p1qp/1R4B1/5QPK/8 w - - 0 46, Best move: g3f4, Eval difference: 293
# Analyzing game FIDE World Championship Match 1951
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 3r1rk1/1p2ppbp/p1n3p1/q2p1b2/1P1P1B2/P1N1P2P/3QBPP1/R2R2K1 b - - 0 17, Best move: a5b6, Eval difference: 284
# Puzzle found: 3r1rk1/1p2ppbp/pqn3p1/3p1b2/NP1P1B2/P3P2P/3QBPP1/R2R2K1 b - - 2 18, Best move: b6a7, Eval difference: 274
# Analyzing game FIDE World Championship Match 1951
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 8/1p6/4pP2/p7/b1Pk2N1/8/1KP5/8 b - - 0 50, Best move: a4e8, Eval difference: 598
# Puzzle found: 4b3/1p6/5P2/p3p3/2P1k1N1/1KP5/8/8 w - - 1 53, Best move: g4h6, Eval difference: 209
# Puzzle found: 3N4/1p6/8/p7/2P2k2/1KP1p3/8/8 w - - 0 57, Best move: d8e6, Eval difference: 346
# Puzzle found: 3N4/1p6/8/p7/2P2k2/2P1p3/2K5/8 b - - 1 57, Best move: f4g3, Eval difference: 319
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 8/8/3k4/Pn1p2pp/1N1P4/2K2P1P/8/8 w - - 1 58, Best move: c3d3, Eval difference: 261
# Analyzing game FIDE World Championship Match 1951
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: rn2qrk1/b1pb2pp/p2p1n2/1P1Ppp2/N7/1Q2PPP1/PP1BN1BP/R3K2R w KQ - 3 15, Best move: b5b6, Eval difference: 260
# Puzzle found: rn2qrk1/b1p3pp/pP1p1n2/3Ppp2/b7/1Q2PPP1/PP1BN1BP/R3K2R w KQ - 0 16, Best move: b6b7, Eval difference: 505
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 5B2/1n3k2/8/2p3pp/1pP1Pp2/1P1K1P1P/8/8 w - - 11 50, Best move: f8h6, Eval difference: 481
# Puzzle found: 8/1n6/6kB/2p3pp/1pP1Pp2/1P1K1P1P/8/8 w - - 13 51, Best move: h6f8, Eval difference: 460
# Puzzle found: 5B2/1n3k2/8/2p3pp/1pP1Pp2/1P3P1P/4K3/8 w - - 17 53, Best move: f8h6, Eval difference: 500
# Puzzle found: 8/1n6/6kB/2p3pp/1pP1Pp2/1P3P1P/4K3/8 w - - 19 54, Best move: h6f8, Eval difference: 400
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 7k/5p1p/1p6/p4N2/1q2p3/1P2R1P1/P1R4P/3r3K w - - 1 36, Best move: h1g2, Eval difference: 9616
# Puzzle found: 7k/5p1p/1p6/p4N2/4p1K1/1P2R1P1/P4q1P/8 b - - 3 39, Best move: f7f6, Eval difference: 258
# Analyzing game FIDE World Championship Match 1951
# Analyzing game FIDE World Championship Match 1951
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 5b2/5p2/6k1/3pPp2/3N3K/r7/8/3R4 w - - 0 58, Best move: d1g1, Eval difference: 306
# Analyzing game FIDE World Championship Match 1951
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 8/1p2Q3/4p2k/1p1p1p1p/3PnP1P/6q1/2R3K1/8 w - - 0 74, Best move: g2h1, Eval difference: 5591
# Analyzing game FIDE World Championship Match 1951
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 1n6/1b4k1/3P1Q2/2PpP1p1/3P1p2/3q4/6PK/2B5 b - - 2 46, Best move: g7h7, Eval difference: 370
# Puzzle found: 1n5k/1b6/3P1Q2/2PpP1p1/3P1p2/3q4/6PK/2B5 b - - 6 48, Best move: h8h7, Eval difference: 341
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 3B1k2/8/6B1/P3n1Pp/3b4/5K2/8/8 w - - 1 55, Best move: f3e4, Eval difference: 384
# Analyzing game FIDE World Championship Match 1951
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 8/6k1/2pp2p1/4p1N1/3nPP2/4R1PK/2r2n2/5B2 w - - 8 50, Best move: h3h4, Eval difference: 304
# Puzzle found: 8/5k2/2p3p1/4p1K1/3nP3/R5PB/5n2/7r w - - 0 59, Best move: a3a7, Eval difference: 235
# Analyzing game FIDE World Championship Match 1951
# Analyzing game FIDE World Championship Match 1951
# Puzzle found: 6k1/1p5p/np2ppp1/3p4/P2P2P1/1n2PPB1/2K4P/5B2 b - - 1 37, Best move: b3a5, Eval difference: 318
# Analyzing game FIDE World Championship Match 1951
# Analyzing analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn...
# Loaded 4 games from PGN file analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn.
# Analyzing game FIDE World Championship Match 1969
# Puzzle found: 8/6kp/2Pn2p1/3B4/1p1R2P1/7P/2rp4/6K1 w - - 0 40, Best move: d5b3, Eval difference: 207
# Puzzle found: 8/5B1R/6p1/2n3k1/8/1p5P/6K1/2r5 w - - 0 47, Best move: h3h4, Eval difference: 227
# Puzzle found: 8/5B1R/5kp1/2n4P/8/5K2/1pr5/8 w - - 0 50, Best move: f7a2, Eval difference: 290
# Puzzle found: 8/8/1R6/2n1k3/8/5K2/Bp6/2r5 b - - 4 53, Best move: c5a4, Eval difference: 211
# Analyzing game FIDE World Championship Match 1969
# Analyzing game FIDE World Championship Match 1969
# Analyzing game FIDE World Championship Match 1969
# Puzzle found: 4r1k1/pp3pp1/5q1p/P1Rp1N2/3P1nP1/1P1b1P2/3Q1K1P/5B2 b - - 2 39, Best move: f6g5, Eval difference: 266
# Puzzle found: 4r1k1/pp3pp1/7p/P1Rp2q1/3P1nP1/1P1bNP2/3Q1K1P/5B2 b - - 4 40, Best move: g5h4, Eval difference: 206
# Analyzing analysis_pgns_test/4S5UuAGn---1986 Karpov vs. Kasparov III.pgn...
# Loaded 5 games from PGN file analysis_pgns_test/4S5UuAGn---1986 Karpov vs. Kasparov III.pgn.
# Analyzing game FIDE World Championship Match 1986
# Analyzing game FIDE World Championship Match 1986
# Analyzing game FIDE World Championship Match 1986
# Analyzing game FIDE World Championship Match 1986
# Analyzing game FIDE World Championship Match 1986
# Analyzing analysis_pgns_test/wgJ634pR---1984 Karpov vs. Kasparov.pgn...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 66
#      64 pgn_file_path = os.path.join(pgn_directory, pgn_file)
#      65 print(f"Analyzing {pgn_file_path}...")
# ---> 66 all_games = load_games_from_pgn(pgn_file_path)
#      68 for game in all_games:
#      69     print(f"Analyzing game {game.headers.get('Event', 'Unknown Event')}")
#
# Cell In[4], line 39, in load_games_from_pgn(file_path)
#      37 def load_games_from_pgn(file_path):
#      38     games = []
# ---> 39     with open(file_path, 'r') as pgn_file:
#      40         while True:
#      41             game = chess.pgn.read_game(pgn_file)
#
# File ~/miniconda3/envs/CSSLAB/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'analysis_pgns_test/wgJ634pR---1984 Karpov vs. Kasparov.pgn'
