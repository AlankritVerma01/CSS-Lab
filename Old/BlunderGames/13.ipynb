# %%
# Import required libraries
import chess
import chess.engine
import chess.pgn
import chess.svg
import subprocess
import os
from PIL import Image
import io

# Paths to your engines and Maia models
stockfish_path = "/opt/homebrew/bin/stockfish"
maia_model_paths = {
    1100: "maia_weights/maia-1100.pb.gz",
    1200: "maia_weights/maia-1200.pb.gz",
    1300: "maia_weights/maia-1300.pb.gz",
    1400: "maia_weights/maia-1400.pb.gz",
    1500: "maia_weights/maia-1500.pb.gz",
    1600: "maia_weights/maia-1600.pb.gz",
    1700: "maia_weights/maia-1700.pb.gz",
    1800: "maia_weights/maia-1800.pb.gz",
    1900: "maia_weights/maia-1900.pb.gz",
}

# Initialize Stockfish engine
print("Initializing Stockfish engine...")
stockfish_engine = chess.engine.SimpleEngine.popen_uci(stockfish_path, stderr=subprocess.DEVNULL)
print("Stockfish engine initialized.")

# Initialize Maia engines
print("Initializing Maia engines...")
maia_engines = {}
for elo, path in maia_model_paths.items():
    print(f"Initializing Maia {elo} engine...")
    maia_engines[elo] = chess.engine.SimpleEngine.popen_uci(["lc0", f"--weights={path}"], stderr=subprocess.DEVNULL)
print("Maia engines initialized.")

def load_games_from_pgn(file_path):
    games = []
    with open(file_path, 'r') as pgn_file:
        while True:
            game = chess.pgn.read_game(pgn_file)
            if game is None:
                break
            games.append(game)
    print(f"Loaded {len(games)} games from PGN file.")
    return games

def analyze_with_engines(game, stockfish_engine, maia_engines):
    board = game.board()
    blunders = []

    for move in game.mainline_moves():
        # Analyze the position before the move
        stockfish_info_before = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1))
        stockfish_eval_before = stockfish_info_before["score"].relative.score(mate_score=10000) / 100.0

        board.push(move)

        # Analyze the position after the move
        stockfish_info_after = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1))
        stockfish_eval_after = stockfish_info_after["score"].relative.score(mate_score=10000) / 100.0
        stockfish_best_move_after = stockfish_info_after["pv"][0] if "pv" in stockfish_info_after else None

        # Define blunder threshold
        if abs(stockfish_eval_before - stockfish_eval_after) > 1.5:
            maia_suggestions = {}
            for elo, maia_engine in maia_engines.items():
                maia_info = maia_engine.analyse(board, chess.engine.Limit(nodes=1))
                maia_eval = maia_info["score"].relative.score(mate_score=10000) / 100.0
                maia_best_move = maia_info["pv"][0] if "pv" in maia_info else None
                maia_suggestions[elo] = (maia_best_move, maia_eval)

            blunders.append((board.fen(), move, stockfish_eval_after, stockfish_best_move_after, maia_suggestions))

    print(f"Analyzed game with {len(blunders)} blunders found.")
    return blunders

def filter_best_blunders(blunders):
    filtered_blunders = []

    # Threshold for considering a majority agreement
    majority_threshold = 0.6  # 60% of the engines should agree

    for fen, move, stockfish_eval, stockfish_best_move, maia_suggestions in blunders:
        move_counts = {}

        # Count how many times each move is suggested
        for elo, (best_move, maia_eval) in maia_suggestions.items():
            if elo > 1300:
                if best_move in move_counts:
                    move_counts[best_move] += 1
                else:
                    move_counts[best_move] = 1

        # Find the move with the highest count
        most_common_move, count = max(move_counts.items(), key=lambda item: item[1])

        # Calculate the agreement ratio
        total_considered = sum(1 for elo in maia_suggestions if elo > 1300)
        agreement_ratio = count / total_considered if total_considered > 0 else 0

        if agreement_ratio >= majority_threshold:
            filtered_blunders.append((fen, move, stockfish_eval, most_common_move, maia_suggestions))

    print(f"Filtered blunders down to {len(filtered_blunders)} consistent ones.")
    return filtered_blunders

def output_blunder_analysis(blunders):
    for fen, move, stockfish_eval, stockfish_best_move, maia_suggestions in blunders:
        print(f"Position: {fen}")
        print(f"Blunder: {move}")
        print(f"Stockfish Evaluation: {stockfish_eval}")
        print(f"Stockfish Suggested Move: {stockfish_best_move}")
        for elo, (best_move, maia_eval) in maia_suggestions.items():
            print(f"Maia {elo} Evaluation: {maia_eval}, Suggested Move: {best_move}")
        print()

# Load games from PGN file
pgn_file_path = "analysis_pgns/0KNdpNQd---1910 Lasker vs. Schlechter.pgn"
all_games = load_games_from_pgn(pgn_file_path)

# Analyze games
all_blunders = []
for game in all_games:
    blunders = analyze_with_engines(game, stockfish_engine, maia_engines)
    filtered_blunders = filter_best_blunders(blunders)
    if filtered_blunders:
        all_blunders.append((game.headers["Event"], filtered_blunders))

# Output analysis
for event, blunder_list in all_blunders:
    print(f"Event: {event}")
    output_blunder_analysis(blunder_list)

# Function to save board image with annotations using svgwrite
def save_board_image_with_svgwrite(board, move=None, output_file="board.png"):
    svg_data = chess.svg.board(board, lastmove=move)
    svg_path = output_file.replace(".png", ".svg")

    # Save the SVG file
    with open(svg_path, "w") as svg_file:
        svg_file.write(svg_data)

    # Convert SVG to PNG using rsvg-convert
    subprocess.run(["rsvg-convert", "-o", output_file, svg_path])

# Function to highlight a move on the board
def highlight_move_with_svgwrite(board, move, output_file="highlighted_board.png"):
    if move in board.legal_moves:
        board.push(move)
        save_board_image_with_svgwrite(board, move, output_file)
        board.pop()  # Revert the move
    else:
        print(f"Illegal move {move} in position {board.fen()}")

# Directory to save images
image_dir = "chess_images"
os.makedirs(image_dir, exist_ok=True)

# Generate images for each critical position
for event, blunder_list in all_blunders:
    print(f"Event: {event}")
    for i, (fen, move, stockfish_eval, stockfish_best_move, maia_suggestions) in enumerate(blunder_list):
        board = chess.Board(fen)

        # Save initial board state
        initial_image_path = os.path.join(image_dir, f"{event.replace(' ', '_')}_pos_{i}_initial.png")
        save_board_image_with_svgwrite(board, output_file=initial_image_path)

        # Highlight the blunder move
        blunder_image_path = os.path.join(image_dir, f"{event.replace(' ', '_')}_pos_{i}_blunder.png")
        highlight_move_with_svgwrite(board, move, output_file=blunder_image_path)

        # Highlight the correct move
        correct_image_path = os.path.join(image_dir, f"{event.replace(' ', '_')}_pos_{i}_correct.png")
        highlight_move_with_svgwrite(board, stockfish_best_move, output_file=correct_image_path)

        print(f"Position: {fen}")
        print(f"Blunder: {move}")
        print(f"Stockfish Evaluation: {stockfish_eval}")
        print(f"Stockfish Suggested Move: {stockfish_best_move}")
        for elo, (best_move, maia_eval) in maia_suggestions.items():
            print(f"Maia {elo} Evaluation: {maia_eval}, Suggested Move: {best_move}")
        print(f"Initial Image: {initial_image_path}")
        print(f"Blunder Image: {blunder_image_path}")
        print(f"Correct Move Image: {correct_image_path}")
        print()

# Cleanup Engines
print("Cleaning up engines...")
stockfish_engine.quit()
for maia_engine in maia_engines.values():
    maia_engine.quit()
print("Engines cleaned up.")
# Out:
# Initializing Stockfish engine...
# Stockfish engine initialized.
# Initializing Maia engines...
# Initializing Maia 1100 engine...
# Initializing Maia 1200 engine...
# Initializing Maia 1300 engine...
# Initializing Maia 1400 engine...
# Initializing Maia 1500 engine...
# Initializing Maia 1600 engine...
# Initializing Maia 1700 engine...
# Initializing Maia 1800 engine...
# Initializing Maia 1900 engine...
# Maia engines initialized.
# Loaded 10 games from PGN file.
# Analyzed game with 7 blunders found.
# Filtered blunders down to 5 consistent ones.
# Analyzed game with 8 blunders found.
# Filtered blunders down to 6 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 13 blunders found.
# Filtered blunders down to 10 consistent ones.
# Analyzed game with 24 blunders found.
# Filtered blunders down to 22 consistent ones.
# Analyzed game with 13 blunders found.
# Filtered blunders down to 13 consistent ones.
# Analyzed game with 15 blunders found.
# Filtered blunders down to 13 consistent ones.
# Analyzed game with 0 blunders found.
# Filtered blunders down to 0 consistent ones.
# Analyzed game with 20 blunders found.
# Filtered blunders down to 18 consistent ones.
# Analyzed game with 78 blunders found.
# Filtered blunders down to 63 consistent ones.
# Event: World Championship Match 1910
# Position: 7r/1rp2k2/3p4/p3np2/P1P2N2/2R3PP/2P3K1/4R3 b - - 0 40
# Blunder: b3c4
# Stockfish Evaluation: -0.81
# Stockfish Suggested Move: b7b4
# Maia 1100 Evaluation: -0.86, Suggested Move: b7b2
# Maia 1200 Evaluation: -1.38, Suggested Move: b7b2
# Maia 1300 Evaluation: -1.54, Suggested Move: b7b2
# Maia 1400 Evaluation: -0.84, Suggested Move: b7b4
# Maia 1500 Evaluation: -0.38, Suggested Move: b7b4
# Maia 1600 Evaluation: -1.32, Suggested Move: b7b4
# Maia 1700 Evaluation: -1.16, Suggested Move: b7b4
# Maia 1800 Evaluation: -0.44, Suggested Move: b7b4
# Maia 1900 Evaluation: -0.99, Suggested Move: b7b2
#
# Position: 7r/2p2k2/3p4/p3np2/PrP2N2/2R3PP/2P3K1/4R3 w - - 1 41
# Blunder: b7b4
# Stockfish Evaluation: 0.8
# Stockfish Suggested Move: c4c5
# Maia 1100 Evaluation: -0.99, Suggested Move: c4c5
# Maia 1200 Evaluation: 0.56, Suggested Move: f4d5
# Maia 1300 Evaluation: -2.12, Suggested Move: c4c5
# Maia 1400 Evaluation: -0.67, Suggested Move: f4d5
# Maia 1500 Evaluation: -1.09, Suggested Move: c4c5
# Maia 1600 Evaluation: -1.27, Suggested Move: c4c5
# Maia 1700 Evaluation: 0.24, Suggested Move: c4c5
# Maia 1800 Evaluation: 0.88, Suggested Move: c4c5
# Maia 1900 Evaluation: -1.86, Suggested Move: c4c5
#
# Position: 7r/2R5/3p4/p2Nnpk1/r7/6PP/2P3K1/4R3 w - - 4 45
# Blunder: f6g5
# Stockfish Evaluation: 1.28
# Stockfish Suggested Move: c7g7
# Maia 1100 Evaluation: 1.44, Suggested Move: c7g7
# Maia 1200 Evaluation: 0.11, Suggested Move: c7g7
# Maia 1300 Evaluation: 0.82, Suggested Move: c7g7
# Maia 1400 Evaluation: 2.63, Suggested Move: c7g7
# Maia 1500 Evaluation: 3.59, Suggested Move: c7g7
# Maia 1600 Evaluation: 3.55, Suggested Move: c7g7
# Maia 1700 Evaluation: 3.0, Suggested Move: c7g7
# Maia 1800 Evaluation: 4.05, Suggested Move: c7g7
# Maia 1900 Evaluation: 1.4, Suggested Move: c7g7
#
# Position: 7r/2R5/3p4/p2Nnpk1/r6P/6P1/2P3K1/4R3 b - - 0 45
# Blunder: h3h4
# Stockfish Evaluation: -1.49
# Stockfish Suggested Move: g5g4
# Maia 1100 Evaluation: -0.24, Suggested Move: g5g4
# Maia 1200 Evaluation: 0.11, Suggested Move: g5g4
# Maia 1300 Evaluation: -0.64, Suggested Move: g5g4
# Maia 1400 Evaluation: -0.13, Suggested Move: g5g4
# Maia 1500 Evaluation: 0.19, Suggested Move: g5g4
# Maia 1600 Evaluation: -0.5, Suggested Move: g5g6
# Maia 1700 Evaluation: 1.36, Suggested Move: g5g4
# Maia 1800 Evaluation: -1.09, Suggested Move: g5g4
# Maia 1900 Evaluation: 0.61, Suggested Move: g5g4
#
# Position: 8/7k/5R2/5p1P/r7/6PK/8/8 w - - 5 70
# Blunder: c4a4
# Stockfish Evaluation: 3.81
# Stockfish Suggested Move: f6f5
# Maia 1100 Evaluation: 0.71, Suggested Move: f6f5
# Maia 1200 Evaluation: 0.91, Suggested Move: f6f5
# Maia 1300 Evaluation: 1.05, Suggested Move: f6f5
# Maia 1400 Evaluation: 1.11, Suggested Move: f6f5
# Maia 1500 Evaluation: 0.96, Suggested Move: f6f5
# Maia 1600 Evaluation: 1.2, Suggested Move: f6f5
# Maia 1700 Evaluation: 1.09, Suggested Move: f6f5
# Maia 1800 Evaluation: 1.31, Suggested Move: f6f5
# Maia 1900 Evaluation: 0.81, Suggested Move: f6f5
#
# Event: World Championship Match 1910
# Position: r2qkb1r/5ppp/p3b3/1pppQ3/P3n3/1BP5/1P3PPP/RNB2RK1 b kq - 1 12
# Blunder: d4e5
# Stockfish Evaluation: 0.98
# Stockfish Suggested Move: c5c4
# Maia 1100 Evaluation: 2.65, Suggested Move: c5c4
# Maia 1200 Evaluation: 1.87, Suggested Move: c5c4
# Maia 1300 Evaluation: -0.03, Suggested Move: c5c4
# Maia 1400 Evaluation: 1.09, Suggested Move: c5c4
# Maia 1500 Evaluation: 5.21, Suggested Move: c5c4
# Maia 1600 Evaluation: 7.18, Suggested Move: c5c4
# Maia 1700 Evaluation: 3.81, Suggested Move: c5c4
# Maia 1800 Evaluation: 2.44, Suggested Move: f8d6
# Maia 1900 Evaluation: 5.8, Suggested Move: c5c4
#
# Position: 1r2k2r/4bppp/4b3/1ppp4/4n3/NBP5/1P3PPP/R1B2RK1 w k - 2 16
# Blunder: f8e7
# Stockfish Evaluation: -0.48
# Stockfish Suggested Move: c1f4
# Maia 1100 Evaluation: -0.64, Suggested Move: c1f4
# Maia 1200 Evaluation: -2.1, Suggested Move: c1f4
# Maia 1300 Evaluation: -1.07, Suggested Move: c1f4
# Maia 1400 Evaluation: -1.53, Suggested Move: c1f4
# Maia 1500 Evaluation: -2.51, Suggested Move: b3c2
# Maia 1600 Evaluation: -2.15, Suggested Move: c1f4
# Maia 1700 Evaluation: -2.95, Suggested Move: c1f4
# Maia 1800 Evaluation: -1.02, Suggested Move: c1f4
# Maia 1900 Evaluation: -2.74, Suggested Move: c1f4
#
# Position: 1r2k2r/4bppp/4b3/1ppp4/4nB2/NBP5/1P3PPP/R4RK1 b k - 3 16
# Blunder: c1f4
# Stockfish Evaluation: 1.08
# Stockfish Suggested Move: b8b7
# Maia 1100 Evaluation: 0.95, Suggested Move: b8b7
# Maia 1200 Evaluation: 1.28, Suggested Move: b8b7
# Maia 1300 Evaluation: 0.86, Suggested Move: b8b7
# Maia 1400 Evaluation: 1.05, Suggested Move: b8b7
# Maia 1500 Evaluation: 1.07, Suggested Move: b8b7
# Maia 1600 Evaluation: 1.73, Suggested Move: b8b7
# Maia 1700 Evaluation: 1.12, Suggested Move: b8b7
# Maia 1800 Evaluation: 5.09, Suggested Move: b8b7
# Maia 1900 Evaluation: 4.16, Suggested Move: b8b7
#
# Position: 4k2r/1r2bppp/4b3/1ppp4/4nB2/NBP5/1P3PPP/R4RK1 w k - 4 17
# Blunder: b8b7
# Stockfish Evaluation: -1.05
# Stockfish Suggested Move: f2f3
# Maia 1100 Evaluation: -0.56, Suggested Move: f2f3
# Maia 1200 Evaluation: -1.19, Suggested Move: f2f3
# Maia 1300 Evaluation: -1.6, Suggested Move: a3c2
# Maia 1400 Evaluation: -0.65, Suggested Move: f2f3
# Maia 1500 Evaluation: -2.1, Suggested Move: f2f3
# Maia 1600 Evaluation: -2.65, Suggested Move: f2f3
# Maia 1700 Evaluation: -3.02, Suggested Move: f2f3
# Maia 1800 Evaluation: -1.46, Suggested Move: a3c2
# Maia 1900 Evaluation: -3.35, Suggested Move: f2f3
#
# Position: 4k2r/1r2bppp/4b3/1ppp4/4nB2/NBP2P2/1P4PP/R4RK1 b k - 0 17
# Blunder: f2f3
# Stockfish Evaluation: 1.5
# Stockfish Suggested Move: e4f6
# Maia 1100 Evaluation: -0.01, Suggested Move: e4f6
# Maia 1200 Evaluation: 1.08, Suggested Move: e4f6
# Maia 1300 Evaluation: 0.0, Suggested Move: e4f6
# Maia 1400 Evaluation: 0.53, Suggested Move: e4f6
# Maia 1500 Evaluation: 1.58, Suggested Move: e4f6
# Maia 1600 Evaluation: 2.03, Suggested Move: e4f6
# Maia 1700 Evaluation: 1.38, Suggested Move: e4f6
# Maia 1800 Evaluation: 2.95, Suggested Move: e4f6
# Maia 1900 Evaluation: 3.0, Suggested Move: e4f6
#
# Position: 4k2r/1r2bppp/4bn2/1ppp4/5B2/NBP2P2/1P4PP/R4RK1 w k - 1 18
# Blunder: e4f6
# Stockfish Evaluation: -0.57
# Stockfish Suggested Move: f1e1
# Maia 1100 Evaluation: -1.38, Suggested Move: f1e1
# Maia 1200 Evaluation: -1.83, Suggested Move: f4e5
# Maia 1300 Evaluation: -1.07, Suggested Move: a3c2
# Maia 1400 Evaluation: -1.06, Suggested Move: f1e1
# Maia 1500 Evaluation: -1.74, Suggested Move: f1e1
# Maia 1600 Evaluation: -3.33, Suggested Move: f4e5
# Maia 1700 Evaluation: -2.74, Suggested Move: b3c2
# Maia 1800 Evaluation: -1.18, Suggested Move: f1e1
# Maia 1900 Evaluation: -4.2, Suggested Move: f1e1
#
# Event: World Championship Match 1910
# Position: 1r1q1rk1/4b1pp/4b3/1p1pPp2/3p1P2/8/1PBB2PP/R2Q1RK1 w - f6 0 18
# Blunder: f7f5
# Stockfish Evaluation: 0.97
# Stockfish Suggested Move: e5f6
# Maia 1100 Evaluation: 0.47, Suggested Move: e5f6
# Maia 1200 Evaluation: -0.47, Suggested Move: e5f6
# Maia 1300 Evaluation: 0.22, Suggested Move: e5f6
# Maia 1400 Evaluation: 0.28, Suggested Move: e5f6
# Maia 1500 Evaluation: 1.08, Suggested Move: e5f6
# Maia 1600 Evaluation: 0.08, Suggested Move: e5f6
# Maia 1700 Evaluation: 0.46, Suggested Move: e5f6
# Maia 1800 Evaluation: 0.77, Suggested Move: e5f6
# Maia 1900 Evaluation: -0.01, Suggested Move: e5f6
#
# Position: 2r3k1/3qbbpp/7r/1p1pBP2/3p4/3B4/1P4PP/R2Q1RK1 w - - 7 23
# Blunder: f6h6
# Stockfish Evaluation: 1.32
# Stockfish Suggested Move: d1g4
# Maia 1100 Evaluation: 3.72, Suggested Move: d1g4
# Maia 1200 Evaluation: 8.17, Suggested Move: d1g4
# Maia 1300 Evaluation: 7.45, Suggested Move: d1g4
# Maia 1400 Evaluation: 7.07, Suggested Move: d1g4
# Maia 1500 Evaluation: 7.85, Suggested Move: d1g4
# Maia 1600 Evaluation: 6.96, Suggested Move: d1g4
# Maia 1700 Evaluation: 4.09, Suggested Move: e5d4
# Maia 1800 Evaluation: 4.92, Suggested Move: d1g4
# Maia 1900 Evaluation: 2.58, Suggested Move: d1g4
#
# Position: 2r3k1/3qbbpp/7r/1p1pBP2/3p2Q1/3B4/1P4PP/R4RK1 b - - 8 23
# Blunder: d1g4
# Stockfish Evaluation: -1.44
# Stockfish Suggested Move: e7f6
# Maia 1100 Evaluation: -13.15, Suggested Move: e7f6
# Maia 1200 Evaluation: -6.43, Suggested Move: e7f6
# Maia 1300 Evaluation: -9.77, Suggested Move: e7f6
# Maia 1400 Evaluation: -6.09, Suggested Move: e7f6
# Maia 1500 Evaluation: -10.73, Suggested Move: e7f6
# Maia 1600 Evaluation: -6.6, Suggested Move: e7f6
# Maia 1700 Evaluation: -10.57, Suggested Move: e7f6
# Maia 1800 Evaluation: -7.56, Suggested Move: e7f6
# Maia 1900 Evaluation: -5.07, Suggested Move: e7f6
#
# Position: 2r3k1/3q1bpp/5b1r/1p1pBP2/3p2Q1/3B4/1P4PP/R4RK1 w - - 9 24
# Blunder: e7f6
# Stockfish Evaluation: 1.37
# Stockfish Suggested Move: e5f6
# Maia 1100 Evaluation: 3.73, Suggested Move: e5f6
# Maia 1200 Evaluation: 1.98, Suggested Move: e5f6
# Maia 1300 Evaluation: 2.76, Suggested Move: e5f6
# Maia 1400 Evaluation: 1.7, Suggested Move: e5f6
# Maia 1500 Evaluation: 4.19, Suggested Move: e5f6
# Maia 1600 Evaluation: 1.81, Suggested Move: e5f6
# Maia 1700 Evaluation: 2.18, Suggested Move: e5f6
# Maia 1800 Evaluation: 0.95, Suggested Move: e5f6
# Maia 1900 Evaluation: 4.55, Suggested Move: e5f6
#
# Position: 2r3k1/3q1bpp/5B1r/1p1p1P2/3p2Q1/3B4/1P4PP/R4RK1 b - - 0 24
# Blunder: e5f6
# Stockfish Evaluation: -0.81
# Stockfish Suggested Move: h6f6
# Maia 1100 Evaluation: -4.2, Suggested Move: h6f6
# Maia 1200 Evaluation: -4.59, Suggested Move: h6f6
# Maia 1300 Evaluation: -1.19, Suggested Move: h6f6
# Maia 1400 Evaluation: -5.88, Suggested Move: h6f6
# Maia 1500 Evaluation: -9.35, Suggested Move: h6f6
# Maia 1600 Evaluation: -5.09, Suggested Move: h6f6
# Maia 1700 Evaluation: -7.46, Suggested Move: h6f6
# Maia 1800 Evaluation: -2.95, Suggested Move: h6f6
# Maia 1900 Evaluation: -5.16, Suggested Move: h6f6
#
# Position: 2r3k1/3q1bpp/5r2/1p1p1P2/3p2Q1/3B4/1P4PP/R4RK1 w - - 0 25
# Blunder: h6f6
# Stockfish Evaluation: 0.94
# Stockfish Suggested Move: g4d4
# Maia 1100 Evaluation: 2.39, Suggested Move: g4d4
# Maia 1200 Evaluation: 1.43, Suggested Move: g4d4
# Maia 1300 Evaluation: 2.68, Suggested Move: g4d4
# Maia 1400 Evaluation: 3.58, Suggested Move: g4d4
# Maia 1500 Evaluation: 2.45, Suggested Move: g4d4
# Maia 1600 Evaluation: 0.89, Suggested Move: g4d4
# Maia 1700 Evaluation: 1.46, Suggested Move: g4d4
# Maia 1800 Evaluation: 1.18, Suggested Move: g4d4
# Maia 1900 Evaluation: 0.24, Suggested Move: g4d4
#
# Position: 2r3k1/3q1bp1/5r1p/1p1p1P2/3Q4/3B4/1P4PP/R4RK1 w - - 0 26
# Blunder: h7h6
# Stockfish Evaluation: 0.75
# Stockfish Suggested Move: a1a7
# Maia 1100 Evaluation: 1.6, Suggested Move: a1a7
# Maia 1200 Evaluation: 1.46, Suggested Move: a1a7
# Maia 1300 Evaluation: 1.95, Suggested Move: a1a7
# Maia 1400 Evaluation: 3.02, Suggested Move: a1a7
# Maia 1500 Evaluation: 1.08, Suggested Move: a1a7
# Maia 1600 Evaluation: 3.25, Suggested Move: a1a7
# Maia 1700 Evaluation: 1.54, Suggested Move: a1a7
# Maia 1800 Evaluation: 0.93, Suggested Move: a1a7
# Maia 1900 Evaluation: 0.86, Suggested Move: a1a7
#
# Position: 6k1/5bp1/7p/3pqP2/1Q6/3B2P1/1P3K1P/8 b - - 0 34
# Blunder: g2g3
# Stockfish Evaluation: -1.07
# Stockfish Suggested Move: d5d4
# Maia 1100 Evaluation: -0.67, Suggested Move: d5d4
# Maia 1200 Evaluation: -0.42, Suggested Move: d5d4
# Maia 1300 Evaluation: -0.24, Suggested Move: d5d4
# Maia 1400 Evaluation: -1.03, Suggested Move: d5d4
# Maia 1500 Evaluation: -1.89, Suggested Move: d5d4
# Maia 1600 Evaluation: 0.44, Suggested Move: d5d4
# Maia 1700 Evaluation: -0.11, Suggested Move: d5d4
# Maia 1800 Evaluation: -1.08, Suggested Move: d5d4
# Maia 1900 Evaluation: -0.34, Suggested Move: d5d4
#
# Position: 6k1/5bp1/8/3pqP1p/1Q6/3B2P1/1P3K1P/8 w - - 0 35
# Blunder: h6h5
# Stockfish Evaluation: 1.42
# Stockfish Suggested Move: h2h4
# Maia 1100 Evaluation: 0.78, Suggested Move: h2h4
# Maia 1200 Evaluation: 0.6, Suggested Move: h2h4
# Maia 1300 Evaluation: 0.88, Suggested Move: h2h4
# Maia 1400 Evaluation: 0.46, Suggested Move: h2h4
# Maia 1500 Evaluation: 0.26, Suggested Move: b4c3
# Maia 1600 Evaluation: 0.47, Suggested Move: h2h4
# Maia 1700 Evaluation: 0.08, Suggested Move: h2h4
# Maia 1800 Evaluation: 0.47, Suggested Move: b4c3
# Maia 1900 Evaluation: 0.25, Suggested Move: h2h4
#
# Position: 6k1/5bp1/1Q6/3pqP2/7p/3B2P1/1P3K1P/8 w - - 0 36
# Blunder: h5h4
# Stockfish Evaluation: 0.79
# Stockfish Suggested Move: b6d8
# Maia 1100 Evaluation: 0.64, Suggested Move: g3h4
# Maia 1200 Evaluation: -0.72, Suggested Move: b6d8
# Maia 1300 Evaluation: 0.79, Suggested Move: b6d8
# Maia 1400 Evaluation: 0.09, Suggested Move: b6d8
# Maia 1500 Evaluation: -0.64, Suggested Move: b6d8
# Maia 1600 Evaluation: -0.36, Suggested Move: b6d8
# Maia 1700 Evaluation: -0.66, Suggested Move: b6d8
# Maia 1800 Evaluation: -0.58, Suggested Move: b6d8
# Maia 1900 Evaluation: -0.1, Suggested Move: b6d8
#
# Event: World Championship Match 1910
# Position: 8/2k3p1/q1pp1p2/4r1p1/1Q2P1P1/7P/5PK1/1R6 b - - 7 44
# Blunder: d4b4
# Stockfish Evaluation: 2.06
# Stockfish Suggested Move: e5b5
# Maia 1100 Evaluation: 0.59, Suggested Move: e5b5
# Maia 1200 Evaluation: -0.08, Suggested Move: e5b5
# Maia 1300 Evaluation: -0.59, Suggested Move: e5b5
# Maia 1400 Evaluation: -0.09, Suggested Move: e5b5
# Maia 1500 Evaluation: 0.0, Suggested Move: e5b5
# Maia 1600 Evaluation: 1.17, Suggested Move: e5b5
# Maia 1700 Evaluation: 1.01, Suggested Move: e5b5
# Maia 1800 Evaluation: 0.52, Suggested Move: e5b5
# Maia 1900 Evaluation: 0.73, Suggested Move: e5b5
#
# Position: 8/2k3p1/2pp1p2/1q2r1p1/1Q2P1P1/7P/5PK1/1R6 w - - 8 45
# Blunder: a6b5
# Stockfish Evaluation: -2.33
# Stockfish Suggested Move: b4b5
# Maia 1100 Evaluation: -0.65, Suggested Move: b4b5
# Maia 1200 Evaluation: -0.96, Suggested Move: b4b5
# Maia 1300 Evaluation: -1.27, Suggested Move: b4b5
# Maia 1400 Evaluation: -0.69, Suggested Move: b4b5
# Maia 1500 Evaluation: -1.31, Suggested Move: b4b5
# Maia 1600 Evaluation: -0.79, Suggested Move: b4b5
# Maia 1700 Evaluation: -2.45, Suggested Move: b4b5
# Maia 1800 Evaluation: -0.87, Suggested Move: b4b5
# Maia 1900 Evaluation: -1.12, Suggested Move: b4b5
#
# Position: 8/2k3p1/2pp1p2/1q2r1p1/4P1P1/7P/5PK1/1R2Q3 b - - 9 45
# Blunder: b4e1
# Stockfish Evaluation: 2.39
# Stockfish Suggested Move: b5d3
# Maia 1100 Evaluation: 0.89, Suggested Move: b5d3
# Maia 1200 Evaluation: 0.23, Suggested Move: b5d3
# Maia 1300 Evaluation: -0.22, Suggested Move: b5d3
# Maia 1400 Evaluation: 0.19, Suggested Move: b5d3
# Maia 1500 Evaluation: 0.26, Suggested Move: b5d3
# Maia 1600 Evaluation: 1.04, Suggested Move: b5c4
# Maia 1700 Evaluation: 1.84, Suggested Move: b5d3
# Maia 1800 Evaluation: 0.23, Suggested Move: b5d3
# Maia 1900 Evaluation: 0.55, Suggested Move: b5d3
#
# Position: 8/2k3p1/2pp1p2/4r1p1/4P1P1/3q3P/5PK1/1R2Q3 w - - 10 46
# Blunder: b5d3
# Stockfish Evaluation: -2.04
# Stockfish Suggested Move: f2f3
# Maia 1100 Evaluation: -0.87, Suggested Move: f2f3
# Maia 1200 Evaluation: -2.77, Suggested Move: f2f3
# Maia 1300 Evaluation: -1.41, Suggested Move: f2f3
# Maia 1400 Evaluation: -1.84, Suggested Move: f2f3
# Maia 1500 Evaluation: -1.33, Suggested Move: f2f3
# Maia 1600 Evaluation: -0.63, Suggested Move: f2f3
# Maia 1700 Evaluation: -2.58, Suggested Move: e1b4
# Maia 1800 Evaluation: -1.68, Suggested Move: f2f3
# Maia 1900 Evaluation: -1.38, Suggested Move: f2f3
#
# Position: 8/2k3p1/2pp1p2/4r1p1/1R2P1P1/3q3P/5PK1/4Q3 b - - 11 46
# Blunder: b1b4
# Stockfish Evaluation: 1.91
# Stockfish Suggested Move: d6d5
# Maia 1100 Evaluation: 1.68, Suggested Move: c6c5
# Maia 1200 Evaluation: 1.02, Suggested Move: d6d5
# Maia 1300 Evaluation: 0.87, Suggested Move: c6c5
# Maia 1400 Evaluation: 0.4, Suggested Move: d6d5
# Maia 1500 Evaluation: 0.17, Suggested Move: d6d5
# Maia 1600 Evaluation: 1.85, Suggested Move: d6d5
# Maia 1700 Evaluation: 2.96, Suggested Move: d6d5
# Maia 1800 Evaluation: 0.92, Suggested Move: c6c5
# Maia 1900 Evaluation: 1.76, Suggested Move: d6d5
#
# Position: 8/2k3p1/3p1p2/2p1r1p1/1R2P1P1/3q3P/5PK1/4Q3 w - - 0 47
# Blunder: c6c5
# Stockfish Evaluation: -1.75
# Stockfish Suggested Move: b4a4
# Maia 1100 Evaluation: -0.94, Suggested Move: b4a4
# Maia 1200 Evaluation: -2.84, Suggested Move: b4a4
# Maia 1300 Evaluation: -1.65, Suggested Move: b4a4
# Maia 1400 Evaluation: -2.85, Suggested Move: b4a4
# Maia 1500 Evaluation: -2.89, Suggested Move: b4a4
# Maia 1600 Evaluation: -2.28, Suggested Move: b4a4
# Maia 1700 Evaluation: -1.89, Suggested Move: b4a4
# Maia 1800 Evaluation: -3.61, Suggested Move: b4a4
# Maia 1900 Evaluation: -2.7, Suggested Move: b4a4
#
# Position: 8/2k3p1/3p1p2/4r1p1/R1p1P1P1/3q3P/5PK1/4Q3 w - - 0 48
# Blunder: c5c4
# Stockfish Evaluation: -1.34
# Stockfish Suggested Move: a4a7
# Maia 1100 Evaluation: -1.09, Suggested Move: a4a7
# Maia 1200 Evaluation: -3.14, Suggested Move: a4a7
# Maia 1300 Evaluation: -1.22, Suggested Move: a4a7
# Maia 1400 Evaluation: -2.06, Suggested Move: a4a7
# Maia 1500 Evaluation: -1.18, Suggested Move: a4a7
# Maia 1600 Evaluation: -1.47, Suggested Move: a4a7
# Maia 1700 Evaluation: -1.33, Suggested Move: a4a7
# Maia 1800 Evaluation: -1.28, Suggested Move: a4a7
# Maia 1900 Evaluation: -1.38, Suggested Move: a4a7
#
# Position: 8/2k3p1/3p1p2/4r1p1/R1p1P1P1/3q3P/5PK1/Q7 b - - 1 48
# Blunder: e1a1
# Stockfish Evaluation: 1.13
# Stockfish Suggested Move: d3e4
# Maia 1100 Evaluation: 1.82, Suggested Move: c4c3
# Maia 1200 Evaluation: 0.97, Suggested Move: d3e4
# Maia 1300 Evaluation: 2.27, Suggested Move: d3e4
# Maia 1400 Evaluation: 1.28, Suggested Move: d3e4
# Maia 1500 Evaluation: 2.76, Suggested Move: d3e4
# Maia 1600 Evaluation: 0.98, Suggested Move: d3e4
# Maia 1700 Evaluation: 1.74, Suggested Move: d3e4
# Maia 1800 Evaluation: -0.51, Suggested Move: d3e4
# Maia 1900 Evaluation: 2.72, Suggested Move: d3e4
#
# Position: 8/2k3p1/3p1p2/4r1p1/R1p1q1P1/7P/5PK1/Q7 w - - 0 49
# Blunder: d3e4
# Stockfish Evaluation: -1.12
# Stockfish Suggested Move: g2g1
# Maia 1100 Evaluation: -4.49, Suggested Move: f2f3
# Maia 1200 Evaluation: -4.33, Suggested Move: f2f3
# Maia 1300 Evaluation: -4.13, Suggested Move: f2f3
# Maia 1400 Evaluation: -5.08, Suggested Move: f2f3
# Maia 1500 Evaluation: -4.73, Suggested Move: g2g1
# Maia 1600 Evaluation: -4.25, Suggested Move: g2g1
# Maia 1700 Evaluation: -6.88, Suggested Move: g2g1
# Maia 1800 Evaluation: -4.09, Suggested Move: g2g1
# Maia 1900 Evaluation: -3.31, Suggested Move: g2g1
#
# Position: 8/2k3p1/3p1p2/4r1p1/R1p1q1P1/7P/5P1K/Q7 b - - 1 49
# Blunder: g2h2
# Stockfish Evaluation: 1.06
# Stockfish Suggested Move: e4f4
# Maia 1100 Evaluation: 1.78, Suggested Move: e4f4
# Maia 1200 Evaluation: 3.35, Suggested Move: e4f4
# Maia 1300 Evaluation: 2.95, Suggested Move: e4f4
# Maia 1400 Evaluation: 1.89, Suggested Move: e4f4
# Maia 1500 Evaluation: 1.31, Suggested Move: e4f4
# Maia 1600 Evaluation: 3.27, Suggested Move: e4f4
# Maia 1700 Evaluation: 4.93, Suggested Move: e4f4
# Maia 1800 Evaluation: 2.92, Suggested Move: e4f4
# Maia 1900 Evaluation: 4.02, Suggested Move: e4f4
#
# Position: 8/2k3p1/3p1p2/1r4p1/R1p1q1P1/7P/5P1K/Q7 w - - 2 50
# Blunder: e5b5
# Stockfish Evaluation: -0.73
# Stockfish Suggested Move: a4a7
# Maia 1100 Evaluation: -2.06, Suggested Move: a4a7
# Maia 1200 Evaluation: -2.68, Suggested Move: a4a7
# Maia 1300 Evaluation: -3.06, Suggested Move: a4a7
# Maia 1400 Evaluation: -3.13, Suggested Move: a4a7
# Maia 1500 Evaluation: -3.44, Suggested Move: a4a7
# Maia 1600 Evaluation: -3.09, Suggested Move: a4a7
# Maia 1700 Evaluation: -3.44, Suggested Move: a4a7
# Maia 1800 Evaluation: -2.75, Suggested Move: a4a7
# Maia 1900 Evaluation: -3.8, Suggested Move: a4a7
#
# Position: 8/2k3p1/3p1p2/1r4p1/R1p3P1/7P/Q4P2/4q1K1 w - - 6 52
# Blunder: e5e1
# Stockfish Evaluation: -0.86
# Stockfish Suggested Move: g1g2
# Maia 1100 Evaluation: -0.66, Suggested Move: g1g2
# Maia 1200 Evaluation: -2.23, Suggested Move: g1g2
# Maia 1300 Evaluation: -2.77, Suggested Move: g1g2
# Maia 1400 Evaluation: -1.52, Suggested Move: g1g2
# Maia 1500 Evaluation: -1.82, Suggested Move: g1g2
# Maia 1600 Evaluation: -2.15, Suggested Move: g1g2
# Maia 1700 Evaluation: -2.32, Suggested Move: g1g2
# Maia 1800 Evaluation: -1.62, Suggested Move: g1g2
# Maia 1900 Evaluation: -1.73, Suggested Move: g1g2
#
# Position: 8/2k3p1/5p2/1r1p2p1/R1p3P1/7P/Q4P1K/4q3 w - - 0 53
# Blunder: d6d5
# Stockfish Evaluation: -1.12
# Stockfish Suggested Move: a4a7
# Maia 1100 Evaluation: -1.9, Suggested Move: a4a7
# Maia 1200 Evaluation: -1.81, Suggested Move: a4a7
# Maia 1300 Evaluation: -3.79, Suggested Move: a4a7
# Maia 1400 Evaluation: -3.47, Suggested Move: a4a7
# Maia 1500 Evaluation: -4.02, Suggested Move: a4a7
# Maia 1600 Evaluation: -3.62, Suggested Move: a4a7
# Maia 1700 Evaluation: -4.25, Suggested Move: a4a7
# Maia 1800 Evaluation: -2.89, Suggested Move: a4a7
# Maia 1900 Evaluation: -3.86, Suggested Move: a4a7
#
# Position: R7/2k3p1/5p2/1r1p2p1/1qp3P1/7P/Q4PK1/8 b - - 3 54
# Blunder: h2g2
# Stockfish Evaluation: 0.8
# Stockfish Suggested Move: c4c3
# Maia 1100 Evaluation: 2.56, Suggested Move: d5d4
# Maia 1200 Evaluation: 1.59, Suggested Move: d5d4
# Maia 1300 Evaluation: 3.12, Suggested Move: c4c3
# Maia 1400 Evaluation: 1.07, Suggested Move: c4c3
# Maia 1500 Evaluation: 1.58, Suggested Move: c4c3
# Maia 1600 Evaluation: 2.01, Suggested Move: d5d4
# Maia 1700 Evaluation: 3.45, Suggested Move: c4c3
# Maia 1800 Evaluation: 2.91, Suggested Move: d5d4
# Maia 1900 Evaluation: 2.53, Suggested Move: c4c3
#
# Position: R7/2k3p1/Q4p2/1rqp2p1/2p3P1/7P/5PK1/8 b - - 5 55
# Blunder: a2a6
# Stockfish Evaluation: -1.22
# Stockfish Suggested Move: b5b6
# Maia 1100 Evaluation: 1.41, Suggested Move: b5b6
# Maia 1200 Evaluation: 2.2, Suggested Move: b5b6
# Maia 1300 Evaluation: 2.92, Suggested Move: b5b6
# Maia 1400 Evaluation: 1.11, Suggested Move: b5b6
# Maia 1500 Evaluation: 1.14, Suggested Move: b5b6
# Maia 1600 Evaluation: 1.02, Suggested Move: b5b6
# Maia 1700 Evaluation: -1.97, Suggested Move: b5b6
# Maia 1800 Evaluation: 4.64, Suggested Move: b5b6
# Maia 1900 Evaluation: 0.77, Suggested Move: b5b6
#
# Position: Rr6/2k3p1/Q4p2/2qp2p1/2p3P1/7P/5PK1/8 w - - 6 56
# Blunder: b5b8
# Stockfish Evaluation: 3.49
# Stockfish Suggested Move: a8a7
# Maia 1100 Evaluation: -0.19, Suggested Move: a8a7
# Maia 1200 Evaluation: 0.0, Suggested Move: a8a7
# Maia 1300 Evaluation: -1.28, Suggested Move: a8a7
# Maia 1400 Evaluation: -0.34, Suggested Move: a8a7
# Maia 1500 Evaluation: -1.16, Suggested Move: a8a7
# Maia 1600 Evaluation: -0.52, Suggested Move: a8a7
# Maia 1700 Evaluation: 0.77, Suggested Move: a8a7
# Maia 1800 Evaluation: -2.29, Suggested Move: a8a7
# Maia 1900 Evaluation: -1.44, Suggested Move: a8a7
#
# Position: 1r6/R1k3p1/Q4p2/2qp2p1/2p3P1/7P/5PK1/8 b - - 7 56
# Blunder: a8a7
# Stockfish Evaluation: -3.88
# Stockfish Suggested Move: c7d8
# Maia 1100 Evaluation: -0.74, Suggested Move: c7d8
# Maia 1200 Evaluation: -2.38, Suggested Move: c7d8
# Maia 1300 Evaluation: -1.6, Suggested Move: c7d8
# Maia 1400 Evaluation: -1.53, Suggested Move: c7d8
# Maia 1500 Evaluation: -0.88, Suggested Move: c5a7
# Maia 1600 Evaluation: -0.87, Suggested Move: c7d8
# Maia 1700 Evaluation: -1.38, Suggested Move: c7d8
# Maia 1800 Evaluation: 0.07, Suggested Move: c5a7
# Maia 1900 Evaluation: 0.19, Suggested Move: c7d8
#
# Position: 1r1k4/R5p1/Q4p2/2qp2p1/2p3P1/7P/5PK1/8 w - - 8 57
# Blunder: c7d8
# Stockfish Evaluation: 5.73
# Stockfish Suggested Move: a7g7
# Maia 1100 Evaluation: 0.7, Suggested Move: a7g7
# Maia 1200 Evaluation: 2.65, Suggested Move: a7g7
# Maia 1300 Evaluation: -0.45, Suggested Move: a7g7
# Maia 1400 Evaluation: 1.86, Suggested Move: a6a5
# Maia 1500 Evaluation: 3.16, Suggested Move: a7g7
# Maia 1600 Evaluation: 1.28, Suggested Move: a7g7
# Maia 1700 Evaluation: 1.78, Suggested Move: a6e6
# Maia 1800 Evaluation: 0.17, Suggested Move: a7g7
# Maia 1900 Evaluation: 2.24, Suggested Move: a7g7
#
# Position: 1r1k4/6R1/Q4p2/2qp2p1/2p3P1/7P/5PK1/8 b - - 0 57
# Blunder: a7g7
# Stockfish Evaluation: -6.13
# Stockfish Suggested Move: c4c3
# Maia 1100 Evaluation: -0.26, Suggested Move: c4c3
# Maia 1200 Evaluation: -1.07, Suggested Move: c4c3
# Maia 1300 Evaluation: -1.08, Suggested Move: c4c3
# Maia 1400 Evaluation: 0.66, Suggested Move: c4c3
# Maia 1500 Evaluation: -2.13, Suggested Move: b8b6
# Maia 1600 Evaluation: -1.04, Suggested Move: c4c3
# Maia 1700 Evaluation: -1.12, Suggested Move: c5e7
# Maia 1800 Evaluation: 0.1, Suggested Move: c4c3
# Maia 1900 Evaluation: -0.31, Suggested Move: c4c3
#
# Position: 1r1k4/6R1/Qq3p2/3p2p1/2p3P1/7P/5PK1/8 w - - 1 58
# Blunder: c5b6
# Stockfish Evaluation: 7.42
# Stockfish Suggested Move: g7g8
# Maia 1100 Evaluation: 2.72, Suggested Move: g7g8
# Maia 1200 Evaluation: 1.57, Suggested Move: g7g8
# Maia 1300 Evaluation: 2.87, Suggested Move: g7g8
# Maia 1400 Evaluation: 1.35, Suggested Move: g7g8
# Maia 1500 Evaluation: 2.6, Suggested Move: g7g8
# Maia 1600 Evaluation: 0.4, Suggested Move: g7g8
# Maia 1700 Evaluation: 0.95, Suggested Move: a6a7
# Maia 1800 Evaluation: 0.77, Suggested Move: g7g8
# Maia 1900 Evaluation: 1.33, Suggested Move: g7g8
#
# Position: 1r1k4/6R1/1q3p2/3p2p1/2p3P1/Q6P/5PK1/8 b - - 2 58
# Blunder: a6a3
# Stockfish Evaluation: -9.44
# Stockfish Suggested Move: b8b7
# Maia 1100 Evaluation: -1.42, Suggested Move: b8b7
# Maia 1200 Evaluation: -2.01, Suggested Move: b6b3
# Maia 1300 Evaluation: -2.32, Suggested Move: b8b7
# Maia 1400 Evaluation: -1.78, Suggested Move: b8b7
# Maia 1500 Evaluation: -3.02, Suggested Move: b6e6
# Maia 1600 Evaluation: -1.52, Suggested Move: b8b7
# Maia 1700 Evaluation: -0.97, Suggested Move: b8b7
# Maia 1800 Evaluation: -2.74, Suggested Move: b8b7
# Maia 1900 Evaluation: -2.21, Suggested Move: b6b4
#
# Position: 1rk5/6R1/1q3p2/3p2p1/2p3P1/Q6P/5PK1/8 w - - 3 59
# Blunder: d8c8
# Stockfish Evaluation: 99.97
# Stockfish Suggested Move: a3f8
# Maia 1100 Evaluation: 5.12, Suggested Move: a3f8
# Maia 1200 Evaluation: 2.82, Suggested Move: g7g8
# Maia 1300 Evaluation: 4.11, Suggested Move: a3f8
# Maia 1400 Evaluation: 3.34, Suggested Move: a3f8
# Maia 1500 Evaluation: 5.99, Suggested Move: a3f8
# Maia 1600 Evaluation: 2.7, Suggested Move: a3f8
# Maia 1700 Evaluation: 3.76, Suggested Move: a3f8
# Maia 1800 Evaluation: 3.22, Suggested Move: a3f8
# Maia 1900 Evaluation: 4.33, Suggested Move: a3f8
#
# Event: World Championship Match 1910
# Position: 1r1q1rk1/2p2ppp/2n1b3/1pbpP3/8/2P2N2/1PBQ1PPP/R1B2RK1 b - - 0 14
# Blunder: d1d2
# Stockfish Evaluation: -0.88
# Stockfish Suggested Move: b5b4
# Maia 1100 Evaluation: -2.75, Suggested Move: b5b4
# Maia 1200 Evaluation: -2.58, Suggested Move: b5b4
# Maia 1300 Evaluation: -4.64, Suggested Move: e6g4
# Maia 1400 Evaluation: -5.49, Suggested Move: e6g4
# Maia 1500 Evaluation: -2.83, Suggested Move: b5b4
# Maia 1600 Evaluation: -2.8, Suggested Move: b5b4
# Maia 1700 Evaluation: -4.02, Suggested Move: b5b4
# Maia 1800 Evaluation: -2.78, Suggested Move: b5b4
# Maia 1900 Evaluation: -1.45, Suggested Move: b5b4
#
# Position: 1r3rk1/2pq1ppp/2n1b3/1pbpP3/8/2P2N2/1PBQ1PPP/R1B2RK1 w - - 1 15
# Blunder: d8d7
# Stockfish Evaluation: 0.8
# Stockfish Suggested Move: d2d3
# Maia 1100 Evaluation: 6.38, Suggested Move: d2d3
# Maia 1200 Evaluation: 11.24, Suggested Move: d2d3
# Maia 1300 Evaluation: 6.87, Suggested Move: d2d3
# Maia 1400 Evaluation: 10.81, Suggested Move: d2d3
# Maia 1500 Evaluation: 5.84, Suggested Move: d2d3
# Maia 1600 Evaluation: 7.11, Suggested Move: f3g5
# Maia 1700 Evaluation: 7.97, Suggested Move: d2d3
# Maia 1800 Evaluation: 5.07, Suggested Move: d2d3
# Maia 1900 Evaluation: 3.44, Suggested Move: d2d3
#
# Position: 1r3rk1/2pq1ppp/2n1b3/1pbpP3/1P6/2P2N2/2BQ1PPP/R1B2RK1 b - - 0 15
# Blunder: b2b4
# Stockfish Evaluation: -0.85
# Stockfish Suggested Move: c5b6
# Maia 1100 Evaluation: -2.0, Suggested Move: c5b6
# Maia 1200 Evaluation: -2.84, Suggested Move: c5b6
# Maia 1300 Evaluation: -2.81, Suggested Move: c5b6
# Maia 1400 Evaluation: -2.62, Suggested Move: c5b6
# Maia 1500 Evaluation: -3.95, Suggested Move: c5b6
# Maia 1600 Evaluation: -3.35, Suggested Move: c5b6
# Maia 1700 Evaluation: -3.93, Suggested Move: c5b6
# Maia 1800 Evaluation: -2.08, Suggested Move: c5b6
# Maia 1900 Evaluation: -1.52, Suggested Move: c5b6
#
# Position: 1r3rk1/2pqbppp/2n1b3/1p1pP3/1P6/2P2N2/2BQ1PPP/R1B2RK1 w - - 1 16
# Blunder: c5e7
# Stockfish Evaluation: 0.79
# Stockfish Suggested Move: d2d3
# Maia 1100 Evaluation: 2.65, Suggested Move: d2d3
# Maia 1200 Evaluation: 5.57, Suggested Move: d2d3
# Maia 1300 Evaluation: 3.94, Suggested Move: d2d3
# Maia 1400 Evaluation: 6.59, Suggested Move: d2d3
# Maia 1500 Evaluation: 3.0, Suggested Move: d2d3
# Maia 1600 Evaluation: 4.5, Suggested Move: d2d3
# Maia 1700 Evaluation: 5.13, Suggested Move: d2d3
# Maia 1800 Evaluation: 3.37, Suggested Move: d2d3
# Maia 1900 Evaluation: 3.25, Suggested Move: d2d3
#
# Position: 1r3rk1/2pqb1pp/2n1bp2/1p1pP3/1P6/2P2N2/2BQ1PPP/R1B1R1K1 w - - 0 17
# Blunder: f7f6
# Stockfish Evaluation: 1.34
# Stockfish Suggested Move: e5f6
# Maia 1100 Evaluation: -0.43, Suggested Move: e5f6
# Maia 1200 Evaluation: 4.78, Suggested Move: e5f6
# Maia 1300 Evaluation: 3.3, Suggested Move: e5f6
# Maia 1400 Evaluation: 1.56, Suggested Move: e5f6
# Maia 1500 Evaluation: 2.94, Suggested Move: d2d3
# Maia 1600 Evaluation: 3.49, Suggested Move: e5f6
# Maia 1700 Evaluation: 4.11, Suggested Move: e5f6
# Maia 1800 Evaluation: 3.32, Suggested Move: e5f6
# Maia 1900 Evaluation: 3.62, Suggested Move: e5f6
#
# Position: 1r3rk1/2pqb1pp/2n1bp2/1p1pP3/1P6/2PQ1N2/2B2PPP/R1B1R1K1 b - - 1 17
# Blunder: d2d3
# Stockfish Evaluation: -1.46
# Stockfish Suggested Move: g7g6
# Maia 1100 Evaluation: -4.42, Suggested Move: f6e5
# Maia 1200 Evaluation: -4.58, Suggested Move: g7g6
# Maia 1300 Evaluation: -11.93, Suggested Move: g7g6
# Maia 1400 Evaluation: -6.58, Suggested Move: g7g6
# Maia 1500 Evaluation: -5.2, Suggested Move: f6f5
# Maia 1600 Evaluation: -5.84, Suggested Move: g7g6
# Maia 1700 Evaluation: -4.28, Suggested Move: g7g6
# Maia 1800 Evaluation: -7.72, Suggested Move: f6f5
# Maia 1900 Evaluation: -3.13, Suggested Move: g7g6
#
# Position: 1r3rk1/2pqb2p/2n1bpp1/1p1pP3/1P6/2PQ1N2/2B2PPP/R1B1R1K1 w - - 0 18
# Blunder: g7g6
# Stockfish Evaluation: 1.28
# Stockfish Suggested Move: c1h6
# Maia 1100 Evaluation: 1.26, Suggested Move: e5f6
# Maia 1200 Evaluation: 4.74, Suggested Move: e5f6
# Maia 1300 Evaluation: 3.19, Suggested Move: c1h6
# Maia 1400 Evaluation: 5.42, Suggested Move: c1h6
# Maia 1500 Evaluation: 3.66, Suggested Move: c1h6
# Maia 1600 Evaluation: 4.94, Suggested Move: c1h6
# Maia 1700 Evaluation: 3.77, Suggested Move: c1h6
# Maia 1800 Evaluation: 4.28, Suggested Move: c1h6
# Maia 1900 Evaluation: 4.8, Suggested Move: c1h6
#
# Position: 1r3rk1/2pqb2p/2n1bppB/1p1pP3/1P6/2PQ1N2/2B2PPP/R3R1K1 b - - 1 18
# Blunder: c1h6
# Stockfish Evaluation: -1.21
# Stockfish Suggested Move: f8f7
# Maia 1100 Evaluation: -1.25, Suggested Move: f8f7
# Maia 1200 Evaluation: -4.9, Suggested Move: f8f7
# Maia 1300 Evaluation: -6.94, Suggested Move: f8f7
# Maia 1400 Evaluation: -2.65, Suggested Move: f8f7
# Maia 1500 Evaluation: -3.5, Suggested Move: f8f7
# Maia 1600 Evaluation: -4.92, Suggested Move: f8f7
# Maia 1700 Evaluation: -5.21, Suggested Move: f8f7
# Maia 1800 Evaluation: -5.85, Suggested Move: f8f7
# Maia 1900 Evaluation: -3.11, Suggested Move: f8f7
#
# Position: 1r2r1k1/2pqb2p/2n1bppB/1p1pP3/1P6/2PQ1N2/2B2PPP/R3R1K1 w - - 2 19
# Blunder: f8e8
# Stockfish Evaluation: 1.23
# Stockfish Suggested Move: e5f6
# Maia 1100 Evaluation: 2.79, Suggested Move: e5f6
# Maia 1200 Evaluation: 9.67, Suggested Move: e5f6
# Maia 1300 Evaluation: 9.26, Suggested Move: e5f6
# Maia 1400 Evaluation: 8.2, Suggested Move: e5f6
# Maia 1500 Evaluation: 5.08, Suggested Move: e5f6
# Maia 1600 Evaluation: 9.5, Suggested Move: e5f6
# Maia 1700 Evaluation: 6.53, Suggested Move: e5f6
# Maia 1800 Evaluation: 6.92, Suggested Move: e5f6
# Maia 1900 Evaluation: 7.55, Suggested Move: e5f6
#
# Position: 1r2r1k1/2pqb2p/2n1bPpB/1p1p4/1P6/2PQ1N2/2B2PPP/R3R1K1 b - - 0 19
# Blunder: e5f6
# Stockfish Evaluation: -1.15
# Stockfish Suggested Move: e7f6
# Maia 1100 Evaluation: -7.04, Suggested Move: e7f6
# Maia 1200 Evaluation: -4.16, Suggested Move: e7f6
# Maia 1300 Evaluation: -8.24, Suggested Move: e7f6
# Maia 1400 Evaluation: -10.85, Suggested Move: e7f6
# Maia 1500 Evaluation: -6.98, Suggested Move: e7f6
# Maia 1600 Evaluation: -9.97, Suggested Move: e7f6
# Maia 1700 Evaluation: -9.41, Suggested Move: e7f6
# Maia 1800 Evaluation: -7.25, Suggested Move: e7f6
# Maia 1900 Evaluation: -4.51, Suggested Move: e7f6
#
# Position: 1r2r1k1/2pq3p/2n1bbpB/1p1p4/1P6/2PQ1N2/2B2PPP/R3R1K1 w - - 0 20
# Blunder: e7f6
# Stockfish Evaluation: 1.13
# Stockfish Suggested Move: f3g5
# Maia 1100 Evaluation: 3.05, Suggested Move: f3g5
# Maia 1200 Evaluation: 4.96, Suggested Move: f3g5
# Maia 1300 Evaluation: 4.16, Suggested Move: f3g5
# Maia 1400 Evaluation: 2.75, Suggested Move: f3g5
# Maia 1500 Evaluation: 4.18, Suggested Move: f3g5
# Maia 1600 Evaluation: 5.79, Suggested Move: f3g5
# Maia 1700 Evaluation: 4.33, Suggested Move: f3g5
# Maia 1800 Evaluation: 6.31, Suggested Move: f3g5
# Maia 1900 Evaluation: 2.63, Suggested Move: f3g5
#
# Position: 1r2r1k1/2pq3p/2n1bbpB/1p1p4/1P6/1BPQ1N2/5PPP/R3R1K1 b - - 1 20
# Blunder: c2b3
# Stockfish Evaluation: -1.14
# Stockfish Suggested Move: e6f5
# Maia 1100 Evaluation: 0.9, Suggested Move: e6f5
# Maia 1200 Evaluation: 1.52, Suggested Move: e6f5
# Maia 1300 Evaluation: -7.01, Suggested Move: e6f5
# Maia 1400 Evaluation: -0.85, Suggested Move: e6f5
# Maia 1500 Evaluation: -1.82, Suggested Move: e6f5
# Maia 1600 Evaluation: -2.74, Suggested Move: e6f5
# Maia 1700 Evaluation: -4.31, Suggested Move: e6f5
# Maia 1800 Evaluation: -3.24, Suggested Move: d5d4
# Maia 1900 Evaluation: -2.69, Suggested Move: c6e7
#
# Position: 1r2r1k1/2pq1b1p/2n2bpB/1p1p4/1P6/1BPQ1N2/5PPP/R3R1K1 w - - 2 21
# Blunder: e6f7
# Stockfish Evaluation: 1.3
# Stockfish Suggested Move: e1e8
# Maia 1100 Evaluation: 1.34, Suggested Move: e1e8
# Maia 1200 Evaluation: 3.67, Suggested Move: e1e8
# Maia 1300 Evaluation: 4.39, Suggested Move: e1e8
# Maia 1400 Evaluation: 1.89, Suggested Move: e1e8
# Maia 1500 Evaluation: 6.82, Suggested Move: e1e8
# Maia 1600 Evaluation: 3.65, Suggested Move: e1e8
# Maia 1700 Evaluation: 1.44, Suggested Move: e1e8
# Maia 1800 Evaluation: 2.73, Suggested Move: a1d1
# Maia 1900 Evaluation: 2.39, Suggested Move: e1e8
#
# Event: World Championship Match 1910
# Position: r3k2r/p3p1bp/bqppP1p1/5p2/N4Bn1/1B6/PPP2PPP/R2Q1RK1 b kq - 7 13
# Blunder: c3a4
# Stockfish Evaluation: 0.92
# Stockfish Suggested Move: b6b5
# Maia 1100 Evaluation: -0.26, Suggested Move: b6b5
# Maia 1200 Evaluation: -1.29, Suggested Move: b6b5
# Maia 1300 Evaluation: 0.88, Suggested Move: b6b5
# Maia 1400 Evaluation: 2.89, Suggested Move: b6b5
# Maia 1500 Evaluation: 1.3, Suggested Move: a6f1
# Maia 1600 Evaluation: 3.87, Suggested Move: b6b5
# Maia 1700 Evaluation: 4.38, Suggested Move: b6b5
# Maia 1800 Evaluation: 0.55, Suggested Move: b6b5
# Maia 1900 Evaluation: 2.46, Suggested Move: b6b5
#
# Position: r3k2r/p3p1bp/b1ppP1p1/5p2/N2q1Bn1/1B6/PPP2PPP/R2Q1RK1 w kq - 8 14
# Blunder: b6d4
# Stockfish Evaluation: -0.84
# Stockfish Suggested Move: d1d4
# Maia 1100 Evaluation: -3.66, Suggested Move: d1d4
# Maia 1200 Evaluation: 3.62, Suggested Move: d1d4
# Maia 1300 Evaluation: -1.75, Suggested Move: d1d4
# Maia 1400 Evaluation: -1.62, Suggested Move: d1d4
# Maia 1500 Evaluation: -5.7, Suggested Move: d1d4
# Maia 1600 Evaluation: -5.38, Suggested Move: d1d4
# Maia 1700 Evaluation: -1.87, Suggested Move: d1d4
# Maia 1800 Evaluation: -1.91, Suggested Move: d1d4
# Maia 1900 Evaluation: -2.17, Suggested Move: d1d4
#
# Position: r3k2r/p3p1bp/b1ppP1p1/5p2/N2Q1Bn1/1B6/PPP2PPP/R4RK1 b kq - 0 14
# Blunder: d1d4
# Stockfish Evaluation: 1.2
# Stockfish Suggested Move: g7d4
# Maia 1100 Evaluation: -0.39, Suggested Move: g7d4
# Maia 1200 Evaluation: 1.28, Suggested Move: g7d4
# Maia 1300 Evaluation: 3.96, Suggested Move: g7d4
# Maia 1400 Evaluation: -0.45, Suggested Move: g7d4
# Maia 1500 Evaluation: 5.5, Suggested Move: g7d4
# Maia 1600 Evaluation: 1.24, Suggested Move: g7d4
# Maia 1700 Evaluation: 6.85, Suggested Move: g7d4
# Maia 1800 Evaluation: -0.5, Suggested Move: g7d4
# Maia 1900 Evaluation: 2.12, Suggested Move: g7d4
#
# Position: r3k2r/p3p2p/b1ppP1p1/5p2/N2b1Bn1/1B6/PPP2PPP/R4RK1 w kq - 0 15
# Blunder: g7d4
# Stockfish Evaluation: -1.01
# Stockfish Suggested Move: c2c3
# Maia 1100 Evaluation: -1.36, Suggested Move: c2c3
# Maia 1200 Evaluation: -1.37, Suggested Move: f1d1
# Maia 1300 Evaluation: -3.92, Suggested Move: c2c3
# Maia 1400 Evaluation: 0.91, Suggested Move: c2c3
# Maia 1500 Evaluation: -2.61, Suggested Move: c2c3
# Maia 1600 Evaluation: 1.19, Suggested Move: c2c3
# Maia 1700 Evaluation: -4.83, Suggested Move: c2c3
# Maia 1800 Evaluation: -1.86, Suggested Move: c2c3
# Maia 1900 Evaluation: -2.87, Suggested Move: c2c3
#
# Position: r3k2r/p3p2p/b1ppP1p1/5p2/N1Pb1Bn1/1B6/PP3PPP/R4RK1 b kq - 0 15
# Blunder: c2c4
# Stockfish Evaluation: 0.96
# Stockfish Suggested Move: c6c5
# Maia 1100 Evaluation: 0.42, Suggested Move: e8g8
# Maia 1200 Evaluation: -2.62, Suggested Move: e8g8
# Maia 1300 Evaluation: 2.62, Suggested Move: e8g8
# Maia 1400 Evaluation: -1.14, Suggested Move: c6c5
# Maia 1500 Evaluation: 2.75, Suggested Move: c6c5
# Maia 1600 Evaluation: 1.64, Suggested Move: c6c5
# Maia 1700 Evaluation: 1.83, Suggested Move: c6c5
# Maia 1800 Evaluation: 2.92, Suggested Move: e8g8
# Maia 1900 Evaluation: 0.86, Suggested Move: e8g8
#
# Position: r4rk1/p3p2p/b1ppP1p1/5p2/N1Pb1Bn1/1B6/PP3PPP/R4RK1 w - - 1 16
# Blunder: e8g8
# Stockfish Evaluation: -0.98
# Stockfish Suggested Move: a1d1
# Maia 1100 Evaluation: -2.32, Suggested Move: a1d1
# Maia 1200 Evaluation: -3.46, Suggested Move: a1d1
# Maia 1300 Evaluation: -3.05, Suggested Move: a1d1
# Maia 1400 Evaluation: -0.48, Suggested Move: a1d1
# Maia 1500 Evaluation: -3.32, Suggested Move: a1d1
# Maia 1600 Evaluation: -1.19, Suggested Move: a1d1
# Maia 1700 Evaluation: -3.52, Suggested Move: h2h3
# Maia 1800 Evaluation: -0.82, Suggested Move: a1d1
# Maia 1900 Evaluation: -1.32, Suggested Move: h2h3
#
# Position: r4rk1/p3p2p/b1ppP1p1/5p2/N1Pb1Bn1/1B6/PP3PPP/3R1RK1 b - - 2 16
# Blunder: a1d1
# Stockfish Evaluation: 0.94
# Stockfish Suggested Move: c6c5
# Maia 1100 Evaluation: -1.26, Suggested Move: c6c5
# Maia 1200 Evaluation: -1.66, Suggested Move: c6c5
# Maia 1300 Evaluation: 0.51, Suggested Move: c6c5
# Maia 1400 Evaluation: -3.06, Suggested Move: c6c5
# Maia 1500 Evaluation: 1.34, Suggested Move: c6c5
# Maia 1600 Evaluation: 1.72, Suggested Move: d4e5
# Maia 1700 Evaluation: 1.66, Suggested Move: c6c5
# Maia 1800 Evaluation: 3.8, Suggested Move: c6c5
# Maia 1900 Evaluation: -0.74, Suggested Move: c6c5
#
# Position: r4rk1/p3p2p/b1pBPb2/5pp1/N1P3n1/1B6/PP3PPP/3RR1K1 b - - 0 18
# Blunder: f4d6
# Stockfish Evaluation: 1.59
# Stockfish Suggested Move: e7d6
# Maia 1100 Evaluation: 3.07, Suggested Move: e7d6
# Maia 1200 Evaluation: 0.78, Suggested Move: e7d6
# Maia 1300 Evaluation: 1.55, Suggested Move: e7d6
# Maia 1400 Evaluation: 0.35, Suggested Move: e7d6
# Maia 1500 Evaluation: 2.5, Suggested Move: e7d6
# Maia 1600 Evaluation: -0.44, Suggested Move: e7d6
# Maia 1700 Evaluation: 1.11, Suggested Move: e7d6
# Maia 1800 Evaluation: 0.44, Suggested Move: e7d6
# Maia 1900 Evaluation: -3.7, Suggested Move: e7d6
#
# Position: r4rk1/p6p/b1ppPb2/5pp1/N1P3n1/1B6/PP3PPP/3RR1K1 w - - 0 19
# Blunder: e7d6
# Stockfish Evaluation: -1.1
# Stockfish Suggested Move: d1d6
# Maia 1100 Evaluation: 0.55, Suggested Move: d1d6
# Maia 1200 Evaluation: -1.26, Suggested Move: d1d6
# Maia 1300 Evaluation: -1.82, Suggested Move: d1d6
# Maia 1400 Evaluation: 1.25, Suggested Move: d1d6
# Maia 1500 Evaluation: -0.1, Suggested Move: d1d6
# Maia 1600 Evaluation: 1.17, Suggested Move: d1d6
# Maia 1700 Evaluation: -0.92, Suggested Move: d1d6
# Maia 1800 Evaluation: 0.7, Suggested Move: d1d6
# Maia 1900 Evaluation: 0.45, Suggested Move: d1d6
#
# Position: r4rk1/p6p/b1pRP3/4bpp1/N1P3n1/1B6/PP3PPP/4R1K1 w - - 1 20
# Blunder: f6e5
# Stockfish Evaluation: -0.4
# Stockfish Suggested Move: d6c6
# Maia 1100 Evaluation: -2.65, Suggested Move: d6c6
# Maia 1200 Evaluation: -3.41, Suggested Move: d6c6
# Maia 1300 Evaluation: -2.76, Suggested Move: d6c6
# Maia 1400 Evaluation: -1.49, Suggested Move: d6c6
# Maia 1500 Evaluation: -0.94, Suggested Move: d6c6
# Maia 1600 Evaluation: -0.43, Suggested Move: d6c6
# Maia 1700 Evaluation: -0.78, Suggested Move: d6c6
# Maia 1800 Evaluation: -1.54, Suggested Move: d6c6
# Maia 1900 Evaluation: 1.95, Suggested Move: d6c6
#
# Position: r3r1k1/p6p/b1pRP3/2P1bpp1/N5n1/1B6/PP3PPP/4R1K1 w - - 1 21
# Blunder: f8e8
# Stockfish Evaluation: -0.94
# Stockfish Suggested Move: e6e7
# Maia 1100 Evaluation: 2.82, Suggested Move: e6e7
# Maia 1200 Evaluation: 1.79, Suggested Move: e6e7
# Maia 1300 Evaluation: 2.28, Suggested Move: d6c6
# Maia 1400 Evaluation: 8.51, Suggested Move: e6e7
# Maia 1500 Evaluation: 3.17, Suggested Move: e6e7
# Maia 1600 Evaluation: 2.08, Suggested Move: e6e7
# Maia 1700 Evaluation: 2.68, Suggested Move: e6e7
# Maia 1800 Evaluation: 0.9, Suggested Move: d6c6
# Maia 1900 Evaluation: 3.41, Suggested Move: e6e7
#
# Position: r3r1k1/p6p/b1pRPb2/2P2pp1/N5n1/1B4P1/PP3P1P/4R1K1 w - - 1 22
# Blunder: e5f6
# Stockfish Evaluation: -1.48
# Stockfish Suggested Move: e6e7
# Maia 1100 Evaluation: 2.37, Suggested Move: e6e7
# Maia 1200 Evaluation: 3.23, Suggested Move: d6c6
# Maia 1300 Evaluation: 1.46, Suggested Move: e6e7
# Maia 1400 Evaluation: 5.98, Suggested Move: d6c6
# Maia 1500 Evaluation: 3.9, Suggested Move: e6e7
# Maia 1600 Evaluation: 2.15, Suggested Move: e6e7
# Maia 1700 Evaluation: 3.18, Suggested Move: e6e7
# Maia 1800 Evaluation: 1.94, Suggested Move: e6e7
# Maia 1900 Evaluation: 5.76, Suggested Move: e6e7
#
# Position: r3r1k1/pb5p/2R1Pb2/2P2pp1/N5n1/1B4P1/PP3P1P/4R1K1 w - - 1 23
# Blunder: a6b7
# Stockfish Evaluation: -0.48
# Stockfish Suggested Move: c6c7
# Maia 1100 Evaluation: 3.61, Suggested Move: c6c7
# Maia 1200 Evaluation: 1.96, Suggested Move: c6c7
# Maia 1300 Evaluation: 3.17, Suggested Move: c6c7
# Maia 1400 Evaluation: 3.55, Suggested Move: c6c7
# Maia 1500 Evaluation: 2.19, Suggested Move: c6c7
# Maia 1600 Evaluation: 3.31, Suggested Move: c6c7
# Maia 1700 Evaluation: 3.35, Suggested Move: c6c7
# Maia 1800 Evaluation: 0.36, Suggested Move: c6c7
# Maia 1900 Evaluation: 0.59, Suggested Move: c6c7
#
# Event: World Championship Match 1910
# Position: 5r1r/ppqk1pp1/2nbb2p/5BBQ/5p2/1NP5/P1P3PP/4RRK1 w - - 4 17
# Blunder: a8f8
# Stockfish Evaluation: -0.13
# Stockfish Suggested Move: f5e6
# Maia 1100 Evaluation: -0.32, Suggested Move: f5e6
# Maia 1200 Evaluation: 5.5, Suggested Move: f5e6
# Maia 1300 Evaluation: -2.1, Suggested Move: f5e6
# Maia 1400 Evaluation: 3.96, Suggested Move: f5e6
# Maia 1500 Evaluation: 5.46, Suggested Move: f5e6
# Maia 1600 Evaluation: 1.39, Suggested Move: f5e6
# Maia 1700 Evaluation: 11.07, Suggested Move: f5e6
# Maia 1800 Evaluation: 5.61, Suggested Move: f5e6
# Maia 1900 Evaluation: 4.11, Suggested Move: f5e6
#
# Position: 8/1p3rp1/p2kn2p/8/8/2PR1N2/P1P1K1P1/8 b - - 27 44
# Blunder: d4f3
# Stockfish Evaluation: 0.95
# Stockfish Suggested Move: d6c5
# Maia 1100 Evaluation: 0.29, Suggested Move: d6c5
# Maia 1200 Evaluation: 0.62, Suggested Move: d6c5
# Maia 1300 Evaluation: 0.32, Suggested Move: d6e7
# Maia 1400 Evaluation: 0.36, Suggested Move: d6c5
# Maia 1500 Evaluation: 0.37, Suggested Move: d6c5
# Maia 1600 Evaluation: 1.25, Suggested Move: d6c5
# Maia 1700 Evaluation: 1.24, Suggested Move: d6c5
# Maia 1800 Evaluation: 0.65, Suggested Move: d6c5
# Maia 1900 Evaluation: -0.17, Suggested Move: d6c5
#
# Position: 8/1pn2rp1/p1k4p/8/8/2PR2P1/P1PNK3/8 w - - 3 47
# Blunder: c5c6
# Stockfish Evaluation: -0.72
# Stockfish Suggested Move: d2e4
# Maia 1100 Evaluation: -0.66, Suggested Move: d2e4
# Maia 1200 Evaluation: -0.99, Suggested Move: d2e4
# Maia 1300 Evaluation: -1.2, Suggested Move: d2e4
# Maia 1400 Evaluation: -0.35, Suggested Move: d2c4
# Maia 1500 Evaluation: 0.2, Suggested Move: d2e4
# Maia 1600 Evaluation: -0.3, Suggested Move: d2c4
# Maia 1700 Evaluation: -1.15, Suggested Move: d2e4
# Maia 1800 Evaluation: -1.1, Suggested Move: d2e4
# Maia 1900 Evaluation: -0.69, Suggested Move: d2e4
#
# Position: 8/1pn2rp1/p6p/2k5/3R4/2P2NP1/P1P1K3/8 w - - 7 49
# Blunder: b5c5
# Stockfish Evaluation: -0.83
# Stockfish Suggested Move: f3e5
# Maia 1100 Evaluation: -0.28, Suggested Move: f3e5
# Maia 1200 Evaluation: -0.83, Suggested Move: f3e5
# Maia 1300 Evaluation: -0.08, Suggested Move: f3e5
# Maia 1400 Evaluation: -0.07, Suggested Move: f3e5
# Maia 1500 Evaluation: -0.67, Suggested Move: f3e5
# Maia 1600 Evaluation: -0.83, Suggested Move: f3e5
# Maia 1700 Evaluation: -0.65, Suggested Move: f3e5
# Maia 1800 Evaluation: -0.28, Suggested Move: f3e5
# Maia 1900 Evaluation: -0.37, Suggested Move: f3e5
#
# Position: 8/1pn2rp1/p6p/2k5/3R4/2P3P1/P1PNK3/8 b - - 8 49
# Blunder: f3d2
# Stockfish Evaluation: 0.73
# Stockfish Suggested Move: c7b5
# Maia 1100 Evaluation: 1.13, Suggested Move: c7b5
# Maia 1200 Evaluation: 1.28, Suggested Move: c7b5
# Maia 1300 Evaluation: 0.2, Suggested Move: c7b5
# Maia 1400 Evaluation: 0.46, Suggested Move: c7b5
# Maia 1500 Evaluation: 1.52, Suggested Move: c7b5
# Maia 1600 Evaluation: 1.45, Suggested Move: f7e7
# Maia 1700 Evaluation: 1.65, Suggested Move: f7e7
# Maia 1800 Evaluation: 1.15, Suggested Move: c7b5
# Maia 1900 Evaluation: 1.15, Suggested Move: c7b5
#
# Position: 8/1p3rp1/p6p/1nk5/3R4/1NP3P1/P1P1K3/8 b - - 10 50
# Blunder: d2b3
# Stockfish Evaluation: 0.99
# Stockfish Suggested Move: c5c6
# Maia 1100 Evaluation: 0.84, Suggested Move: c5c6
# Maia 1200 Evaluation: -0.17, Suggested Move: c5c6
# Maia 1300 Evaluation: 0.88, Suggested Move: c5c6
# Maia 1400 Evaluation: 0.61, Suggested Move: c5c6
# Maia 1500 Evaluation: 0.82, Suggested Move: c5b6
# Maia 1600 Evaluation: 0.94, Suggested Move: c5c6
# Maia 1700 Evaluation: 0.92, Suggested Move: c5c6
# Maia 1800 Evaluation: 0.89, Suggested Move: c5c6
# Maia 1900 Evaluation: 1.15, Suggested Move: c5c6
#
# Position: 8/1p3rp1/pk5p/1n6/3R4/1NP3P1/P1P1K3/8 w - - 11 51
# Blunder: c5b6
# Stockfish Evaluation: -1.01
# Stockfish Suggested Move: d4d3
# Maia 1100 Evaluation: -0.91, Suggested Move: d4b4
# Maia 1200 Evaluation: -0.93, Suggested Move: d4b4
# Maia 1300 Evaluation: -0.6, Suggested Move: d4b4
# Maia 1400 Evaluation: -0.83, Suggested Move: d4b4
# Maia 1500 Evaluation: -1.32, Suggested Move: c3c4
# Maia 1600 Evaluation: -1.18, Suggested Move: d4d3
# Maia 1700 Evaluation: -1.45, Suggested Move: d4d3
# Maia 1800 Evaluation: -2.01, Suggested Move: d4d3
# Maia 1900 Evaluation: -0.77, Suggested Move: d4d3
#
# Position: 8/1p3rp1/pk5p/1n6/8/1NPR2P1/P1P1K3/8 b - - 12 51
# Blunder: d4d3
# Stockfish Evaluation: 0.92
# Stockfish Suggested Move: f7e7
# Maia 1100 Evaluation: 0.59, Suggested Move: f7e7
# Maia 1200 Evaluation: 1.15, Suggested Move: f7e7
# Maia 1300 Evaluation: 0.5, Suggested Move: f7e7
# Maia 1400 Evaluation: 0.7, Suggested Move: f7e7
# Maia 1500 Evaluation: 0.88, Suggested Move: f7e7
# Maia 1600 Evaluation: 1.06, Suggested Move: f7e7
# Maia 1700 Evaluation: 1.05, Suggested Move: f7e7
# Maia 1800 Evaluation: 1.24, Suggested Move: f7e7
# Maia 1900 Evaluation: 1.57, Suggested Move: f7e7
#
# Position: 8/1pr3p1/pk5p/1n6/8/1NPR2P1/P1P1K3/8 w - - 13 52
# Blunder: f7c7
# Stockfish Evaluation: -0.91
# Stockfish Suggested Move: e2d2
# Maia 1100 Evaluation: -1.0, Suggested Move: b3d4
# Maia 1200 Evaluation: -1.02, Suggested Move: e2d2
# Maia 1300 Evaluation: -0.75, Suggested Move: e2d2
# Maia 1400 Evaluation: -1.18, Suggested Move: e2d2
# Maia 1500 Evaluation: -0.85, Suggested Move: e2d2
# Maia 1600 Evaluation: -0.61, Suggested Move: e2d2
# Maia 1700 Evaluation: -1.16, Suggested Move: e2d2
# Maia 1800 Evaluation: -1.52, Suggested Move: e2d2
# Maia 1900 Evaluation: -0.04, Suggested Move: e2d2
#
# Position: 8/1pr3p1/pk5p/1n6/8/1NPR2P1/P1PK4/8 b - - 14 52
# Blunder: e2d2
# Stockfish Evaluation: 1.01
# Stockfish Suggested Move: a6a5
# Maia 1100 Evaluation: 0.49, Suggested Move: a6a5
# Maia 1200 Evaluation: 1.15, Suggested Move: a6a5
# Maia 1300 Evaluation: -0.26, Suggested Move: b5a3
# Maia 1400 Evaluation: 0.4, Suggested Move: a6a5
# Maia 1500 Evaluation: 0.95, Suggested Move: b5a3
# Maia 1600 Evaluation: 0.84, Suggested Move: c7f7
# Maia 1700 Evaluation: 0.73, Suggested Move: a6a5
# Maia 1800 Evaluation: 0.5, Suggested Move: a6a5
# Maia 1900 Evaluation: 0.97, Suggested Move: a6a5
#
# Position: 8/1p4p1/pk5p/1n6/2r5/1NPR2P1/P1PK4/8 w - - 15 53
# Blunder: c7c4
# Stockfish Evaluation: -0.72
# Stockfish Suggested Move: b3d4
# Maia 1100 Evaluation: -0.33, Suggested Move: b3d4
# Maia 1200 Evaluation: -0.41, Suggested Move: b3d4
# Maia 1300 Evaluation: 0.19, Suggested Move: d3d7
# Maia 1400 Evaluation: -0.77, Suggested Move: d3d7
# ...
# Initial Image: chess_images/World_Championship_Match_1910_pos_44_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_44_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_44_correct.png
#
# Illegal move g5e5 in position 8/3kp3/2qn4/4R3/8/P2Q4/K7/8 b - - 12 61
# Position: 8/3kp3/2qn4/4R3/8/P2Q4/K7/8 b - - 12 61
# Blunder: g5e5
# Stockfish Evaluation: -2.57
# Stockfish Suggested Move: c6c4
# Maia 1100 Evaluation: -1.31, Suggested Move: e7e6
# Maia 1200 Evaluation: -0.81, Suggested Move: e7e6
# Maia 1300 Evaluation: -1.18, Suggested Move: d7e8
# Maia 1400 Evaluation: -1.28, Suggested Move: c6g2
# Maia 1500 Evaluation: -1.01, Suggested Move: c6c4
# Maia 1600 Evaluation: -1.23, Suggested Move: c6c4
# Maia 1700 Evaluation: -1.1, Suggested Move: c6c4
# Maia 1800 Evaluation: -1.31, Suggested Move: c6c4
# Maia 1900 Evaluation: -0.92, Suggested Move: c6c4
# Initial Image: chess_images/World_Championship_Match_1910_pos_45_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_45_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_45_correct.png
#
# Illegal move c6g2 in position 8/3kp3/3n4/4R3/8/P2Q4/K5q1/8 w - - 13 62
# Position: 8/3kp3/3n4/4R3/8/P2Q4/K5q1/8 w - - 13 62
# Blunder: c6g2
# Stockfish Evaluation: 2.59
# Stockfish Suggested Move: a2b3
# Maia 1100 Evaluation: 0.53, Suggested Move: a2b3
# Maia 1200 Evaluation: 0.43, Suggested Move: a2b3
# Maia 1300 Evaluation: 0.44, Suggested Move: e5e2
# Maia 1400 Evaluation: 0.37, Suggested Move: a2b3
# Maia 1500 Evaluation: 1.27, Suggested Move: a2b3
# Maia 1600 Evaluation: 0.74, Suggested Move: a2b3
# Maia 1700 Evaluation: 0.72, Suggested Move: a2b3
# Maia 1800 Evaluation: 0.73, Suggested Move: a2b3
# Maia 1900 Evaluation: 0.84, Suggested Move: a2b3
# Initial Image: chess_images/World_Championship_Match_1910_pos_46_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_46_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_46_correct.png
#
# Illegal move e2d2 in position 8/3kp3/3n4/8/6q1/P2Q4/K2R4/8 b - - 16 63
# Position: 8/3kp3/3n4/8/6q1/P2Q4/K2R4/8 b - - 16 63
# Blunder: e2d2
# Stockfish Evaluation: -2.62
# Stockfish Suggested Move: g4e6
# Maia 1100 Evaluation: -0.84, Suggested Move: g4e6
# Maia 1200 Evaluation: -1.53, Suggested Move: g4e6
# Maia 1300 Evaluation: -1.13, Suggested Move: g4e6
# Maia 1400 Evaluation: -1.31, Suggested Move: g4e6
# Maia 1500 Evaluation: -1.95, Suggested Move: g4e6
# Maia 1600 Evaluation: -1.62, Suggested Move: g4e6
# Maia 1700 Evaluation: -1.84, Suggested Move: g4e6
# Maia 1800 Evaluation: -2.15, Suggested Move: g4e6
# Maia 1900 Evaluation: -2.32, Suggested Move: g4e6
# Initial Image: chess_images/World_Championship_Match_1910_pos_47_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_47_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_47_correct.png
#
# Illegal move g4a4 in position 8/3kp3/3n4/8/q7/P2Q4/K2R4/8 w - - 17 64
# Position: 8/3kp3/3n4/8/q7/P2Q4/K2R4/8 w - - 17 64
# Blunder: g4a4
# Stockfish Evaluation: 2.62
# Stockfish Suggested Move: d3b3
# Maia 1100 Evaluation: 1.03, Suggested Move: d3b3
# Maia 1200 Evaluation: 1.04, Suggested Move: d3b3
# Maia 1300 Evaluation: 1.3, Suggested Move: d3b3
# Maia 1400 Evaluation: 1.05, Suggested Move: d3b3
# Maia 1500 Evaluation: 1.64, Suggested Move: d3b3
# Maia 1600 Evaluation: 1.13, Suggested Move: d2b2
# Maia 1700 Evaluation: 1.38, Suggested Move: d3b3
# Maia 1800 Evaluation: 1.14, Suggested Move: d3b3
# Maia 1900 Evaluation: 1.55, Suggested Move: d3b3
# Initial Image: chess_images/World_Championship_Match_1910_pos_48_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_48_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_48_correct.png
#
# Illegal move d7c7 in position 8/2k1p3/3n4/5Q2/q7/P7/K2R4/8 w - - 19 65
# Position: 8/2k1p3/3n4/5Q2/q7/P7/K2R4/8 w - - 19 65
# Blunder: d7c7
# Stockfish Evaluation: 3.27
# Stockfish Suggested Move: f5c5
# Maia 1100 Evaluation: 0.5, Suggested Move: f5c5
# Maia 1200 Evaluation: 0.72, Suggested Move: f5c5
# Maia 1300 Evaluation: 1.64, Suggested Move: f5c5
# Maia 1400 Evaluation: 0.89, Suggested Move: f5c5
# Maia 1500 Evaluation: 1.41, Suggested Move: f5c5
# Maia 1600 Evaluation: 1.0, Suggested Move: f5c5
# Maia 1700 Evaluation: 1.3, Suggested Move: d2c2
# Maia 1800 Evaluation: 0.78, Suggested Move: f5c5
# Maia 1900 Evaluation: 0.93, Suggested Move: f5c5
# Initial Image: chess_images/World_Championship_Match_1910_pos_49_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_49_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_49_correct.png
#
# Illegal move f5c2 in position 8/2k1p3/3n4/8/q7/P7/K1QR4/8 b - - 20 65
# Position: 8/2k1p3/3n4/8/q7/P7/K1QR4/8 b - - 20 65
# Blunder: f5c2
# Stockfish Evaluation: -3.37
# Stockfish Suggested Move: a4c2
# Maia 1100 Evaluation: -1.01, Suggested Move: a4c2
# Maia 1200 Evaluation: -1.32, Suggested Move: a4c4
# Maia 1300 Evaluation: -1.78, Suggested Move: d6c4
# Maia 1400 Evaluation: -1.65, Suggested Move: c7d7
# Maia 1500 Evaluation: -1.78, Suggested Move: a4c2
# Maia 1600 Evaluation: -1.44, Suggested Move: a4c6
# Maia 1700 Evaluation: -1.45, Suggested Move: a4c2
# Maia 1800 Evaluation: -2.63, Suggested Move: a4c2
# Maia 1900 Evaluation: -1.89, Suggested Move: a4c2
# Initial Image: chess_images/World_Championship_Match_1910_pos_50_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_50_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_50_correct.png
#
# Illegal move a4c2 in position 8/2k1p3/3n4/8/8/P7/K1qR4/8 w - - 0 66
# Position: 8/2k1p3/3n4/8/8/P7/K1qR4/8 w - - 0 66
# Blunder: a4c2
# Stockfish Evaluation: 3.53
# Stockfish Suggested Move: d2c2
# Maia 1100 Evaluation: 0.54, Suggested Move: d2c2
# Maia 1200 Evaluation: 1.69, Suggested Move: d2c2
# Maia 1300 Evaluation: 1.52, Suggested Move: d2c2
# Maia 1400 Evaluation: 1.17, Suggested Move: d2c2
# Maia 1500 Evaluation: 2.25, Suggested Move: d2c2
# Maia 1600 Evaluation: 1.79, Suggested Move: d2c2
# Maia 1700 Evaluation: 1.11, Suggested Move: d2c2
# Maia 1800 Evaluation: 1.41, Suggested Move: d2c2
# Maia 1900 Evaluation: 2.35, Suggested Move: d2c2
# Initial Image: chess_images/World_Championship_Match_1910_pos_51_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_51_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_51_correct.png
#
# Illegal move d2c2 in position 8/2k1p3/3n4/8/8/P7/K1R5/8 b - - 0 66
# Position: 8/2k1p3/3n4/8/8/P7/K1R5/8 b - - 0 66
# Blunder: d2c2
# Stockfish Evaluation: -3.46
# Stockfish Suggested Move: c7d7
# Maia 1100 Evaluation: -0.76, Suggested Move: c7d7
# Maia 1200 Evaluation: -0.9, Suggested Move: c7d7
# Maia 1300 Evaluation: -1.02, Suggested Move: c7d7
# Maia 1400 Evaluation: -0.9, Suggested Move: c7d7
# Maia 1500 Evaluation: -1.37, Suggested Move: c7d7
# Maia 1600 Evaluation: -1.35, Suggested Move: c7d7
# Maia 1700 Evaluation: -1.45, Suggested Move: c7d7
# Maia 1800 Evaluation: -1.15, Suggested Move: c7b6
# Maia 1900 Evaluation: -1.57, Suggested Move: c7b6
# Initial Image: chess_images/World_Championship_Match_1910_pos_52_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_52_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_52_correct.png
#
# Illegal move c7b7 in position 8/1k2p3/3n4/8/8/P7/K1R5/8 w - - 1 67
# Position: 8/1k2p3/3n4/8/8/P7/K1R5/8 w - - 1 67
# Blunder: c7b7
# Stockfish Evaluation: 3.13
# Stockfish Suggested Move: a2b3
# Maia 1100 Evaluation: 0.82, Suggested Move: c2b2
# Maia 1200 Evaluation: 1.05, Suggested Move: a3a4
# Maia 1300 Evaluation: 1.21, Suggested Move: a3a4
# Maia 1400 Evaluation: 1.01, Suggested Move: a3a4
# Maia 1500 Evaluation: 1.83, Suggested Move: a3a4
# Maia 1600 Evaluation: 1.7, Suggested Move: a2b3
# Maia 1700 Evaluation: 1.17, Suggested Move: a2b3
# Maia 1800 Evaluation: 1.6, Suggested Move: a2b3
# Maia 1900 Evaluation: 1.63, Suggested Move: a2b3
# Initial Image: chess_images/World_Championship_Match_1910_pos_53_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_53_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_53_correct.png
#
# Illegal move c2e2 in position 8/1k2p3/3n4/8/8/P7/K3R3/8 b - - 2 67
# Position: 8/1k2p3/3n4/8/8/P7/K3R3/8 b - - 2 67
# Blunder: c2e2
# Stockfish Evaluation: -3.52
# Stockfish Suggested Move: d6f5
# Maia 1100 Evaluation: -0.97, Suggested Move: d6c4
# Maia 1200 Evaluation: -1.13, Suggested Move: d6c4
# Maia 1300 Evaluation: -0.83, Suggested Move: d6f5
# Maia 1400 Evaluation: -1.06, Suggested Move: d6f5
# Maia 1500 Evaluation: -1.21, Suggested Move: d6f5
# Maia 1600 Evaluation: -1.19, Suggested Move: d6f5
# Maia 1700 Evaluation: -1.43, Suggested Move: d6f5
# Maia 1800 Evaluation: -1.64, Suggested Move: d6f5
# Maia 1900 Evaluation: -1.8, Suggested Move: d6c8
# Initial Image: chess_images/World_Championship_Match_1910_pos_54_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_54_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_54_correct.png
#
# Illegal move d6c8 in position 2n5/1k2p3/8/8/8/P7/K3R3/8 w - - 3 68
# Position: 2n5/1k2p3/8/8/8/P7/K3R3/8 w - - 3 68
# Blunder: d6c8
# Stockfish Evaluation: 3.68
# Stockfish Suggested Move: a2b3
# Maia 1100 Evaluation: 1.0, Suggested Move: e2b2
# Maia 1200 Evaluation: 0.89, Suggested Move: a3a4
# Maia 1300 Evaluation: 0.93, Suggested Move: a3a4
# Maia 1400 Evaluation: 0.99, Suggested Move: e2b2
# Maia 1500 Evaluation: 1.38, Suggested Move: a2b3
# Maia 1600 Evaluation: 1.84, Suggested Move: a2b3
# Maia 1700 Evaluation: 1.33, Suggested Move: a2b3
# Maia 1800 Evaluation: 1.47, Suggested Move: a2b3
# Maia 1900 Evaluation: 1.53, Suggested Move: a2b3
# Initial Image: chess_images/World_Championship_Match_1910_pos_55_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_55_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_55_correct.png
#
# Illegal move a2b3 in position 2n5/1k2p3/8/8/8/PK6/4R3/8 b - - 4 68
# Position: 2n5/1k2p3/8/8/8/PK6/4R3/8 b - - 4 68
# Blunder: a2b3
# Stockfish Evaluation: -4.09
# Stockfish Suggested Move: b7b6
# Maia 1100 Evaluation: -1.0, Suggested Move: b7c7
# Maia 1200 Evaluation: -1.22, Suggested Move: c8d6
# Maia 1300 Evaluation: -0.99, Suggested Move: c8b6
# Maia 1400 Evaluation: -1.09, Suggested Move: b7b6
# Maia 1500 Evaluation: -1.46, Suggested Move: b7b6
# Maia 1600 Evaluation: -1.39, Suggested Move: b7b6
# Maia 1700 Evaluation: -1.74, Suggested Move: b7b6
# Maia 1800 Evaluation: -1.39, Suggested Move: b7c6
# Maia 1900 Evaluation: -1.48, Suggested Move: b7c6
# Initial Image: chess_images/World_Championship_Match_1910_pos_56_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_56_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_56_correct.png
#
# Illegal move b7c6 in position 2n5/4p3/2k5/8/8/PK6/4R3/8 w - - 5 69
# Position: 2n5/4p3/2k5/8/8/PK6/4R3/8 w - - 5 69
# Blunder: b7c6
# Stockfish Evaluation: 4.09
# Stockfish Suggested Move: b3b4
# Maia 1100 Evaluation: 1.05, Suggested Move: a3a4
# Maia 1200 Evaluation: 0.85, Suggested Move: a3a4
# Maia 1300 Evaluation: 1.04, Suggested Move: b3b4
# Maia 1400 Evaluation: 1.09, Suggested Move: b3b4
# Maia 1500 Evaluation: 1.18, Suggested Move: b3b4
# Maia 1600 Evaluation: 1.79, Suggested Move: b3b4
# Maia 1700 Evaluation: 1.47, Suggested Move: b3b4
# Maia 1800 Evaluation: 1.83, Suggested Move: b3b4
# Maia 1900 Evaluation: 1.81, Suggested Move: b3c4
# Initial Image: chess_images/World_Championship_Match_1910_pos_57_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_57_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_57_correct.png
#
# Illegal move e2c2 in position 2n5/4p3/2k5/8/8/PK6/2R5/8 b - - 6 69
# Position: 2n5/4p3/2k5/8/8/PK6/2R5/8 b - - 6 69
# Blunder: e2c2
# Stockfish Evaluation: -3.93
# Stockfish Suggested Move: c6d7
# Maia 1100 Evaluation: -0.56, Suggested Move: c6d7
# Maia 1200 Evaluation: -0.94, Suggested Move: c6d7
# Maia 1300 Evaluation: -1.05, Suggested Move: c6d7
# Maia 1400 Evaluation: -1.05, Suggested Move: c6d7
# Maia 1500 Evaluation: -1.29, Suggested Move: c6d7
# Maia 1600 Evaluation: -1.53, Suggested Move: c6d7
# Maia 1700 Evaluation: -2.28, Suggested Move: c6d7
# Maia 1800 Evaluation: -1.97, Suggested Move: c6d7
# Maia 1900 Evaluation: -1.43, Suggested Move: c6d7
# Initial Image: chess_images/World_Championship_Match_1910_pos_58_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_58_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_58_correct.png
#
# Illegal move c6b7 in position 2n5/1k2p3/8/8/8/PK6/2R5/8 w - - 7 70
# Position: 2n5/1k2p3/8/8/8/PK6/2R5/8 w - - 7 70
# Blunder: c6b7
# Stockfish Evaluation: 4.28
# Stockfish Suggested Move: b3b4
# Maia 1100 Evaluation: 0.96, Suggested Move: a3a4
# Maia 1200 Evaluation: 1.15, Suggested Move: a3a4
# Maia 1300 Evaluation: 1.05, Suggested Move: a3a4
# Maia 1400 Evaluation: 1.1, Suggested Move: a3a4
# Maia 1500 Evaluation: 1.45, Suggested Move: b3b4
# Maia 1600 Evaluation: 1.99, Suggested Move: b3b4
# Maia 1700 Evaluation: 1.39, Suggested Move: b3b4
# Maia 1800 Evaluation: 2.16, Suggested Move: b3b4
# Maia 1900 Evaluation: 1.67, Suggested Move: a3a4
# Initial Image: chess_images/World_Championship_Match_1910_pos_59_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_59_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_59_correct.png
#
# Illegal move b3b4 in position 2n5/1k2p3/8/8/1K6/P7/2R5/8 b - - 8 70
# Position: 2n5/1k2p3/8/8/1K6/P7/2R5/8 b - - 8 70
# Blunder: b3b4
# Stockfish Evaluation: -4.3
# Stockfish Suggested Move: c8d6
# Maia 1100 Evaluation: -1.12, Suggested Move: e7e5
# Maia 1200 Evaluation: -1.29, Suggested Move: c8d6
# Maia 1300 Evaluation: -1.16, Suggested Move: e7e5
# Maia 1400 Evaluation: -1.22, Suggested Move: c8d6
# Maia 1500 Evaluation: -1.34, Suggested Move: e7e5
# Maia 1600 Evaluation: -1.34, Suggested Move: c8d6
# Maia 1700 Evaluation: -1.54, Suggested Move: e7e5
# Maia 1800 Evaluation: -1.29, Suggested Move: c8d6
# Maia 1900 Evaluation: -1.58, Suggested Move: c8d6
# Initial Image: chess_images/World_Championship_Match_1910_pos_60_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_60_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_60_correct.png
#
# Illegal move c8a7 in position 8/nk2p3/8/8/1K6/P7/2R5/8 w - - 9 71
# Position: 8/nk2p3/8/8/1K6/P7/2R5/8 w - - 9 71
# Blunder: c8a7
# Stockfish Evaluation: 4.37
# Stockfish Suggested Move: a3a4
# Maia 1100 Evaluation: 1.09, Suggested Move: a3a4
# Maia 1200 Evaluation: 1.36, Suggested Move: a3a4
# Maia 1300 Evaluation: 1.31, Suggested Move: a3a4
# Maia 1400 Evaluation: 1.19, Suggested Move: a3a4
# Maia 1500 Evaluation: 1.65, Suggested Move: a3a4
# Maia 1600 Evaluation: 2.18, Suggested Move: a3a4
# Maia 1700 Evaluation: 1.28, Suggested Move: a3a4
# Maia 1800 Evaluation: 1.97, Suggested Move: c2e2
# Maia 1900 Evaluation: 2.07, Suggested Move: a3a4
# Initial Image: chess_images/World_Championship_Match_1910_pos_61_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_61_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_61_correct.png
#
# Illegal move b4c5 in position 8/nk2p3/8/2K5/8/P7/2R5/8 b - - 10 71
# Position: 8/nk2p3/8/2K5/8/P7/2R5/8 b - - 10 71
# Blunder: b4c5
# Stockfish Evaluation: -4.47
# Stockfish Suggested Move: a7c6
# Maia 1100 Evaluation: -1.06, Suggested Move: a7c6
# Maia 1200 Evaluation: -1.43, Suggested Move: a7c6
# Maia 1300 Evaluation: -1.28, Suggested Move: a7c6
# Maia 1400 Evaluation: -1.09, Suggested Move: a7c6
# Maia 1500 Evaluation: -1.49, Suggested Move: a7c6
# Maia 1600 Evaluation: -1.43, Suggested Move: a7c6
# Maia 1700 Evaluation: -1.54, Suggested Move: a7c6
# Maia 1800 Evaluation: -1.73, Suggested Move: b7a6
# Maia 1900 Evaluation: -1.44, Suggested Move: a7c6
# Initial Image: chess_images/World_Championship_Match_1910_pos_62_initial.png
# Blunder Image: chess_images/World_Championship_Match_1910_pos_62_blunder.png
# Correct Move Image: chess_images/World_Championship_Match_1910_pos_62_correct.png
#
# Cleaning up engines...
# Engines cleaned up.
