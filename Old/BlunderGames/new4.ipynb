# %%
# Part 1: Initialization and Loading PGN Files

# Import required libraries
import chess
import chess.engine
import chess.pgn
import chess.svg
import subprocess
import os
from PIL import Image
import io
import json
import random
import time
import csv
from IPython.display import display

# Paths to your engines and Maia models
stockfish_path = "/opt/homebrew/bin/stockfish"
maia_model_paths = {
    1100: "maia_weights/maia-1100.pb.gz",
    1200: "maia_weights/maia-1200.pb.gz",
    1300: "maia_weights/maia-1300.pb.gz",
    1400: "maia_weights/maia-1400.pb.gz",
    1500: "maia_weights/maia-1500.pb.gz",
    1600: "maia_weights/maia-1600.pb.gz",
    1700: "maia_weights/maia-1700.pb.gz",
    1800: "maia_weights/maia-1800.pb.gz",
    1900: "maia_weights/maia-1900.pb.gz",
}

# Initialize Stockfish engine
print("Initializing Stockfish engine...")
try:
    stockfish_engine = chess.engine.SimpleEngine.popen_uci(stockfish_path, stderr=subprocess.DEVNULL)
    print("Stockfish engine initialized.")
except Exception as e:
    print(f"Error initializing Stockfish engine: {e}")

# Initialize Maia engines
print("Initializing Maia engines...")
maia_engines = {}
for elo, path in maia_model_paths.items():
    try:
        print(f"Initializing Maia {elo} engine...")
        maia_engines[elo] = chess.engine.SimpleEngine.popen_uci(["lc0", f"--weights={path}"], stderr=subprocess.DEVNULL)
        print(f"Maia {elo} engine initialized.")
    except Exception as e:
        print(f"Error initializing Maia {elo} engine: {e}")


# Function to load games from a PGN file
def load_games_from_pgn(file_path):
    games = []
    with open(file_path, 'r') as pgn_file:
        while True:
            game = chess.pgn.read_game(pgn_file)
            if game is None:
                break
            games.append(game)
    print(f"Loaded {len(games)} games from PGN file {file_path}.")
    return games


# Directory containing PGN files
pgn_directory = "analysis_pgns_test"
all_games = []

print("Starting to load PGN files...")

for pgn_file in os.listdir(pgn_directory):
    if pgn_file.endswith(".pgn"):
        pgn_file_path = os.path.join(pgn_directory, pgn_file)
        print(f"Loading {pgn_file_path}...")
        all_games.extend(load_games_from_pgn(pgn_file_path))

print(f"Total games loaded: {len(all_games)}")
# Out:
# Initializing Stockfish engine...
# Stockfish engine initialized.
# Initializing Maia engines...
# Initializing Maia 1100 engine...
# Maia 1100 engine initialized.
# Initializing Maia 1200 engine...
# Maia 1200 engine initialized.
# Initializing Maia 1300 engine...
# Maia 1300 engine initialized.
# Initializing Maia 1400 engine...
# Maia 1400 engine initialized.
# Initializing Maia 1500 engine...
# Maia 1500 engine initialized.
# Initializing Maia 1600 engine...
# Maia 1600 engine initialized.
# Initializing Maia 1700 engine...
# Maia 1700 engine initialized.
# Initializing Maia 1800 engine...
# Maia 1800 engine initialized.
# Initializing Maia 1900 engine...
# Maia 1900 engine initialized.
# Starting to load PGN files...
# Loading analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn...
# Loaded 9 games from PGN file analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn.
# Loading analysis_pgns_test/4S5UuAGn---1986 Karpov vs. Kasparov III.pgn...
# Loaded 11 games from PGN file analysis_pgns_test/4S5UuAGn---1986 Karpov vs. Kasparov III.pgn.
# Total games loaded: 20

# %%
# Part 2: Analysis Functions

import chess.pgn


# Function to calculate average error for a position using Stockfish
def calculate_average_error(board, stockfish_engine):
    legal_moves = list(board.legal_moves)
    total_error = 0
    num_moves = len(legal_moves)

    for move in legal_moves:
        board.push(move)
        info = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1))
        eval_score = info["score"].relative.score(mate_score=10000) / 100.0
        total_error += abs(eval_score)
        board.pop()

    average_error = total_error / num_moves if num_moves > 0 else 0
    return average_error


# Function to analyze a game using Stockfish and Maia engines
def analyze_with_engines(game, stockfish_engine, maia_engines):
    board = game.board()
    blunders = []

    for move in game.mainline_moves():
        fen_before = board.fen()  # Get FEN before the move
        player = board.turn  # True for White, False for Black

        # Analyze the position before the move
        stockfish_info_before = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1))
        stockfish_eval_before = stockfish_info_before["score"].relative.score(mate_score=10000) / 100.0

        board.push(move)

        # Analyze the position after the move
        stockfish_info_after = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1))
        stockfish_eval_after = stockfish_info_after["score"].relative.score(mate_score=10000) / 100.0
        stockfish_best_move_after = stockfish_info_after["pv"][0] if "pv" in stockfish_info_after else None

        # Define blunder threshold
        if player and stockfish_eval_after < stockfish_eval_before - 4:
            # White's turn, evaluation worsened significantly
            maia_suggestions = {}
            board.pop()  # Revert to the position before the blunder
            for elo, maia_engine in maia_engines.items():
                # Analyze the position before the blunder for Maia suggestions
                maia_info = maia_engine.analyse(board, chess.engine.Limit(nodes=1))
                maia_eval = maia_info["score"].relative.score(mate_score=10000) / 100.0
                maia_best_move = maia_info["pv"][0] if "pv" in maia_info else None
                maia_suggestions[elo] = (maia_best_move, maia_eval)
            board.push(move)  # Push the move again to keep the board state

            blunders.append((fen_before, move, stockfish_eval_after, stockfish_best_move_after, maia_suggestions))
        elif not player and stockfish_eval_after > stockfish_eval_before + 4:
            # Black's turn, evaluation worsened significantly
            maia_suggestions = {}
            board.pop()  # Revert to the position before the blunder
            for elo, maia_engine in maia_engines.items():
                # Analyze the position before the blunder for Maia suggestions
                maia_info = maia_engine.analyse(board, chess.engine.Limit(nodes=1))
                maia_eval = maia_info["score"].relative.score(mate_score=10000) / 100.0
                maia_best_move = maia_info["pv"][0] if "pv" in maia_info else None
                maia_suggestions[elo] = (maia_best_move, maia_eval)
            board.push(move)  # Push the move again to keep the board state

            blunders.append((fen_before, move, stockfish_eval_after, stockfish_best_move_after, maia_suggestions))

    print(f"Analyzed game with {len(blunders)} blunders found.")
    return blunders


# Function to filter the best blunders based on majority agreement and magnitude of evaluation change
def filter_best_blunders(blunders, evaluation_change_threshold=3.0, majority_threshold=0.8):
    filtered_blunders = []

    for fen, move, stockfish_eval, stockfish_best_move, maia_suggestions in blunders:
        move_counts = {}

        # Count how many times each move is suggested by Maia engines above 1300
        for elo, (best_move, maia_eval) in maia_suggestions.items():
            if elo > 1300:
                if best_move in move_counts:
                    move_counts[best_move] += 1
                else:
                    move_counts[best_move] = 1

        # Find the move with the highest count
        if move_counts:
            most_common_move, count = max(move_counts.items(), key=lambda item: item[1])

            # Calculate the agreement ratio
            total_considered = sum(1 for elo in maia_suggestions if elo > 1300)
            agreement_ratio = count / total_considered if total_considered > 0 else 0

            # Calculate the evaluation change
            eval_change = abs(stockfish_eval)

            # Filter based on majority agreement and evaluation change threshold
            if agreement_ratio >= majority_threshold and eval_change >= evaluation_change_threshold:
                filtered_blunders.append((fen, move, stockfish_eval, most_common_move, maia_suggestions))

    print(f"Filtered blunders down to {len(filtered_blunders)} consistent ones.")
    return filtered_blunders

# %%
# Part 3: Analyzing Games and Saving Results

import csv
import json

# Directory containing PGN files
pgn_directory = "analysis_pgns_test"
all_positions = []

# Function to save results incrementally to CSV
def save_results_to_csv(csv_file_path, data):
    with open(csv_file_path, "a", newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        for entry in data:
            csvwriter.writerow([
                entry["FEN"], entry["Average Error"], entry["Event"], entry["Move"],
                entry["Best Move"], entry["Player"], entry["To Move"], entry["White"],
                entry["Black"], entry["Round"], entry["Result"], entry["WhiteElo"],
                entry["BlackElo"], entry["Opening"], entry["File"]
            ])

# Function to save results incrementally to JSON
def save_results_to_json(json_file_path, data):
    if os.path.exists(json_file_path):
        with open(json_file_path, "r") as jsonfile:
            json_data = json.load(jsonfile)
    else:
        json_data = {}

    for entry in data:
        event = entry["Event"]
        if event not in json_data:
            json_data[event] = []
        json_data[event].append(entry)

    with open(json_file_path, "w") as jsonfile:
        json.dump(json_data, jsonfile, indent=4)

# Paths to save results
csv_file_path = "positions_with_errors.csv"
json_file_path = "positions_with_errors.json"

# Initialize CSV file with headers
with open(csv_file_path, "w", newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow([
        "FEN", "Average Error", "Event", "Move", "Best Move", "Player",
        "To Move", "White", "Black", "Round", "Result", "WhiteElo",
        "BlackElo", "Opening", "File"
    ])

print("Starting analysis of PGN files...")

for pgn_file in os.listdir(pgn_directory):
    if pgn_file.endswith(".pgn"):
        pgn_file_path = os.path.join(pgn_directory, pgn_file)
        print(f"Analyzing {pgn_file_path}...")
        all_games = load_games_from_pgn(pgn_file_path)
        print(f"Loaded {len(all_games)} games from PGN file {pgn_file_path}.")

        # Analyze games without using Maia
        for game in all_games:
            print(f"Analyzing game {game.headers.get('Event', 'Unknown Event')} without Maia...")
            board = game.board()
            node = game
            current_positions = []
            while node.variations:
                move = node.variation(0).move
                fen = board.fen()
                print(f"Analyzing position: {fen}")
                avg_error = calculate_average_error(board, stockfish_engine)
                stockfish_info = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1))
                best_move = stockfish_info["pv"][0] if "pv" in stockfish_info else None

                # Check for move equality and filter out if they are the same
                if str(move) == str(best_move):
                    print(f"Skipping move {move} as it is the same as the best move {best_move}.")
                    board.push(move)
                    node = node.variation(0)
                    continue

                event_details = {
                    "FEN": fen,
                    "Average Error": avg_error,
                    "Event": game.headers.get("Event", "Unknown Event"),
                    "Move": str(move),
                    "Best Move": str(best_move),
                    "Player": "White" if board.turn else "Black",
                    "To Move": "White" if board.turn else "Black",
                    "White": game.headers.get("White", "Unknown"),
                    "Black": game.headers.get("Black", "Unknown"),
                    "Round": game.headers.get("Round", "Unknown"),
                    "Result": game.headers.get("Result", "*"),
                    "WhiteElo": game.headers.get("WhiteElo", "N/A"),
                    "BlackElo": game.headers.get("BlackElo", "N/A"),
                    "Opening": game.headers.get("Opening", "Unknown Opening"),
                    "File": pgn_file_path
                }
                current_positions.append(event_details)
                try:
                    board.push(move)
                except AssertionError as e:
                    print(f"Error: {e}, move: {move}, position: {board.fen()}")
                    break  # Skip to the next game
                node = node.variation(0)  # Move to the next node in the game tree

                # Debugging print to ensure we are making progress
                print(f"Processed move: {move}, current positions collected: {len(current_positions)}")

            # Save results incrementally
            save_results_to_csv(csv_file_path, current_positions)
            save_results_to_json(json_file_path, current_positions)

            print(f"Finished analyzing game {game.headers.get('Event', 'Unknown Event')} without Maia.")

# Analyze games using Maia
for pgn_file in os.listdir(pgn_directory):
    if pgn_file.endswith(".pgn"):
        pgn_file_path = os.path.join(pgn_directory, pgn_file)
        print(f"Analyzing {pgn_file_path} (with Maia)...")
        all_games = load_games_from_pgn(pgn_file_path)
        print(f"Loaded {len(all_games)} games from PGN file {pgn_file_path}.")

        for game in all_games:
            print(f"Analyzing game {game.headers.get('Event', 'Unknown Event')} with Maia...")
            blunders = analyze_with_engines(game, stockfish_engine, maia_engines)
            filtered_blunders = filter_best_blunders(blunders)
            current_positions = []

            for fen, move, stockfish_eval, best_move, maia_suggestions in filtered_blunders:
                avg_error = calculate_average_error(chess.Board(fen), stockfish_engine)

                # Check for move equality and filter out if they are the same
                if str(move) == str(best_move):
                    print(f"Skipping move {move} as it is the same as the best move {best_move}.")
                    continue

                event_details = {
                    "FEN": fen,
                    "Average Error": avg_error,
                    "Event": game.headers.get("Event", "Unknown Event"),
                    "Move": str(move),
                    "Best Move": str(best_move),
                    "Player": "White" if chess.Board(fen).turn else "Black",
                    "To Move": "White" if chess.Board(fen).turn else "Black",
                    "White": game.headers.get("White", "Unknown"),
                    "Black": game.headers.get("Black", "Unknown"),
                    "Round": game.headers.get("Round", "Unknown"),
                    "Result": game.headers.get("Result", "*"),
                    "WhiteElo": game.headers.get("WhiteElo", "N/A"),
                    "BlackElo": game.headers.get("BlackElo", "N/A"),
                    "Opening": game.headers.get("Opening", "Unknown Opening"),
                    "File": pgn_file_path
                }
                current_positions.append(event_details)

                # Debugging print to ensure we are making progress
                print(f"Processed move: {move}, current positions collected: {len(current_positions)}")

            # Save results incrementally
            save_results_to_csv(csv_file_path, current_positions)
            save_results_to_json(json_file_path, current_positions)

            print(f"Finished analyzing game {game.headers.get('Event', 'Unknown Event')} with Maia.")

print("Analysis complete. Results saved incrementally.")
# Out:
# Starting analysis of PGN files...
# Analyzing analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn...
# Loaded 9 games from PGN file analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn.
# Loaded 9 games from PGN file analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn.
# Analyzing game FIDE World Championship Match 1969 without Maia...
# Analyzing position: rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1
# Skipping move e2e4 as it is the same as the best move e2e4.
# Analyzing position: rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1
# Skipping move c7c5 as it is the same as the best move c7c5.
# Analyzing position: rnbqkbnr/pp1ppppp/8/2p5/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Skipping move g1f3 as it is the same as the best move g1f3.
# Analyzing position: rnbqkbnr/pp1ppppp/8/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 2
# Processed move: e7e6, current positions collected: 1
# Analyzing position: rnbqkbnr/pp1p1ppp/4p3/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R w KQkq - 0 3
# Processed move: d2d4, current positions collected: 2
# Analyzing position: rnbqkbnr/pp1p1ppp/4p3/2p5/3PP3/5N2/PPP2PPP/RNBQKB1R b KQkq - 0 3
# Skipping move c5d4 as it is the same as the best move c5d4.
# Analyzing position: rnbqkbnr/pp1p1ppp/4p3/8/3pP3/5N2/PPP2PPP/RNBQKB1R w KQkq - 0 4
# Skipping move f3d4 as it is the same as the best move f3d4.
# Analyzing position: rnbqkbnr/pp1p1ppp/4p3/8/3NP3/8/PPP2PPP/RNBQKB1R b KQkq - 0 4
# Skipping move a7a6 as it is the same as the best move a7a6.
# Analyzing position: rnbqkbnr/1p1p1ppp/p3p3/8/3NP3/8/PPP2PPP/RNBQKB1R w KQkq - 0 5
# Skipping move f1d3 as it is the same as the best move f1d3.
# Analyzing position: rnbqkbnr/1p1p1ppp/p3p3/8/3NP3/3B4/PPP2PPP/RNBQK2R b KQkq - 1 5
# Processed move: b8c6, current positions collected: 3
# Analyzing position: r1bqkbnr/1p1p1ppp/p1n1p3/8/3NP3/3B4/PPP2PPP/RNBQK2R w KQkq - 2 6
# Skipping move d4c6 as it is the same as the best move d4c6.
# Analyzing position: r1bqkbnr/1p1p1ppp/p1N1p3/8/4P3/3B4/PPP2PPP/RNBQK2R b KQkq - 0 6
# Processed move: b7c6, current positions collected: 4
# Analyzing position: r1bqkbnr/3p1ppp/p1p1p3/8/4P3/3B4/PPP2PPP/RNBQK2R w KQkq - 0 7
# Skipping move e1g1 as it is the same as the best move e1g1.
# Analyzing position: r1bqkbnr/3p1ppp/p1p1p3/8/4P3/3B4/PPP2PPP/RNBQ1RK1 b kq - 1 7
# Processed move: d7d5, current positions collected: 5
# Analyzing position: r1bqkbnr/5ppp/p1p1p3/3p4/4P3/3B4/PPP2PPP/RNBQ1RK1 w kq - 0 8
# Processed move: b1d2, current positions collected: 6
# Analyzing position: r1bqkbnr/5ppp/p1p1p3/3p4/4P3/3B4/PPPN1PPP/R1BQ1RK1 b kq - 1 8
# Skipping move g8f6 as it is the same as the best move g8f6.
# Analyzing position: r1bqkb1r/5ppp/p1p1pn2/3p4/4P3/3B4/PPPN1PPP/R1BQ1RK1 w kq - 2 9
# Processed move: d1e2, current positions collected: 7
# Analyzing position: r1bqkb1r/5ppp/p1p1pn2/3p4/4P3/3B4/PPPNQPPP/R1B2RK1 b kq - 3 9
# Skipping move f8e7 as it is the same as the best move f8e7.
# Analyzing position: r1bqk2r/4bppp/p1p1pn2/3p4/4P3/3B4/PPPNQPPP/R1B2RK1 w kq - 4 10
# Processed move: b2b3, current positions collected: 8
# Analyzing position: r1bqk2r/4bppp/p1p1pn2/3p4/4P3/1P1B4/P1PNQPPP/R1B2RK1 b kq - 0 10
# Skipping move e8g8 as it is the same as the best move e8g8.
# Analyzing position: r1bq1rk1/4bppp/p1p1pn2/3p4/4P3/1P1B4/P1PNQPPP/R1B2RK1 w - - 1 11
# Processed move: c1b2, current positions collected: 9
# Analyzing position: r1bq1rk1/4bppp/p1p1pn2/3p4/4P3/1P1B4/PBPNQPPP/R4RK1 b - - 2 11
# Skipping move a6a5 as it is the same as the best move a6a5.
# Analyzing position: r1bq1rk1/4bppp/2p1pn2/p2p4/4P3/1P1B4/PBPNQPPP/R4RK1 w - - 0 12
# Processed move: f2f4, current positions collected: 10
# Analyzing position: r1bq1rk1/4bppp/2p1pn2/p2p4/4PP2/1P1B4/PBPNQ1PP/R4RK1 b - - 0 12
# Processed move: g7g6, current positions collected: 11
# Analyzing position: r1bq1rk1/4bp1p/2p1pnp1/p2p4/4PP2/1P1B4/PBPNQ1PP/R4RK1 w - - 0 13
# Processed move: a1d1, current positions collected: 12
# Analyzing position: r1bq1rk1/4bp1p/2p1pnp1/p2p4/4PP2/1P1B4/PBPNQ1PP/3R1RK1 b - - 1 13
# Processed move: f6d7, current positions collected: 13
# Analyzing position: r1bq1rk1/3nbp1p/2p1p1p1/p2p4/4PP2/1P1B4/PBPNQ1PP/3R1RK1 w - - 2 14
# Processed move: c2c4, current positions collected: 14
# Analyzing position: r1bq1rk1/3nbp1p/2p1p1p1/p2p4/2P1PP2/1P1B4/PB1NQ1PP/3R1RK1 b - - 0 14
# Skipping move a5a4 as it is the same as the best move a5a4.
# Analyzing position: r1bq1rk1/3nbp1p/2p1p1p1/3p4/p1P1PP2/1P1B4/PB1NQ1PP/3R1RK1 w - - 0 15
# Processed move: f4f5, current positions collected: 15
# Analyzing position: r1bq1rk1/3nbp1p/2p1p1p1/3p1P2/p1P1P3/1P1B4/PB1NQ1PP/3R1RK1 b - - 0 15
# Skipping move e6f5 as it is the same as the best move e6f5.
# Analyzing position: r1bq1rk1/3nbp1p/2p3p1/3p1p2/p1P1P3/1P1B4/PB1NQ1PP/3R1RK1 w - - 0 16
# Skipping move e4f5 as it is the same as the best move e4f5.
# Analyzing position: r1bq1rk1/3nbp1p/2p3p1/3p1P2/p1P5/1P1B4/PB1NQ1PP/3R1RK1 b - - 0 16
# Skipping move e7f6 as it is the same as the best move e7f6.
# Analyzing position: r1bq1rk1/3n1p1p/2p2bp1/3p1P2/p1P5/1P1B4/PB1NQ1PP/3R1RK1 w - - 1 17
# Skipping move b2f6 as it is the same as the best move b2f6.
# Analyzing position: r1bq1rk1/3n1p1p/2p2Bp1/3p1P2/p1P5/1P1B4/P2NQ1PP/3R1RK1 b - - 0 17
# Skipping move d7f6 as it is the same as the best move d7f6.
# Analyzing position: r1bq1rk1/5p1p/2p2np1/3p1P2/p1P5/1P1B4/P2NQ1PP/3R1RK1 w - - 0 18
# Processed move: e2f2, current positions collected: 16
# Analyzing position: r1bq1rk1/5p1p/2p2np1/3p1P2/p1P5/1P1B4/P2N1QPP/3R1RK1 b - - 1 18
# Processed move: a4b3, current positions collected: 17
# Analyzing position: r1bq1rk1/5p1p/2p2np1/3p1P2/2P5/1p1B4/P2N1QPP/3R1RK1 w - - 0 19
# Processed move: a2b3, current positions collected: 18
# Analyzing position: r1bq1rk1/5p1p/2p2np1/3p1P2/2P5/1P1B4/3N1QPP/3R1RK1 b - - 0 19
# Processed move: a8a2, current positions collected: 19
# Analyzing position: 2bq1rk1/5p1p/2p2np1/3p1P2/2P5/1P1B4/r2N1QPP/3R1RK1 w - - 1 20
# Skipping move f5g6 as it is the same as the best move f5g6.
# Analyzing position: 2bq1rk1/5p1p/2p2nP1/3p4/2P5/1P1B4/r2N1QPP/3R1RK1 b - - 0 20
# Skipping move f7g6 as it is the same as the best move f7g6.
# Analyzing position: 2bq1rk1/7p/2p2np1/3p4/2P5/1P1B4/r2N1QPP/3R1RK1 w - - 0 21
# Processed move: h2h3, current positions collected: 20
# Analyzing position: 2bq1rk1/7p/2p2np1/3p4/2P5/1P1B3P/r2N1QP1/3R1RK1 b - - 0 21
# Processed move: d8e7, current positions collected: 21
# Analyzing position: 2b2rk1/4q2p/2p2np1/3p4/2P5/1P1B3P/r2N1QP1/3R1RK1 w - - 1 22
# Processed move: f2d4, current positions collected: 22
# Analyzing position: 2b2rk1/4q2p/2p2np1/3p4/2PQ4/1P1B3P/r2N2P1/3R1RK1 b - - 2 22
# Skipping move c6c5 as it is the same as the best move c6c5.
# Analyzing position: 2b2rk1/4q2p/5np1/2pp4/2PQ4/1P1B3P/r2N2P1/3R1RK1 w - - 0 23
# Processed move: d4f4, current positions collected: 23
# Analyzing position: 2b2rk1/4q2p/5np1/2pp4/2P2Q2/1P1B3P/r2N2P1/3R1RK1 b - - 1 23
# Processed move: c8b7, current positions collected: 24
# Analyzing position: 5rk1/1b2q2p/5np1/2pp4/2P2Q2/1P1B3P/r2N2P1/3R1RK1 w - - 2 24
# Processed move: d1e1, current positions collected: 25
# Analyzing position: 5rk1/1b2q2p/5np1/2pp4/2P2Q2/1P1B3P/r2N2P1/4RRK1 b - - 3 24
# Processed move: e7g7, current positions collected: 26
# Analyzing position: 5rk1/1b4qp/5np1/2pp4/2P2Q2/1P1B3P/r2N2P1/4RRK1 w - - 4 25
# Processed move: f4e3, current positions collected: 27
# Analyzing position: 5rk1/1b4qp/5np1/2pp4/2P5/1P1BQ2P/r2N2P1/4RRK1 b - - 5 25
# Skipping move d5d4 as it is the same as the best move d5d4.
# Analyzing position: 5rk1/1b4qp/5np1/2p5/2Pp4/1P1BQ2P/r2N2P1/4RRK1 w - - 0 26
# Processed move: e3e6, current positions collected: 28
# Analyzing position: 5rk1/1b4qp/4Qnp1/2p5/2Pp4/1P1B3P/r2N2P1/4RRK1 b - - 1 26
# Skipping move g7f7 as it is the same as the best move g7f7.
# Analyzing position: 5rk1/1b3q1p/4Qnp1/2p5/2Pp4/1P1B3P/r2N2P1/4RRK1 w - - 2 27
# Processed move: e6e2, current positions collected: 29
# Analyzing position: 5rk1/1b3q1p/5np1/2p5/2Pp4/1P1B3P/r2NQ1P1/4RRK1 b - - 3 27
# Skipping move f8e8 as it is the same as the best move f8e8.
# Analyzing position: 4r1k1/1b3q1p/5np1/2p5/2Pp4/1P1B3P/r2NQ1P1/4RRK1 w - - 4 28
# Skipping move e2f2 as it is the same as the best move e2f2.
# Analyzing position: 4r1k1/1b3q1p/5np1/2p5/2Pp4/1P1B3P/r2N1QP1/4RRK1 b - - 5 28
# Skipping move e8e1 as it is the same as the best move e8e1.
# Analyzing position: 6k1/1b3q1p/5np1/2p5/2Pp4/1P1B3P/r2N1QP1/4rRK1 w - - 0 29
# Skipping move f2e1 as it is the same as the best move f2e1.
# Analyzing position: 6k1/1b3q1p/5np1/2p5/2Pp4/1P1B3P/r2N2P1/4QRK1 b - - 0 29
# Skipping move f7e8 as it is the same as the best move f7e8.
# Analyzing position: 4q1k1/1b5p/5np1/2p5/2Pp4/1P1B3P/r2N2P1/4QRK1 w - - 1 30
# Skipping move e1e8 as it is the same as the best move e1e8.
# Analyzing position: 4Q1k1/1b5p/5np1/2p5/2Pp4/1P1B3P/r2N2P1/5RK1 b - - 0 30
# Skipping move f6e8 as it is the same as the best move f6e8.
# Analyzing position: 4n1k1/1b5p/6p1/2p5/2Pp4/1P1B3P/r2N2P1/5RK1 w - - 0 31
# Processed move: d3e4, current positions collected: 30
# Analyzing position: 4n1k1/1b5p/6p1/2p5/2PpB3/1P5P/r2N2P1/5RK1 b - - 1 31
# Skipping move a2d2 as it is the same as the best move a2d2.
# Analyzing position: 4n1k1/1b5p/6p1/2p5/2PpB3/1P5P/3r2P1/5RK1 w - - 0 32
# Skipping move e4b7 as it is the same as the best move e4b7.
# Analyzing position: 4n1k1/1B5p/6p1/2p5/2Pp4/1P5P/3r2P1/5RK1 b - - 0 32
# Processed move: e8d6, current positions collected: 31
# Analyzing position: 6k1/1B5p/3n2p1/2p5/2Pp4/1P5P/3r2P1/5RK1 w - - 1 33
# Skipping move b7d5 as it is the same as the best move b7d5.
# Analyzing position: 6k1/7p/3n2p1/2pB4/2Pp4/1P5P/3r2P1/5RK1 b - - 2 33
# Skipping move g8g7 as it is the same as the best move g8g7.
# Analyzing position: 8/6kp/3n2p1/2pB4/2Pp4/1P5P/3r2P1/5RK1 w - - 3 34
# Processed move: b3b4, current positions collected: 32
# Analyzing position: 8/6kp/3n2p1/2pB4/1PPp4/7P/3r2P1/5RK1 b - - 0 34
# Skipping move c5b4 as it is the same as the best move c5b4.
# Analyzing position: 8/6kp/3n2p1/3B4/1pPp4/7P/3r2P1/5RK1 w - - 0 35
# Skipping move c4c5 as it is the same as the best move c4c5.
# Analyzing position: 8/6kp/3n2p1/2PB4/1p1p4/7P/3r2P1/5RK1 b - - 0 35
# Skipping move d6f5 as it is the same as the best move d6f5.
# Analyzing position: 8/6kp/6p1/2PB1n2/1p1p4/7P/3r2P1/5RK1 w - - 1 36
# Skipping move c5c6 as it is the same as the best move c5c6.
# Analyzing position: 8/6kp/2P3p1/3B1n2/1p1p4/7P/3r2P1/5RK1 b - - 0 36
# Skipping move d2c2 as it is the same as the best move d2c2.
# Analyzing position: 8/6kp/2P3p1/3B1n2/1p1p4/7P/2r3P1/5RK1 w - - 1 37
# Processed move: g2g4, current positions collected: 33
# Analyzing position: 8/6kp/2P3p1/3B1n2/1p1p2P1/7P/2r5/5RK1 b - - 0 37
# Processed move: f5d6, current positions collected: 34
# Analyzing position: 8/6kp/2Pn2p1/3B4/1p1p2P1/7P/2r5/5RK1 w - - 1 38
# Processed move: f1f4, current positions collected: 35
# Analyzing position: 8/6kp/2Pn2p1/3B4/1p1p1RP1/7P/2r5/6K1 b - - 2 38
# Skipping move d4d3 as it is the same as the best move d4d3.
# Analyzing position: 8/6kp/2Pn2p1/3B4/1p3RP1/3p3P/2r5/6K1 w - - 0 39
# Processed move: f4d4, current positions collected: 36
# Analyzing position: 8/6kp/2Pn2p1/3B4/1p1R2P1/3p3P/2r5/6K1 b - - 1 39
# Processed move: d3d2, current positions collected: 37
# Analyzing position: 8/6kp/2Pn2p1/3B4/1p1R2P1/7P/2rp4/6K1 w - - 0 40
# Skipping move d5b3 as it is the same as the best move d5b3.
# Analyzing position: 8/6kp/2Pn2p1/8/1p1R2P1/1B5P/2rp4/6K1 b - - 1 40
# Skipping move c2c6 as it is the same as the best move c2c6.
# Analyzing position: 8/6kp/2rn2p1/8/1p1R2P1/1B5P/3p4/6K1 w - - 0 41
# Skipping move d4d2 as it is the same as the best move d4d2.
# Analyzing position: 8/6kp/2rn2p1/8/1p4P1/1B5P/3R4/6K1 b - - 0 41
# Skipping move d6e4 as it is the same as the best move d6e4.
# Analyzing position: 8/6kp/2r3p1/8/1p2n1P1/1B5P/3R4/6K1 w - - 1 42
# Skipping move d2d7 as it is the same as the best move d2d7.
# Analyzing position: 8/3R2kp/2r3p1/8/1p2n1P1/1B5P/8/6K1 b - - 2 42
# Processed move: g7f6, current positions collected: 38
# Analyzing position: 8/3R3p/2r2kp1/8/1p2n1P1/1B5P/8/6K1 w - - 3 43
# Processed move: d7h7, current positions collected: 39
# Analyzing position: 8/7R/2r2kp1/8/1p2n1P1/1B5P/8/6K1 b - - 0 43
# Processed move: c6c1, current positions collected: 40
# Analyzing position: 8/7R/5kp1/8/1p2n1P1/1B5P/8/2r3K1 w - - 1 44
# Skipping move g1g2 as it is the same as the best move g1g2.
# Analyzing position: 8/7R/5kp1/8/1p2n1P1/1B5P/6K1/2r5 b - - 2 44
# Processed move: e4c5, current positions collected: 41
# Analyzing position: 8/7R/5kp1/2n5/1p4P1/1B5P/6K1/2r5 w - - 3 45
# Processed move: b3f7, current positions collected: 42
# Analyzing position: 8/5B1R/5kp1/2n5/1p4P1/7P/6K1/2r5 b - - 4 45
# Skipping move b4b3 as it is the same as the best move b4b3.
# Analyzing position: 8/5B1R/5kp1/2n5/6P1/1p5P/6K1/2r5 w - - 0 46
# Skipping move g4g5 as it is the same as the best move g4g5.
# Analyzing position: 8/5B1R/5kp1/2n3P1/8/1p5P/6K1/2r5 b - - 0 46
# Skipping move f6g5 as it is the same as the best move f6g5.
# Analyzing position: 8/5B1R/6p1/2n3k1/8/1p5P/6K1/2r5 w - - 0 47
# Skipping move h3h4 as it is the same as the best move h3h4.
# Analyzing position: 8/5B1R/6p1/2n3k1/7P/1p6/6K1/2r5 b - - 0 47
# Skipping move g5f6 as it is the same as the best move g5f6.
# Analyzing position: 8/5B1R/5kp1/2n5/7P/1p6/6K1/2r5 w - - 1 48
# Skipping move h4h5 as it is the same as the best move h4h5.
# Analyzing position: 8/5B1R/5kp1/2n4P/8/1p6/6K1/2r5 b - - 0 48
# Skipping move c1c2 as it is the same as the best move c1c2.
# Analyzing position: 8/5B1R/5kp1/2n4P/8/1p6/2r3K1/8 w - - 1 49
# Skipping move g2f3 as it is the same as the best move g2f3.
# Analyzing position: 8/5B1R/5kp1/2n4P/8/1p3K2/2r5/8 b - - 2 49
# Processed move: b3b2, current positions collected: 43
# Analyzing position: 8/5B1R/5kp1/2n4P/8/5K2/1pr5/8 w - - 0 50
# Skipping move f7a2 as it is the same as the best move f7a2.
# Analyzing position: 8/7R/5kp1/2n4P/8/5K2/Bpr5/8 b - - 1 50
# Processed move: g6h5, current positions collected: 44
# Analyzing position: 8/7R/5k2/2n4p/8/5K2/Bpr5/8 w - - 0 51
# Skipping move h7h5 as it is the same as the best move h7h5.
# Analyzing position: 8/8/5k2/2n4R/8/5K2/Bpr5/8 b - - 0 51
# Skipping move c2c1 as it is the same as the best move c2c1.
# Analyzing position: 8/8/5k2/2n4R/8/5K2/Bp6/2r5 w - - 1 52
# Processed move: h5h6, current positions collected: 45
# Analyzing position: 8/8/5k1R/2n5/8/5K2/Bp6/2r5 b - - 2 52
# Processed move: f6e5, current positions collected: 46
# Analyzing position: 8/8/7R/2n1k3/8/5K2/Bp6/2r5 w - - 3 53
# Skipping move h6b6 as it is the same as the best move h6b6.
# Analyzing position: 8/8/1R6/2n1k3/8/5K2/Bp6/2r5 b - - 4 53
# Skipping move c5a4 as it is the same as the best move c5a4.
# Analyzing position: 8/8/1R6/4k3/n7/5K2/Bp6/2r5 w - - 5 54
# Skipping move b6e6 as it is the same as the best move b6e6.
# Analyzing position: 8/8/4R3/4k3/n7/5K2/Bp6/2r5 b - - 6 54
# Processed move: e5d4, current positions collected: 47
# Analyzing position: 8/8/4R3/8/n2k4/5K2/Bp6/2r5 w - - 7 55
# Skipping move e6e4 as it is the same as the best move e6e4.
# Analyzing position: 8/8/8/8/n2kR3/5K2/Bp6/2r5 b - - 8 55
# Skipping move d4c5 as it is the same as the best move d4c5.
# Analyzing position: 8/8/8/2k5/n3R3/5K2/Bp6/2r5 w - - 9 56
# Skipping move e4a4 as it is the same as the best move e4a4.
# Analyzing position: 8/8/8/2k5/R7/5K2/Bp6/2r5 b - - 0 56
# Skipping move c1a1 as it is the same as the best move c1a1.
# Finished analyzing game FIDE World Championship Match 1969 without Maia.
# Analyzing game FIDE World Championship Match 1969 without Maia...
# Analyzing position: rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1
# Processed move: c2c4, current positions collected: 1
# Analyzing position: rnbqkbnr/pppppppp/8/8/2P5/8/PP1PPPPP/RNBQKBNR b KQkq - 0 1
# Processed move: e7e6, current positions collected: 2
# Analyzing position: rnbqkbnr/pppp1ppp/4p3/8/2P5/8/PP1PPPPP/RNBQKBNR w KQkq - 0 2
# Skipping move d2d4 as it is the same as the best move d2d4.
# Analyzing position: rnbqkbnr/pppp1ppp/4p3/8/2PP4/8/PP2PPPP/RNBQKBNR b KQkq - 0 2
# Skipping move d7d5 as it is the same as the best move d7d5.
# Analyzing position: rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/8/PP2PPPP/RNBQKBNR w KQkq - 0 3
# Skipping move b1c3 as it is the same as the best move b1c3.
# Analyzing position: rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/2N5/PP2PPPP/R1BQKBNR b KQkq - 1 3
# Processed move: c7c5, current positions collected: 3
# Analyzing position: rnbqkbnr/pp3ppp/4p3/2pp4/2PP4/2N5/PP2PPPP/R1BQKBNR w KQkq - 0 4
# Skipping move c4d5 as it is the same as the best move c4d5.
# Analyzing position: rnbqkbnr/pp3ppp/4p3/2pP4/3P4/2N5/PP2PPPP/R1BQKBNR b KQkq - 0 4
# Skipping move e6d5 as it is the same as the best move e6d5.
# Analyzing position: rnbqkbnr/pp3ppp/8/2pp4/3P4/2N5/PP2PPPP/R1BQKBNR w KQkq - 0 5
# Skipping move g1f3 as it is the same as the best move g1f3.
# Analyzing position: rnbqkbnr/pp3ppp/8/2pp4/3P4/2N2N2/PP2PPPP/R1BQKB1R b KQkq - 1 5
# Processed move: b8c6, current positions collected: 4
# Analyzing position: r1bqkbnr/pp3ppp/2n5/2pp4/3P4/2N2N2/PP2PPPP/R1BQKB1R w KQkq - 2 6
# Processed move: g2g3, current positions collected: 5
# Analyzing position: r1bqkbnr/pp3ppp/2n5/2pp4/3P4/2N2NP1/PP2PP1P/R1BQKB1R b KQkq - 0 6
# Processed move: g8f6, current positions collected: 6
# Analyzing position: r1bqkb1r/pp3ppp/2n2n2/2pp4/3P4/2N2NP1/PP2PP1P/R1BQKB1R w KQkq - 1 7
# Skipping move f1g2 as it is the same as the best move f1g2.
# Analyzing position: r1bqkb1r/pp3ppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQK2R b KQkq - 2 7
# Processed move: f8e7, current positions collected: 7
# Analyzing position: r1bqk2r/pp2bppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQK2R w KQkq - 3 8
# Processed move: e1g1, current positions collected: 8
# Analyzing position: r1bqk2r/pp2bppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQ1RK1 b kq - 4 8
# Processed move: e8g8, current positions collected: 9
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQ1RK1 w - - 5 9
# Skipping move c1g5 as it is the same as the best move c1g5.
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/2pp2B1/3P4/2N2NP1/PP2PPBP/R2Q1RK1 b - - 6 9
# Processed move: c5d4, current positions collected: 10
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/3p2B1/3p4/2N2NP1/PP2PPBP/R2Q1RK1 w - - 0 10
# Skipping move f3d4 as it is the same as the best move f3d4.
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/3p2B1/3N4/2N3P1/PP2PPBP/R2Q1RK1 b - - 0 10
# Processed move: h7h6, current positions collected: 11
# Analyzing position: r1bq1rk1/pp2bpp1/2n2n1p/3p2B1/3N4/2N3P1/PP2PPBP/R2Q1RK1 w - - 0 11
# Skipping move g5e3 as it is the same as the best move g5e3.
# Analyzing position: r1bq1rk1/pp2bpp1/2n2n1p/3p4/3N4/2N1B1P1/PP2PPBP/R2Q1RK1 b - - 1 11
# Skipping move c8g4 as it is the same as the best move c8g4.
# Analyzing position: r2q1rk1/pp2bpp1/2n2n1p/3p4/3N2b1/2N1B1P1/PP2PPBP/R2Q1RK1 w - - 2 12
# Processed move: d4b3, current positions collected: 12
# Analyzing position: r2q1rk1/pp2bpp1/2n2n1p/3p4/6b1/1NN1B1P1/PP2PPBP/R2Q1RK1 b - - 3 12
# Processed move: g4e6, current positions collected: 13
# Analyzing position: r2q1rk1/pp2bpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/R2Q1RK1 w - - 4 13
# Processed move: a1c1, current positions collected: 14
# Analyzing position: r2q1rk1/pp2bpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/2RQ1RK1 b - - 5 13
# Processed move: f8e8, current positions collected: 15
# Analyzing position: r2qr1k1/pp2bpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/2RQ1RK1 w - - 6 14
# Processed move: c3b5, current positions collected: 16
# Analyzing position: r2qr1k1/pp2bpp1/2n1bn1p/1N1p4/8/1N2B1P1/PP2PPBP/2RQ1RK1 b - - 7 14
# Skipping move d8d7 as it is the same as the best move d8d7.
# Analyzing position: r3r1k1/pp1qbpp1/2n1bn1p/1N1p4/8/1N2B1P1/PP2PPBP/2RQ1RK1 w - - 8 15
# Processed move: b5d4, current positions collected: 17
# Analyzing position: r3r1k1/pp1qbpp1/2n1bn1p/3p4/3N4/1N2B1P1/PP2PPBP/2RQ1RK1 b - - 9 15
# Skipping move e6h3 as it is the same as the best move e6h3.
# Analyzing position: r3r1k1/pp1qbpp1/2n2n1p/3p4/3N4/1N2B1Pb/PP2PPBP/2RQ1RK1 w - - 10 16
# Skipping move d4c6 as it is the same as the best move d4c6.
# Analyzing position: r3r1k1/pp1qbpp1/2N2n1p/3p4/8/1N2B1Pb/PP2PPBP/2RQ1RK1 b - - 0 16
# Skipping move b7c6 as it is the same as the best move b7c6.
# Analyzing position: r3r1k1/p2qbpp1/2p2n1p/3p4/8/1N2B1Pb/PP2PPBP/2RQ1RK1 w - - 0 17
# Skipping move d1d3 as it is the same as the best move d1d3.
# Analyzing position: r3r1k1/p2qbpp1/2p2n1p/3p4/8/1N1QB1Pb/PP2PPBP/2R2RK1 b - - 1 17
# Processed move: h3g2, current positions collected: 18
# Analyzing position: r3r1k1/p2qbpp1/2p2n1p/3p4/8/1N1QB1P1/PP2PPbP/2R2RK1 w - - 0 18
# Skipping move g1g2 as it is the same as the best move g1g2.
# Analyzing position: r3r1k1/p2qbpp1/2p2n1p/3p4/8/1N1QB1P1/PP2PPKP/2R2R2 b - - 0 18
# Skipping move a7a5 as it is the same as the best move a7a5.
# Analyzing position: r3r1k1/3qbpp1/2p2n1p/p2p4/8/1N1QB1P1/PP2PPKP/2R2R2 w - - 0 19
# Processed move: c1c2, current positions collected: 19
# Analyzing position: r3r1k1/3qbpp1/2p2n1p/p2p4/8/1N1QB1P1/PPR1PPKP/5R2 b - - 1 19
# Skipping move a5a4 as it is the same as the best move a5a4.
# Analyzing position: r3r1k1/3qbpp1/2p2n1p/3p4/p7/1N1QB1P1/PPR1PPKP/5R2 w - - 0 20
# Processed move: b3d2, current positions collected: 20
# Analyzing position: r3r1k1/3qbpp1/2p2n1p/3p4/p7/3QB1P1/PPRNPPKP/5R2 b - - 1 20
# Processed move: d7b7, current positions collected: 21
# Analyzing position: r3r1k1/1q2bpp1/2p2n1p/3p4/p7/3QB1P1/PPRNPPKP/5R2 w - - 2 21
# Processed move: g2g1, current positions collected: 22
# Analyzing position: r3r1k1/1q2bpp1/2p2n1p/3p4/p7/3QB1P1/PPRNPP1P/5RK1 b - - 3 21
# Processed move: a8c8, current positions collected: 23
# Analyzing position: 2r1r1k1/1q2bpp1/2p2n1p/3p4/p7/3QB1P1/PPRNPP1P/5RK1 w - - 4 22
# Processed move: f1c1, current positions collected: 24
# Analyzing position: 2r1r1k1/1q2bpp1/2p2n1p/3p4/p7/3QB1P1/PPRNPP1P/2R3K1 b - - 5 22
# Skipping move f6d7 as it is the same as the best move f6d7.
# Analyzing position: 2r1r1k1/1q1nbpp1/2p4p/3p4/p7/3QB1P1/PPRNPP1P/2R3K1 w - - 6 23
# Processed move: d2f3, current positions collected: 25
# Analyzing position: 2r1r1k1/1q1nbpp1/2p4p/3p4/p7/3QBNP1/PPR1PP1P/2R3K1 b - - 7 23
# Skipping move c6c5 as it is the same as the best move c6c5.
# Analyzing position: 2r1r1k1/1q1nbpp1/7p/2pp4/p7/3QBNP1/PPR1PP1P/2R3K1 w - - 0 24
# Processed move: b2b3, current positions collected: 26
# Analyzing position: 2r1r1k1/1q1nbpp1/7p/2pp4/p7/1P1QBNP1/P1R1PP1P/2R3K1 b - - 0 24
# Processed move: a4b3, current positions collected: 27
# Analyzing position: 2r1r1k1/1q1nbpp1/7p/2pp4/8/1p1QBNP1/P1R1PP1P/2R3K1 w - - 0 25
# Skipping move a2b3 as it is the same as the best move a2b3.
# Analyzing position: 2r1r1k1/1q1nbpp1/7p/2pp4/8/1P1QBNP1/2R1PP1P/2R3K1 b - - 0 25
# Skipping move e7f8 as it is the same as the best move e7f8.
# Analyzing position: 2r1rbk1/1q1n1pp1/7p/2pp4/8/1P1QBNP1/2R1PP1P/2R3K1 w - - 1 26
# Skipping move c1a1 as it is the same as the best move c1a1.
# Analyzing position: 2r1rbk1/1q1n1pp1/7p/2pp4/8/1P1QBNP1/2R1PP1P/R5K1 b - - 2 26
# Processed move: d7f6, current positions collected: 28
# Analyzing position: 2r1rbk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/2R1PP1P/R5K1 w - - 3 27
# Processed move: c2a2, current positions collected: 29
# Analyzing position: 2r1rbk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/R3PP1P/R5K1 b - - 4 27
# Processed move: c8a8, current positions collected: 30
# Analyzing position: r3rbk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/R3PP1P/R5K1 w - - 5 28
# Skipping move a2a8 as it is the same as the best move a2a8.
# Analyzing position: R3rbk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/4PP1P/R5K1 b - - 0 28
# Skipping move e8a8 as it is the same as the best move e8a8.
# Analyzing position: r4bk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/4PP1P/R5K1 w - - 0 29
# Skipping move a1a8 as it is the same as the best move a1a8.
# Analyzing position: R4bk1/1q3pp1/5n1p/2pp4/8/1P1QBNP1/4PP1P/6K1 b - - 0 29
# Skipping move b7a8 as it is the same as the best move b7a8.
# Analyzing position: q4bk1/5pp1/5n1p/2pp4/8/1P1QBNP1/4PP1P/6K1 w - - 0 30
# Processed move: d3c2, current positions collected: 31
# Analyzing position: q4bk1/5pp1/5n1p/2pp4/8/1P2BNP1/2Q1PP1P/6K1 b - - 1 30
# Processed move: f6e4, current positions collected: 32
# Analyzing position: q4bk1/5pp1/7p/2pp4/4n3/1P2BNP1/2Q1PP1P/6K1 w - - 2 31
# Skipping move f3d2 as it is the same as the best move f3d2.
# Analyzing position: q4bk1/5pp1/7p/2pp4/4n3/1P2B1P1/2QNPP1P/6K1 b - - 3 31
# Processed move: e4d2, current positions collected: 33
# Analyzing position: q4bk1/5pp1/7p/2pp4/8/1P2B1P1/2QnPP1P/6K1 w - - 0 32
# Skipping move e3d2 as it is the same as the best move e3d2.
# Analyzing position: q4bk1/5pp1/7p/2pp4/8/1P4P1/2QBPP1P/6K1 b - - 0 32
# Processed move: a8a6, current positions collected: 34
# Analyzing position: 5bk1/5pp1/q6p/2pp4/8/1P4P1/2QBPP1P/6K1 w - - 1 33
# Processed move: g1f1, current positions collected: 35
# Analyzing position: 5bk1/5pp1/q6p/2pp4/8/1P4P1/2QBPP1P/5K2 b - - 2 33
# Processed move: a6b5, current positions collected: 36
# Analyzing position: 5bk1/5pp1/7p/1qpp4/8/1P4P1/2QBPP1P/5K2 w - - 3 34
# Processed move: d2c3, current positions collected: 37
# Analyzing position: 5bk1/5pp1/7p/1qpp4/8/1PB3P1/2Q1PP1P/5K2 b - - 4 34
# Processed move: g7g6, current positions collected: 38
# Analyzing position: 5bk1/5p2/6pp/1qpp4/8/1PB3P1/2Q1PP1P/5K2 w - - 0 35
# Processed move: c2d1, current positions collected: 39
# Analyzing position: 5bk1/5p2/6pp/1qpp4/8/1PB3P1/4PP1P/3Q1K2 b - - 1 35
# Processed move: b5c6, current positions collected: 40
# Analyzing position: 5bk1/5p2/2q3pp/2pp4/8/1PB3P1/4PP1P/3Q1K2 w - - 2 36
# Processed move: f2f3, current positions collected: 41
# Analyzing position: 5bk1/5p2/2q3pp/2pp4/8/1PB2PP1/4P2P/3Q1K2 b - - 0 36
# Processed move: c6e6, current positions collected: 42
# Analyzing position: 5bk1/5p2/4q1pp/2pp4/8/1PB2PP1/4P2P/3Q1K2 w - - 1 37
# Skipping move f1g2 as it is the same as the best move f1g2.
# Analyzing position: 5bk1/5p2/4q1pp/2pp4/8/1PB2PP1/4P1KP/3Q4 b - - 2 37
# Processed move: h6h5, current positions collected: 43
# Analyzing position: 5bk1/5p2/4q1p1/2pp3p/8/1PB2PP1/4P1KP/3Q4 w - - 0 38
# Processed move: h2h3, current positions collected: 44
# Analyzing position: 5bk1/5p2/4q1p1/2pp3p/8/1PB2PPP/4P1K1/3Q4 b - - 0 38
# Processed move: f8d6, current positions collected: 45
# Analyzing position: 6k1/5p2/3bq1p1/2pp3p/8/1PB2PPP/4P1K1/3Q4 w - - 1 39
# Skipping move d1d3 as it is the same as the best move d1d3.
# Analyzing position: 6k1/5p2/3bq1p1/2pp3p/8/1PBQ1PPP/4P1K1/8 b - - 2 39
# Processed move: d6e5, current positions collected: 46
# Analyzing position: 6k1/5p2/4q1p1/2ppb2p/8/1PBQ1PPP/4P1K1/8 w - - 3 40
# Skipping move c3e5 as it is the same as the best move c3e5.
# Analyzing position: 6k1/5p2/4q1p1/2ppB2p/8/1P1Q1PPP/4P1K1/8 b - - 0 40
# Skipping move e6e5 as it is the same as the best move e6e5.
# Analyzing position: 6k1/5p2/6p1/2ppq2p/8/1P1Q1PPP/4P1K1/8 w - - 0 41
# Skipping move h3h4 as it is the same as the best move h3h4.
# Analyzing position: 6k1/5p2/6p1/2ppq2p/7P/1P1Q1PP1/4P1K1/8 b - - 0 41
# Processed move: g8f8, current positions collected: 47
# Analyzing position: 5k2/5p2/6p1/2ppq2p/7P/1P1Q1PP1/4P1K1/8 w - - 1 42
# Processed move: g2f1, current positions collected: 48
# Analyzing position: 5k2/5p2/6p1/2ppq2p/7P/1P1Q1PP1/4P3/5K2 b - - 2 42
# Processed move: f8e7, current positions collected: 49
# Analyzing position: 8/4kp2/6p1/2ppq2p/7P/1P1Q1PP1/4P3/5K2 w - - 3 43
# Skipping move f1f2 as it is the same as the best move f1f2.
# Analyzing position: 8/4kp2/6p1/2ppq2p/7P/1P1Q1PP1/4PK2/8 b - - 4 43
# Processed move: e5e6, current positions collected: 50
# Analyzing position: 8/4kp2/4q1p1/2pp3p/7P/1P1Q1PP1/4PK2/8 w - - 5 44
# Processed move: d3b5, current positions collected: 51
# Analyzing position: 8/4kp2/4q1p1/1Qpp3p/7P/1P3PP1/4PK2/8 b - - 6 44
# Skipping move e6d6 as it is the same as the best move e6d6.
# Analyzing position: 8/4kp2/3q2p1/1Qpp3p/7P/1P3PP1/4PK2/8 w - - 7 45
# Processed move: b5b7, current positions collected: 52
# Analyzing position: 8/1Q2kp2/3q2p1/2pp3p/7P/1P3PP1/4PK2/8 b - - 8 45
# Processed move: e7f6, current positions collected: 53
# Analyzing position: 8/1Q3p2/3q1kp1/2pp3p/7P/1P3PP1/4PK2/8 w - - 9 46
# Processed move: b7b5, current positions collected: 54
# Analyzing position: 8/5p2/3q1kp1/1Qpp3p/7P/1P3PP1/4PK2/8 b - - 10 46
# Processed move: d6c7, current positions collected: 55
# Analyzing position: 8/2q2p2/5kp1/1Qpp3p/7P/1P3PP1/4PK2/8 w - - 11 47
# Processed move: b5d3, current positions collected: 56
# Analyzing position: 8/2q2p2/5kp1/2pp3p/7P/1P1Q1PP1/4PK2/8 b - - 12 47
# Skipping move c5c4 as it is the same as the best move c5c4.
# Analyzing position: 8/2q2p2/5kp1/3p3p/2p4P/1P1Q1PP1/4PK2/8 w - - 0 48
# Skipping move b3c4 as it is the same as the best move b3c4.
# Analyzing position: 8/2q2p2/5kp1/3p3p/2P4P/3Q1PP1/4PK2/8 b - - 0 48
# Skipping move d5c4 as it is the same as the best move d5c4.
# Analyzing position: 8/2q2p2/5kp1/7p/2p4P/3Q1PP1/4PK2/8 w - - 0 49
# Skipping move d3c3 as it is the same as the best move d3c3.
# Analyzing position: 8/2q2p2/5kp1/7p/2p4P/2Q2PP1/4PK2/8 b - - 1 49
# Skipping move f6e6 as it is the same as the best move f6e6.
# Analyzing position: 8/2q2p2/4k1p1/7p/2p4P/2Q2PP1/4PK2/8 w - - 2 50
# Processed move: f2e3, current positions collected: 57
# Analyzing position: 8/2q2p2/4k1p1/7p/2p4P/2Q1KPP1/4P3/8 b - - 3 50
# Skipping move c7c5 as it is the same as the best move c7c5.
# Analyzing position: 8/5p2/4k1p1/2q4p/2p4P/2Q1KPP1/4P3/8 w - - 4 51
# Processed move: c3d4, current positions collected: 58
# Analyzing position: 8/5p2/4k1p1/2q4p/2pQ3P/4KPP1/4P3/8 b - - 5 51
# Processed move: c5a3, current positions collected: 59
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/q3KPP1/4P3/8 w - - 6 52
# Skipping move e3d2 as it is the same as the best move e3d2.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/q4PP1/3KP3/8 b - - 7 52
# Processed move: a3a5, current positions collected: 60
# Analyzing position: 8/5p2/4k1p1/q6p/2pQ3P/5PP1/3KP3/8 w - - 8 53
# Processed move: d2c2, current positions collected: 61
# Analyzing position: 8/5p2/4k1p1/q6p/2pQ3P/5PP1/2K1P3/8 b - - 9 53
# Processed move: a5b5, current positions collected: 62
# Analyzing position: 8/5p2/4k1p1/1q5p/2pQ3P/5PP1/2K1P3/8 w - - 10 54
# Processed move: c2c3, current positions collected: 63
# Analyzing position: 8/5p2/4k1p1/1q5p/2pQ3P/2K2PP1/4P3/8 b - - 11 54
# Skipping move b5b3 as it is the same as the best move b5b3.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1qK2PP1/4P3/8 w - - 12 55
# Skipping move c3d2 as it is the same as the best move c3d2.
# Analyzing position: 8/5p2/4k1p1/7p/2pQ3P/1q3PP1/3KP3/8 b - - 13 55
# Skipping move b3b4 as it is the same as the best move b3b4.
# Analyzing position: 8/5p2/4k1p1/7p/1qpQ3P/5PP1/3KP3/8 w - - 14 56
# Processed move: d2c2, current positions collected: 64
# Analyzing position: 8/5p2/4k1p1/7p/1qpQ3P/5PP1/2K1P3/8 b - - 15 56
# Processed move: b4a4, current positions collected: 65
# Analyzing position: 8/5p2/4k1p1/7p/q1pQ3P/5PP1/2K1P3/8 w - - 16 57
# Processed move: c2c3, current positions collected: 66
# Analyzing position: 8/5p2/4k1p1/7p/q1pQ3P/2K2PP1/4P3/8 b - - 17 57
# Processed move: a4a5, current positions collected: 67
# Analyzing position: 8/5p2/4k1p1/q6p/2pQ3P/2K2PP1/4P3/8 w - - 18 58
# Processed move: c3c4, current positions collected: 68
# Analyzing position: 8/5p2/4k1p1/q6p/2KQ3P/5PP1/4P3/8 b - - 0 58
# Processed move: a5c7, current positions collected: 69
# Analyzing position: 8/2q2p2/4k1p1/7p/2KQ3P/5PP1/4P3/8 w - - 1 59
# Skipping move c4d3 as it is the same as the best move c4d3.
# Analyzing position: 8/2q2p2/4k1p1/7p/3Q3P/3K1PP1/4P3/8 b - - 2 59
# Skipping move c7g3 as it is the same as the best move c7g3.
# Analyzing position: 8/5p2/4k1p1/7p/3Q3P/3K1Pq1/4P3/8 w - - 0 60
# Processed move: d4c4, current positions collected: 70
# Analyzing position: 8/5p2/4k1p1/7p/2Q4P/3K1Pq1/4P3/8 b - - 1 60
# Skipping move e6f6 as it is the same as the best move e6f6.
# Analyzing position: 8/5p2/5kp1/7p/2Q4P/3K1Pq1/4P3/8 w - - 2 61
# Skipping move c4d4 as it is the same as the best move c4d4.
# Analyzing position: 8/5p2/5kp1/7p/3Q3P/3K1Pq1/4P3/8 b - - 3 61
# Processed move: f6e7, current positions collected: 71
# Finished analyzing game FIDE World Championship Match 1969 without Maia.
# Analyzing game FIDE World Championship Match 1969 without Maia...
# Analyzing position: rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1
# Skipping move e2e4 as it is the same as the best move e2e4.
# Analyzing position: rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1
# Skipping move c7c5 as it is the same as the best move c7c5.
# Analyzing position: rnbqkbnr/pp1ppppp/8/2p5/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Skipping move g1f3 as it is the same as the best move g1f3.
# Analyzing position: rnbqkbnr/pp1ppppp/8/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 2
# Skipping move b8c6 as it is the same as the best move b8c6.
# Analyzing position: r1bqkbnr/pp1ppppp/2n5/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R w KQkq - 2 3
# Processed move: d2d4, current positions collected: 1
# Analyzing position: r1bqkbnr/pp1ppppp/2n5/2p5/3PP3/5N2/PPP2PPP/RNBQKB1R b KQkq - 0 3
# Skipping move c5d4 as it is the same as the best move c5d4.
# Analyzing position: r1bqkbnr/pp1ppppp/2n5/8/3pP3/5N2/PPP2PPP/RNBQKB1R w KQkq - 0 4
# Skipping move f3d4 as it is the same as the best move f3d4.
# Analyzing position: r1bqkbnr/pp1ppppp/2n5/8/3NP3/8/PPP2PPP/RNBQKB1R b KQkq - 0 4
# Processed move: g7g6, current positions collected: 2
# Analyzing position: r1bqkbnr/pp1ppp1p/2n3p1/8/3NP3/8/PPP2PPP/RNBQKB1R w KQkq - 0 5
# Skipping move c2c4 as it is the same as the best move c2c4.
# Analyzing position: r1bqkbnr/pp1ppp1p/2n3p1/8/2PNP3/8/PP3PPP/RNBQKB1R b KQkq - 0 5
# Processed move: g8f6, current positions collected: 3
# Analyzing position: r1bqkb1r/pp1ppp1p/2n2np1/8/2PNP3/8/PP3PPP/RNBQKB1R w KQkq - 1 6
# Skipping move b1c3 as it is the same as the best move b1c3.
# Analyzing position: r1bqkb1r/pp1ppp1p/2n2np1/8/2PNP3/2N5/PP3PPP/R1BQKB1R b KQkq - 2 6
# Processed move: c6d4, current positions collected: 4
# Analyzing position: r1bqkb1r/pp1ppp1p/5np1/8/2PnP3/2N5/PP3PPP/R1BQKB1R w KQkq - 0 7
# Processed move: d1d4, current positions collected: 5
# Analyzing position: r1bqkb1r/pp1ppp1p/5np1/8/2PQP3/2N5/PP3PPP/R1B1KB1R b KQkq - 0 7
# Skipping move d7d6 as it is the same as the best move d7d6.
# Analyzing position: r1bqkb1r/pp2pp1p/3p1np1/8/2PQP3/2N5/PP3PPP/R1B1KB1R w KQkq - 0 8
# Processed move: c1e3, current positions collected: 6
# Analyzing position: r1bqkb1r/pp2pp1p/3p1np1/8/2PQP3/2N1B3/PP3PPP/R3KB1R b KQkq - 1 8
# Skipping move f8g7 as it is the same as the best move f8g7.
# Analyzing position: r1bqk2r/pp2ppbp/3p1np1/8/2PQP3/2N1B3/PP3PPP/R3KB1R w KQkq - 2 9
# Skipping move f2f3 as it is the same as the best move f2f3.
# Analyzing position: r1bqk2r/pp2ppbp/3p1np1/8/2PQP3/2N1BP2/PP4PP/R3KB1R b KQkq - 0 9
# Processed move: e8g8, current positions collected: 7
# Analyzing position: r1bq1rk1/pp2ppbp/3p1np1/8/2PQP3/2N1BP2/PP4PP/R3KB1R w KQ - 1 10
# Skipping move d4d2 as it is the same as the best move d4d2.
# Analyzing position: r1bq1rk1/pp2ppbp/3p1np1/8/2P1P3/2N1BP2/PP1Q2PP/R3KB1R b KQ - 2 10
# Processed move: c8e6, current positions collected: 8
# Analyzing position: r2q1rk1/pp2ppbp/3pbnp1/8/2P1P3/2N1BP2/PP1Q2PP/R3KB1R w KQ - 3 11
# Skipping move a1c1 as it is the same as the best move a1c1.
# Analyzing position: r2q1rk1/pp2ppbp/3pbnp1/8/2P1P3/2N1BP2/PP1Q2PP/2R1KB1R b K - 4 11
# Skipping move d8a5 as it is the same as the best move d8a5.
# Analyzing position: r4rk1/pp2ppbp/3pbnp1/q7/2P1P3/2N1BP2/PP1Q2PP/2R1KB1R w K - 5 12
# Processed move: f1e2, current positions collected: 9
# Analyzing position: r4rk1/pp2ppbp/3pbnp1/q7/2P1P3/2N1BP2/PP1QB1PP/2R1K2R b K - 6 12
# Skipping move f8c8 as it is the same as the best move f8c8.
# Analyzing position: r1r3k1/pp2ppbp/3pbnp1/q7/2P1P3/2N1BP2/PP1QB1PP/2R1K2R w K - 7 13
# Skipping move b2b3 as it is the same as the best move b2b3.
# Analyzing position: r1r3k1/pp2ppbp/3pbnp1/q7/2P1P3/1PN1BP2/P2QB1PP/2R1K2R b K - 0 13
# Skipping move a7a6 as it is the same as the best move a7a6.
# Analyzing position: r1r3k1/1p2ppbp/p2pbnp1/q7/2P1P3/1PN1BP2/P2QB1PP/2R1K2R w K - 0 14
# Processed move: c3d5, current positions collected: 10
# Analyzing position: r1r3k1/1p2ppbp/p2pbnp1/q2N4/2P1P3/1P2BP2/P2QB1PP/2R1K2R b K - 1 14
# Skipping move a5d2 as it is the same as the best move a5d2.
# Analyzing position: r1r3k1/1p2ppbp/p2pbnp1/3N4/2P1P3/1P2BP2/P2qB1PP/2R1K2R w K - 0 15
# Skipping move e1d2 as it is the same as the best move e1d2.
# Analyzing position: r1r3k1/1p2ppbp/p2pbnp1/3N4/2P1P3/1P2BP2/P2KB1PP/2R4R b - - 0 15
# Skipping move f6d5 as it is the same as the best move f6d5.
# Analyzing position: r1r3k1/1p2ppbp/p2pb1p1/3n4/2P1P3/1P2BP2/P2KB1PP/2R4R w - - 0 16
# Skipping move c4d5 as it is the same as the best move c4d5.
# Analyzing position: r1r3k1/1p2ppbp/p2pb1p1/3P4/4P3/1P2BP2/P2KB1PP/2R4R b - - 0 16
# Skipping move e6d7 as it is the same as the best move e6d7.
# Analyzing position: r1r3k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P2KB1PP/2R4R w - - 1 17
# Processed move: c1c8, current positions collected: 11
# Analyzing position: r1R3k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P2KB1PP/7R b - - 0 17
# Skipping move a8c8 as it is the same as the best move a8c8.
# Analyzing position: 2r3k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P2KB1PP/7R w - - 0 18
# Processed move: h1c1, current positions collected: 12
# Analyzing position: 2r3k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P2KB1PP/2R5 b - - 1 18
# Skipping move c8c1 as it is the same as the best move c8c1.
# Analyzing position: 6k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P2KB1PP/2r5 w - - 0 19
# Skipping move d2c1 as it is the same as the best move d2c1.
# Analyzing position: 6k1/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P3B1PP/2K5 b - - 0 19
# Processed move: g8f8, current positions collected: 13
# Analyzing position: 5k2/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P3B1PP/2K5 w - - 1 20
# Processed move: c1c2, current positions collected: 14
# Analyzing position: 5k2/1p1bppbp/p2p2p1/3P4/4P3/1P2BP2/P1K1B1PP/8 b - - 2 20
# Skipping move e7e6 as it is the same as the best move e7e6.
# Analyzing position: 5k2/1p1b1pbp/p2pp1p1/3P4/4P3/1P2BP2/P1K1B1PP/8 w - - 0 21
# Processed move: a2a4, current positions collected: 15
# Analyzing position: 5k2/1p1b1pbp/p2pp1p1/3P4/P3P3/1P2BP2/2K1B1PP/8 b - - 0 21
# Skipping move e6d5 as it is the same as the best move e6d5.
# Analyzing position: 5k2/1p1b1pbp/p2p2p1/3p4/P3P3/1P2BP2/2K1B1PP/8 w - - 0 22
# Skipping move e4d5 as it is the same as the best move e4d5.
# Analyzing position: 5k2/1p1b1pbp/p2p2p1/3P4/P7/1P2BP2/2K1B1PP/8 b - - 0 22
# Processed move: f8e7, current positions collected: 16
# Analyzing position: 8/1p1bkpbp/p2p2p1/3P4/P7/1P2BP2/2K1B1PP/8 w - - 1 23
# Processed move: e2d3, current positions collected: 17
# Analyzing position: 8/1p1bkpbp/p2p2p1/3P4/P7/1P1BBP2/2K3PP/8 b - - 2 23
# Processed move: g7e5, current positions collected: 18
# Analyzing position: 8/1p1bkp1p/p2p2p1/3Pb3/P7/1P1BBP2/2K3PP/8 w - - 3 24
# Processed move: g2g3, current positions collected: 19
# Analyzing position: 8/1p1bkp1p/p2p2p1/3Pb3/P7/1P1BBPP1/2K4P/8 b - - 0 24
# Processed move: e7e8, current positions collected: 20
# Analyzing position: 4k3/1p1b1p1p/p2p2p1/3Pb3/P7/1P1BBPP1/2K4P/8 w - - 1 25
# Processed move: c2d2, current positions collected: 21
# Analyzing position: 4k3/1p1b1p1p/p2p2p1/3Pb3/P7/1P1BBPP1/3K3P/8 b - - 2 25
# Processed move: e8e7, current positions collected: 22
# Analyzing position: 8/1p1bkp1p/p2p2p1/3Pb3/P7/1P1BBPP1/3K3P/8 w - - 3 26
# Processed move: e3b6, current positions collected: 23
# Analyzing position: 8/1p1bkp1p/pB1p2p1/3Pb3/P7/1P1B1PP1/3K3P/8 b - - 4 26
# Processed move: d7e8, current positions collected: 24
# Analyzing position: 4b3/1p2kp1p/pB1p2p1/3Pb3/P7/1P1B1PP1/3K3P/8 w - - 5 27
# Skipping move f3f4 as it is the same as the best move f3f4.
# Analyzing position: 4b3/1p2kp1p/pB1p2p1/3Pb3/P4P2/1P1B2P1/3K3P/8 b - - 0 27
# Processed move: e5g7, current positions collected: 25
# Analyzing position: 4b3/1p2kpbp/pB1p2p1/3P4/P4P2/1P1B2P1/3K3P/8 w - - 1 28
# Skipping move g3g4 as it is the same as the best move g3g4.
# Analyzing position: 4b3/1p2kpbp/pB1p2p1/3P4/P4PP1/1P1B4/3K3P/8 b - - 0 28
# Processed move: e8d7, current positions collected: 26
# Analyzing position: 8/1p1bkpbp/pB1p2p1/3P4/P4PP1/1P1B4/3K3P/8 w - - 1 29
# Processed move: h2h3, current positions collected: 27
# Analyzing position: 8/1p1bkpbp/pB1p2p1/3P4/P4PP1/1P1B3P/3K4/8 b - - 0 29
# Processed move: h7h5, current positions collected: 28
# Analyzing position: 8/1p1bkpb1/pB1p2p1/3P3p/P4PP1/1P1B3P/3K4/8 w - - 0 30
# Skipping move d3e2 as it is the same as the best move d3e2.
# Analyzing position: 8/1p1bkpb1/pB1p2p1/3P3p/P4PP1/1P5P/3KB3/8 b - - 1 30
# Processed move: h5g4, current positions collected: 29
# Analyzing position: 8/1p1bkpb1/pB1p2p1/3P4/P4Pp1/1P5P/3KB3/8 w - - 0 31
# Skipping move h3g4 as it is the same as the best move h3g4.
# Analyzing position: 8/1p1bkpb1/pB1p2p1/3P4/P4PP1/1P6/3KB3/8 b - - 0 31
# Processed move: g7b2, current positions collected: 30
# Analyzing position: 8/1p1bkp2/pB1p2p1/3P4/P4PP1/1P6/1b1KB3/8 w - - 1 32
# Processed move: d2e3, current positions collected: 31
# Analyzing position: 8/1p1bkp2/pB1p2p1/3P4/P4PP1/1P2K3/1b2B3/8 b - - 2 32
# Processed move: b2c1, current positions collected: 32
# Analyzing position: 8/1p1bkp2/pB1p2p1/3P4/P4PP1/1P2K3/4B3/2b5 w - - 3 33
# Skipping move e3f3 as it is the same as the best move e3f3.
# Analyzing position: 8/1p1bkp2/pB1p2p1/3P4/P4PP1/1P3K2/4B3/2b5 b - - 4 33
# Processed move: c1b2, current positions collected: 33
# Analyzing position: 8/1p1bkp2/pB1p2p1/3P4/P4PP1/1P3K2/1b2B3/8 w - - 5 34
# Processed move: e2d3, current positions collected: 34
# Analyzing position: 8/1p1bkp2/pB1p2p1/3P4/P4PP1/1P1B1K2/1b6/8 b - - 6 34
# Processed move: b2c3, current positions collected: 35
# Analyzing position: 8/1p1bkp2/pB1p2p1/3P4/P4PP1/1PbB1K2/8/8 w - - 7 35
# Skipping move f4f5 as it is the same as the best move f4f5.
# Analyzing position: 8/1p1bkp2/pB1p2p1/3P1P2/P5P1/1PbB1K2/8/8 b - - 0 35
# Skipping move g6f5 as it is the same as the best move g6f5.
# Analyzing position: 8/1p1bkp2/pB1p4/3P1p2/P5P1/1PbB1K2/8/8 w - - 0 36
# Skipping move d3f5 as it is the same as the best move d3f5.
# Analyzing position: 8/1p1bkp2/pB1p4/3P1B2/P5P1/1Pb2K2/8/8 b - - 0 36
# Skipping move d7f5 as it is the same as the best move d7f5.
# Analyzing position: 8/1p2kp2/pB1p4/3P1b2/P5P1/1Pb2K2/8/8 w - - 0 37
# Skipping move g4f5 as it is the same as the best move g4f5.
# Analyzing position: 8/1p2kp2/pB1p4/3P1P2/P7/1Pb2K2/8/8 b - - 0 37
# Processed move: e7d7, current positions collected: 36
# Analyzing position: 8/1p1k1p2/pB1p4/3P1P2/P7/1Pb2K2/8/8 w - - 1 38
# Processed move: f3e4, current positions collected: 37
# Analyzing position: 8/1p1k1p2/pB1p4/3P1P2/P3K3/1Pb5/8/8 b - - 2 38
# Processed move: c3e1, current positions collected: 38
# Analyzing position: 8/1p1k1p2/pB1p4/3P1P2/P3K3/1P6/8/4b3 w - - 3 39
# Processed move: e4d3, current positions collected: 39
# Analyzing position: 8/1p1k1p2/pB1p4/3P1P2/P7/1P1K4/8/4b3 b - - 4 39
# Processed move: d7c8, current positions collected: 40
# Analyzing position: 2k5/1p3p2/pB1p4/3P1P2/P7/1P1K4/8/4b3 w - - 5 40
# Skipping move d3c4 as it is the same as the best move d3c4.
# Analyzing position: 2k5/1p3p2/pB1p4/3P1P2/P1K5/1P6/8/4b3 b - - 6 40
# Processed move: e1d2, current positions collected: 41
# Analyzing position: 2k5/1p3p2/pB1p4/3P1P2/P1K5/1P6/3b4/8 w - - 7 41
# Skipping move b3b4 as it is the same as the best move b3b4.
# Analyzing position: 2k5/1p3p2/pB1p4/3P1P2/PPK5/8/3b4/8 b - - 0 41
# Processed move: d2e1, current positions collected: 42
# Analyzing position: 2k5/1p3p2/pB1p4/3P1P2/PPK5/8/8/4b3 w - - 1 42
# Skipping move b4b5 as it is the same as the best move b4b5.
# Analyzing position: 2k5/1p3p2/pB1p4/1P1P1P2/P1K5/8/8/4b3 b - - 0 42
# Skipping move e1d2 as it is the same as the best move e1d2.
# Analyzing position: 2k5/1p3p2/pB1p4/1P1P1P2/P1K5/8/3b4/8 w - - 1 43
# Processed move: b6d4, current positions collected: 43
# Analyzing position: 2k5/1p3p2/p2p4/1P1P1P2/P1KB4/8/3b4/8 b - - 2 43
# Skipping move d2e1 as it is the same as the best move d2e1.
# Finished analyzing game FIDE World Championship Match 1969 without Maia.
# Analyzing game FIDE World Championship Match 1969 without Maia...
# Analyzing position: rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1
# Processed move: c2c4, current positions collected: 1
# Analyzing position: rnbqkbnr/pppppppp/8/8/2P5/8/PP1PPPPP/RNBQKBNR b KQkq - 0 1
# Processed move: e7e6, current positions collected: 2
# Analyzing position: rnbqkbnr/pppp1ppp/4p3/8/2P5/8/PP1PPPPP/RNBQKBNR w KQkq - 0 2
# Skipping move d2d4 as it is the same as the best move d2d4.
# Analyzing position: rnbqkbnr/pppp1ppp/4p3/8/2PP4/8/PP2PPPP/RNBQKBNR b KQkq - 0 2
# Skipping move d7d5 as it is the same as the best move d7d5.
# Analyzing position: rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/8/PP2PPPP/RNBQKBNR w KQkq - 0 3
# Processed move: b1c3, current positions collected: 3
# Analyzing position: rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/2N5/PP2PPPP/R1BQKBNR b KQkq - 1 3
# Processed move: c7c5, current positions collected: 4
# Analyzing position: rnbqkbnr/pp3ppp/4p3/2pp4/2PP4/2N5/PP2PPPP/R1BQKBNR w KQkq - 0 4
# Skipping move c4d5 as it is the same as the best move c4d5.
# Analyzing position: rnbqkbnr/pp3ppp/4p3/2pP4/3P4/2N5/PP2PPPP/R1BQKBNR b KQkq - 0 4
# Skipping move e6d5 as it is the same as the best move e6d5.
# Analyzing position: rnbqkbnr/pp3ppp/8/2pp4/3P4/2N5/PP2PPPP/R1BQKBNR w KQkq - 0 5
# Skipping move g1f3 as it is the same as the best move g1f3.
# Analyzing position: rnbqkbnr/pp3ppp/8/2pp4/3P4/2N2N2/PP2PPPP/R1BQKB1R b KQkq - 1 5
# Skipping move b8c6 as it is the same as the best move b8c6.
# Analyzing position: r1bqkbnr/pp3ppp/2n5/2pp4/3P4/2N2N2/PP2PPPP/R1BQKB1R w KQkq - 2 6
# Processed move: g2g3, current positions collected: 5
# Analyzing position: r1bqkbnr/pp3ppp/2n5/2pp4/3P4/2N2NP1/PP2PP1P/R1BQKB1R b KQkq - 0 6
# Processed move: g8f6, current positions collected: 6
# Analyzing position: r1bqkb1r/pp3ppp/2n2n2/2pp4/3P4/2N2NP1/PP2PP1P/R1BQKB1R w KQkq - 1 7
# Skipping move f1g2 as it is the same as the best move f1g2.
# Analyzing position: r1bqkb1r/pp3ppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQK2R b KQkq - 2 7
# Processed move: f8e7, current positions collected: 7
# Analyzing position: r1bqk2r/pp2bppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQK2R w KQkq - 3 8
# Skipping move e1g1 as it is the same as the best move e1g1.
# Analyzing position: r1bqk2r/pp2bppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQ1RK1 b kq - 4 8
# Skipping move e8g8 as it is the same as the best move e8g8.
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/2pp4/3P4/2N2NP1/PP2PPBP/R1BQ1RK1 w - - 5 9
# Processed move: c1g5, current positions collected: 8
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/2pp2B1/3P4/2N2NP1/PP2PPBP/R2Q1RK1 b - - 6 9
# Processed move: c5d4, current positions collected: 9
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/3p2B1/3p4/2N2NP1/PP2PPBP/R2Q1RK1 w - - 0 10
# Skipping move f3d4 as it is the same as the best move f3d4.
# Analyzing position: r1bq1rk1/pp2bppp/2n2n2/3p2B1/3N4/2N3P1/PP2PPBP/R2Q1RK1 b - - 0 10
# Skipping move h7h6 as it is the same as the best move h7h6.
# Analyzing position: r1bq1rk1/pp2bpp1/2n2n1p/3p2B1/3N4/2N3P1/PP2PPBP/R2Q1RK1 w - - 0 11
# Skipping move g5e3 as it is the same as the best move g5e3.
# Analyzing position: r1bq1rk1/pp2bpp1/2n2n1p/3p4/3N4/2N1B1P1/PP2PPBP/R2Q1RK1 b - - 1 11
# Skipping move c8g4 as it is the same as the best move c8g4.
# Analyzing position: r2q1rk1/pp2bpp1/2n2n1p/3p4/3N2b1/2N1B1P1/PP2PPBP/R2Q1RK1 w - - 2 12
# Processed move: d4b3, current positions collected: 10
# Analyzing position: r2q1rk1/pp2bpp1/2n2n1p/3p4/6b1/1NN1B1P1/PP2PPBP/R2Q1RK1 b - - 3 12
# Processed move: g4e6, current positions collected: 11
# Analyzing position: r2q1rk1/pp2bpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/R2Q1RK1 w - - 4 13
# Processed move: a1c1, current positions collected: 12
# Analyzing position: r2q1rk1/pp2bpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/2RQ1RK1 b - - 5 13
# Processed move: f8e8, current positions collected: 13
# Analyzing position: r2qr1k1/pp2bpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/2RQ1RK1 w - - 6 14
# Processed move: f1e1, current positions collected: 14
# Analyzing position: r2qr1k1/pp2bpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/2RQR1K1 b - - 7 14
# Skipping move d8d7 as it is the same as the best move d8d7.
# Analyzing position: r3r1k1/pp1qbpp1/2n1bn1p/3p4/8/1NN1B1P1/PP2PPBP/2RQR1K1 w - - 8 15
# Processed move: e3c5, current positions collected: 15
# Analyzing position: r3r1k1/pp1qbpp1/2n1bn1p/2Bp4/8/1NN3P1/PP2PPBP/2RQR1K1 b - - 9 15
# Skipping move a8c8 as it is the same as the best move a8c8.
# Analyzing position: 2r1r1k1/pp1qbpp1/2n1bn1p/2Bp4/8/1NN3P1/PP2PPBP/2RQR1K1 w - - 10 16
# Skipping move c5e7 as it is the same as the best move c5e7.
# Analyzing position: 2r1r1k1/pp1qBpp1/2n1bn1p/3p4/8/1NN3P1/PP2PPBP/2RQR1K1 b - - 0 16
# Skipping move d7e7 as it is the same as the best move d7e7.
# Analyzing position: 2r1r1k1/pp2qpp1/2n1bn1p/3p4/8/1NN3P1/PP2PPBP/2RQR1K1 w - - 0 17
# Skipping move e2e3 as it is the same as the best move e2e3.
# Analyzing position: 2r1r1k1/pp2qpp1/2n1bn1p/3p4/8/1NN1P1P1/PP3PBP/2RQR1K1 b - - 0 17
# Processed move: e8d8, current positions collected: 16
# Analyzing position: 2rr2k1/pp2qpp1/2n1bn1p/3p4/8/1NN1P1P1/PP3PBP/2RQR1K1 w - - 1 18
# ...
# Processed move: f8b4, current positions collected: 4
# Analyzing position: rn1qk2r/pp3ppp/2p1pn2/5b2/PbBP4/2N1PN2/1P3PPP/R1BQK2R w KQkq - 1 8
# Skipping move e1g1 as it is the same as the best move e1g1.
# Analyzing position: rn1qk2r/pp3ppp/2p1pn2/5b2/PbBP4/2N1PN2/1P3PPP/R1BQ1RK1 b kq - 2 8
# Skipping move b8d7 as it is the same as the best move b8d7.
# Analyzing position: r2qk2r/pp1n1ppp/2p1pn2/5b2/PbBP4/2N1PN2/1P3PPP/R1BQ1RK1 w kq - 3 9
# Processed move: d1e2, current positions collected: 5
# Analyzing position: r2qk2r/pp1n1ppp/2p1pn2/5b2/PbBP4/2N1PN2/1P2QPPP/R1B2RK1 b kq - 4 9
# Skipping move e8g8 as it is the same as the best move e8g8.
# Analyzing position: r2q1rk1/pp1n1ppp/2p1pn2/5b2/PbBP4/2N1PN2/1P2QPPP/R1B2RK1 w - - 5 10
# Processed move: e3e4, current positions collected: 6
# Analyzing position: r2q1rk1/pp1n1ppp/2p1pn2/5b2/PbBPP3/2N2N2/1P2QPPP/R1B2RK1 b - - 0 10
# Skipping move f5g6 as it is the same as the best move f5g6.
# Analyzing position: r2q1rk1/pp1n1ppp/2p1pnb1/8/PbBPP3/2N2N2/1P2QPPP/R1B2RK1 w - - 1 11
# Skipping move c4d3 as it is the same as the best move c4d3.
# Analyzing position: r2q1rk1/pp1n1ppp/2p1pnb1/8/Pb1PP3/2NB1N2/1P2QPPP/R1B2RK1 b - - 2 11
# Processed move: f8e8, current positions collected: 7
# Analyzing position: r2qr1k1/pp1n1ppp/2p1pnb1/8/Pb1PP3/2NB1N2/1P2QPPP/R1B2RK1 w - - 3 12
# Processed move: e4e5, current positions collected: 8
# Analyzing position: r2qr1k1/pp1n1ppp/2p1pnb1/4P3/Pb1P4/2NB1N2/1P2QPPP/R1B2RK1 b - - 0 12
# Processed move: f6d5, current positions collected: 9
# Analyzing position: r2qr1k1/pp1n1ppp/2p1p1b1/3nP3/Pb1P4/2NB1N2/1P2QPPP/R1B2RK1 w - - 1 13
# Skipping move d3g6 as it is the same as the best move d3g6.
# Analyzing position: r2qr1k1/pp1n1ppp/2p1p1B1/3nP3/Pb1P4/2N2N2/1P2QPPP/R1B2RK1 b - - 0 13
# Processed move: f7g6, current positions collected: 10
# Analyzing position: r2qr1k1/pp1n2pp/2p1p1p1/3nP3/Pb1P4/2N2N2/1P2QPPP/R1B2RK1 w - - 0 14
# Processed move: c1d2, current positions collected: 11
# Analyzing position: r2qr1k1/pp1n2pp/2p1p1p1/3nP3/Pb1P4/2N2N2/1P1BQPPP/R4RK1 b - - 1 14
# Processed move: b4e7, current positions collected: 12
# Analyzing position: r2qr1k1/pp1nb1pp/2p1p1p1/3nP3/P2P4/2N2N2/1P1BQPPP/R4RK1 w - - 2 15
# Processed move: e2e4, current positions collected: 13
# Analyzing position: r2qr1k1/pp1nb1pp/2p1p1p1/3nP3/P2PQ3/2N2N2/1P1B1PPP/R4RK1 b - - 3 15
# Processed move: d7f8, current positions collected: 14
# Analyzing position: r2qrnk1/pp2b1pp/2p1p1p1/3nP3/P2PQ3/2N2N2/1P1B1PPP/R4RK1 w - - 4 16
# Skipping move a4a5 as it is the same as the best move a4a5.
# Analyzing position: r2qrnk1/pp2b1pp/2p1p1p1/P2nP3/3PQ3/2N2N2/1P1B1PPP/R4RK1 b - - 0 16
# Processed move: a8c8, current positions collected: 15
# Analyzing position: 2rqrnk1/pp2b1pp/2p1p1p1/P2nP3/3PQ3/2N2N2/1P1B1PPP/R4RK1 w - - 1 17
# Processed move: f1c1, current positions collected: 16
# Analyzing position: 2rqrnk1/pp2b1pp/2p1p1p1/P2nP3/3PQ3/2N2N2/1P1B1PPP/R1R3K1 b - - 2 17
# Processed move: a7a6, current positions collected: 17
# Analyzing position: 2rqrnk1/1p2b1pp/p1p1p1p1/P2nP3/3PQ3/2N2N2/1P1B1PPP/R1R3K1 w - - 0 18
# Processed move: e4g4, current positions collected: 18
# Analyzing position: 2rqrnk1/1p2b1pp/p1p1p1p1/P2nP3/3P2Q1/2N2N2/1P1B1PPP/R1R3K1 b - - 1 18
# Processed move: h7h6, current positions collected: 19
# Analyzing position: 2rqrnk1/1p2b1p1/p1p1p1pp/P2nP3/3P2Q1/2N2N2/1P1B1PPP/R1R3K1 w - - 0 19
# Skipping move c3e4 as it is the same as the best move c3e4.
# Analyzing position: 2rqrnk1/1p2b1p1/p1p1p1pp/P2nP3/3PN1Q1/5N2/1P1B1PPP/R1R3K1 b - - 1 19
# Skipping move d8d7 as it is the same as the best move d8d7.
# Analyzing position: 2r1rnk1/1p1qb1p1/p1p1p1pp/P2nP3/3PN1Q1/5N2/1P1B1PPP/R1R3K1 w - - 2 20
# Processed move: h2h4, current positions collected: 20
# Analyzing position: 2r1rnk1/1p1qb1p1/p1p1p1pp/P2nP3/3PN1QP/5N2/1P1B1PP1/R1R3K1 b - - 0 20
# Skipping move e8d8 as it is the same as the best move e8d8.
# Analyzing position: 2rr1nk1/1p1qb1p1/p1p1p1pp/P2nP3/3PN1QP/5N2/1P1B1PP1/R1R3K1 w - - 1 21
# Skipping move c1c4 as it is the same as the best move c1c4.
# Analyzing position: 2rr1nk1/1p1qb1p1/p1p1p1pp/P2nP3/2RPN1QP/5N2/1P1B1PP1/R5K1 b - - 2 21
# Processed move: d7e8, current positions collected: 21
# Analyzing position: 2rrqnk1/1p2b1p1/p1p1p1pp/P2nP3/2RPN1QP/5N2/1P1B1PP1/R5K1 w - - 3 22
# Processed move: a1c1, current positions collected: 22
# Analyzing position: 2rrqnk1/1p2b1p1/p1p1p1pp/P2nP3/2RPN1QP/5N2/1P1B1PP1/2R3K1 b - - 4 22
# Processed move: c8c7, current positions collected: 23
# Analyzing position: 3rqnk1/1pr1b1p1/p1p1p1pp/P2nP3/2RPN1QP/5N2/1P1B1PP1/2R3K1 w - - 5 23
# Processed move: e4g3, current positions collected: 24
# Analyzing position: 3rqnk1/1pr1b1p1/p1p1p1pp/P2nP3/2RP2QP/5NN1/1P1B1PP1/2R3K1 b - - 6 23
# Processed move: e8f7, current positions collected: 25
# Analyzing position: 3r1nk1/1pr1bqp1/p1p1p1pp/P2nP3/2RP2QP/5NN1/1P1B1PP1/2R3K1 w - - 7 24
# Skipping move f3e1 as it is the same as the best move f3e1.
# Analyzing position: 3r1nk1/1pr1bqp1/p1p1p1pp/P2nP3/2RP2QP/6N1/1P1B1PP1/2R1N1K1 b - - 8 24
# Skipping move c7d7 as it is the same as the best move c7d7.
# Analyzing position: 3r1nk1/1p1rbqp1/p1p1p1pp/P2nP3/2RP2QP/6N1/1P1B1PP1/2R1N1K1 w - - 9 25
# Processed move: e1f3, current positions collected: 26
# Analyzing position: 3r1nk1/1p1rbqp1/p1p1p1pp/P2nP3/2RP2QP/5NN1/1P1B1PP1/2R3K1 b - - 10 25
# Processed move: d7c7, current positions collected: 27
# Analyzing position: 3r1nk1/1pr1bqp1/p1p1p1pp/P2nP3/2RP2QP/5NN1/1P1B1PP1/2R3K1 w - - 11 26
# Processed move: g4e4, current positions collected: 28
# Analyzing position: 3r1nk1/1pr1bqp1/p1p1p1pp/P2nP3/2RPQ2P/5NN1/1P1B1PP1/2R3K1 b - - 12 26
# Processed move: c7d7, current positions collected: 29
# Analyzing position: 3r1nk1/1p1rbqp1/p1p1p1pp/P2nP3/2RPQ2P/5NN1/1P1B1PP1/2R3K1 w - - 13 27
# Processed move: e4g4, current positions collected: 30
# Finished analyzing game FIDE World Championship Match 1969 without Maia.
# Analyzing game FIDE World Championship Match 1969 without Maia...
# Analyzing position: rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1
# Processed move: c2c4, current positions collected: 1
# Analyzing position: rnbqkbnr/pppppppp/8/8/2P5/8/PP1PPPPP/RNBQKBNR b KQkq - 0 1
# Processed move: e7e6, current positions collected: 2
# Analyzing position: rnbqkbnr/pppp1ppp/4p3/8/2P5/8/PP1PPPPP/RNBQKBNR w KQkq - 0 2
# Skipping move d2d4 as it is the same as the best move d2d4.
# Analyzing position: rnbqkbnr/pppp1ppp/4p3/8/2PP4/8/PP2PPPP/RNBQKBNR b KQkq - 0 2
# Processed move: d7d5, current positions collected: 3
# Analyzing position: rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/8/PP2PPPP/RNBQKBNR w KQkq - 0 3
# Skipping move b1c3 as it is the same as the best move b1c3.
# Analyzing position: rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/2N5/PP2PPPP/R1BQKBNR b KQkq - 1 3
# Processed move: f8e7, current positions collected: 4
# Analyzing position: rnbqk1nr/ppp1bppp/4p3/3p4/2PP4/2N5/PP2PPPP/R1BQKBNR w KQkq - 2 4
# Processed move: g1f3, current positions collected: 5
# Analyzing position: rnbqk1nr/ppp1bppp/4p3/3p4/2PP4/2N2N2/PP2PPPP/R1BQKB1R b KQkq - 3 4
# Skipping move g8f6 as it is the same as the best move g8f6.
# Analyzing position: rnbqk2r/ppp1bppp/4pn2/3p4/2PP4/2N2N2/PP2PPPP/R1BQKB1R w KQkq - 4 5
# Skipping move c1f4 as it is the same as the best move c1f4.
# Analyzing position: rnbqk2r/ppp1bppp/4pn2/3p4/2PP1B2/2N2N2/PP2PPPP/R2QKB1R b KQkq - 5 5
# Processed move: c7c5, current positions collected: 6
# Analyzing position: rnbqk2r/pp2bppp/4pn2/2pp4/2PP1B2/2N2N2/PP2PPPP/R2QKB1R w KQkq - 0 6
# Skipping move d4c5 as it is the same as the best move d4c5.
# Analyzing position: rnbqk2r/pp2bppp/4pn2/2Pp4/2P2B2/2N2N2/PP2PPPP/R2QKB1R b KQkq - 0 6
# Processed move: b8a6, current positions collected: 7
# Analyzing position: r1bqk2r/pp2bppp/n3pn2/2Pp4/2P2B2/2N2N2/PP2PPPP/R2QKB1R w KQkq - 1 7
# Processed move: e2e3, current positions collected: 8
# Analyzing position: r1bqk2r/pp2bppp/n3pn2/2Pp4/2P2B2/2N1PN2/PP3PPP/R2QKB1R b KQkq - 0 7
# Skipping move a6c5 as it is the same as the best move a6c5.
# Analyzing position: r1bqk2r/pp2bppp/4pn2/2np4/2P2B2/2N1PN2/PP3PPP/R2QKB1R w KQkq - 0 8
# Skipping move c4d5 as it is the same as the best move c4d5.
# Analyzing position: r1bqk2r/pp2bppp/4pn2/2nP4/5B2/2N1PN2/PP3PPP/R2QKB1R b KQkq - 0 8
# Processed move: e6d5, current positions collected: 9
# Analyzing position: r1bqk2r/pp2bppp/5n2/2np4/5B2/2N1PN2/PP3PPP/R2QKB1R w KQkq - 0 9
# Skipping move f1e2 as it is the same as the best move f1e2.
# Analyzing position: r1bqk2r/pp2bppp/5n2/2np4/5B2/2N1PN2/PP2BPPP/R2QK2R b KQkq - 1 9
# Skipping move e8g8 as it is the same as the best move e8g8.
# Analyzing position: r1bq1rk1/pp2bppp/5n2/2np4/5B2/2N1PN2/PP2BPPP/R2QK2R w KQ - 2 10
# Skipping move e1g1 as it is the same as the best move e1g1.
# Analyzing position: r1bq1rk1/pp2bppp/5n2/2np4/5B2/2N1PN2/PP2BPPP/R2Q1RK1 b - - 3 10
# Skipping move c8e6 as it is the same as the best move c8e6.
# Analyzing position: r2q1rk1/pp2bppp/4bn2/2np4/5B2/2N1PN2/PP2BPPP/R2Q1RK1 w - - 4 11
# Processed move: f4e5, current positions collected: 10
# Analyzing position: r2q1rk1/pp2bppp/4bn2/2npB3/8/2N1PN2/PP2BPPP/R2Q1RK1 b - - 5 11
# Skipping move a8c8 as it is the same as the best move a8c8.
# Analyzing position: 2rq1rk1/pp2bppp/4bn2/2npB3/8/2N1PN2/PP2BPPP/R2Q1RK1 w - - 6 12
# Processed move: a1c1, current positions collected: 11
# Analyzing position: 2rq1rk1/pp2bppp/4bn2/2npB3/8/2N1PN2/PP2BPPP/2RQ1RK1 b - - 7 12
# Skipping move a7a6 as it is the same as the best move a7a6.
# Analyzing position: 2rq1rk1/1p2bppp/p3bn2/2npB3/8/2N1PN2/PP2BPPP/2RQ1RK1 w - - 0 13
# Processed move: h2h3, current positions collected: 12
# Analyzing position: 2rq1rk1/1p2bppp/p3bn2/2npB3/8/2N1PN1P/PP2BPP1/2RQ1RK1 b - - 0 13
# Processed move: b7b5, current positions collected: 13
# Analyzing position: 2rq1rk1/4bppp/p3bn2/1pnpB3/8/2N1PN1P/PP2BPP1/2RQ1RK1 w - - 0 14
# Processed move: e2d3, current positions collected: 14
# Analyzing position: 2rq1rk1/4bppp/p3bn2/1pnpB3/8/2NBPN1P/PP3PP1/2RQ1RK1 b - - 1 14
# Skipping move d5d4 as it is the same as the best move d5d4.
# Analyzing position: 2rq1rk1/4bppp/p3bn2/1pn1B3/3p4/2NBPN1P/PP3PP1/2RQ1RK1 w - - 0 15
# Skipping move e5d4 as it is the same as the best move e5d4.
# Analyzing position: 2rq1rk1/4bppp/p3bn2/1pn5/3B4/2NBPN1P/PP3PP1/2RQ1RK1 b - - 0 15
# Skipping move c5d3 as it is the same as the best move c5d3.
# Analyzing position: 2rq1rk1/4bppp/p3bn2/1p6/3B4/2NnPN1P/PP3PP1/2RQ1RK1 w - - 0 16
# Skipping move d1d3 as it is the same as the best move d1d3.
# Analyzing position: 2rq1rk1/4bppp/p3bn2/1p6/3B4/2NQPN1P/PP3PP1/2R2RK1 b - - 0 16
# Skipping move e6c4 as it is the same as the best move e6c4.
# Analyzing position: 2rq1rk1/4bppp/p4n2/1p6/2bB4/2NQPN1P/PP3PP1/2R2RK1 w - - 1 17
# Skipping move d3b1 as it is the same as the best move d3b1.
# Analyzing position: 2rq1rk1/4bppp/p4n2/1p6/2bB4/2N1PN1P/PP3PP1/1QR2RK1 b - - 2 17
# Skipping move c4f1 as it is the same as the best move c4f1.
# Analyzing position: 2rq1rk1/4bppp/p4n2/1p6/3B4/2N1PN1P/PP3PP1/1QR2bK1 w - - 0 18
# Skipping move c1f1 as it is the same as the best move c1f1.
# Analyzing position: 2rq1rk1/4bppp/p4n2/1p6/3B4/2N1PN1P/PP3PP1/1Q3RK1 b - - 0 18
# Processed move: f6d5, current positions collected: 15
# Analyzing position: 2rq1rk1/4bppp/p7/1p1n4/3B4/2N1PN1P/PP3PP1/1Q3RK1 w - - 1 19
# Processed move: c3e2, current positions collected: 16
# Analyzing position: 2rq1rk1/4bppp/p7/1p1n4/3B4/4PN1P/PP2NPP1/1Q3RK1 b - - 2 19
# Skipping move e7f6 as it is the same as the best move e7f6.
# Analyzing position: 2rq1rk1/5ppp/p4b2/1p1n4/3B4/4PN1P/PP2NPP1/1Q3RK1 w - - 3 20
# Processed move: f1d1, current positions collected: 17
# Analyzing position: 2rq1rk1/5ppp/p4b2/1p1n4/3B4/4PN1P/PP2NPP1/1Q1R2K1 b - - 4 20
# Skipping move d8c7 as it is the same as the best move d8c7.
# Analyzing position: 2r2rk1/2q2ppp/p4b2/1p1n4/3B4/4PN1P/PP2NPP1/1Q1R2K1 w - - 5 21
# Processed move: d4f6, current positions collected: 18
# Analyzing position: 2r2rk1/2q2ppp/p4B2/1p1n4/8/4PN1P/PP2NPP1/1Q1R2K1 b - - 0 21
# Skipping move d5f6 as it is the same as the best move d5f6.
# Analyzing position: 2r2rk1/2q2ppp/p4n2/1p6/8/4PN1P/PP2NPP1/1Q1R2K1 w - - 0 22
# Skipping move f3d4 as it is the same as the best move f3d4.
# Analyzing position: 2r2rk1/2q2ppp/p4n2/1p6/3N4/4P2P/PP2NPP1/1Q1R2K1 b - - 1 22
# Processed move: c7e5, current positions collected: 19
# Analyzing position: 2r2rk1/5ppp/p4n2/1p2q3/3N4/4P2P/PP2NPP1/1Q1R2K1 w - - 2 23
# Processed move: b1d3, current positions collected: 20
# Analyzing position: 2r2rk1/5ppp/p4n2/1p2q3/3N4/3QP2P/PP2NPP1/3R2K1 b - - 3 23
# Processed move: f8d8, current positions collected: 21
# Analyzing position: 2rr2k1/5ppp/p4n2/1p2q3/3N4/3QP2P/PP2NPP1/3R2K1 w - - 4 24
# Skipping move a2a4 as it is the same as the best move a2a4.
# Analyzing position: 2rr2k1/5ppp/p4n2/1p2q3/P2N4/3QP2P/1P2NPP1/3R2K1 b - - 0 24
# Skipping move b5a4 as it is the same as the best move b5a4.
# Analyzing position: 2rr2k1/5ppp/p4n2/4q3/p2N4/3QP2P/1P2NPP1/3R2K1 w - - 0 25
# Skipping move d1a1 as it is the same as the best move d1a1.
# Analyzing position: 2rr2k1/5ppp/p4n2/4q3/p2N4/3QP2P/1P2NPP1/R5K1 b - - 1 25
# Skipping move f6e4 as it is the same as the best move f6e4.
# Analyzing position: 2rr2k1/5ppp/p7/4q3/p2Nn3/3QP2P/1P2NPP1/R5K1 w - - 2 26
# Skipping move d3a6 as it is the same as the best move d3a6.
# Analyzing position: 2rr2k1/5ppp/Q7/4q3/p2Nn3/4P2P/1P2NPP1/R5K1 b - - 0 26
# Processed move: c8a8, current positions collected: 22
# Analyzing position: r2r2k1/5ppp/Q7/4q3/p2Nn3/4P2P/1P2NPP1/R5K1 w - - 1 27
# Skipping move a6d3 as it is the same as the best move a6d3.
# Analyzing position: r2r2k1/5ppp/8/4q3/p2Nn3/3QP2P/1P2NPP1/R5K1 b - - 2 27
# Processed move: d8e8, current positions collected: 23
# Analyzing position: r3r1k1/5ppp/8/4q3/p2Nn3/3QP2P/1P2NPP1/R5K1 w - - 3 28
# Processed move: e2f4, current positions collected: 24
# Analyzing position: r3r1k1/5ppp/8/4q3/p2NnN2/3QP2P/1P3PP1/R5K1 b - - 4 28
# Processed move: g7g6, current positions collected: 25
# Analyzing position: r3r1k1/5p1p/6p1/4q3/p2NnN2/3QP2P/1P3PP1/R5K1 w - - 0 29
# Processed move: d3a3, current positions collected: 26
# Analyzing position: r3r1k1/5p1p/6p1/4q3/p2NnN2/Q3P2P/1P3PP1/R5K1 b - - 1 29
# Processed move: e5f6, current positions collected: 27
# Analyzing position: r3r1k1/5p1p/5qp1/8/p2NnN2/Q3P2P/1P3PP1/R5K1 w - - 2 30
# Processed move: f4d3, current positions collected: 28
# Analyzing position: r3r1k1/5p1p/5qp1/8/p2Nn3/Q2NP2P/1P3PP1/R5K1 b - - 3 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 71
#      69 fen = board.fen()
#      70 print(f"Analyzing position: {fen}")
# ---> 71 avg_error = calculate_average_error(board, stockfish_engine)
#      72 stockfish_info = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1))
#      73 best_move = stockfish_info["pv"][0] if "pv" in stockfish_info else None
#
# Cell In[8], line 14, in calculate_average_error(board, stockfish_engine)
#      12 for move in legal_moves:
#      13     board.push(move)
# ---> 14     info = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1))
#      15     eval_score = info["score"].relative.score(mate_score=10000) / 100.0
#      16     total_error += abs(eval_score)
#
# File ~/miniconda3/envs/CSSLAB/lib/python3.8/site-packages/chess/engine.py:2996, in SimpleEngine.analyse(self, board, limit, multipv, game, info, root_moves, options)
#    2992     coro = asyncio.wait_for(
#    2993         self.protocol.analyse(board, limit, multipv=multipv, game=game, info=info, root_moves=root_moves, options=options),
#    2994         self._timeout_for(limit))
#    2995     future = asyncio.run_coroutine_threadsafe(coro, self.protocol.loop)
# -> 2996 return future.result()
#
# File ~/miniconda3/envs/CSSLAB/lib/python3.8/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     436 elif self._state == FINISHED:
#     437     return self.__get_result()
# --> 439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     442     raise CancelledError()
#
# File ~/miniconda3/envs/CSSLAB/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:
