# %%
# Part 1: Initialization and Loading PGN Files

# Import required libraries
import chess
import chess.engine
import chess.pgn
import subprocess
import os
import json
import csv
from IPython.display import display

# Paths to your engines and Maia models
stockfish_path = "/opt/homebrew/bin/stockfish"
maia_model_paths = {
    1100: "maia_weights/maia-1100.pb.gz",
    1200: "maia_weights/maia-1200.pb.gz",
    1300: "maia_weights/maia-1300.pb.gz",
    1400: "maia_weights/maia-1400.pb.gz",
    1500: "maia_weights/maia-1500.pb.gz",
    1600: "maia_weights/maia-1600.pb.gz",
    1700: "maia_weights/maia-1700.pb.gz",
    1800: "maia_weights/maia-1800.pb.gz",
    1900: "maia_weights/maia-1900.pb.gz",
}

# Initialize Stockfish engine
print("Initializing Stockfish engine...")
stockfish_engine = chess.engine.SimpleEngine.popen_uci(stockfish_path)
print("Stockfish engine initialized.")

# Initialize Maia engines
print("Initializing Maia engines...")
maia_engines = {}
for elo, path in maia_model_paths.items():
    maia_engines[elo] = chess.engine.SimpleEngine.popen_uci(["lc0", f"--weights={path}"])
    print(f"Maia {elo} engine initialized.")
print("Maia engines initialized.")


# Function to load games from a PGN file
def load_games_from_pgn(file_path):
    games = []
    with open(file_path, 'r') as pgn_file:
        while True:
            game = chess.pgn.read_game(pgn_file)
            if game is None:
                break
            games.append(game)
    print(f"Loaded {len(games)} games from PGN file {file_path}.")
    return games


# Function to find classic puzzles in a game
def find_classic_puzzles(game, stockfish_engine, threshold=200):
    board = game.board()
    puzzles = []

    for move in game.mainline_moves():
        fen_before = board.fen()

        # Analyze the position before the move
        info = stockfish_engine.analyse(board, chess.engine.Limit(time=0.1), multipv=2)
        #print(info)
        if len(info) < 2:
            continue

        best_move = info[0]["pv"][0]
        best_eval = info[0]["score"].relative.score(mate_score=10000)
        second_best_eval = info[1]["score"].relative.score(mate_score=10000)
        #print(board.is_capture(best_move))
        # Check if the difference is large enough and the move is not a simple recapture
        if abs(best_eval - second_best_eval) >= threshold and not board.is_capture(best_move):
            puzzles.append((fen_before, best_move, best_eval, second_best_eval))
            print(
                f"Puzzle found: {fen_before}, Best move: {best_move}, Eval difference: {abs(best_eval - second_best_eval)}")

        board.push(move)

    return puzzles


# Function to get multiple best moves from Maia using multipv
def get_multiple_best_moves(engine, board, n=3):
    result = engine.analyse(board, chess.engine.Limit(nodes=1000), multipv=n)
    best_moves = [(info["pv"][0], info["score"].relative.score(mate_score=10000)) for info in result]
    # Sort the best moves based on their evaluation scores
    best_moves_sorted = sorted(best_moves, key=lambda x: x[1], reverse=True)
    return best_moves_sorted


# Function to evaluate Maia easiness
def evaluate_maia_easiness(fen, best_move, maia_engines, multipv=3):
    board = chess.Board(fen)
    easiness_scores = {}
    print(f"Evaluating Maia easiness for FEN: {fen}, Best Move: {best_move}")

    for elo, engine in maia_engines.items():
        multiple_best_moves = get_multiple_best_moves(engine, board, multipv)
        print(f"Maia {elo} best moves: {multiple_best_moves}")

        move_probabilities = {move: (i + 1) / len(multiple_best_moves) for i, (move, score) in
                              enumerate(multiple_best_moves)}

        if best_move in move_probabilities:
            easiness_score = move_probabilities[best_move]
        else:
            easiness_score = 1.0  # Assign 1.0 if the best move is not in the PV list

        easiness_scores[elo] = easiness_score

    # Combine easiness scores from different models into a single score
    combined_easiness_score = mean(easiness_scores.values()) if easiness_scores else 1.0
    return combined_easiness_score


# Function to save results to CSV
def save_results_to_csv(csv_file_path, data):
    with open(csv_file_path, "a", newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        for fen, best_move, best_eval, second_best_eval, maia_easiness in data:
            csvwriter.writerow([
                fen,
                best_move.uci(),  # Convert Move object to UCI notation
                best_eval,
                second_best_eval,
                maia_easiness
            ])


# Function to save results to JSON
def save_results_to_json(json_file_path, data):
    if os.path.exists(json_file_path):
        with open(json_file_path, "r") as jsonfile:
            json_data = json.load(jsonfile)
    else:
        json_data = []

    json_data.extend([{
        "fen": fen,
        "best_move": best_move.uci(),  # Convert Move object to UCI notation
        "best_eval": best_eval,
        "second_best_eval": second_best_eval,
        "maia_easiness": maia_easiness
    } for fen, best_move, best_eval, second_best_eval, maia_easiness in data])

    with open(json_file_path, "w") as jsonfile:
        json.dump(json_data, jsonfile, indent=4)


# Paths to save results
csv_file_path = "classic_puzzles.csv"
json_file_path = "classic_puzzles.json"

# Initialize CSV file with headers
with open(csv_file_path, "w", newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["FEN", "Best Move", "Best Eval", "Second Best Eval", "Maia Easiness"])

# Load PGN files and find classic puzzles
pgn_directory = "analysis_pgns_test"
all_puzzles = []

print("Starting to find classic puzzles in PGN files...")

for pgn_file in os.listdir(pgn_directory):
    if pgn_file.endswith(".pgn"):
        pgn_file_path = os.path.join(pgn_directory, pgn_file)
        print(f"Analyzing {pgn_file_path}...")
        all_games = load_games_from_pgn(pgn_file_path)

        for game in all_games:
            print(f"Analyzing game {game.headers.get('Event', 'Unknown Event')}")
            puzzles = find_classic_puzzles(game, stockfish_engine)
            extended_puzzles = []
            for fen, best_move, best_eval, second_best_eval in puzzles:
                maia_easiness = evaluate_maia_easiness(fen, best_move, maia_engines)
                extended_puzzles.append((fen, best_move, best_eval, second_best_eval, maia_easiness))
                print(f"Puzzle added with easiness: {maia_easiness}")

            # Save results incrementally
            save_results_to_csv(csv_file_path, extended_puzzles)
            save_results_to_json(json_file_path, extended_puzzles)

            all_puzzles.extend(extended_puzzles)

print("Classic puzzles analysis complete. Results saved.")

# Cleanup Maia engines
print("Cleaning up engines...")
for engine in maia_engines.values():
    engine.quit()
stockfish_engine.quit()
print("Engines cleaned.")
# Out:
# Initializing Stockfish engine...
# <UciProtocol (pid=20709)>: stderr >>        _
# <UciProtocol (pid=20709)>: stderr >> |   _ | |
# <UciProtocol (pid=20709)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=20710)>: stderr >>        _
# <UciProtocol (pid=20710)>: stderr >> |   _ | |
# <UciProtocol (pid=20710)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=20711)>: stderr >>        _
# <UciProtocol (pid=20711)>: stderr >> |   _ | |
# <UciProtocol (pid=20711)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=20712)>: stderr >>        _
# <UciProtocol (pid=20712)>: stderr >> |   _ | |
# <UciProtocol (pid=20712)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=20713)>: stderr >>        _
# <UciProtocol (pid=20713)>: stderr >> |   _ | |
# <UciProtocol (pid=20713)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=20714)>: stderr >>        _
# <UciProtocol (pid=20714)>: stderr >> |   _ | |
# <UciProtocol (pid=20714)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=20715)>: stderr >>        _
# <UciProtocol (pid=20715)>: stderr >> |   _ | |
# <UciProtocol (pid=20715)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=20716)>: stderr >>        _
# <UciProtocol (pid=20716)>: stderr >> |   _ | |
# <UciProtocol (pid=20716)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# <UciProtocol (pid=20717)>: stderr >>        _
# <UciProtocol (pid=20717)>: stderr >> |   _ | |
# <UciProtocol (pid=20717)>: stderr >> |_ |_ |_| v0.30.0+git.dirty built Jul 21 2023
# Stockfish engine initialized.
# Initializing Maia engines...
# Maia 1100 engine initialized.
# Maia 1200 engine initialized.
# Maia 1300 engine initialized.
# Maia 1400 engine initialized.
# Maia 1500 engine initialized.
# Maia 1600 engine initialized.
# Maia 1700 engine initialized.
# Maia 1800 engine initialized.
# Maia 1900 engine initialized.
# Maia engines initialized.
# Starting to find classic puzzles in PGN files...
# Analyzing analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn...
# Loaded 4 games from PGN file analysis_pgns_test/4c6eS6SH---1969 Petrosian vs. Spassky .pgn.
# Analyzing game FIDE World Championship Match 1969
# Puzzle found: 8/5B1R/6p1/2n3k1/8/1p5P/6K1/2r5 w - - 0 47, Best move: h3h4, Eval difference: 222
# Puzzle found: 8/5B1R/5kp1/2n4P/8/5K2/1pr5/8 w - - 0 50, Best move: f7a2, Eval difference: 233
# <UciProtocol (pid=20709)>: stderr >> Loading weights file from: maia_weights/maia-1100.pb.gz
# <UciProtocol (pid=20709)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=20709)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Evaluating Maia easiness for FEN: 8/5B1R/6p1/2n3k1/8/1p5P/6K1/2r5 w - - 0 47, Best Move: h3h4
# <UciProtocol (pid=20710)>: stderr >> Loading weights file from: maia_weights/maia-1200.pb.gz
# <UciProtocol (pid=20710)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=20710)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Maia 1100 best moves: [(Move.from_uci('f7b3'), -84), (Move.from_uci('h3h4'), -121), (Move.from_uci('h7g7'), -161)]
# <UciProtocol (pid=20711)>: stderr >> Loading weights file from: maia_weights/maia-1300.pb.gz
# <UciProtocol (pid=20711)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=20711)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Maia 1200 best moves: [(Move.from_uci('f7b3'), -105), (Move.from_uci('h3h4'), -136), (Move.from_uci('h7g7'), -205)]
# <UciProtocol (pid=20712)>: stderr >> Loading weights file from: maia_weights/maia-1400.pb.gz
# <UciProtocol (pid=20712)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=20712)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Maia 1300 best moves: [(Move.from_uci('f7b3'), -102), (Move.from_uci('h3h4'), -155), (Move.from_uci('h7g7'), -230)]
# <UciProtocol (pid=20713)>: stderr >> Loading weights file from: maia_weights/maia-1500.pb.gz
# <UciProtocol (pid=20713)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=20713)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Maia 1400 best moves: [(Move.from_uci('f7b3'), -136), (Move.from_uci('h3h4'), -181), (Move.from_uci('h7g7'), -239)]
# <UciProtocol (pid=20714)>: stderr >> Loading weights file from: maia_weights/maia-1600.pb.gz
# <UciProtocol (pid=20714)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=20714)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Maia 1500 best moves: [(Move.from_uci('f7b3'), -116), (Move.from_uci('h3h4'), -160), (Move.from_uci('h7g7'), -242)]
# <UciProtocol (pid=20715)>: stderr >> Loading weights file from: maia_weights/maia-1700.pb.gz
# <UciProtocol (pid=20715)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=20715)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Maia 1600 best moves: [(Move.from_uci('f7b3'), -155), (Move.from_uci('h3h4'), -170), (Move.from_uci('h7g7'), -255)]
# <UciProtocol (pid=20716)>: stderr >> Loading weights file from: maia_weights/maia-1800.pb.gz
# <UciProtocol (pid=20716)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=20716)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Maia 1700 best moves: [(Move.from_uci('f7b3'), -192), (Move.from_uci('h3h4'), -212), (Move.from_uci('h7g7'), -255)]
# <UciProtocol (pid=20717)>: stderr >> Loading weights file from: maia_weights/maia-1900.pb.gz
# <UciProtocol (pid=20717)>: stderr >> Creating backend [metal]...
# <UciProtocol (pid=20717)>: stderr >> Initialized metal backend on device Apple M1 Pro
# Maia 1800 best moves: [(Move.from_uci('f7b3'), -180), (Move.from_uci('h3h4'), -206), (Move.from_uci('h7g7'), -312)]
# Maia 1900 best moves: [(Move.from_uci('f7b3'), -197), (Move.from_uci('h3h4'), -224), (Move.from_uci('h7g7'), -293)]
# Puzzle added with easiness: 0.6666666666666666
# Evaluating Maia easiness for FEN: 8/5B1R/5kp1/2n4P/8/5K2/1pr5/8 w - - 0 50, Best Move: f7a2
# Maia 1100 best moves: [(Move.from_uci('f7a2'), -93), (Move.from_uci('f7g6'), -140), (Move.from_uci('h5g6'), -321)]
# Maia 1200 best moves: [(Move.from_uci('f7a2'), -141), (Move.from_uci('f7g6'), -179), (Move.from_uci('h5g6'), -420)]
# Maia 1300 best moves: [(Move.from_uci('f7a2'), -127), (Move.from_uci('f7g6'), -226), (Move.from_uci('h5g6'), -438)]
# Maia 1400 best moves: [(Move.from_uci('f7a2'), -157), (Move.from_uci('f7g6'), -207), (Move.from_uci('h5g6'), -466)]
# Maia 1500 best moves: [(Move.from_uci('f7a2'), -140), (Move.from_uci('f7g6'), -266), (Move.from_uci('h5g6'), -488)]
# Maia 1600 best moves: [(Move.from_uci('f7a2'), -173), (Move.from_uci('f7g6'), -309), (Move.from_uci('h5g6'), -583)]
# Maia 1700 best moves: [(Move.from_uci('f7a2'), -163), (Move.from_uci('f7g6'), -354), (Move.from_uci('h5g6'), -572)]
# Maia 1800 best moves: [(Move.from_uci('f7a2'), -164), (Move.from_uci('f7g6'), -280), (Move.from_uci('h5g6'), -513)]
# Maia 1900 best moves: [(Move.from_uci('f7a2'), -164), (Move.from_uci('f7g6'), -403), (Move.from_uci('h5g6'), -669)]
# Puzzle added with easiness: 0.3333333333333333
# Analyzing game FIDE World Championship Match 1969
# Analyzing game FIDE World Championship Match 1969
# Analyzing game FIDE World Championship Match 1969
# Puzzle found: 4r1k1/pp3pp1/7p/P1Rp2q1/3P1nP1/1P1bNP2/3Q1K1P/5B2 b - - 4 40, Best move: g5h4, Eval difference: 226
# Evaluating Maia easiness for FEN: 4r1k1/pp3pp1/7p/P1Rp2q1/3P1nP1/1P1bNP2/3Q1K1P/5B2 b - - 4 40, Best Move: g5h4
# Maia 1100 best moves: [(Move.from_uci('g5h4'), 800), (Move.from_uci('d3f1'), 137), (Move.from_uci('b7b6'), -66)]
# Maia 1200 best moves: [(Move.from_uci('g5h4'), 826), (Move.from_uci('d3f1'), 341), (Move.from_uci('d3g6'), 190)]
# Maia 1300 best moves: [(Move.from_uci('g5h4'), 713), (Move.from_uci('d3f1'), 478), (Move.from_uci('f4h3'), 197)]
# Maia 1400 best moves: [(Move.from_uci('g5h4'), 1115), (Move.from_uci('d3f1'), 631), (Move.from_uci('d3g6'), 595)]
# Maia 1500 best moves: [(Move.from_uci('g5h4'), 1027), (Move.from_uci('d3f1'), 424), (Move.from_uci('d3a6'), 411)]
# Maia 1600 best moves: [(Move.from_uci('g5h4'), 1066), (Move.from_uci('d3f1'), 638), (Move.from_uci('d3g6'), 585)]
# Maia 1700 best moves: [(Move.from_uci('g5h4'), 958), (Move.from_uci('d3f1'), 582), (Move.from_uci('d3g6'), 285)]
# Maia 1800 best moves: [(Move.from_uci('g5h4'), 1258), (Move.from_uci('d3g6'), 673), (Move.from_uci('d3f1'), 496)]
# Maia 1900 best moves: [(Move.from_uci('g5h4'), 1107), (Move.from_uci('d3f1'), 619), (Move.from_uci('d3g6'), 372)]
# Puzzle added with easiness: 0.3333333333333333
# Analyzing analysis_pgns_test/4S5UuAGn---1986 Karpov vs. Kasparov III.pgn...
# Loaded 1 games from PGN file analysis_pgns_test/4S5UuAGn---1986 Karpov vs. Kasparov III.pgn.
# Analyzing game FIDE World Championship Match 1986
# Analyzing analysis_pgns_test/TFFyOff1---1908 Lasker vs. Tarrasch.pgn...
# Loaded 7 games from PGN file analysis_pgns_test/TFFyOff1---1908 Lasker vs. Tarrasch.pgn.
# Analyzing game World Championship Match 1908
# Analyzing game World Championship Match 1908
# Puzzle found: 3rr2k/p1pqbp1p/2pp4/5N2/3QP3/1P6/P1P2KPP/R3R3 b - - 3 18, Best move: f7f6, Eval difference: 9825
# Puzzle found: 4r2k/2p4p/8/6r1/3p1p2/1P1NbQ2/P1P1R1P1/R2K2q1 w - - 2 36, Best move: d3e1, Eval difference: 216
# Puzzle found: 3Q4/4r1kp/4r3/8/P2p1p2/1P2b3/2P1R1P1/R2KN1q1 b - - 0 40, Best move: f4f3, Eval difference: 269
# Puzzle found: 3Q4/4r1kp/4r3/8/P2p4/1P2bP2/2P1R3/R2KN1q1 b - - 0 41, Best move: e3g5, Eval difference: 538
# Evaluating Maia easiness for FEN: 3rr2k/p1pqbp1p/2pp4/5N2/3QP3/1P6/P1P2KPP/R3R3 b - - 3 18, Best Move: f7f6
# Maia 1100 best moves: [(Move.from_uci('f7f6'), -246), (Move.from_uci('e7f6'), -2143), (Move.from_uci('h8g8'), -9999)]
# Maia 1200 best moves: [(Move.from_uci('f7f6'), -409), (Move.from_uci('e7f6'), -9998), (Move.from_uci('h8g8'), -9999)]
# Maia 1300 best moves: [(Move.from_uci('f7f6'), -338), (Move.from_uci('e7f6'), -1631), (Move.from_uci('h8g8'), -9999)]
# Maia 1400 best moves: [(Move.from_uci('f7f6'), -327), (Move.from_uci('e7f6'), -9998), (Move.from_uci('h8g8'), -9999)]
# Maia 1500 best moves: [(Move.from_uci('f7f6'), -318), (Move.from_uci('e7f6'), -1750), (Move.from_uci('h8g8'), -9999)]
# Maia 1600 best moves: [(Move.from_uci('f7f6'), -297), (Move.from_uci('e7f6'), -2262), (Move.from_uci('h8g8'), -9999)]
# Maia 1700 best moves: [(Move.from_uci('f7f6'), -324), (Move.from_uci('e7f6'), -1410), (Move.from_uci('h8g8'), -9999)]
# Maia 1800 best moves: [(Move.from_uci('f7f6'), -321), (Move.from_uci('e7f6'), -1629), (Move.from_uci('h8g8'), -9999)]
# Maia 1900 best moves: [(Move.from_uci('f7f6'), -320), (Move.from_uci('e7f6'), -1037), (Move.from_uci('h8g8'), -9999)]
# Puzzle added with easiness: 0.3333333333333333
# Evaluating Maia easiness for FEN: 4r2k/2p4p/8/6r1/3p1p2/1P1NbQ2/P1P1R1P1/R2K2q1 w - - 2 36, Best Move: d3e1
# Maia 1100 best moves: [(Move.from_uci('e2e1'), -244), (Move.from_uci('d3e1'), -409), (Move.from_uci('f3f1'), -1758)]
# Maia 1200 best moves: [(Move.from_uci('e2e1'), -196), (Move.from_uci('f3f1'), -200), (Move.from_uci('d3e1'), -204)]
# Maia 1300 best moves: [(Move.from_uci('e2e1'), -217), (Move.from_uci('f3f1'), -272), (Move.from_uci('d3e1'), -506)]
# Maia 1400 best moves: [(Move.from_uci('e2e1'), -405), (Move.from_uci('d3e1'), -414), (Move.from_uci('f3f1'), -1832)]
# Maia 1500 best moves: [(Move.from_uci('d3e1'), -540), (Move.from_uci('f3f1'), -566), (Move.from_uci('e2e1'), -570)]
# Maia 1600 best moves: [(Move.from_uci('d3e1'), -429), (Move.from_uci('e2e1'), -558), (Move.from_uci('f3f1'), -3239)]
# Maia 1700 best moves: [(Move.from_uci('d3e1'), -486), (Move.from_uci('f3f1'), -534), (Move.from_uci('e2e1'), -685)]
# Maia 1800 best moves: [(Move.from_uci('e2e1'), -735), (Move.from_uci('d3e1'), -743), (Move.from_uci('f3f1'), -2276)]
# Maia 1900 best moves: [(Move.from_uci('d3e1'), -393), (Move.from_uci('f3f1'), -470), (Move.from_uci('e2e1'), -611)]
# Puzzle added with easiness: 0.5925925925925926
# Evaluating Maia easiness for FEN: 3Q4/4r1kp/4r3/8/P2p1p2/1P2b3/2P1R1P1/R2KN1q1 b - - 0 40, Best Move: f4f3
# Maia 1100 best moves: [(Move.from_uci('f4f3'), 615), (Move.from_uci('g1f1'), 448), (Move.from_uci('e3f2'), 261)]
# Maia 1200 best moves: [(Move.from_uci('f4f3'), 556), (Move.from_uci('g1f1'), 302), (Move.from_uci('e3f2'), 163)]
# Maia 1300 best moves: [(Move.from_uci('f4f3'), 619), (Move.from_uci('g1f1'), 450), (Move.from_uci('e7e8'), 161)]
# Maia 1400 best moves: [(Move.from_uci('f4f3'), 731), (Move.from_uci('d4d3'), 392), (Move.from_uci('g1f1'), 365)]
# Maia 1500 best moves: [(Move.from_uci('f4f3'), 976), (Move.from_uci('e6e5'), 554), (Move.from_uci('e3f2'), 197)]
# Maia 1600 best moves: [(Move.from_uci('e6e5'), 462), (Move.from_uci('h7h5'), 393), (Move.from_uci('g1f1'), 314)]
# Maia 1700 best moves: [(Move.from_uci('f4f3'), 641), (Move.from_uci('g1h1'), 355), (Move.from_uci('g1f1'), 325)]
# Maia 1800 best moves: [(Move.from_uci('d4d3'), 571), (Move.from_uci('g1h2'), 501), (Move.from_uci('e6e5'), 311)]
# Maia 1900 best moves: [(Move.from_uci('e6e5'), 339), (Move.from_uci('g1f1'), 338), (Move.from_uci('d4d3'), 244)]
# Puzzle added with easiness: 0.5555555555555556
# Evaluating Maia easiness for FEN: 3Q4/4r1kp/4r3/8/P2p4/1P2bP2/2P1R3/R2KN1q1 b - - 0 41, Best Move: e3g5
# Maia 1100 best moves: [(Move.from_uci('e3d2'), 656), (Move.from_uci('e3g5'), 582), (Move.from_uci('e3f2'), 277)]
# Maia 1200 best moves: [(Move.from_uci('e3g5'), 1026), (Move.from_uci('e3f2'), 354), (Move.from_uci('e3f4'), 240)]
# Maia 1300 best moves: [(Move.from_uci('e3g5'), 696), (Move.from_uci('g1f1'), 461), (Move.from_uci('e3f2'), -4)]
# Maia 1400 best moves: [(Move.from_uci('e3g5'), 799), (Move.from_uci('e3f2'), 438), (Move.from_uci('g1f1'), 61)]
# Maia 1500 best moves: [(Move.from_uci('e3g5'), 755), (Move.from_uci('g1f1'), 275), (Move.from_uci('e3f2'), 180)]
# Maia 1600 best moves: [(Move.from_uci('e3g5'), 955), (Move.from_uci('e3f2'), 97), (Move.from_uci('g1f1'), -47)]
# Maia 1700 best moves: [(Move.from_uci('e3g5'), 1169), (Move.from_uci('e3f2'), 143), (Move.from_uci('g1f1'), 117)]
# Maia 1800 best moves: [(Move.from_uci('e3g5'), 1099), (Move.from_uci('g1f1'), 92), (Move.from_uci('e3f2'), -134)]
# Maia 1900 best moves: [(Move.from_uci('e3g5'), 770), (Move.from_uci('e3f2'), 245), (Move.from_uci('e3f4'), 192)]
# Puzzle added with easiness: 0.37037037037037035
# Analyzing game World Championship Match 1908
# Puzzle found: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQR1K1 w kq - 0 7, Best move: a4b3, Eval difference: 263
# Puzzle found: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4R2P/PP3KN1/3q4 b - - 0 36, Best move: d1f3, Eval difference: 365
# Puzzle found: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4Rq1P/PP3KN1/8 w - - 1 37, Best move: f2g1, Eval difference: 9316
# Puzzle found: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4Rq1P/PP4N1/4K3 b - - 2 37, Best move: e5d3, Eval difference: 9137
# Puzzle found: 2b4k/4Q2p/p2p2p1/qp1Bn3/4P3/4Rq1P/PP4N1/4K3 w - - 3 38, Best move: e3c3, Eval difference: 9515
# Evaluating Maia easiness for FEN: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQR1K1 w kq - 0 7, Best Move: a4b3
# Maia 1100 best moves: [(Move.from_uci('a4b3'), 164), (Move.from_uci('d2d4'), -354), (Move.from_uci('b1c3'), -743)]
# Maia 1200 best moves: [(Move.from_uci('a4b3'), 147), (Move.from_uci('d2d4'), -160), (Move.from_uci('c2c3'), -546)]
# Maia 1300 best moves: [(Move.from_uci('a4b3'), 166), (Move.from_uci('d2d4'), -400), (Move.from_uci('c2c3'), -422)]
# Maia 1400 best moves: [(Move.from_uci('a4b3'), 236), (Move.from_uci('d2d4'), -243), (Move.from_uci('c2c3'), -622)]
# Maia 1500 best moves: [(Move.from_uci('a4b3'), 177), (Move.from_uci('a4b5'), -606), (Move.from_uci('c2c3'), -923)]
# Maia 1600 best moves: [(Move.from_uci('a4b3'), 200), (Move.from_uci('d2d4'), -349), (Move.from_uci('c2c3'), -860)]
# Maia 1700 best moves: [(Move.from_uci('a4b3'), 183), (Move.from_uci('d2d4'), -358), (Move.from_uci('c2c3'), -761)]
# Maia 1800 best moves: [(Move.from_uci('a4b3'), 132), (Move.from_uci('d2d4'), -398), (Move.from_uci('c2c3'), -556)]
# Maia 1900 best moves: [(Move.from_uci('a4b3'), 111), (Move.from_uci('d2d4'), -364), (Move.from_uci('c2c3'), -788)]
# Puzzle added with easiness: 0.3333333333333333
# Evaluating Maia easiness for FEN: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4R2P/PP3KN1/3q4 b - - 0 36, Best Move: d1f3
# Maia 1100 best moves: [(Move.from_uci('e5d7'), 70), (Move.from_uci('d1d2'), 12), (Move.from_uci('e5d3'), -1061)]
# Maia 1200 best moves: [(Move.from_uci('b6e3'), 217), (Move.from_uci('e5d3'), -124), (Move.from_uci('d1d2'), -266)]
# Maia 1300 best moves: [(Move.from_uci('b6e3'), 344), (Move.from_uci('d1d2'), -9), (Move.from_uci('e5d3'), -466)]
# Maia 1400 best moves: [(Move.from_uci('d1f3'), 1261), (Move.from_uci('d1d2'), -51), (Move.from_uci('d1c2'), -1045)]
# Maia 1500 best moves: [(Move.from_uci('e5d3'), 225), (Move.from_uci('d1d2'), -235), (Move.from_uci('e5g4'), -1167)]
# Maia 1600 best moves: [(Move.from_uci('d1f3'), 328), (Move.from_uci('d1d2'), -68), (Move.from_uci('e5g4'), -206)]
# Maia 1700 best moves: [(Move.from_uci('d1d2'), -36), (Move.from_uci('d1d5'), -370), (Move.from_uci('d1c2'), -2132)]
# Maia 1800 best moves: [(Move.from_uci('b6e3'), 183), (Move.from_uci('d1d2'), -42), (Move.from_uci('e5g4'), -277)]
# Maia 1900 best moves: [(Move.from_uci('e5d3'), 85), (Move.from_uci('e5d7'), -88), (Move.from_uci('d1d2'), -164)]
# Puzzle added with easiness: 0.8518518518518519
# Evaluating Maia easiness for FEN: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4Rq1P/PP3KN1/8 w - - 1 37, Best Move: f2g1
# Maia 1100 best moves: [(Move.from_uci('f2g1'), -315), (Move.from_uci('f2e1'), -9995)]
# Maia 1200 best moves: [(Move.from_uci('f2g1'), -504), (Move.from_uci('f2e1'), -9995)]
# Maia 1300 best moves: [(Move.from_uci('f2g1'), -405), (Move.from_uci('f2e1'), -1345)]
# Maia 1400 best moves: [(Move.from_uci('f2g1'), -472), (Move.from_uci('f2e1'), -9995)]
# Maia 1500 best moves: [(Move.from_uci('f2g1'), -416), (Move.from_uci('f2e1'), -649)]
# Maia 1600 best moves: [(Move.from_uci('f2g1'), -485), (Move.from_uci('f2e1'), -9995)]
# Maia 1700 best moves: [(Move.from_uci('f2g1'), -349), (Move.from_uci('f2e1'), -9995)]
# Maia 1800 best moves: [(Move.from_uci('f2g1'), -416), (Move.from_uci('f2e1'), -9995)]
# Maia 1900 best moves: [(Move.from_uci('f2e1'), -184), (Move.from_uci('f2g1'), -547)]
# Puzzle added with easiness: 0.5555555555555556
# Evaluating Maia easiness for FEN: 2b4k/4Q2p/pq1p2p1/1p1Bn3/4P3/4Rq1P/PP4N1/4K3 b - - 2 37, Best Move: e5d3
# Maia 1100 best moves: [(Move.from_uci('e5d3'), 9995), (Move.from_uci('f3e3'), 328), (Move.from_uci('b6a5'), 273)]
# Maia 1200 best moves: [(Move.from_uci('e5d3'), 9995), (Move.from_uci('b6a5'), 765), (Move.from_uci('b6e3'), 557)]
# Maia 1300 best moves: [(Move.from_uci('e5d3'), 9995), (Move.from_uci('b6a5'), 802), (Move.from_uci('f3e3'), 424)]
# Maia 1400 best moves: [(Move.from_uci('e5d3'), 9995), (Move.from_uci('b6e3'), 359), (Move.from_uci('f3e3'), 351)]
# Maia 1500 best moves: [(Move.from_uci('e5d3'), 9995), (Move.from_uci('b6a5'), 863), (Move.from_uci('f3e3'), 508)]
# Maia 1600 best moves: [(Move.from_uci('e5d3'), 9995), (Move.from_uci('b6a5'), 288), (Move.from_uci('b6e3'), 188)]
# Maia 1700 best moves: [(Move.from_uci('e5d3'), 9995), (Move.from_uci('b6a5'), 346), (Move.from_uci('f3e3'), 199)]
# Maia 1800 best moves: [(Move.from_uci('e5d3'), 9995), (Move.from_uci('f3e3'), 155), (Move.from_uci('b6e3'), 131)]
# Maia 1900 best moves: [(Move.from_uci('e5d3'), 9995), (Move.from_uci('f3e3'), 188), (Move.from_uci('b6e3'), 186)]
# Puzzle added with easiness: 0.3333333333333333
# Evaluating Maia easiness for FEN: 2b4k/4Q2p/p2p2p1/qp1Bn3/4P3/4Rq1P/PP4N1/4K3 w - - 3 38, Best Move: e3c3
# Maia 1100 best moves: [(Move.from_uci('e3c3'), 122), (Move.from_uci('b2b4'), -9998)]
# Maia 1200 best moves: [(Move.from_uci('e3c3'), -29), (Move.from_uci('b2b4'), -9998)]
# Maia 1300 best moves: [(Move.from_uci('e3c3'), -354), (Move.from_uci('b2b4'), -9998)]
# Maia 1400 best moves: [(Move.from_uci('e3c3'), -596), (Move.from_uci('b2b4'), -9998)]
# Maia 1500 best moves: [(Move.from_uci('e3c3'), -195), (Move.from_uci('b2b4'), -9998)]
# Maia 1600 best moves: [(Move.from_uci('e3c3'), -213), (Move.from_uci('b2b4'), -9998)]
# Maia 1700 best moves: [(Move.from_uci('e3c3'), -333), (Move.from_uci('b2b4'), -9998)]
# Maia 1800 best moves: [(Move.from_uci('e3c3'), 68), (Move.from_uci('b2b4'), -9998)]
# Maia 1900 best moves: [(Move.from_uci('e3c3'), -116), (Move.from_uci('b2b4'), -9998)]
# Puzzle added with easiness: 0.5
# Analyzing game World Championship Match 1908
# Puzzle found: 4r1k1/1pp2pp1/1n1p1q1p/2r5/pP1NPP2/2P2Q2/P5PP/3RR1K1 b - - 0 22, Best move: c5c4, Eval difference: 241
# Puzzle found: 6k1/1p3pp1/1n1r1q1p/1N2P3/pp3P2/2P1RQ2/P6P/6K1 b - - 0 28, Best move: f6g6, Eval difference: 505
# Evaluating Maia easiness for FEN: 4r1k1/1pp2pp1/1n1p1q1p/2r5/pP1NPP2/2P2Q2/P5PP/3RR1K1 b - - 0 22, Best Move: c5c4
# Maia 1100 best moves: [(Move.from_uci('c5c4'), -43), (Move.from_uci('c5c3'), -509), (Move.from_uci('b6c4'), -826)]
# Maia 1200 best moves: [(Move.from_uci('c5c4'), 13), (Move.from_uci('b6c4'), -662), (Move.from_uci('c5c3'), -811)]
# Maia 1300 best moves: [(Move.from_uci('c5c4'), -16), (Move.from_uci('c5c3'), -614), (Move.from_uci('c5h5'), -995)]
# Maia 1400 best moves: [(Move.from_uci('c5c4'), 114), (Move.from_uci('b6c4'), -908), (Move.from_uci('c5c3'), -1150)]
# Maia 1500 best moves: [(Move.from_uci('c5c4'), 46), (Move.from_uci('c5c6'), -204), (Move.from_uci('c5c3'), -1012)]
# Maia 1600 best moves: [(Move.from_uci('c5c4'), 35), (Move.from_uci('c5c6'), -295), (Move.from_uci('c5c3'), -974)]
# Maia 1700 best moves: [(Move.from_uci('c5c4'), 127), (Move.from_uci('c5g5'), -357), (Move.from_uci('c5c3'), -920)]
# Maia 1800 best moves: [(Move.from_uci('c5c4'), 32), (Move.from_uci('c5c3'), -869), (Move.from_uci('b6c4'), -1153)]
# Maia 1900 best moves: [(Move.from_uci('c5c4'), 11), (Move.from_uci('c5c6'), -250), (Move.from_uci('c5c3'), -708)]
# Puzzle added with easiness: 0.3333333333333333
# Evaluating Maia easiness for FEN: 6k1/1p3pp1/1n1r1q1p/1N2P3/pp3P2/2P1RQ2/P6P/6K1 b - - 0 28, Best Move: f6g6
# Maia 1100 best moves: [(Move.from_uci('f6g6'), 407), (Move.from_uci('d6d1'), -263), (Move.from_uci('f6e6'), -786)]
# Maia 1200 best moves: [(Move.from_uci('f6g6'), 515), (Move.from_uci('d6d1'), -98), (Move.from_uci('f6e6'), -673)]
# Maia 1300 best moves: [(Move.from_uci('f6g6'), 490), (Move.from_uci('d6d1'), -236), (Move.from_uci('f6e6'), -775)]
# Maia 1400 best moves: [(Move.from_uci('f6g6'), 672), (Move.from_uci('d6d1'), -579), (Move.from_uci('b6c4'), -790)]
# Maia 1500 best moves: [(Move.from_uci('f6g6'), 705), (Move.from_uci('d6d1'), -333), (Move.from_uci('f6f5'), -770)]
# Maia 1600 best moves: [(Move.from_uci('f6g6'), 609), (Move.from_uci('d6d1'), 84), (Move.from_uci('f6h4'), -822)]
# Maia 1700 best moves: [(Move.from_uci('f6g6'), 606), (Move.from_uci('d6d1'), 209), (Move.from_uci('f6f5'), -833)]
# Maia 1800 best moves: [(Move.from_uci('f6g6'), 608), (Move.from_uci('d6d1'), -120), (Move.from_uci('f6e6'), -763)]
# Maia 1900 best moves: [(Move.from_uci('f6g6'), 570), (Move.from_uci('d6d1'), -310), (Move.from_uci('d6c6'), -1325)]
# Puzzle added with easiness: 0.3333333333333333
# Analyzing game World Championship Match 1908
# Puzzle found: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQR1K1 w kq - 0 7, Best move: a4b3, Eval difference: 310
# Puzzle found: r1r3k1/3nbp2/pq1pb2p/1p2P1p1/3p4/3Q2BP/PP3PP1/1B1RRNK1 b - - 0 22, Best move: d7f8, Eval difference: 267
# Evaluating Maia easiness for FEN: r1bqk2r/2ppbppp/p1n2n2/1p2p3/B3P3/5N2/PPPP1PPP/RNBQR1K1 w kq - 0 7, Best Move: a4b3
# Maia 1100 best moves: [(Move.from_uci('a4b3'), 159), (Move.from_uci('d2d4'), -239), (Move.from_uci('b1c3'), -738)]
# Maia 1200 best moves: [(Move.from_uci('a4b3'), 148), (Move.from_uci('d2d4'), -180), (Move.from_uci('c2c3'), -495)]
# Maia 1300 best moves: [(Move.from_uci('a4b3'), 163), (Move.from_uci('d2d4'), -289), (Move.from_uci('c2c3'), -476)]
# Maia 1400 best moves: [(Move.from_uci('a4b3'), 226), (Move.from_uci('d2d4'), -445), (Move.from_uci('c2c3'), -588)]
# Maia 1500 best moves: [(Move.from_uci('a4b3'), 170), (Move.from_uci('d2d4'), -743), (Move.from_uci('c2c3'), -773)]
# Maia 1600 best moves: [(Move.from_uci('a4b3'), 206), (Move.from_uci('d2d4'), -456), (Move.from_uci('c2c3'), -815)]
# Maia 1700 best moves: [(Move.from_uci('a4b3'), 184), (Move.from_uci('d2d4'), -260), (Move.from_uci('c2c3'), -791)]
# Maia 1800 best moves: [(Move.from_uci('a4b3'), 135), (Move.from_uci('d2d4'), -398), (Move.from_uci('c2c3'), -605)]
# Maia 1900 best moves: [(Move.from_uci('a4b3'), 112), (Move.from_uci('d2d4'), -364), (Move.from_uci('c2c3'), -752)]
# Puzzle added with easiness: 0.3333333333333333
# Evaluating Maia easiness for FEN: r1r3k1/3nbp2/pq1pb2p/1p2P1p1/3p4/3Q2BP/PP3PP1/1B1RRNK1 b - - 0 22, Best Move: d7f8
# Maia 1100 best moves: [(Move.from_uci('d7f8'), -330), (Move.from_uci('g8f8'), -1446), (Move.from_uci('f7f5'), -1911)]
# Maia 1200 best moves: [(Move.from_uci('d7f8'), -380), (Move.from_uci('g8f8'), -836), (Move.from_uci('f7f5'), -1633)]
# Maia 1300 best moves: [(Move.from_uci('d7f8'), -537), (Move.from_uci('g8f8'), -1273), (Move.from_uci('f7f5'), -2233)]
# Maia 1400 best moves: [(Move.from_uci('d7f8'), -464), (Move.from_uci('g8f8'), -1612), (Move.from_uci('f7f5'), -2220)]
# Maia 1500 best moves: [(Move.from_uci('d7f8'), -441), (Move.from_uci('g8f8'), -2512), (Move.from_uci('f7f5'), -2593)]
# Maia 1600 best moves: [(Move.from_uci('d7f8'), -607), (Move.from_uci('g8f8'), -1906), (Move.from_uci('e6c4'), -3032)]
# Maia 1700 best moves: [(Move.from_uci('d7f8'), -438), (Move.from_uci('g8g7'), -2171), (Move.from_uci('f7f5'), -2927)]
# Maia 1800 best moves: [(Move.from_uci('d7f8'), -287), (Move.from_uci('g8g7'), -730), (Move.from_uci('g8f8'), -1247)]
# Maia 1900 best moves: [(Move.from_uci('d7f8'), -368), (Move.from_uci('d7c5'), -1899), (Move.from_uci('e6c4'), -2514)]
# Puzzle added with easiness: 0.3333333333333333
# Analyzing game World Championship Match 1908
# Analyzing game World Championship Match 1908
# Puzzle found: 3r4/p3kp1p/5p2/1Rn1p3/8/2P1P1N1/P1P2RPP/3r2K1 w - - 5 24, Best move: f2f1, Eval difference: 270
# Evaluating Maia easiness for FEN: 3r4/p3kp1p/5p2/1Rn1p3/8/2P1P1N1/P1P2RPP/3r2K1 w - - 5 24, Best Move: f2f1
# Maia 1100 best moves: [(Move.from_uci('f2f1'), 68), (Move.from_uci('g3f1'), -224)]
# Maia 1200 best moves: [(Move.from_uci('f2f1'), 64), (Move.from_uci('g3f1'), -231)]
# Maia 1300 best moves: [(Move.from_uci('f2f1'), 88), (Move.from_uci('g3f1'), -164)]
# Maia 1400 best moves: [(Move.from_uci('f2f1'), 91), (Move.from_uci('g3f1'), -243)]
# Maia 1500 best moves: [(Move.from_uci('f2f1'), 81), (Move.from_uci('g3f1'), -341)]
# Maia 1600 best moves: [(Move.from_uci('f2f1'), 101), (Move.from_uci('g3f1'), -322)]
# Maia 1700 best moves: [(Move.from_uci('f2f1'), 83), (Move.from_uci('g3f1'), -456)]
# Maia 1800 best moves: [(Move.from_uci('f2f1'), 87), (Move.from_uci('g3f1'), -419)]
# Maia 1900 best moves: [(Move.from_uci('f2f1'), 69), (Move.from_uci('g3f1'), -447)]
# Puzzle added with easiness: 0.5
# Classic puzzles analysis complete. Results saved.
# Cleaning up engines...
# Engines cleaned.
